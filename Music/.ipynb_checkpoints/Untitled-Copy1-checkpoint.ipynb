# %%
# !pip install moviepy

# %%
from moviepy.editor import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from moviepy.editor import *
#
# ModuleNotFoundError: No module named 'moviepy.editor'

# %%
# 1. First, uninstall completely
# !pip uninstall -y moviepy
# Out:
# Found existing installation: moviepy 2.2.1
# Uninstalling moviepy-2.2.1:
#   Successfully uninstalled moviepy-2.2.1

# %%
# 2. Clear pip cache
# !pip cache purge
# Out:
# Files removed: 5582

# %%
# 3. Install with --force-reinstall
# !pip install --force-reinstall moviepy
# Out:
# ...
#    ---------------------------------------- 0.0/31.2 MB ? eta -:--:--
#    ---- ----------------------------------- 3.7/31.2 MB 18.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 8.7/31.2 MB 20.7 MB/s eta 0:00:02
#    ------------------- -------------------- 14.9/31.2 MB 23.5 MB/s eta 0:00:01
#    -------------------------- ------------- 20.7/31.2 MB 25.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 27.8/31.2 MB 26.7 MB/s eta 0:00:01
#    ---------------------------------------  31.2/31.2 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 31.2/31.2 MB 24.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------- ----------------- 6.8/12.3 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 30.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
# ...

# %%
# !pip install numpy==1.26.4 pillow==10.4.0 moviepy==2.2.1
# Out:
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/15.5 MB 21.0 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 26.7 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 28.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 27.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 29.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.0
#     Uninstalling numpy-2.4.0:
#       Successfully uninstalled numpy-2.4.0
# ...

# %%
# First uninstall the incompatible versions
# !pip uninstall -y moviepy numpy pillow
# Out:
# Found existing installation: moviepy 2.2.1
# Uninstalling moviepy-2.2.1:
#   Successfully uninstalled moviepy-2.2.1
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: pillow 10.4.0
# Uninstalling pillow-10.4.0:
#   Successfully uninstalled pillow-10.4.0

# %%
# Install compatible versions
# !pip install numpy==1.26.4  
# !pip install pillow==10.4.0  
# !pip install moviepy==2.2.1
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 3.6.0 requires pillow>=7.1.0, which is not installed.
# datashader 0.16.3 requires pillow, which is not installed.
# imageio 2.37.2 requires pillow>=8.3.2, which is not installed.
# matplotlib 3.9.2 requires pillow>=8, which is not installed.
# scikit-image 0.24.0 requires pillow>=9.1, which is not installed.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, which is not installed.
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# ...
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
# Using cached moviepy-2.2.1-py3-none-any.whl (129 kB)
# ...

# %%
# Install required packages if needed
# !pip install sqlalchemy pymysql
