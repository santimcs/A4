# %%
import pandas as pd
import os
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

year = "2026"
quarter = "1"
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2026-05-15 22:21:00

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Quarterly
# Base path: C:\Users\PC1\OneDrive\A4
# Data path (dat_path): C:\Users\PC1\OneDrive\A4\Data
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()
format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:.2f}%','acc_pct':'{:.2f}%'
              }

# %%
sql = """
SELECT * 
FROM epss 
WHERE name = 'AOT' AND year = %s AND quarter = %s
"""
sql = sql % (year, quarter)
print(sql)

df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE name = 'AOT' AND year = 2026 AND quarter = 1
# <style type="text/css">
# </style>
# <table id="T_2d090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d090_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_2d090_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_2d090_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_2d090_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_2d090_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_2d090_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_2d090_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_2d090_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_2d090_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_2d090_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_2d090_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_2d090_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_2d090_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_2d090_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d090_row0_col0" class="data row0 col0" >24904</td>
#       <td id="T_2d090_row0_col1" class="data row0 col1" >AOT</td>
#       <td id="T_2d090_row0_col2" class="data row0 col2" >2026</td>
#       <td id="T_2d090_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2d090_row0_col4" class="data row0 col4" >4,652,626</td>
#       <td id="T_2d090_row0_col5" class="data row0 col5" >5,344,298</td>
#       <td id="T_2d090_row0_col6" class="data row0 col6" >4,652,626</td>
#       <td id="T_2d090_row0_col7" class="data row0 col7" >5,344,298</td>
#       <td id="T_2d090_row0_col8" class="data row0 col8" >0.3300</td>
#       <td id="T_2d090_row0_col9" class="data row0 col9" >0.3700</td>
#       <td id="T_2d090_row0_col10" class="data row0 col10" >0.3300</td>
#       <td id="T_2d090_row0_col11" class="data row0 col11" >0.3700</td>
#       <td id="T_2d090_row0_col12" class="data row0 col12" >24</td>
#       <td id="T_2d090_row0_col13" class="data row0 col13" >2026-02-12</td>
#     </tr>
#   </tbody>
# </table>

# %%
today = date(2026, 5, 14)
select_date = today.strftime("%Y-%m-%d")
select_date
# Out:
# '2026-05-14'

# %% [markdown]
# ### Restart and Run All

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= '%s'
ORDER BY name
"""
sql = sql % (year, quarter, select_date)
print(sql)

df_epss_inp = pd.read_sql(sql, conlt)
df_epss_inp.style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2026 AND quarter = 1
# AND publish_date >= '2026-05-14'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_6ba2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ba2b_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_6ba2b_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_6ba2b_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_6ba2b_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_6ba2b_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_6ba2b_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_6ba2b_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_6ba2b_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_6ba2b_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_6ba2b_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_6ba2b_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_6ba2b_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_6ba2b_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_6ba2b_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ba2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ba2b_row0_col0" class="data row0 col0" >25205</td>
#       <td id="T_6ba2b_row0_col1" class="data row0 col1" >AH</td>
#       <td id="T_6ba2b_row0_col2" class="data row0 col2" >2026</td>
#       <td id="T_6ba2b_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_6ba2b_row0_col4" class="data row0 col4" >314,360</td>
#       <td id="T_6ba2b_row0_col5" class="data row0 col5" >306,182</td>
#       <td id="T_6ba2b_row0_col6" class="data row0 col6" >314,360</td>
#       <td id="T_6ba2b_row0_col7" class="data row0 col7" >306,182</td>
#       <td id="T_6ba2b_row0_col8" class="data row0 col8" >0.9400</td>
#       <td id="T_6ba2b_row0_col9" class="data row0 col9" >0.9100</td>
#       <td id="T_6ba2b_row0_col10" class="data row0 col10" >0.9400</td>
#       <td id="T_6ba2b_row0_col11" class="data row0 col11" >0.9100</td>
#       <td id="T_6ba2b_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_6ba2b_row0_col13" class="data row0 col13" >2026-05-14</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ba2b_row1_col0" class="data row1 col0" >25229</td>
#       <td id="T_6ba2b_row1_col1" class="data row1 col1" >AIE</td>
#       <td id="T_6ba2b_row1_col2" class="data row1 col2" >2026</td>
#       <td id="T_6ba2b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_6ba2b_row1_col4" class="data row1 col4" >52,231</td>
#       <td id="T_6ba2b_row1_col5" class="data row1 col5" >11,136</td>
#       <td id="T_6ba2b_row1_col6" class="data row1 col6" >52,231</td>
#       <td id="T_6ba2b_row1_col7" class="data row1 col7" >11,136</td>
#       <td id="T_6ba2b_row1_col8" class="data row1 col8" >0.0380</td>
#       <td id="T_6ba2b_row1_col9" class="data row1 col9" >0.0080</td>
#       <td id="T_6ba2b_row1_col10" class="data row1 col10" >0.0380</td>
#       <td id="T_6ba2b_row1_col11" class="data row1 col11" >0.0080</td>
#       <td id="T_6ba2b_row1_col12" class="data row1 col12" >720</td>
#       <td id="T_6ba2b_row1_col13" class="data row1 col13" >2026-05-14</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ba2b_row2_col0" class="data row2 col0" >25220</td>
#       <td id="T_6ba2b_row2_col1" class="data row2 col1" >ANAN</td>
#       <td id="T_6ba2b_row2_col2" class="data row2 col2" >2026</td>
#       <td id="T_6ba2b_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_6ba2b_row2_col4" class="data row2 col4" >-71,779</td>
#       <td id="T_6ba2b_row2_col5" class="data row2 col5" >-203,945</td>
#       <td id="T_6ba2b_row2_col6" class="data row2 col6" >-71,779</td>
#       <td id="T_6ba2b_row2_col7" class="data row2 col7" >-203,945</td>
#       <td id="T_6ba2b_row2_col8" class="data row2 col8" >-0.0340</td>
#       <td id="T_6ba2b_row2_col9" class="data row2 col9" >-0.0650</td>
#       <td id="T_6ba2b_row2_col10" class="data row2 col10" >-0.0340</td>
#       <td id="T_6ba2b_row2_col11" class="data row2 col11" >-0.0650</td>
#       <td id="T_6ba2b_row2_col12" class="data row2 col12" >23</td>
#       <td id="T_6ba2b_row2_col13" class="data row2 col13" >2026-05-14</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ba2b_row3_col0" class="data row3 col0" >25230</td>
#       <td id="T_6ba2b_row3_col1" class="data row3 col1" >AP</td>
#       <td id="T_6ba2b_row3_col2" class="data row3 col2" >2026</td>
#       <td id="T_6ba2b_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_6ba2b_row3_col4" class="data row3 col4" >903,480</td>
#       <td id="T_6ba2b_row3_col5" class="data row3 col5" >863,721</td>
#       <td id="T_6ba2b_row3_col6" class="data row3 col6" >903,480</td>
#       <td id="T_6ba2b_row3_col7" class="data row3 col7" >863,721</td>
#       <td id="T_6ba2b_row3_col8" class="data row3 col8" >0.2900</td>
#       <td id="T_6ba2b_row3_col9" class="data row3 col9" >0.2700</td>
#       <td id="T_6ba2b_row3_col10" class="data row3 col10" >0.2900</td>
#       <td id="T_6ba2b_row3_col11" class="data row3 col11" >0.2700</td>
#       <td id="T_6ba2b_row3_col12" class="data row3 col12" >25</td>
#       <td id="T_6ba2b_row3_col13" class="data row3 col13" >2026-05-14</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ba2b_row4_col0" class="data row4 col0" >25238</td>
#       <td id="T_6ba2b_row4_col1" class="data row4 col1" >BCH</td>
#       <td id="T_6ba2b_row4_col2" class="data row4 col2" >2026</td>
#       <td id="T_6ba2b_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_6ba2b_row4_col4" class="data row4 col4" >267,555</td>
#       <td id="T_6ba2b_row4_col5" class="data row4 col5" >321,312</td>
#       <td id="T_6ba2b_row4_col6" class="data row4 col6" >267,555</td>
#       <td id="T_6ba2b_row4_col7" class="data row4 col7" >321,312</td>
#       <td id="T_6ba2b_row4_col8" class="data row4 col8" >0.1100</td>
#       <td id="T_6ba2b_row4_col9" class="data row4 col9" >0.1300</td>
#       <td id="T_6ba2b_row4_col10" class="data row4 col10" >0.1100</td>
#       <td id="T_6ba2b_row4_col11" class="data row4 col11" >0.1300</td>
#       <td id="T_6ba2b_row4_col12" class="data row4 col12" >51</td>
#       <td id="T_6ba2b_row4_col13" class="data row4 col13" >2026-05-15</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ba2b_row5_col0" class="data row5 col0" >25227</td>
#       <td id="T_6ba2b_row5_col1" class="data row5 col1" >BCP</td>
#       <td id="T_6ba2b_row5_col2" class="data row5 col2" >2026</td>
#       <td id="T_6ba2b_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_6ba2b_row5_col4" class="data row5 col4" >6,143,762</td>
#       <td id="T_6ba2b_row5_col5" class="data row5 col5" >2,115,295</td>
#       <td id="T_6ba2b_row5_col6" class="data row5 col6" >6,143,762</td>
#       <td id="T_6ba2b_row5_col7" class="data row5 col7" >2,115,295</td>
#       <td id="T_6ba2b_row5_col8" class="data row5 col8" >4.1700</td>
#       <td id="T_6ba2b_row5_col9" class="data row5 col9" >1.5400</td>
#       <td id="T_6ba2b_row5_col10" class="data row5 col10" >4.1700</td>
#       <td id="T_6ba2b_row5_col11" class="data row5 col11" >1.5400</td>
#       <td id="T_6ba2b_row5_col12" class="data row5 col12" >52</td>
#       <td id="T_6ba2b_row5_col13" class="data row5 col13" >2026-05-14</td>
#     </tr>
#     <tr>
#       <th id="T_6ba2b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ba2b_row6_col0" class="data row6 col0" >25217</td>
#       <td id="T_6ba2b_row6_col1" class="data row6 col1" >BEM</td>
#       <td id="T_6ba2b_row6_col2" class="data row6 col2" >2026</td>
#       <td id="T_6ba2b_row6_col3" class="data row6 col3" >1</td>

# %%
df_epss_inp["yoy_gain"] = df_epss_inp["q_amt"] - df_epss_inp["y_amt"]
df_epss_inp["yoy_pct"]  = round(df_epss_inp["yoy_gain"] / abs(df_epss_inp["y_amt"]) * 100,2)
df_epss_inp["acc_gain"] = df_epss_inp["aq_amt"] - df_epss_inp["ay_amt"]
df_epss_inp["acc_pct"] = round(df_epss_inp["acc_gain"] / abs(df_epss_inp["ay_amt"]) * 100,2)
df_aggr = df_epss_inp[
    [
        "name",
        "year",
        "quarter",
        "q_amt",
        "y_amt",
        "yoy_gain",
        "yoy_pct",
        "aq_amt",
        "ay_amt",
        "acc_gain",
        "acc_pct",
    ]
]
df_aggr.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa0c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa0c8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_fa0c8_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_fa0c8_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_fa0c8_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_fa0c8_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_fa0c8_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_fa0c8_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_fa0c8_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_fa0c8_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_fa0c8_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_fa0c8_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa0c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa0c8_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_fa0c8_row0_col1" class="data row0 col1" >2026</td>
#       <td id="T_fa0c8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_fa0c8_row0_col3" class="data row0 col3" >314,360</td>
#       <td id="T_fa0c8_row0_col4" class="data row0 col4" >306,182</td>
#       <td id="T_fa0c8_row0_col5" class="data row0 col5" >8,178</td>
#       <td id="T_fa0c8_row0_col6" class="data row0 col6" >2.67%</td>
#       <td id="T_fa0c8_row0_col7" class="data row0 col7" >314,360</td>
#       <td id="T_fa0c8_row0_col8" class="data row0 col8" >306,182</td>
#       <td id="T_fa0c8_row0_col9" class="data row0 col9" >8,178</td>
#       <td id="T_fa0c8_row0_col10" class="data row0 col10" >2.67%</td>
#     </tr>
#     <tr>
#       <th id="T_fa0c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa0c8_row1_col0" class="data row1 col0" >AIE</td>
#       <td id="T_fa0c8_row1_col1" class="data row1 col1" >2026</td>
#       <td id="T_fa0c8_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_fa0c8_row1_col3" class="data row1 col3" >52,231</td>
#       <td id="T_fa0c8_row1_col4" class="data row1 col4" >11,136</td>
#       <td id="T_fa0c8_row1_col5" class="data row1 col5" >41,095</td>
#       <td id="T_fa0c8_row1_col6" class="data row1 col6" >369.03%</td>
#       <td id="T_fa0c8_row1_col7" class="data row1 col7" >52,231</td>
#       <td id="T_fa0c8_row1_col8" class="data row1 col8" >11,136</td>
#       <td id="T_fa0c8_row1_col9" class="data row1 col9" >41,095</td>
#       <td id="T_fa0c8_row1_col10" class="data row1 col10" >369.03%</td>
#     </tr>
#     <tr>
#       <th id="T_fa0c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f
_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa0c8_row6_col0" class="data row6 col0" >BEM</td>
#       <td id="T_fa0c8_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_fa0c8_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_fa0c8_row6_col3" class="data row6 col3" >874,777</td>
#       <td id="T_fa0c8_row6_col4" class="data row6 col4" >871,013</td>
#       <td id="T_fa0c8_row6_col5" class="data row6 col5" >3,764</td>
#       <td id="T_fa0c8_row6_col6" class="data row6 col6" >0.43%</td>
#       <td id="T_fa0c8_row6_col7" class="data row6 col7" >874,777</td>
#       <td id="T_fa0c8_row6_col8" class="data row6 col8" >871,013</td>
#       <td id="T_fa0c8_row6_col9" class="data row6 col9" >3,764</td>
#       <td id="T_fa0c8_row6_col10" class="data row6 col10" >0.43%</td>
#     </tr>
#     <tr>
#       <th id="T_fa0c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa0c8_row7_col0" class="data row7 col0" >CHG</td>
#       <td id="T_fa0c8_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_fa0c8_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_fa0c8_row7_col3" class="data row7 col3" >247,644</td>
#       <td id="T_fa0c8_row7_col4" class="data row7 col4" >225,330</td>
#       <td id="T_fa0c8_row7_col5" class="data row7 col5" >22,314</td>
#       <td id="T_fa0c8_row7_col6" class="data row7 col6" >9.90%</td>
#       <td id="T_fa0c8_row7_col7" class="data row7 col7" >247,644</td>
#       <td id="T_fa0c8_row7_col8" class="data row7 col8" >225,330</td>
#       <td id="T_fa0c8_row7_col9" class="data row7 col9" >22,314</td>
#       <td id="T_fa0c8_row7_col10" class="data row7 col10" >9.90%</td>
#     </tr>
#     <tr>
#       <th id="T_fa0c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa0c8_row8_col0" class="data row8 col0" >CPF</td>
#       <td id="T_fa

# %%
criteria_1 = df_aggr.q_amt > 110_000
df_aggr.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab700">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab700_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ab700_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_ab700_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_ab700_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_ab700_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_ab700_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_ab700_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab700_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab700_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_ab700_row0_col1" class="data row0 col1" >2026</td>
#       <td id="T_ab700_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ab700_row0_col3" class="data row0 col3" >314,360</td>
#       <td id="T_ab700_row0_col4" class="data row0 col4" >306,182</td>
#       <td id="T_ab700_row0_col5" class="data row0 col5" >8,178</td>
#       <td id="T_ab700_row0_col6" class="data row0 col6" >2.67%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_ab700_row1_col0" class="data row1 col0" >AP</td>
#       <td id="T_ab700_row1_col1" class="data row1 col1" >2026</td>
#       <td id="T_ab700_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_ab700_row1_col3" class="data row1 col3" >903,480</td>
#       <td id="T_ab700_row1_col4" class="data row1 col4" >863,721</td>
#       <td id="T_ab700_row1_col5" class="data row1 col5" >39,759</td>
#       <td id="T_ab700_row1_col6" class="data row1 col6" >4.60%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_ab700_row2_col0" class="data row2 col0" >BCH</td>
#       <td id="T_ab700_row2_col1" class="data row2 col1" >2026</td>
#       <td id="T_ab700_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_ab700_row2_col3" class="data row2 col3" >267,555</td>
#       <td id="T_ab700_row2_col4" class="data row2 col4" >321,312</td>
#       <td id="T_ab700_row2_col5" class="data row2 col5" >-53,757</td>
#       <td id="T_ab700_row2_col6" class="data row2 col6" >-16.73%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_ab700_row3_col0" class="data row3 col0" >BCP</td>
#       <td id="T_ab700_row3_col1" class="data row3 col1" >2026</td>
#       <td id="T_ab700_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_ab700_row3_col3" class="data row3 col3" >6,143,762</td>
#       <td id="T_ab700_row3_col4" class="data row3 col4" >2,115,295</td>
#       <td id="T_ab700_row3_col5" class="data row3 col5" >4,028,467</td>
#       <td id="T_ab700_row3_col6" class="data row3 col6" >190.44%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_ab700_row4_col0" class="data row4 col0" >BEM</td>
#       <td id="T_ab700_row4_col1" class="data row4 col1" >2026</td>
#       <td id="T_ab700_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_ab700_row4_col3" class="data row4 col3" >874,777</td>
#       <td id="T_ab700_row4_col4" class="data row4 col4" >871,013</td>
#       <td id="T_ab700_row4_col5" class="data row4 col5" >3,764</td>
#       <td id="T_ab700_row4_col6" class="data row4 col6" >0.43%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_ab700_row5_col0" class="data row5 col0" >CHG</td>
#       <td id="T_ab700_row5_col1" class="data row5 col1" >2026</td>
#       <td id="T_ab700_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_ab700_row5_col3" class="data row5 col3" >247,644</td>
#       <td id="T_ab700_row5_col4" class="data row5 col4" >225,330</td>
#       <td id="T_ab700_row5_col5" class="data row5 col5" >22,314</td>
#       <td id="T_ab700_row5_col6" class="data row5 col6" >9.90%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_ab700_row6_col0" class="data row6 col0" >CPF</td>
#       <td id="T_ab700_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_ab700_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_ab700_row6_col3" class="data row6 col3" >4,874,798</td>
#       <td id="T_ab700_row6_col4" class="data row6 col4" >8,549,183</td>
#       <td id="T_ab700_row6_col5" class="data row6 col5" >-3,674,385</td>
#       <td id="T_ab700_row6_col6" class="data row6 col6" >-42.98%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_ab700_row7_col0" class="data row7 col0" >CPNREIT</td>
#       <td id="T_ab700_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_ab700_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_ab700_row7_col3" class="data row7 col3" >809,381</td>
#       <td id="T_ab700_row7_col4" class="data row7 col4" >907,578</td>
#       <td id="T_ab700_row7_col5" class="data row7 col5" >-98,197</td>
#       <td id="T_ab700_row7_col6" class="data row7 col6" >-10.82%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_ab700_row8_col0" class="data row8 col0" >DIF</td>
#       <td id="T_ab700_row8_col1" class="data row8 col1" >2026</td>
#       <td id="T_ab700_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_ab700_row8_col3" class="data row8 col3" >2,767,480</td>
#       <td id="T_ab700_row8_col4" class="data row8 col4" >2,731,943</td>
#       <td id="T_ab700_row8_col5" class="data row8 col5" >35,537</td>
#       <td id="T_ab700_row8_col6" class="data row8 col6" >1.30%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_ab700_row9_col0" class="data row9 col0" >EA</td>
#       <td id="T_ab700_row9_col1" class="data row9 col1" >2026</td>
#       <td id="T_ab700_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_ab700_row9_col3" class="data row9 col3" >361,821</td>
#       <td id="T_ab700_row9_col4" class="data row9 col4" >252,333</td>
#       <td id="T_ab700_row9_col5" class="data row9 col5" >109,488</td>
#       <td id="T_ab700_row9_col6" class="data row9 col6" >43.39%</td>
#     </tr>
#     <tr>
#       <th id="T_ab700_level0_
</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_4a43b_row4_col0" class="data row4 col0" >BEM</td>
#       <td id="T_4a43b_row4_col1" class="data row4 col1" >2026</td>
#       <td id="T_4a43b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_4a43b_row4_col3" class="data row4 col3" >874,777</td>
#       <td id="T_4a43b_row4_col4" class="data row4 col4" >871,013</td>
#       <td id="T_4a43b_row4_col5" class="data row4 col5" >3,764</td>
#       <td id="T_4a43b_row4_col6" class="data row4 col6" >0.43%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_4a43b_row5_col0" class="data row5 col0" >CHG</td>
#       <td id="T_4a43b_row5_col1" class="data row5 col1" >2026</td>
#       <td id="T_4a43b_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_4a43b_row5_col3" class="data row5 col3" >247,644</td>
#       <td id="T_4a43b_row5_col4" class="data row5 col4" >225,330</td>
#       <td id="T_4a43b_row5_col5" class="data row5 col5" >22,314</td>
#       <td id="T_4a43b_row5_col6" class="data row5 col6" >9.90%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_4a43b_row6_col0" class="data row6 col0" >CPF</td>
#       <td id="T_4a43b_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_4a43b_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_4a43b_row6_col3" class="data row6 col3" >4,874,798</td>
#       <td id="T_4a43b_row6_col4" class="data row6 col4" >8,549,183</td>
#       <td id="T_4a43b_row6_col5" class="data row6 col5" >-3,674,385</td>
#       <td id="T_4a43b_row6_col6" class="data row6 col6" >-42.98%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_4a43b_row7_col0" class="data row7 col0" >CPNREIT</td>
#       <td id="T_4a43b_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_4a43b_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_4a43b_row7_col3" class="data row7 col3" >809,381</td>
#       <td id="T_4a43b_row7_col4" class="data row7 col4" >907,578</td>
#       <td id="T_4a43b_row7_col5" class="data row7 col5" >-98,197</td>
#       <td id="T_4a43b_row7_col6" class="data row7 col6" >-10.82%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_4a43b_row8_col0" class="data row8 col0" >DIF</td>
#       <td id="T_4a43b_row8_col1" class="data row8 col1" >2026</td>
#       <td id="T_4a43b_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_4a43b_row8_col3" class="data row8 col3" >2,767,480</td>
#       <td id="T_4a43b_row8_col4" class="data row8 col4" >2,731,943</td>
#       <td id="T_4a43b_row8_col5" class="data row8 col5" >35,537</td>
#       <td id="T_4a43b_row8_col6" class="data row8 col6" >1.30%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_4a43b_row9_col0" class="data row9 col0" >EA</td>
#       <td id="T_4a43b_row9_col1" class="data row9 col1" >2026</td>
#       <td id="T_4a43b_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_4a43b_row9_col3" class="data row9 col3" >361,821</td>
#       <td id="T_4a43b_row9_col4" class="data row9 col4" >252,333</td>
#       <td id="T_4a43b_row9_col5" class="data row9 col5" >109,488</td>
#       <td id="T_4a43b_row9_col6" class="data row9 col6" >43.39%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_4a43b_row10_col0" class="data row10 col0" >FSMART</td>
#       <td id="T_4a43b_row10_col1" class="data row10 col1" >2026</td>
#       <td id="T_4a43b_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_4a43b_row10_col3" class="data row10 col3" >135,492</td>
#       <td id="T_4a43b_row10_col4" class="data row10 col4" >152,755</td>
#       <td id="T_4a43b_row10_col5" class="data row10 col5" >-17,263</td>
#       <td id="T_4a43b_row10_col6" class="data row10 col6" >-11.30%</td>
#     </tr>
#     <tr>
#       <th id="T_4a43b_level0_
</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_f2725_row5_col0" class="data row5 col0" >PREB</td>
#       <td id="T_f2725_row5_col1" class="data row5 col1" >2026</td>
#       <td id="T_f2725_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_f2725_row5_col3" class="data row5 col3" >45,257</td>
#       <td id="T_f2725_row5_col4" class="data row5 col4" >20,099</td>
#       <td id="T_f2725_row5_col5" class="data row5 col5" >25,158</td>
#       <td id="T_f2725_row5_col6" class="data row5 col6" >125.17%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_f2725_row6_col0" class="data row6 col0" >PTT</td>
#       <td id="T_f2725_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_f2725_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_f2725_row6_col3" class="data row6 col3" >25,738,299</td>
#       <td id="T_f2725_row6_col4" class="data row6 col4" >23,315,489</td>
#       <td id="T_f2725_row6_col5" class="data row6 col5" >2,422,810</td>
#       <td id="T_f2725_row6_col6" class="data row6 col6" >10.39%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_f2725_row7_col0" class="data row7 col0" >SAT</td>
#       <td id="T_f2725_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_f2725_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_f2725_row7_col3" class="data row7 col3" >211,920</td>
#       <td id="T_f2725_row7_col4" class="data row7 col4" >189,198</td>
#       <td id="T_f2725_row7_col5" class="data row7 col5" >22,722</td>
#       <td id="T_f2725_row7_col6" class="data row7 col6" >12.01%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row8" class="row_heading level0 row8" >30</th>
#       <td id="T_f2725_row8_col0" class="data row8 col0" >SGP</td>
#       <td id="T_f2725_row8_col1" class="data row8 col1" >2026</td>
#       <td id="T_f2725_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_f2725_row8_col3" class="data row8 col3" >1,530,428</td>
#       <td id="T_f2725_row8_col4" class="data row8 col4" >125,064</td>
#       <td id="T_f2725_row8_col5" class="data row8 col5" >1,405,364</td>
#       <td id="T_f2725_row8_col6" class="data row8 col6" >1123.72%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row9" class="row_heading level0 row9" >31</th>
#       <td id="T_f2725_row9_col0" class="data row9 col0" >SINGER</td>
#       <td id="T_f2725_row9_col1" class="data row9 col1" >2026</td>
#       <td id="T_f2725_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_f2725_row9_col3" class="data row9 col3" >142,942</td>
#       <td id="T_f2725_row9_col4" class="data row9 col4" >-946</td>
#       <td id="T_f2725_row9_col5" class="data row9 col5" >143,888</td>
#       <td id="T_f2725_row9_col6" class="data row9 col6" >15210.15%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row10" class="row_heading level0 row10" >33</th>
#       <td id="T_f2725_row10_col0" class="data row10 col0" >SPRC</td>
#       <td id="T_f2725_row10_col1" class="data row10 col1" >2026</td>
#       <td id="T_f2725_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_f2725_row10_col3" class="data row10 col3" >7,366,927</td>
#       <td id="T_f2725_row10_col4" class="data row10 col4" >713,522</td>
#       <td id="T_f2725_row10_col5" class="data row10 col5" >6,653,405</td>
#       <td id="T_f2725_row10_col6" class="data row10 col6" >932.47%</td>
#     </tr>
#     <tr>
#       <th id="T_f2725_level0_row11" class="row_heading level0 row11" >35</th>
#       <td id="T_f2725_row11_col0" class="data row11 col0" >TOA</td>
#       <td id="T_f2725_row11_col1" class="data row11 col1" >2026</td>
#       <td id="T_f2725_row11_col2" class="data row11 col2" >1</td>
#       <td id="T
row5_col2" class="data row5 col2" >1</td>
#       <td id="T_1efce_row5_col3" class="data row5 col3" >1,530,428</td>
#       <td id="T_1efce_row5_col4" class="data row5 col4" >125,064</td>
#       <td id="T_1efce_row5_col5" class="data row5 col5" >1,405,364</td>
#       <td id="T_1efce_row5_col6" class="data row5 col6" >1123.72%</td>
#     </tr>
#     <tr>
#       <th id="T_1efce_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_1efce_row6_col0" class="data row6 col0" >SPRC</td>
#       <td id="T_1efce_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_1efce_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_1efce_row6_col3" class="data row6 col3" >7,366,927</td>
#       <td id="T_1efce_row6_col4" class="data row6 col4" >713,522</td>
#       <td id="T_1efce_row6_col5" class="data row6 col5" >6,653,405</td>
#       <td id="T_1efce_row6_col6" class="data row6 col6" >932.47%</td>
#     </tr>
#     <tr>
#       <th id="T_1efce_level0_row7" class="row_heading level0 row7" >35</th>
#       <td id="T_1efce_row7_col0" class="data row7 col0" >TOA</td>
#       <td id="T_1efce_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_1efce_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_1efce_row7_col3" class="data row7 col3" >953,247</td>
#       <td id="T_1efce_row7_col4" class="data row7 col4" >733,099</td>
#       <td id="T_1efce_row7_col5" class="data row7 col5" >220,148</td>
#       <td id="T_1efce_row7_col6" class="data row7 col6" >30.03%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_aggr[df_aggr_criteria].sort_values(by=["yoy_pct"], ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_629ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_629ed_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_629ed_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_629ed_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_629ed_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_629ed_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_629ed_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_629ed_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_629ed_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_629ed_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_629ed_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_629ed_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_629ed_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_629ed_row0_col0" class="data row0 col0" >SGP</td>
#       <td id="T_629ed_row0_col1" class="data row0 col1" >2026</td>
#       <td id="T_629ed_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_629ed_row0_col3" class="data row0 col3" >1,530,428</td>
#       <td id="T_629ed_row0_col4" class="data row0 col4" >125,064</td>
#       <td id="T_629ed_row0_col5" class="data row0 col5" >1,405,364</td>
#       <td id="T_629ed_row0_col6" class="data row0 col6" >1123.72%</td>
#       <td id="T_629ed_row0_col7" class="data row0 col7" >1,530,428</td>
#       <td id="T_629ed_row0_col8" class="data row0 col8" >125,064</td>
#       <td id="T_629ed_row0_col9" class="data row0 col9" >1,405,364</td>
#       <td id="T_629ed_row0_col10" class="data row0 col10" >1123.72%</td>
#     </tr>
#     <tr>
#       <th id="T_629ed_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_629ed_row1_col0" class="data row1 col0" >SPRC</td>
#       <td id="T_629ed_row1_col1" class="data row1 col1" >2026</td>
#       <td id="T_629ed_row1_col2" class="data row1 col2" >1</td>
#       <td id="T
row5_col2" class="data row5 col2" >1</td>
#       <td id="T_629ed_row5_col3" class="data row5 col3" >162,715</td>
#       <td id="T_629ed_row5_col4" class="data row5 col4" >140,334</td>
#       <td id="T_629ed_row5_col5" class="data row5 col5" >22,381</td>
#       <td id="T_629ed_row5_col6" class="data row5 col6" >15.95%</td>
#       <td id="T_629ed_row5_col7" class="data row5 col7" >162,715</td>
#       <td id="T_629ed_row5_col8" class="data row5 col8" >140,334</td>
#       <td id="T_629ed_row5_col9" class="data row5 col9" >22,381</td>
#       <td id="T_629ed_row5_col10" class="data row5 col10" >15.95%</td>
#     </tr>
#     <tr>
#       <th id="T_629ed_level0_row6" class="row_heading level0 row6" >28</th>
#       <td id="T_629ed_row6_col0" class="data row6 col0" >SAT</td>
#       <td id="T_629ed_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_629ed_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_629ed_row6_col3" class="data row6 col3" >211,920</td>
#       <td id="T_629ed_row6_col4" class="data row6 col4" >189,198</td>
#       <td id="T_629ed_row6_col5" class="data row6 col5" >22,722</td>
#       <td id="T_629ed_row6_col6" class="data row6 col6" >12.01%</td>
#       <td id="T_629ed_row6_col7" class="data row6 col7" >211,920</td>
#       <td id="T_629ed_row6_col8" class="data row6 col8" >189,198</td>
#       <td id="T_629ed_row6_col9" class="data row6 col9" >22,722</td>
#       <td id="T_629ed_row6_col10" class="data row6 col10" >12.01%</td>
#     </tr>
#     <tr>
#       <th id="T_629ed_level0_row7" class="row_heading level0 row7" >26</th>
#       <td id="T_629ed_row7_col0" class="data row7 col0" >PTT</td>
#       <td id="T_629ed_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_629ed_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_629ed_row7_col3" class="data row7 col3" >25,738,299</td>
#       <td id="T_629ed_row7_col4" class="data row7 col4" >23,315,489</td>
#       <td id="T_629ed_row7_col5" class="data row7 col5" >2,422,810</td>
#       <td id="T_629ed_row7_col6" class="data row7 col6" >10.39%</td>
#       <td id="T_629ed_row7_col7" class="data row7 col7" >25,738,299</td>
#       <td id="T_629ed_row7_col8" class="data row7 col8" >23,315,489</td>
#       <td id="T_629ed_row7_col9" class="data row7 col9" >2,422,810</td>
#       <td id="T_629ed_row7_col10" class="data row7 col10" >10.39%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_aggr[df_aggr_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b451f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b451f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b451f_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_b451f_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_b451f_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_b451f_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_b451f_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_b451f_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_b451f_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_b451f_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_b451f_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_b451f_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b451f_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_b451f_row0_col0" class="data row0 col0" >BCP</td>
#       <td id="T_b451f_row0_col1" class="data row0 col1" >2026</td>
#       <td id="T_b451f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_b451f_row0_col3" class="data row0 col3" >6,143,762</td>
#       <td id="T_b451f_row0_col4" class="data row0 col4" >2,115,295</td>
#       <td id="T_b451f_row0_col5" class="data row0 col5" >4,028,467</td>
#       <td id="T_b451f_row0_col6" class="data row0 col6" >190.44%</td>
#       <td id="T_b451f_row0_col7" class="data row0 col7" >6,143,762</td>
#       <td id="T_b451f_row0_col8" class="data row0 col8" >2,115,295</td>
#       <td id="T_b451f_row0_col9" class="data row0 col9" >4,028,467</td>
#       <td id="T_b451f_row0_col10" class="data row0 col10" >190.44%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_b451f_row1_col0" class="data row1 col0" >EA</td>
#       <td id="T_b451f_row1_col1" class="data row1 col1" >2026</td>
#       <td id="T_b451f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_b451f_row1_col3" class="data row1 col3" >361,821</td>
#       <td id="T_b451f_row1_col4" class="data row1 col4" >252,333</td>
#       <td id="T_b451f_row1_col5" class="data row1 col5" >109,488</td>
#       <td id="T_b451f_row1_col6" class="data row1 col6" >43.39%</td>
#       <td id="T_b451f_row1_col7" class="data row1 col7" >361,821</td>
#       <td id="T_b451f_row1_col8" class="data row1 col8" >252,333</td>
#       <td id="T_b451f_row1_col9" class="data row1 col9" >109,488</td>
#       <td id="T_b451f_row1_col10" class="data row1 col10" >43.39%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_b451f_row2_col0" class="data row2 col0" >JMART</td>
#       <td id="T_b451f_row2_col1" class="data row2 col1" >2026</td>
#       <td id="T_b451f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_b451f_row2_col3" class="data row2 col3" >162,715</td>
#       <td id="T_b451f_row2_col4" class="data row2 col4" >140,334</td>
#       <td id="T_b451f_row2_col5" class="data row2 col5" >22,381</td>
#       <td id="T_b451f_row2_col6" class="data row2 col6" >15.95%</td>
#       <td id="T_b451f_row2_col7" class="data row2 col7" >162,715</td>
#       <td id="T_b451f_row2_col8" class="data row2 col8" >140,334</td>
#       <td id="T_b451f_row2_col9" class="data row2 col9" >22,381</td>
#       <td id="T_b451f_row2_col10" class="data row2 col10" >15.95%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row3" class="row_heading level0 row3" >26</th>
#       <td id="T_b451f_row3_col0" class="data row3 col0" >PTT</td>
#       <td id="T_b451f_row3_col1" class="data row3 col1" >2026</td>
#       <td id="T_b451f_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_b451f_row3_col3" class="data row3 col3" >25,738,299</td>
#       <td id="T_b451f_row3_col4" class="data row3 col4" >23,315,489</td>
#       <td id="T_b451f_row3_col5" class="data row3 col5" >2,422,810</td>
#       <td id="T_b451f_row3_col6" class="data row3 col6" >10.39%</td>
#       <td id="T_b451f_row3_col7" class="data row3 col7" >25,738,299</td>
#       <td id="T_b451f_row3_col8" class="data row3 col8" >23,315,489</td>
#       <td id="T_b451f_row3_col9" class="data row3 col9" >2,422,810</td>
#       <td id="T_b451f_row3_col10" class="data row3 col10" >10.39%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_b451f_row4_col0" class="data row4 col0" >SAT</td>
#       <td id="T_b451f_row4_col1" class="data row4 col1" >2026</td>
#       <td id="T_b451f_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_b451f_row4_col3" class="data row4 col3" >211,920</td>
#       <td id="T_b451f_row4_col4" class="data row4 col4" >189,198</td>
#       <td id="T_b451f_row4_col5" class="data row4 col5" >22,722</td>
#       <td id="T_b451f_row4_col6" class="data row4 col6" >12.01%</td>
#       <td id="T_b451f_row4_col7" class="data row4 col7" >211,920</td>
#       <td id="T_b451f_row4_col8" class="data row4 col8" >189,198</td>
#       <td id="T_b451f_row4_col9" class="data row4 col9" >22,722</td>
#       <td id="T_b451f_row4_col10" class="data row4 col10" >12.01%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row5" class="row_heading level0 row5" >30</th>
#       <td id="T_b451f_row5_col0" class="data row5 col0" >SGP</td>
#       <td id="T_b451f_row5_col1" class="data row5 col1" >2026</td>
#       <td id="T_b451f_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_b451f_row5_col3" class="data row5 col3" >1,530,428</td>
#       <td id="T_b451f_row5_col4" class="data row5 col4" >125,064</td>
#       <td id="T_b451f_row5_col5" class="data row5 col5" >1,405,364</td>
#       <td id="T_b451f_row5_col6" class="data row5 col6" >1123.72%</td>
#       <td id="T_b451f_row5_col7" class="data row5 col7" >1,530,428</td>
#       <td id="T_b451f_row5_col8" class="data row5 col8" >125,064</td>
#       <td id="T_b451f_row5_col9" class="data row5 col9" >1,405,364</td>
#       <td id="T_b451f_row5_col10" class="data row5 col10" >1123.72%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_b451f_row6_col0" class="data row6 col0" >SPRC</td>
#       <td id="T_b451f_row6_col1" class="data row6 col1" >2026</td>
#       <td id="T_b451f_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_b451f_row6_col3" class="data row6 col3" >7,366,927</td>
#       <td id="T_b451f_row6_col4" class="data row6 col4" >713,522</td>
#       <td id="T_b451f_row6_col5" class="data row6 col5" >6,653,405</td>
#       <td id="T_b451f_row6_col6" class="data row6 col6" >932.47%</td>
#       <td id="T_b451f_row6_col7" class="data row6 col7" >7,366,927</td>
#       <td id="T_b451f_row6_col8" class="data row6 col8" >713,522</td>
#       <td id="T_b451f_row6_col9" class="data row6 col9" >6,653,405</td>
#       <td id="T_b451f_row6_col10" class="data row6 col10" >932.47%</td>
#     </tr>
#     <tr>
#       <th id="T_b451f_level0_row7" class="row_heading level0 row7" >35</th>
#       <td id="T_b451f_row7_col0" class="data row7 col0" >TOA</td>
#       <td id="T_b451f_row7_col1" class="data row7 col1" >2026</td>
#       <td id="T_b451f_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_b451f_row7_col3" class="data row7 col3" >953,247</td>
#       <td id="T_b451f_row7_col4" class="data row7 col4" >733,099</td>
#       <td id="T_b451f_row7_col5" class="data row7 col5" >220,148</td>
#       <td id="T_b451f_row7_col6" class="data row7 col6" >30.03%</td>
#       <td id="T_b451f_row7_col7" class="data row7 col7" >953,247</td>
#       <td id="T_b451f_row7_col8" class="data row7 col8" >733,099</td>
#       <td id="T_b451f_row7_col9" class="data row7 col9" >220,148</td>
#       <td id="T_b451f_row7_col10" class="data row7 col10" >30.03%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
stock_list = df_epss_inp['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# AH','AIE','ANAN','AP','BCH','BCP','BEM','CHG','CPF','CPNREIT','DIF','EA','FSMART','GFPT','HANA','HTC','IVL','JMART','JMT','LH','LPN','MCS','ORI','PLANB','PREB','PRM','PTT','SAPPE','SAT','SC','SGP','SINGER','SJWD','SPRC','TKN','TOA','VNG

# %%
sql = f"""
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN ('{stock_list_str}')
ORDER BY E.name, year DESC, quarter DESC 
"""
print(sql)

epss_stocks = pd.read_sql(sql, conlt)
epss_stocks.shape
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('AH','AIE','ANAN','AP','BCH','BCP','BEM','CHG','CPF','CPNREIT','DIF','EA','FSMART','GFPT','HANA','HTC','IVL','JMART','JMT','LH','LPN','MCS','ORI','PLANB','PREB','PRM','PTT','SAPPE','SAT','SC','SGP','SINGER','SJWD','SPRC','TKN','TOA','VNG')
# ORDER BY E.name, year DESC, quarter DESC
# (1804, 11)

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
sqlDel = text("""
    DELETE FROM profits 
    WHERE name IN ('{stock_list_str}')
    AND quarter < :quarter
""")
print(sqlDel)
# Execute with parameters
rp = conlt.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
#     DELETE FROM profits
#     WHERE name IN ('{stock_list_str}')
#     AND quarter < :quarter
# 0

# %%
rp = conmy.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 0

# %%
rp = conpg.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 0

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index
# Out:
# Index(['3BBIF', 'ADVANC', 'ADVANC', 'BCP', 'CENTEL', 'COM7', 'CPALL',
#        'CPNREIT', 'DELTA', 'DIF', 'FPT', 'GPSC', 'GULF', 'GUNKUL', 'KKP',
#        'KKP', 'KTB', 'MTC', 'NER', 'SCC', 'SCGP', 'SCGP', 'SIS', 'THANI',
#        'THANI', 'TIDLOR', 'TOA', 'TPIPL', 'TVO', 'VIBHA', 'WHA', 'WHART'],
#       dtype='object', name='name')

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index
# Out:
# Index(['2842', '2843', '2844', '2845', '2846', '2847', '2848', '2849', '2850',
#        '2851', '2851', '2852', '2853', '2854', '2855', '2856', '3BBIF',
#        'ADVANC', 'ADVANC', 'BCP', 'CENTEL', 'COM7', 'CPALL', 'CPNREIT',
#        'DELTA', 'DIF', 'FPT', 'GPSC', 'GULF', 'GUNKUL', 'KKP', 'KKP', 'KTB',
#        'MTC', 'NER', 'SCC', 'SCGP', 'SCGP', 'SIS', 'THANI', 'THANI', 'TIDLOR',
#        'TOA', 'TPIPL', 'TVO', 'VIBHA', 'WHA', 'WHART'],
#       dtype='object', name='name')

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index
# Out:
# Index(['3BBIF', 'ADVANC', 'ADVANC', 'BCP', 'DELTA', 'FPT', 'GPSC', 'GUNKUL',
#        'KKP', 'KKP', 'KTB', 'SCC', 'SCGP', 'SCGP', 'THANI', 'TIDLOR', 'TPIPL',
#        'TVO', 'WHART'],
#       dtype='object', name='name')

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = f"""
SELECT * 
FROM tickers
WHERE name IN ('{stock_list_str}')
ORDER BY name"""
print(sql)

pg_tickers = pd.read_sql(sql, conpg)
pg_tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('AH','AIE','ANAN','AP','BCH','BCP','BEM','CHG','CPF','CPNREIT','DIF','EA','FSMART','GFPT','HANA','HTC','IVL','JMART','JMT','LH','LPN','MCS','ORI','PLANB','PREB','PRM','PTT','SAPPE','SAT','SC','SGP','SINGER','SJWD','SPRC','TKN','TOA','VNG')
# ORDER BY name
#        name   id
# 0        AH   11
# 1       AIE  691
# 2      ANAN   27
# 3        AP   29
# 4       BCH   55
# 5       BCP   56
# 6       BEM   61
# 7       CHG  101
# 8       CPF  121
# 9   CPNREIT  127
# 10      DIF  146
# 11       EA  153
# 12   FSMART  183
# 13     GFPT  192
# 14     HANA  211
# 15      HTC  218
# 16      IVL  238
# 17    JMART  244
# 18      JMT  245
# 19       LH  275
# 20      LPN  284
# 21      MCS  301
# 22      ORI  347
# 23    PLANB  366
# 24     PREB  377
# 25      PRM  382
# 26      PTT  389
# 27    SAPPE  426
# 28      SAT  427
# 29       SC  431
# 30      SGP  447
# 31   SINGER  452
# 32     SJWD  250
# 33     SPRC  478
# 34      TKN  542
# 35      TOA  562
# 36      VNG  703

# %%
sql = """
SELECT name 
FROM buy
"""
df_buy = pd.read_sql(sql, const)
df_buy.shape
# Out:
# (27, 1)

# %%
df_merge = pd.merge(pg_tickers, df_buy, on='name', how='inner')
df_merge
# Out:
#      id     name                                       full_name  \
# 0    11       AH            AAPICO HITECH PUBLIC COMPANY LIMITED
# 1    55      BCH   BANGKOK CHAIN HOSPITAL PUBLIC COMPANY LIMITED
# 2   121      CPF   CHAROEN POKPHAND FOODS PUBLIC COMPANY LIMITED
# 3   127  CPNREIT                CPN RETAIL GROWTH LEASEHOLD REIT
# 4   146      DIF  DIGITAL TELECOMMUNICATIONS INFRASTRUCTURE FUND
# 5   238      IVL        INDORAMA VENTURES PUBLIC COMPANY LIMITED
# 6   245      JMT     JMT NETWORK SERVICES PUBLIC COMPANY LIMITED
# 7   301      MCS              M.C.S.STEEL PUBLIC COMPANY LIMITED
# 8   347      ORI          ORIGIN PROPERTY PUBLIC COMPANY LIMITED
# 9   389      PTT                      PTT PUBLIC COMPANY LIMITED
# 10  452   SINGER          SINGER THAILAND PUBLIC COMPANY LIMITED
# 11  562      TOA     TOA PAINT (THAILAND) PUBLIC COMPANY LIMITED
#
#                      sector                               subsector  \
# 0               Industrials                              Automotive
# 1                  Services                    Health Care Services
# 2      Agro & Food Industry                         Food & Beverage
# 3   Property & Construction                   Property Fund & REITs
# 4                Technology  Information & Communication Technology
# 5               Industrials              Petrochemicals & Chemicals
# 6                Financials                    Finance & Securities
# 7               Industrials                Steel and Metal Products
# 8   Property & Construction                    Property Development
# 9                 Resources                      Energy & Utilities
# 10                 Services                                Commerce
# 11  Property & Construction                  Construction Materials
#
#                                        market                       website  \
# 0                              sSET / SETTHSI                www.aapico.com
# 1                              SET100 / SETWB  www.bangkokchainhospital.com
# 2   SET50 / SETCLMV / SETHD / SETTHSI / SETWB          www.cpfworldwide.com
# 3                                         SET               www.cpnreit.com
# 4                                         SET           www.digital-tif.com
# 5                             SET50 / SETTHSI      www.indoramaventures.com
# 6                                       SET50          www.jmtnetwork.co.th
# 7                                        sSET              www.mcssteel.com
# 8                    SET100 / SETHD / SETTHSI              www.origin.co.th
# 9           SET50 / SETCLMV / SETHD / SETTHSI                www.pttplc.com
# 10                                     SET100          www.singerthai.co.th
# 11                                    SETTHSI              www.toagroup.com
#
#                    created_at                 updated_at
# 0  2018-04-22 04:29:36.134601 2021-07-07 03:33:38.806441
# 1  2018-04-22 04:29:36.442067 2019-11-19 07:13:52.520896
# 2  2018-04-22 04:29:36.867977 2021-07-07 03:33:38.893396
# 3  2018-04-22 04:29:36.900508 2018-04-22 04:29:36.900508
# 4  2018-04-22 04:29:37.030748 2018-04-22 04:29:37.030748
# 5  2018-04-22 04:29:37.583373 2021-07-07 03:33:38.986666
# 6  2018-04-22 04:29:37.621811 2020-07-06 13:23:59.311892
# 7  2018-04-22 04:29:37.957104 2021-08-22 18:22:07.463483
# 8  2018-04-22 04:29:38.228072 2022-01-15 03:54:48.440923
# 9  2018-04-22 04:29:38.484745 2019-11-19 07:13:53.785316
# 10 2018-04-22 04:29:38.875668 2021-07-07 03:33:39.150064
# 11 2018-04-22 04:29:39.494571 2021-07-07 03:33:39.241053

# %%
# To check if the DataFrame is empty
if not df_merge.empty:
    file_name = 'pub_stock.xlsx'
    output_file = os.path.join(dat_path, file_name)
    print(f"Output file : {output_file}") 

    df_merge[['id','name','sector','market']].to_excel(output_file, index=False)
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\pub_stock.xlsx

# %% [markdown]
# ### Portfolio that already published

# %%
sql = """
SELECT * 
FROM buy"""
df_buy = pd.read_sql(sql, const)
df_buy.shape
# Out:
# (27, 10)

# %%
stock_list = df_buy['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# STA','SINGER','PTG','PTT','MCS','DIF','ADVANC','JMT','WHART','BCH','SENA','TFFIF','3BBIF','CPF','IVL','PTTGC','WHAIR','ORI','AH','GVREIT','NER','TOA','AWC','SYNEX','RCL','CPNREIT','TVO

# %%
select_date = '2026-01-01'

# %%
sql = f"""
SELECT *
FROM epss
WHERE name IN ('{stock_list_str}')
AND publish_date >= '2026-04-01'
ORDER BY name, year DESC, quarter DESC"""
df_tmp = pd.read_sql(sql, conlt)
df_tmp.shape
# Out:
# (27, 14)

# %%
# Get unique rows based on 'name' column
result = df_tmp.drop_duplicates(subset=['name'])
result.sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7dc67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dc67_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_7dc67_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7dc67_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_7dc67_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_7dc67_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_7dc67_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_7dc67_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_7dc67_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_7dc67_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_7dc67_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_7dc67_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_7dc67_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_7dc67_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_7dc67_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dc67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7