# %% [markdown]
# ## Restart and Run All

# %%
import pandas as pd
import os
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

year = "2025"
quarter = "3"
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2026-03-08 22:10:23

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
ORDER BY publish_date DESC LIMIT 2
"""
sql = sql % (year, quarter)
print(sql)

df_tmp = pd.read_sql(sql, conlt)
df_tmp
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 3
# ORDER BY publish_date DESC LIMIT 2
#       id name  year  quarter   q_amt    y_amt   aq_amt   ay_amt  q_eps  y_eps  \
# 0  24926  BTS  2025        3 -957827  2842380 -1085031  2113486  -0.06   0.21
# 1  24919   TR  2025        3 -800652   622431 -1641424    18792  -3.97   3.09
#
#    aq_eps  ay_eps  ticker_id publish_date
# 0   -0.07    0.15         83   2026-02-16
# 1   -8.14    0.09        564   2026-02-13

# %%
today = date(2026, 1, 1)
select_date = today.strftime("%Y-%m-%d")
select_date
# Out:
# '2026-01-01'

# %% [markdown]
# ### Tables in the process

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Excel path (xsl_path): {xsl_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Quarterly
# Base path: C:\Users\PC1\OneDrive\A4
# Data path (dat_path): C:\Users\PC1\OneDrive\A4\Data
# Excel path (xsl_path): C:\Users\PC1\OneDrive\A4\Excel
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()

format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:,.2f}%','acc_pct':'{:,.2f}%'
              }

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= '%s'
ORDER BY id DESC
"""
sql = sql % (year, quarter, select_date)
print(sql)

df_epss_inp = pd.read_sql(sql, conlt)
df_epss_inp.tail().style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 3
# AND publish_date >= '2026-01-01'
# ORDER BY id DESC
# <style type="text/css">
# </style>
# <table id="T_2884f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2884f_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_2884f_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_2884f_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_2884f_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_2884f_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_2884f_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_2884f_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_2884f_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_2884f_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_2884f_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_2884f_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_2884f_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_2884f_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_2884f_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2884f_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_2884f_row0_col0" class="data row0 col0" >24898</td>
#       <td id="T_2884f_row0_col1" class="data row0 col1" >PTL</td>
#       <td id="T_2884f_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_2884f_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_2884f_row0_col4" class="data row0 col4" >89,350</td>
#       <td id="T_2884f_row0_col5" class="data row0 col5" >343,879</td>
#       <td id="T_2884f_row0_col6" class="data row0 col6" >-228,021</td>
#       <td id="T_2884f_row0_col7" class="data row0 col7" >1,305,934</td>
#       <td id="T_2884f_row0_col8" class="data row0 col8" >0.0990</td>
#       <td id="T_2884f_row0_col9" class="data row0 col9" >0.3820</td>
#       <td id="T_2884f_row0_col10" class="data row0 col10" >-0.2530</td>
#       <td id="T_2884f_row0_col11" class="data row0 col11" >1.4510</td>
#       <td id="T_2884f_row0_col12" class="data row0 col12" >382</td>
#       <td id="T_2884f_row0_col13" class="data row0 col13" >2026-02-12</td>
#     </tr>
#     <tr>
#       <th id="T_2884f_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_2884f_row1_col0" class="data row1 col0" >24895</td>
#       <td id="T_2884f_row1_col1" class="data row1 col1" >VGI</td>
#       <td id="T_2884f_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_2884f_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_2884f_row1_col4" class="data row1 col4" >83,228</td>
#       <td id="T_2884f_row1_col5" class="data row1 col5" >307,749</td>
#       <td id="T_2884f_row1_col6" class="data row1 col6" >206,645</td>
#       <td id="T_2884f_row1_col7" class="data row1 col7" >448,557</td>
#       <td id="T_2884f_row1_col8" class="data row1 col8" >0.0040</td>
#       <td id="T_2884f_row1_col9" class="data row1 col9" >0.0220</td>
#       <td id="T_2884f_row1_col10" class="data row1 col10" >0.0100</td>
#       <td id="T_2884f_row1_col11" class="data row1 col11" >0.0370</td>
#       <td id="T_2884f_row1_col12" class="data row1 col12" >609</td>
#       <td id="T_2884f_row1_col13" class="data row1 col13" >2026-02-12</td>
#     </tr>
#     <tr>
#       <th id="T_2884f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_2884f_row2_col0" class="data row2 col0" >24892</td>
#       <td id="T_2884f_row2_col1" class="data row2 col1" >EPG</td>
#       <td id="T_2884f_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_2884f_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_2884f_row2_col4" class="data row2 col4" >333,718</td>
#       <td id="T_2884f_row2_col5" class="data row2 col5" >163,958</td>
#       <td id="T_2884f_row2_col6" class="data row2 col6" >915,584</td>
#       <td id="T_2884f_row2_col7" class="data row2 col7" >547,877</td>
#       <td id="T_2884f_row2_col8" class="data row2 col8" >0.1190</td>
#       <td id="T_2884f_row2_col9" class="data row2 col9" >0.0590</td>
#       <td id="T_2884f_row2_col10" class="data row2 col10" >0.3270</td>
#       <td id="T_2884f_row2_col11" class="data row2 col11" >0.1960</td>
#       <td id="T_2884f_row2_col12" class="data row2 col12" >162</td>
#       <td id="T_2884f_row2_col13" class="data row2 col13" >2026-02-12</td>
#     </tr>
#     <tr>
#       <th id="T_2884f_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_2884f_row3_col0" class="data row3 col0" >24882</td>
#       <td id="T_2884f_row3_col1" class="data row3 col1" >TSTH</td>
#       <td id="T_2884f_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_2884f_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_2884f_row3_col4" class="data row3 col4" >496,694</td>
#       <td id="T_2884f_row3_col5" class="data row3 col5" >249,001</td>
#       <td id="T_2884f_row3_col6" class="data row3 col6" >1,726,788</td>
#       <td id="T_2884f_row3_col7" class="data row3 col7" >179,408</td>
#       <td id="T_2884f_row3_col8" class="data row3 col8" >0.0592</td>
#       <td id="T_2884f_row3_col9" class="data row3 col9" >0.0290</td>
#       <td id="T_2884f_row3_col10" class="data row3 col10" >0.2050</td>
#       <td id="T_2884f_row3_col11" class="data row3 col11" >0.0213</td>
#       <td id="T_2884f_row3_col12" class="data row3 col12" >578</td>
#       <td id="T_2884f_row3_col13" class="data row3 col13" >2026-01-19</td>
#     </tr>
#     <tr>
#       <th id="T_2884f_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_2884f_row4_col0" class="data row4 col0" >24881</td>
#       <td id="T_2884f_row4_col1" class="data row4 col1" >STANLY</td>
#       <td id="T_2884f_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_2884f_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_2884f_row4_col4" class="data row4 col4" >490,497</td>
#       <td id="T_2884f_row4_col5" class="data row4 col5" >310,402</td>
#       <td id="T_2884f_row4_col6" class="data row4 col6" >1,476,679</td>
#       <td id="T_2884f_row4_col7" class="data row4 col7" >945,371</td>
#       <td id="T_2884f_row4_col8" class="data row4 col8" >6.4000</td>
#       <td id="T_2884f_row4_col9" class="data row4 col9" >4.0500</td>
#       <td id="T_2884f_row4_col10" class="data row4 col10" >19.2700</td>
#       <td id="T_2884f_row4_col11" class="data row4 col11" >12.3400</td>
#       <td id="T_2884f_row4_col12" class="data row4 col12" >482</td>
#       <td id="T_2884f_row4_col13" class="data row4 col13" >2026-01-26</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_epss_inp["yoy_gain"] = df_epss_inp["q_amt"] - df_epss_inp["y_amt"]
df_epss_inp["yoy_pct"] = round(df_epss_inp["yoy_gain"] / abs(df_epss_inp["y_amt"]) * 100, 2)
df_epss_inp["acc_gain"] = df_epss_inp["aq_amt"] - df_epss_inp["ay_amt"]
df_epss_inp["acc_pct"] = round(df_epss_inp["acc_gain"] / abs(df_epss_inp["ay_amt"]) * 100,2)

df_aggr = df_epss_inp[colt]
df_aggr.tail().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bd97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bd97_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_5bd97_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_5bd97_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_5bd97_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_5bd97_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_5bd97_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_5bd97_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_5bd97_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_5bd97_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_5bd97_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_5bd97_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bd97_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_5bd97_row0_col0" class="data row0 col0" >PTL</td>
#       <td id="T_5bd97_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_5bd97_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_5bd97_row0_col3" class="data row0 col3" >89,350</td>
#       <td id="T_5bd97_row0_col4" class="data row0 col4" >343,879</td>
#       <td id="T_5bd97_row0_col5" class="data row0 col5" >-254,529</td>
#       <td id="T_5bd97_row0_col6" class="data row0 col6" >-74.02%</td>
#       <td id="T_5bd97_row0_col7" class="data row0 col7" >-228,021</td>
#       <td id="T_5bd97_row0_col8" class="data row0 col8" >1,305,934</td>
#       <td id="T_5bd97_row0_col9" class="data row0 col9" >-1,533,955</td>
#       <td id="T_5bd97_row0_col10" class="data row0 col10" >-117.46%</td>
#     </tr>
#     <tr>
#       <th id="T_5bd97_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_5bd97_row1_col0" class="data row1 col0" >VGI</td>
#       <td id="T_5bd97_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_5bd97_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_5bd97_row1_col3" class="data row1 col3" >83,228</td>
#       <td id="T_5bd97_row1_col4" class="data row1 col4" >307,749</td>
#       <td id="T_5bd97_row1_col5" class="data row1 col5" >-224,521</td>
#       <td id="T_5bd97_row1_col6" class="data row1 col6" >-72.96%</td>
#       <td id="T_5bd97_row1_col7" class="data row1 col7" >206,645</td>
#       <td id="T_5bd97_row1_col8" class="data row1 col8" >448,557</td>
#       <td id="T_5bd97_row1_col9" class="data row1 col9" >-241,912</td>
#       <td id="T_5bd97_row1_col10" class="data row1 col10" >-53.93%</td>
#     </tr>
#     <tr>
#       <th id="T_5bd97_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_5bd97_row2_col0" class="data row2 col0" >EPG</td>
#       <td id="T_5bd97_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_5bd97_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_5bd97_row2_col3" class="data row2 col3" >333,718</td>
#       <td id="T_5bd97_row2_col4" class="data row2 col4" >163,958</td>
#       <td id="T_5bd97_row2_col5" class="data row2 col5" >169,760</td>
#       <td id="T_5bd97_row2_col6" class="data row2 col6" >103.54%</td>
#       <td id="T_5bd97_row2_col7" class="data row2 col7" >915,584</td>
#       <td id="T_5bd97_row2_col8" class="data row2 col8" >547,877</td>
#       <td id="T_5bd97_row2_col9" class="data row2 col9" >367,707</td>
#       <td id="T_5bd97_row2_col10" class="data row2 col10" >67.11%</td>
#     </tr>
#     <tr>
#       <th id="T_5bd97_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_5bd97_row3_col0" class="data row3 col0" >TSTH</td>
#       <td id="T_5bd97_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_5bd97_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_5bd97_row3_col3" class="data row3 col3" >496,694</td>
#       <td id="T_5bd97_row3_col4" class="data row3 col4" >249,001</td>
#       <td id="T_5bd97_row3_col5" class="data row3 col5" >247,693</td>
#       <td id="T_5bd97_row3_col6" class="data row3 col6" >99.47%</td>
#       <td id="T_5bd97_row3_col7" class="data row3 col7" >1,726,788</td>
#       <td id="T_5bd97_row3_col8" class="data row3 col8" >179,408</td>
#       <td id="T_5bd97_row3_col9" class="data row3 col9" >1,547,380</td>
#       <td id="T_5bd97_row3_col10" class="data row3 col10" >862.49%</td>
#     </tr>
#     <tr>
#       <th id="T_5bd97_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_5bd97_row4_col0" class="data row4 col0" >STANLY</td>
#       <td id="T_5bd97_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_5bd97_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_5bd97_row4_col3" class="data row4 col3" >490,497</td>
#       <td id="T_5bd97_row4_col4" class="data row4 col4" >310,402</td>
#       <td id="T_5bd97_row4_col5" class="data row4 col5" >180,095</td>
#       <td id="T_5bd97_row4_col6" class="data row4 col6" >58.02%</td>
#       <td id="T_5bd97_row4_col7" class="data row4 col7" >1,476,679</td>
#       <td id="T_5bd97_row4_col8" class="data row4 col8" >945,371</td>
#       <td id="T_5bd97_row4_col9" class="data row4 col9" >531,308</td>
#       <td id="T_5bd97_row4_col10" class="data row4 col10" >56.20%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_1 = df_aggr.q_amt > 110_000
df_aggr.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_68dee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68dee_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_68dee_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_68dee_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_68dee_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_68dee_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_68dee_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_68dee_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68dee_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_68dee_row0_col0" class="data row0 col0" >TMW</td>
#       <td id="T_68dee_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_68dee_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_68dee_row0_col3" class="data row0 col3" >135,414</td>
#       <td id="T_68dee_row0_col4" class="data row0 col4" >131,226</td>
#       <td id="T_68dee_row0_col5" class="data row0 col5" >4,188</td>
#       <td id="T_68dee_row0_col6" class="data row0 col6" >3.19%</td>
#     </tr>
#     <tr>
#       <th id="T_68dee_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_68dee_row1_col0" class="data row1 col0" >KYE</td>
#       <td id="T_68dee_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_68dee_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_68dee_row1_col3" class="data row1 col3" >277,724</td>
#       <td id="T_68dee_row1_col4" class="data row1 col4" >368,959</td>
#       <td id="T_68dee_row1_col5" class="data row1 col5" >-91,235</td>
#       <td id="T_68dee_row1_col6" class="data row1 col6" >-24.73%</td>
#     </tr>
#     <tr>
#       <th id="T_68dee_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_68dee_row2_col0" class="data row2 col0" >IMPACT</td>
#       <td id="T_68dee_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_68dee_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_68dee_row2_col3" class="data row2 col3" >394,738</td>
#       <td id="T_68dee_row2_col4" class="data row2 col4" >277,552</td>
#       <td id="T_68dee_row2_col5" class="data row2 col5" >117,186</td>
#       <td id="T_68dee_row2_col6" class="data row2 col6" >42.22%</td>
#     </tr>
#     <tr>
#       <th id="T_68dee_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_68dee_row3_col0" class="data row3 col0" >EPG</td>
#       <td id="T_68dee_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_68dee_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_68dee_row3_col3" class="data row3 col3" >333,718</td>
#       <td id="T_68dee_row3_col4" class="data row3 col4" >163,958</td>
#       <td id="T_68dee_row3_col5" class="data row3 col5" >169,760</td>
#       <td id="T_68dee_row3_col6" class="data row3 col6" >103.54%</td>
#     </tr>
#     <tr>
#       <th id="T_68dee_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_68dee_row4_col0" class="data row4 col0" >TSTH</td>
#       <td id="T_68dee_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_68dee_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_68dee_row4_col3" class="data row4 col3" >496,694</td>
#       <td id="T_68dee_row4_col4" class="data row4 col4" >249,001</td>
#       <td id="T_68dee_row4_col5" class="data row4 col5" >247,693</td>
#       <td id="T_68dee_row4_col6" class="data row4 col6" >99.47%</td>
#     </tr>
#     <tr>
#       <th id="T_68dee_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_68dee_row5_col0" class="data row5 col0" >STANLY</td>
#       <td id="T_68dee_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_68dee_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_68dee_row5_col3" class="data row5 col3" >490,497</td>
#       <td id="T_68dee_row5_col4" class="data row5 col4" >310,402</td>
#       <td id="T_68dee_row5_col5" class="data row5 col5" >180,095</td>
#       <td id="T_68dee_row5_col6" class="data row5 col6" >58.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_2 = df_aggr.y_amt > 100_000
df_aggr.loc[criteria_2, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ff96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ff96_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1ff96_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_1ff96_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_1ff96_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_1ff96_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_1ff96_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_1ff96_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ff96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ff96_row0_col0" class="data row0 col0" >BTS</td>
#       <td id="T_1ff96_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_1ff96_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_1ff96_row0_col3" class="data row0 col3" >-957,827</td>
#       <td id="T_1ff96_row0_col4" class="data row0 col4" >2,842,380</td>
#       <td id="T_1ff96_row0_col5" class="data row0 col5" >-3,800,207</td>
#       <td id="T_1ff96_row0_col6" class="data row0 col6" >-133.70%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ff96_row1_col0" class="data row1 col0" >TMW</td>
#       <td id="T_1ff96_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_1ff96_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_1ff96_row1_col3" class="data row1 col3" >135,414</td>
#       <td id="T_1ff96_row1_col4" class="data row1 col4" >131,226</td>
#       <td id="T_1ff96_row1_col5" class="data row1 col5" >4,188</td>
#       <td id="T_1ff96_row1_col6" class="data row1 col6" >3.19%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ff96_row2_col0" class="data row2 col0" >BTSGIF</td>
#       <td id="T_1ff96_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_1ff96_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_1ff96_row2_col3" class="data row2 col3" >-58,825</td>
#       <td id="T_1ff96_row2_col4" class="data row2 col4" >491,903</td>
#       <td id="T_1ff96_row2_col5" class="data row2 col5" >-550,728</td>
#       <td id="T_1ff96_row2_col6" class="data row2 col6" >-111.96%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ff96_row3_col0" class="data row3 col0" >TR</td>
#       <td id="T_1ff96_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_1ff96_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_1ff96_row3_col3" class="data row3 col3" >-800,652</td>
#       <td id="T_1ff96_row3_col4" class="data row3 col4" >622,431</td>
#       <td id="T_1ff96_row3_col5" class="data row3 col5" >-1,423,083</td>
#       <td id="T_1ff96_row3_col6" class="data row3 col6" >-228.63%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_1ff96_row4_col0" class="data row4 col0" >KYE</td>
#       <td id="T_1ff96_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_1ff96_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_1ff96_row4_col3" class="data row4 col3" >277,724</td>
#       <td id="T_1ff96_row4_col4" class="data row4 col4" >368,959</td>
#       <td id="T_1ff96_row4_col5" class="data row4 col5" >-91,235</td>
#       <td id="T_1ff96_row4_col6" class="data row4 col6" >-24.73%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_1ff96_row5_col0" class="data row5 col0" >IMPACT</td>
#       <td id="T_1ff96_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_1ff96_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_1ff96_row5_col3" class="data row5 col3" >394,738</td>
#       <td id="T_1ff96_row5_col4" class="data row5 col4" >277,552</td>
#       <td id="T_1ff96_row5_col5" class="data row5 col5" >117,186</td>
#       <td id="T_1ff96_row5_col6" class="data row5 col6" >42.22%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_1ff96_row6_col0" class="data row6 col0" >PTL</td>
#       <td id="T_1ff96_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_1ff96_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_1ff96_row6_col3" class="data row6 col3" >89,350</td>
#       <td id="T_1ff96_row6_col4" class="data row6 col4" >343,879</td>
#       <td id="T_1ff96_row6_col5" class="data row6 col5" >-254,529</td>
#       <td id="T_1ff96_row6_col6" class="data row6 col6" >-74.02%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_1ff96_row7_col0" class="data row7 col0" >VGI</td>
#       <td id="T_1ff96_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_1ff96_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_1ff96_row7_col3" class="data row7 col3" >83,228</td>
#       <td id="T_1ff96_row7_col4" class="data row7 col4" >307,749</td>
#       <td id="T_1ff96_row7_col5" class="data row7 col5" >-224,521</td>
#       <td id="T_1ff96_row7_col6" class="data row7 col6" >-72.96%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_1ff96_row8_col0" class="data row8 col0" >EPG</td>
#       <td id="T_1ff96_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_1ff96_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_1ff96_row8_col3" class="data row8 col3" >333,718</td>
#       <td id="T_1ff96_row8_col4" class="data row8 col4" >163,958</td>
#       <td id="T_1ff96_row8_col5" class="data row8 col5" >169,760</td>
#       <td id="T_1ff96_row8_col6" class="data row8 col6" >103.54%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_1ff96_row9_col0" class="data row9 col0" >TSTH</td>
#       <td id="T_1ff96_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_1ff96_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_1ff96_row9_col3" class="data row9 col3" >496,694</td>
#       <td id="T_1ff96_row9_col4" class="data row9 col4" >249,001</td>
#       <td id="T_1ff96_row9_col5" class="data row9 col5" >247,693</td>
#       <td id="T_1ff96_row9_col6" class="data row9 col6" >99.47%</td>
#     </tr>
#     <tr>
#       <th id="T_1ff96_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_1ff96_row10_col0" class="data row10 col0" >STANLY</td>
#       <td id="T_1ff96_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_1ff96_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_1ff96_row10_col3" class="data row10 col3" >490,497</td>
#       <td id="T_1ff96_row10_col4" class="data row10 col4" >310,402</td>
#       <td id="T_1ff96_row10_col5" class="data row10 col5" >180,095</td>
#       <td id="T_1ff96_row10_col6" class="data row10 col6" >58.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_3 = df_aggr.yoy_pct > 10.00
df_aggr.loc[criteria_3, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3666b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3666b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3666b_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_3666b_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_3666b_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_3666b_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_3666b_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_3666b_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3666b_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_3666b_row0_col0" class="data row0 col0" >BLAND</td>
#       <td id="T_3666b_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_3666b_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_3666b_row0_col3" class="data row0 col3" >68,029</td>
#       <td id="T_3666b_row0_col4" class="data row0 col4" >-65,593</td>
#       <td id="T_3666b_row0_col5" class="data row0 col5" >133,622</td>
#       <td id="T_3666b_row0_col6" class="data row0 col6" >203.71%</td>
#     </tr>
#     <tr>
#       <th id="T_3666b_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_3666b_row1_col0" class="data row1 col0" >IMPACT</td>
#       <td id="T_3666b_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_3666b_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_3666b_row1_col3" class="data row1 col3" >394,738</td>
#       <td id="T_3666b_row1_col4" class="data row1 col4" >277,552</td>
#       <td id="T_3666b_row1_col5" class="data row1 col5" >117,186</td>
#       <td id="T_3666b_row1_col6" class="data row1 col6" >42.22%</td>
#     </tr>
#     <tr>
#       <th id="T_3666b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_3666b_row2_col0" class="data row2 col0" >EPG</td>
#       <td id="T_3666b_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_3666b_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_3666b_row2_col3" class="data row2 col3" >333,718</td>
#       <td id="T_3666b_row2_col4" class="data row2 col4" >163,958</td>
#       <td id="T_3666b_row2_col5" class="data row2 col5" >169,760</td>
#       <td id="T_3666b_row2_col6" class="data row2 col6" >103.54%</td>
#     </tr>
#     <tr>
#       <th id="T_3666b_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_3666b_row3_col0" class="data row3 col0" >TSTH</td>
#       <td id="T_3666b_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_3666b_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_3666b_row3_col3" class="data row3 col3" >496,694</td>
#       <td id="T_3666b_row3_col4" class="data row3 col4" >249,001</td>
#       <td id="T_3666b_row3_col5" class="data row3 col5" >247,693</td>
#       <td id="T_3666b_row3_col6" class="data row3 col6" >99.47%</td>
#     </tr>
#     <tr>
#       <th id="T_3666b_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_3666b_row4_col0" class="data row4 col0" >STANLY</td>
#       <td id="T_3666b_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_3666b_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_3666b_row4_col3" class="data row4 col3" >490,497</td>
#       <td id="T_3666b_row4_col4" class="data row4 col4" >310,402</td>
#       <td id="T_3666b_row4_col5" class="data row4 col5" >180,095</td>
#       <td id="T_3666b_row4_col6" class="data row4 col6" >58.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_aggr_criteria = criteria_1 & criteria_2 & criteria_3
#df_aggr_criteria = criteria_1 & criteria_3 
df_aggr.loc[df_aggr_criteria, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_39a00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39a00_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_39a00_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_39a00_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_39a00_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_39a00_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_39a00_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_39a00_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39a00_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_39a00_row0_col0" class="data row0 col0" >IMPACT</td>
#       <td id="T_39a00_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_39a00_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_39a00_row0_col3" class="data row0 col3" >394,738</td>
#       <td id="T_39a00_row0_col4" class="data row0 col4" >277,552</td>
#       <td id="T_39a00_row0_col5" class="data row0 col5" >117,186</td>
#       <td id="T_39a00_row0_col6" class="data row0 col6" >42.22%</td>
#     </tr>
#     <tr>
#       <th id="T_39a00_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_39a00_row1_col0" class="data row1 col0" >EPG</td>
#       <td id="T_39a00_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_39a00_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_39a00_row1_col3" class="data row1 col3" >333,718</td>
#       <td id="T_39a00_row1_col4" class="data row1 col4" >163,958</td>
#       <td id="T_39a00_row1_col5" class="data row1 col5" >169,760</td>
#       <td id="T_39a00_row1_col6" class="data row1 col6" >103.54%</td>
#     </tr>
#     <tr>
#       <th id="T_39a00_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_39a00_row2_col0" class="data row2 col0" >TSTH</td>
#       <td id="T_39a00_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_39a00_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_39a00_row2_col3" class="data row2 col3" >496,694</td>
#       <td id="T_39a00_row2_col4" class="data row2 col4" >249,001</td>
#       <td id="T_39a00_row2_col5" class="data row2 col5" >247,693</td>
#       <td id="T_39a00_row2_col6" class="data row2 col6" >99.47%</td>
#     </tr>
#     <tr>
#       <th id="T_39a00_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_39a00_row3_col0" class="data row3 col0" >STANLY</td>
#       <td id="T_39a00_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_39a00_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_39a00_row3_col3" class="data row3 col3" >490,497</td>
#       <td id="T_39a00_row3_col4" class="data row3 col4" >310,402</td>
#       <td id="T_39a00_row3_col5" class="data row3 col5" >180,095</td>
#       <td id="T_39a00_row3_col6" class="data row3 col6" >58.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_aggr[df_aggr_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f1d43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1d43_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_f1d43_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_f1d43_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_f1d43_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_f1d43_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_f1d43_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_f1d43_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_f1d43_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_f1d43_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_f1d43_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_f1d43_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1d43_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_f1d43_row0_col0" class="data row0 col0" >EPG</td>
#       <td id="T_f1d43_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_f1d43_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_f1d43_row0_col3" class="data row0 col3" >333,718</td>
#       <td id="T_f1d43_row0_col4" class="data row0 col4" >163,958</td>
#       <td id="T_f1d43_row0_col5" class="data row0 col5" >169,760</td>
#       <td id="T_f1d43_row0_col6" class="data row0 col6" >103.54%</td>
#       <td id="T_f1d43_row0_col7" class="data row0 col7" >915,584</td>
#       <td id="T_f1d43_row0_col8" class="data row0 col8" >547,877</td>
#       <td id="T_f1d43_row0_col9" class="data row0 col9" >367,707</td>
#       <td id="T_f1d43_row0_col10" class="data row0 col10" >67.11%</td>
#     </tr>
#     <tr>
#       <th id="T_f1d43_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_f1d43_row1_col0" class="data row1 col0" >IMPACT</td>
#       <td id="T_f1d43_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_f1d43_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_f1d43_row1_col3" class="data row1 col3" >394,738</td>
#       <td id="T_f1d43_row1_col4" class="data row1 col4" >277,552</td>
#       <td id="T_f1d43_row1_col5" class="data row1 col5" >117,186</td>
#       <td id="T_f1d43_row1_col6" class="data row1 col6" >42.22%</td>
#       <td id="T_f1d43_row1_col7" class="data row1 col7" >949,916</td>
#       <td id="T_f1d43_row1_col8" class="data row1 col8" >837,143</td>
#       <td id="T_f1d43_row1_col9" class="data row1 col9" >112,773</td>
#       <td id="T_f1d43_row1_col10" class="data row1 col10" >13.47%</td>
#     </tr>
#     <tr>
#       <th id="T_f1d43_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_f1d43_row2_col0" class="data row2 col0" >STANLY</td>
#       <td id="T_f1d43_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_f1d43_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_f1d43_row2_col3" class="data row2 col3" >490,497</td>
#       <td id="T_f1d43_row2_col4" class="data row2 col4" >310,402</td>
#       <td id="T_f1d43_row2_col5" class="data row2 col5" >180,095</td>
#       <td id="T_f1d43_row2_col6" class="data row2 col6" >58.02%</td>
#       <td id="T_f1d43_row2_col7" class="data row2 col7" >1,476,679</td>
#       <td id="T_f1d43_row2_col8" class="data row2 col8" >945,371</td>
#       <td id="T_f1d43_row2_col9" class="data row2 col9" >531,308</td>
#       <td id="T_f1d43_row2_col10" class="data row2 col10" >56.20%</td>
#     </tr>
#     <tr>
#       <th id="T_f1d43_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_f1d43_row3_col0" class="data row3 col0" >TSTH</td>
#       <td id="T_f1d43_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_f1d43_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_f1d43_row3_col3" class="data row3 col3" >496,694</td>
#       <td id="T_f1d43_row3_col4" class="data row3 col4" >249,001</td>
#       <td id="T_f1d43_row3_col5" class="data row3 col5" >247,693</td>
#       <td id="T_f1d43_row3_col6" class="data row3 col6" >99.47%</td>
#       <td id="T_f1d43_row3_col7" class="data row3 col7" >1,726,788</td>
#       <td id="T_f1d43_row3_col8" class="data row3 col8" >179,408</td>
#       <td id="T_f1d43_row3_col9" class="data row3 col9" >1,547,380</td>
#       <td id="T_f1d43_row3_col10" class="data row3 col10" >862.49%</td>
#     </tr>
#   </tbody>
# </table>

# %%
stock_list = df_epss_inp['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# BTS','TMW','BTSGIF','TR','LHK','BLAND','KYE','IMPACT','PTL','VGI','EPG','TSTH','STANLY

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
sql = f"""
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN ('{stock_list_str}')
ORDER BY E.name, year DESC, quarter DESC 
LIMIT 12
"""
print(sql)

epss_stocks = pd.read_sql(sql, conlt)
epss_stocks.style.format(format_dict)
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('BTS','TMW','BTSGIF','TR','LHK','BLAND','KYE','IMPACT','PTL','VGI','EPG','TSTH','STANLY')
# ORDER BY E.name, year DESC, quarter DESC
# LIMIT 12
# <style type="text/css">
# </style>
# <table id="T_c1a5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1a5e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c1a5e_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_c1a5e_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_c1a5e_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_c1a5e_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_c1a5e_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_c1a5e_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_c1a5e_level0_col7" class="col_heading level0 col7" >q_eps</th>
#       <th id="T_c1a5e_level0_col8" class="col_heading level0 col8" >y_eps</th>
#       <th id="T_c1a5e_level0_col9" class="col_heading level0 col9" >aq_eps</th>
#       <th id="T_c1a5e_level0_col10" class="col_heading level0 col10" >ay_eps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1a5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1a5e_row0_col0" class="data row0 col0" >BLAND</td>
#       <td id="T_c1a5e_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_c1a5e_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_c1a5e_row0_col3" class="data row0 col3" >68,029</td>
#       <td id="T_c1a5e_row0_col4" class="data row0 col4" >-65,593</td>
#       <td id="T_c1a5e_row0_col5" class="data row0 col5" >77,023</td>
#       <td id="T_c1a5e_row0_col6" class="data row0 col6" >176,792</td>
#       <td id="T_c1a5e_row0_col7" class="data row0 col7" >0.0040</td>
#       <td id="T_c1a5e_row0_col8" class="data row0 col8" >-0.0040</td>
#       <td id="T_c1a5e_row0_col9" class="data row0 col9" >0.0040</td>
#       <td id="T_c1a5e_row0_col10" class="data row0 col10" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1a5e_row1_col0" class="data row1 col0" >BLAND</td>
#       <td id="T_c1a5e_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_c1a5e_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_c1a5e_row1_col3" class="data row1 col3" >-86,105</td>
#       <td id="T_c1a5e_row1_col4" class="data row1 col4" >66,074</td>
#       <td id="T_c1a5e_row1_col5" class="data row1 col5" >8,994</td>
#       <td id="T_c1a5e_row1_col6" class="data row1 col6" >146,763</td>
#       <td id="T_c1a5e_row1_col7" class="data row1 col7" >-0.0050</td>
#       <td id="T_c1a5e_row1_col8" class="data row1 col8" >0.0040</td>
#       <td id="T_c1a5e_row1_col9" class="data row1 col9" >0.0005</td>
#       <td id="T_c1a5e_row1_col10" class="data row1 col10" >0.0085</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1a5e_row2_col0" class="data row2 col0" >BLAND</td>
#       <td id="T_c1a5e_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_c1a5e_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_c1a5e_row2_col3" class="data row2 col3" >95,099</td>
#       <td id="T_c1a5e_row2_col4" class="data row2 col4" >76,584</td>
#       <td id="T_c1a5e_row2_col5" class="data row2 col5" >95,099</td>
#       <td id="T_c1a5e_row2_col6" class="data row2 col6" >76,584</td>
#       <td id="T_c1a5e_row2_col7" class="data row2 col7" >0.0050</td>
#       <td id="T_c1a5e_row2_col8" class="data row2 col8" >0.0040</td>
#       <td id="T_c1a5e_row2_col9" class="data row2 col9" >0.0050</td>
#       <td id="T_c1a5e_row2_col10" class="data row2 col10" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1a5e_row3_col0" class="data row3 col0" >BLAND</td>
#       <td id="T_c1a5e_row3_col1" class="data row3 col1" >2024</td>
#       <td id="T_c1a5e_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_c1a5e_row3_col3" class="data row3 col3" >479,330</td>
#       <td id="T_c1a5e_row3_col4" class="data row3 col4" >957,381</td>
#       <td id="T_c1a5e_row3_col5" class="data row3 col5" >656,122</td>
#       <td id="T_c1a5e_row3_col6" class="data row3 col6" >957,557</td>
#       <td id="T_c1a5e_row3_col7" class="data row3 col7" >0.0278</td>
#       <td id="T_c1a5e_row3_col8" class="data row3 col8" >0.0550</td>
#       <td id="T_c1a5e_row3_col9" class="data row3 col9" >0.0380</td>
#       <td id="T_c1a5e_row3_col10" class="data row3 col10" >0.0550</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1a5e_row4_col0" class="data row4 col0" >BLAND</td>
#       <td id="T_c1a5e_row4_col1" class="data row4 col1" >2024</td>
#       <td id="T_c1a5e_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_c1a5e_row4_col3" class="data row4 col3" >-65,593</td>
#       <td id="T_c1a5e_row4_col4" class="data row4 col4" >121,431</td>
#       <td id="T_c1a5e_row4_col5" class="data row4 col5" >176,792</td>
#       <td id="T_c1a5e_row4_col6" class="data row4 col6" >176</td>
#       <td id="T_c1a5e_row4_col7" class="data row4 col7" >-0.0040</td>
#       <td id="T_c1a5e_row4_col8" class="data row4 col8" >0.0070</td>
#       <td id="T_c1a5e_row4_col9" class="data row4 col9" >0.0102</td>
#       <td id="T_c1a5e_row4_col10" class="data row4 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c1a5e_row5_col0" class="data row5 col0" >BLAND</td>
#       <td id="T_c1a5e_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_c1a5e_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_c1a5e_row5_col3" class="data row5 col3" >66,073</td>
#       <td id="T_c1a5e_row5_col4" class="data row5 col4" >-54,635</td>
#       <td id="T_c1a5e_row5_col5" class="data row5 col5" >146,762</td>
#       <td id="T_c1a5e_row5_col6" class="data row5 col6" >-121,256</td>
#       <td id="T_c1a5e_row5_col7" class="data row5 col7" >0.0040</td>
#       <td id="T_c1a5e_row5_col8" class="data row5 col8" >-0.0030</td>
#       <td id="T_c1a5e_row5_col9" class="data row5 col9" >0.0085</td>
#       <td id="T_c1a5e_row5_col10" class="data row5 col10" >-0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c1a5e_row6_col0" class="data row6 col0" >BLAND</td>
#       <td id="T_c1a5e_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_c1a5e_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_c1a5e_row6_col3" class="data row6 col3" >76,584</td>
#       <td id="T_c1a5e_row6_col4" class="data row6 col4" >-66,621</td>
#       <td id="T_c1a5e_row6_col5" class="data row6 col5" >76,584</td>
#       <td id="T_c1a5e_row6_col6" class="data row6 col6" >-66,621</td>
#       <td id="T_c1a5e_row6_col7" class="data row6 col7" >0.0040</td>
#       <td id="T_c1a5e_row6_col8" class="data row6 col8" >-0.0040</td>
#       <td id="T_c1a5e_row6_col9" class="data row6 col9" >0.0040</td>
#       <td id="T_c1a5e_row6_col10" class="data row6 col10" >-0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c1a5e_row7_col0" class="data row7 col0" >BLAND</td>
#       <td id="T_c1a5e_row7_col1" class="data row7 col1" >2023</td>
#       <td id="T_c1a5e_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_c1a5e_row7_col3" class="data row7 col3" >957,381</td>
#       <td id="T_c1a5e_row7_col4" class="data row7 col4" >578,852</td>
#       <td id="T_c1a5e_row7_col5" class="data row7 col5" >957,557</td>
#       <td id="T_c1a5e_row7_col6" class="data row7 col6" >654,140</td>
#       <td id="T_c1a5e_row7_col7" class="data row7 col7" >0.0550</td>
#       <td id="T_c1a5e_row7_col8" class="data row7 col8" >0.0337</td>
#       <td id="T_c1a5e_row7_col9" class="data row7 col9" >0.0550</td>
#       <td id="T_c1a5e_row7_col10" class="data row7 col10" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_c1a5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c1a5e_row8_col0" class="data row8 col0" >BLAND</td>
#       <td id="T_c1a5e_row

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
sqlDel = f"""
    DELETE FROM profits 
    WHERE name IN ('{stock_list_str}')
    AND quarter < {quarter}
"""
print(sqlDel)
# Out:
#     DELETE FROM profits
#     WHERE name IN ('BTS','TMW','BTSGIF','TR','LHK','BLAND','KYE','IMPACT','PTL','VGI','EPG','TSTH','STANLY')
#     AND quarter < 3

# %%
# Execute with parameters
rp = conlt.execute(text(sqlDel))
rp.rowcount
# Out:
# 0

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.exc import OperationalError
import time

def delete_with_retry(stock_list_str, quarter, max_retries=5):
    """
    Attempt delete operation with retry logic for database locks.
    """
    # Create engine with longer timeout and WAL mode enabled
    engine = create_engine(
        "sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3",
        connect_args={"timeout": 30}  # Wait up to 30 seconds for lock to clear
    )
    
    for attempt in range(max_retries):
        try:
            with engine.connect() as conn:
                # Enable WAL mode for better concurrency (doesn't require transaction)
                conn.execute(text("PRAGMA journal_mode=WAL"))
                
                # Execute delete in its own transaction block
                with conn.begin():  # This starts a new transaction
                    sqlDel = f"""
                        DELETE FROM profits 
                        WHERE name IN ('{stock_list_str}')
                        AND quarter < {quarter}
                    """
                    result = conn.execute(text(sqlDel))
                    rowcount = result.rowcount
                
                # Transaction auto-commits here if no errors
                print(f"✅ Success: Deleted {rowcount} rows")
                return rowcount
                
        except OperationalError as e:
            if "database is locked" in str(e) and attempt < max_retries - 1:
                print(f"⏳ Database locked, retrying in {2 ** attempt} seconds... (Attempt {attempt + 1}/{max_retries})")
                time.sleep(2 ** attempt)  # Exponential backoff
            else:
                print(f"❌ Failed after {max_retries} attempts: {e}")
                raise
        finally:
            # Ensure engine resources are cleaned up
            engine.dispose()

# Use the function
try:
    rows_deleted = delete_with_retry(stock_list_str, quarter)
except Exception as e:
    print(f"Delete operation failed: {e}")
# Out:
# ⏳ Database locked, retrying in 1 seconds... (Attempt 1/5)
# ⏳ Database locked, retrying in 2 seconds... (Attempt 2/5)
# ⏳ Database locked, retrying in 4 seconds... (Attempt 3/5)
# ⏳ Database locked, retrying in 8 seconds... (Attempt 4/5)
# ❌ Failed after 5 attempts: (sqlite3.OperationalError) database is locked
# [SQL: PRAGMA journal_mode=WAL]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Delete operation failed: (sqlite3.OperationalError) database is locked
# [SQL: PRAGMA journal_mode=WAL]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
rp = conpg.execute(text(sqlDel))
rp.rowcount

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = f"""
SELECT * 
FROM tickers
WHERE name IN ('{stock_list_str}')
ORDER BY name"""
print(sql)

pg_tickers = pd.read_sql(sql, conpg)
pg_tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])

# %%
sql = """
SELECT name 
FROM buy
"""
df_buy = pd.read_sql(sql, const)
df_buy.shape

# %%
df_merge = pd.merge(pg_tickers, df_buy, on='name', how='inner')
df_merge

# %%
file_name = 'pub_stock.xlsx'
xsl_file = xsl_path + '\\' + file_name
df_merge[['id','name','sector','market']].to_excel(xsl_file, index=False)

# %% [markdown]
# ### Portfolio that already published

# %%
stock_list = df_buy['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)

# %%
sql = f"""
SELECT *
FROM epss
WHERE publish_date >= '{select_date}'
AND name IN ('{stock_list_str}')
ORDER BY publish_date DESC, name"""
df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)

# %%
conlt.commit()
conlt.close()

# %%
conmy.commit()
conmy.close()
