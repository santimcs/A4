# %% [markdown]
# ## Restart and Run All

# %%
import pandas as pd
import os
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

year = "2025"
quarter = "3"
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2025-11-30 11:00:17

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
ORDER BY publish_date DESC LIMIT 2
"""
sql = sql % (year, quarter)
print(sql)

df_tmp = pd.read_sql(sql, conlt)
df_tmp
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 3
# ORDER BY publish_date DESC LIMIT 2
#       id  name  year  quarter    q_amt   y_amt    aq_amt  ay_amt  q_eps  \
# 0  24830  GULF  2025        3  7274297       0  71145776       0   0.49
# 1  24814    AJ  2025        3  -169001 -164130   -378325 -247507  -0.28
#
#    y_eps  aq_eps  ay_eps  ticker_id publish_date
# 0   0.00    4.76     0.0        653   2025-11-22
# 1  -0.28   -0.63    -0.5         12   2025-11-17

# %%
today = date(2025, 10, 24)
select_date = today.strftime("%Y-%m-%d")
select_date
# Out:
# '2025-10-24'

# %% [markdown]
# ### Tables in the process

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Excel path (xsl_path): {xsl_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Quarterly
# Base path: C:\Users\PC1\OneDrive\A5
# Data path (dat_path): C:\Users\PC1\OneDrive\A5\Data
# Excel path (xsl_path): C:\Users\PC1\OneDrive\A5\Excel
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()

format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:,.2f}%','acc_pct':'{:,.2f}%'
              }

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= '%s'
ORDER BY id DESC
"""
sql = sql % (year, quarter, select_date)
print(sql)

df_epss_inp = pd.read_sql(sql, conlt)
df_epss_inp.tail().style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 3
# AND publish_date >= '2025-10-24'
# ORDER BY id DESC
# <style type="text/css">
# </style>
# <table id="T_b2b36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2b36_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b2b36_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_b2b36_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_b2b36_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_b2b36_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_b2b36_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_b2b36_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_b2b36_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_b2b36_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_b2b36_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_b2b36_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_b2b36_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_b2b36_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_b2b36_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2b36_level0_row0" class="row_heading level0 row0" >179</th>
#       <td id="T_b2b36_row0_col0" class="data row0 col0" >24664</td>
#       <td id="T_b2b36_row0_col1" class="data row0 col1" >TU</td>
#       <td id="T_b2b36_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_b2b36_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_b2b36_row0_col4" class="data row0 col4" >1,304,355</td>
#       <td id="T_b2b36_row0_col5" class="data row0 col5" >1,400,223</td>
#       <td id="T_b2b36_row0_col6" class="data row0 col6" >3,596,173</td>
#       <td id="T_b2b36_row0_col7" class="data row0 col7" >3,771,905</td>
#       <td id="T_b2b36_row0_col8" class="data row0 col8" >0.3400</td>
#       <td id="T_b2b36_row0_col9" class="data row0 col9" >0.3000</td>
#       <td id="T_b2b36_row0_col10" class="data row0 col10" >0.9000</td>
#       <td id="T_b2b36_row0_col11" class="data row0 col11" >0.8100</td>
#       <td id="T_b2b36_row0_col12" class="data row0 col12" >582</td>
#       <td id="T_b2b36_row0_col13" class="data row0 col13" >2025-11-03</td>
#     </tr>
#     <tr>
#       <th id="T_b2b36_level0_row1" class="row_heading level0 row1" >180</th>
#       <td id="T_b2b36_row1_col0" class="data row1 col0" >24662</td>
#       <td id="T_b2b36_row1_col1" class="data row1 col1" >DELTA</td>
#       <td id="T_b2b36_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_b2b36_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_b2b36_row1_col4" class="data row1 col4" >7,441,375</td>
#       <td id="T_b2b36_row1_col5" class="data row1 col5" >5,910,895</td>
#       <td id="T_b2b36_row1_col6" class="data row1 col6" >17,558,557</td>
#       <td id="T_b2b36_row1_col7" class="data row1 col7" >16,783,428</td>
#       <td id="T_b2b36_row1_col8" class="data row1 col8" >0.6000</td>
#       <td id="T_b2b36_row1_col9" class="data row1 col9" >0.4700</td>
#       <td id="T_b2b36_row1_col10" class="data row1 col10" >1.4100</td>
#       <td id="T_b2b36_row1_col11" class="data row1 col11" >1.3500</td>
#       <td id="T_b2b36_row1_col12" class="data row1 col12" >138</td>
#       <td id="T_b2b36_row1_col13" class="data row1 col13" >2025-10-24</td>
#     </tr>
#     <tr>
#       <th id="T_b2b36_level0_row2" class="row_heading level0 row2" >181</th>
#       <td id="T_b2b36_row2_col0" class="data row2 col0" >24661</td>
#       <td id="T_b2b36_row2_col1" class="data row2 col1" >MST</td>
#       <td id="T_b2b36_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_b2b36_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_b2b36_row2_col4" class="data row2 col4" >64,116</td>
#       <td id="T_b2b36_row2_col5" class="data row2 col5" >146,581</td>
#       <td id="T_b2b36_row2_col6" class="data row2 col6" >197,996</td>
#       <td id="T_b2b36_row2_col7" class="data row2 col7" >364,717</td>
#       <td id="T_b2b36_row2_col8" class="data row2 col8" >0.1100</td>
#       <td id="T_b2b36_row2_col9" class="data row2 col9" >0.2600</td>
#       <td id="T_b2b36_row2_col10" class="data row2 col10" >0.3500</td>
#       <td id="T_b2b36_row2_col11" class="data row2 col11" >0.6400</td>
#       <td id="T_b2b36_row2_col12" class="data row2 col12" >290</td>
#       <td id="T_b2b36_row2_col13" class="data row2 col13" >2025-10-27</td>
#     </tr>
#     <tr>
#       <th id="T_b2b36_level0_row3" class="row_heading level0 row3" >182</th>
#       <td id="T_b2b36_row3_col0" class="data row3 col0" >24660</td>
#       <td id="T_b2b36_row3_col1" class="data row3 col1" >SCC</td>
#       <td id="T_b2b36_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_b2b36_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_b2b36_row3_col4" class="data row3 col4" >-669,143</td>
#       <td id="T_b2b36_row3_col5" class="data row3 col5" >721,289</td>
#       <td id="T_b2b36_row3_col6" class="data row3 col6" >17,766,991</td>
#       <td id="T_b2b36_row3_col7" class="data row3 col7" >6,854,075</td>
#       <td id="T_b2b36_row3_col8" class="data row3 col8" >-0.5600</td>
#       <td id="T_b2b36_row3_col9" class="data row3 col9" >0.6000</td>
#       <td id="T_b2b36_row3_col10" class="data row3 col10" >14.8100</td>
#       <td id="T_b2b36_row3_col11" class="data row3 col11" >5.7100</td>
#       <td id="T_b2b36_row3_col12" class="data row3 col12" >427</td>
#       <td id="T_b2b36_row3_col13" class="data row3 col13" >2025-10-29</td>
#     </tr>
#     <tr>
#       <th id="T_b2b36_level0_row4" class="row_heading level0 row4" >183</th>
#       <td id="T_b2b36_row4_col0" class="data row4 col0" >24659</td>
#       <td id="T_b2b36_row4_col1" class="data row4 col1" >PTTEP</td>
#       <td id="T_b2b36_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_b2b36_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_b2b36_row4_col4" class="data row4 col4" >12,695,087</td>
#       <td id="T_b2b36_row4_col5" class="data row4 col5" >17,864,571</td>
#       <td id="T_b2b36_row4_col6" class="data row4 col6" >42,771,323</td>
#       <td id="T_b2b36_row4_col7" class="data row4 col7" >60,525,063</td>
#       <td id="T_b2b36_row4_col8" class="data row4 col8" >3.1900</td>
#       <td id="T_b2b36_row4_col9" class="data row4 col9" >4.5000</td>
#       <td id="T_b2b36_row4_col10" class="data row4 col10" >10.7700</td>
#       <td id="T_b2b36_row4_col11" class="data row4 col11" >15.2500</td>
#       <td id="T_b2b36_row4_col12" class="data row4 col12" >384</td>
#       <td id="T_b2b36_row4_col13" class="data row4 col13" >2025-10-30</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_epss_inp["yoy_gain"] = df_epss_inp["q_amt"] - df_epss_inp["y_amt"]
df_epss_inp["yoy_pct"] = round(df_epss_inp["yoy_gain"] / abs(df_epss_inp["y_amt"]) * 100, 2)
df_epss_inp["acc_gain"] = df_epss_inp["aq_amt"] - df_epss_inp["ay_amt"]
df_epss_inp["acc_pct"] = round(df_epss_inp["acc_gain"] / abs(df_epss_inp["ay_amt"]) * 100,2)

df_aggr = df_epss_inp[colt]
df_aggr.tail().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd7c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd7c6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bd7c6_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_bd7c6_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_bd7c6_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_bd7c6_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_bd7c6_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_bd7c6_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_bd7c6_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_bd7c6_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_bd7c6_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_bd7c6_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd7c6_level0_row0" class="row_heading level0 row0" >179</th>
#       <td id="T_bd7c6_row0_col0" class="data row0 col0" >TU</td>
#       <td id="T_bd7c6_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_bd7c6_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_bd7c6_row0_col3" class="data row0 col3" >1,304,355</td>
#       <td id="T_bd7c6_row0_col4" class="data row0 col4" >1,400,223</td>
#       <td id="T_bd7c6_row0_col5" class="data row0 col5" >-95,868</td>
#       <td id="T_bd7c6_row0_col6" class="data row0 col6" >-6.85%</td>
#       <td id="T_bd7c6_row0_col7" class="data row0 col7" >3,596,173</td>
#       <td id="T_bd7c6_row0_col8" class="data row0 col8" >3,771,905</td>
#       <td id="T_bd7c6_row0_col9" class="data row0 col9" >-175,732</td>
#       <td id="T_bd7c6_row0_col10" class="data row0 col10" >-4.66%</td>
#     </tr>
#     <tr>
#       <th id="T_bd7c6_level0_row1" class="row_heading level0 row1" >180</th>
#       <td id="T_bd7c6_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_bd7c6_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_bd7c6_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_bd7c6_row1_col3" class="data row1 col3" >7,441,375</td>
#       <td id="T_bd7c6_row1_col4" class="data row1 col4" >5,910,895</td>
#       <td id="T_bd7c6_row1_col5" class="data row1 col5" >1,530,480</td>
#       <td id="T_bd7c6_row1_col6" class="data row1 col6" >25.89%</td>
#       <td id="T_bd7c6_row1_col7" class="data row1 col7" >17,558,557</td>
#       <td id="T_bd7c6_row1_col8" class="data row1 col8" >16,783,428</td>
#       <td id="T_bd7c6_row1_col9" class="data row1 col9" >775,129</td>
#       <td id="T_bd7c6_row1_col10" class="data row1 col10" >4.62%</td>
#     </tr>
#     <tr>
#       <th id="T_bd7c6_level0_row2" class="row_heading level0 row2" >181</th>
#       <td id="T_bd7c6_row2_col0" class="data row2 col0" >MST</td>
#       <td id="T_bd7c6_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_bd7c6_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_bd7c6_row2_col3" class="data row2 col3" >64,116</td>
#       <td id="T_bd7c6_row2_col4" class="data row2 col4" >146,581</td>
#       <td id="T_bd7c6_row2_col5" class="data row2 col5" >-82,465</td>
#       <td id="T_bd7c6_row2_col6" class="data row2 col6" >-56.26%</td>
#       <td id="T_bd7c6_row2_col7" class="data row2 col7" >197,996</td>
#       <td id="T_bd7c6_row2_col8" class="data row2 col8" >364,717</td>
#       <td id="T_bd7c6_row2_col9" class="data row2 col9" >-166,721</td>
#       <td id="T_bd7c6_row2_col10" class="data row2 col10" >-45.71%</td>
#     </tr>
#     <tr>
#       <th id="T_bd7c6_level0_row3" class="row_heading level0 row3" >182</th>
#       <td id="T_bd7c6_row3_col0" class="data row3 col0" >SCC</td>
#       <td id="T_bd7c6_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_bd7c6_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_bd7c6_row3_col3" class="data row3 col3" >-669,143</td>
#       <td id="T_bd7c6_row3_col4" class="data row3 col4" >721,289</td>
#       <td id="T_bd7c6_row3_col5" class="data row3 col5" >-1,390,432</td>
#       <td id="T_bd7c6_row3_col6" class="data row3 col6" >-192.77%</td>
#       <td id="T_bd7c6_row3_col7" class="data row3 col7" >17,766,991</td>
#       <td id="T_bd7c6_row3_col8" class="data row3 col8" >6,854,075</td>
#       <td id="T_bd7c6_row3_col9" class="data row3 col9" >10,912,916</td>
#       <td id="T_bd7c6_row3_col10" class="data row3 col10" >159.22%</td>
#     </tr>
#     <tr>
#       <th id="T_bd7c6_level0_row4" class="row_heading level0 row4" >183</th>
#       <td id="T_bd7c6_row4_col0" class="data row4 col0" >PTTEP</td>
#       <td id="T_bd7c6_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_bd7c6_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_bd7c6_row4_col3" class="data row4 col3" >12,695,087</td>
#       <td id="T_bd7c6_row4_col4" class="data row4 col4" >17,864,571</td>
#       <td id="T_bd7c6_row4_col5" class="data row4 col5" >-5,169,484</td>
#       <td id="T_bd7c6_row4_col6" class="data row4 col6" >-28.94%</td>
#       <td id="T_bd7c6_row4_col7" class="data row4 col7" >42,771,323</td>
#       <td id="T_bd7c6_row4_col8" class="data row4 col8" >60,525,063</td>
#       <td id="T_bd7c6_row4_col9" class="data row4 col9" >-17,753,740</td>
#       <td id="T_bd7c6_row4_col10" class="data row4 col10" >-29.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_1 = df_aggr.q_amt > 110_000
df_aggr.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8783">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8783_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b8783_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_b8783_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_b8783_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_b8783_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_b8783_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_b8783_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8783_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_b8783_row0_col0" class="data row0 col0" >TPIPP</td>
#       <td id="T_b8783_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_b8783_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_b8783_row0_col3" class="data row0 col3" >491,652</td>
#       <td id="T_b8783_row0_col4" class="data row0 col4" >833,341</td>
#       <td id="T_b8783_row0_col5" class="data row0 col5" >-341,689</td>
#       <td id="T_b8783_row0_col6" class="data row0 col6" >-41.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_b8783_row1_col0" class="data row1 col0" >TPIPL</td>
#       <td id="T_b8783_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_b8783_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_b8783_row1_col3" class="data row1 col3" >281,035</td>
#       <td id="T_b8783_row1_col4" class="data row1 col4" >-392,543</td>
#       <td id="T_b8783_row1_col5" class="data row1 col5" >673,578</td>
#       <td id="T_b8783_row1_col6" class="data row1 col6" >171.59%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_b8783_row2_col0" class="data row2 col0" >THANI</td>
#       <td id="T_b8783_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_b8783_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_b8783_row2_col3" class="data row2 col3" >300,620</td>
#       <td id="T_b8783_row2_col4" class="data row2 col4" >79,786</td>
#       <td id="T_b8783_row2_col5" class="data row2 col5" >220,834</td>
#       <td id="T_b8783_row2_col6" class="data row2 col6" >276.78%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_b8783_row3_col0" class="data row3 col0" >TCAP</td>
#       <td id="T_b8783_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_b8783_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_b8783_row3_col3" class="data row3 col3" >2,078,432</td>
#       <td id="T_b8783_row3_col4" class="data row3 col4" >1,645,736</td>
#       <td id="T_b8783_row3_col5" class="data row3 col5" >432,696</td>
#       <td id="T_b8783_row3_col6" class="data row3 col6" >26.29%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_b8783_row4_col0" class="data row4 col0" >SVI</td>
#       <td id="T_b8783_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_b8783_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_b8783_row4_col3" class="data row4 col3" >269,744</td>
#       <td id="T_b8783_row4_col4" class="data row4 col4" >164,791</td>
#       <td id="T_b8783_row4_col5" class="data row4 col5" >104,953</td>
#       <td id="T_b8783_row4_col6" class="data row4 col6" >63.69%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_b8783_row5_col0" class="data row5 col0" >SSP</td>
#       <td id="T_b8783_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_b8783_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_b8783_row5_col3" class="data row5 col3" >111,736</td>
#       <td id="T_b8783_row5_col4" class="data row5 col4" >113,660</td>
#       <td id="T_b8783_row5_col5" class="data row5 col5" >-1,924</td>
#       <td id="T_b8783_row5_col6" class="data row5 col6" >-1.69%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_b8783_row6_col0" class="data row6 col0" >SPRC</td>
#       <td id="T_b8783_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_b8783_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_b8783_row6_col3" class="data row6 col3" >1,578,587</td>
#       <td id="T_b8783_row6_col4" class="data row6 col4" >-2,216,364</td>
#       <td id="T_b8783_row6_col5" class="data row6 col5" >3,794,951</td>
#       <td id="T_b8783_row6_col6" class="data row6 col6" >171.22%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row7" class="row_heading level0 row7" >18</th>
#       <td id="T_b8783_row7_col0" class="data row7 col0" >OR</td>
#       <td id="T_b8783_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_b8783_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_b8783_row7_col3" class="data row7 col3" >2,614,259</td>
#       <td id="T_b8783_row7_col4" class="data row7 col4" >-1,608,745</td>
#       <td id="T_b8783_row7_col5" class="data row7 col5" >4,223,004</td>
#       <td id="T_b8783_row7_col6" class="data row7 col6" >262.50%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_b8783_row8_col0" class="data row8 col0" >ONEE</td>
#       <td id="T_b8783_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_b8783_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_b8783_row8_col3" class="data row8 col3" >205,566</td>
#       <td id="T_b8783_row8_col4" class="data row8 col4" >163,586</td>
#       <td id="T_b8783_row8_col5" class="data row8 col5" >41,980</td>
#       <td id="T_b8783_row8_col6" class="data row8 col6" >25.66%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row9" class="row_heading level0 row9" >20</th>
#       <td id="T_b8783_row9_col0" class="data row9 col0" >MEGA</td>
#       <td id="T_b8783_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_b8783_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_b8783_row9_col3" class="data row9 col3" >494,188</td>
#       <td id="T_b8783_row9_col4" class="data row9 col4" >382,592</td>
#       <td id="T_b8783_row9_col5" class="data row9 col5" >111,596</td>
#       <td id="T_b8783_row9_col6" class="data row9 col6" >29.17%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row10" class="row_heading level0 row10" >23</th>
#       <td id="T_b8783_row10_col0" class="data row10 col0" >ILM</td>
#       <td id="T_b8783_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_b8783_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_b8783_row10_col3" class="data row10 col3" >182,184</td>
#       <td id="T_b8783_row10_col4" class="data row10 col4" >193,775</td>
#       <td id="T_b8783_row10_col5" class="data row10 col5" >-11,591</td>
#       <td id="T_b8783_row10_col6" class="data row10 col6" >-5.98%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row11" class="row_heading level0 row11" >25</th>
#       <td id="T_b8783_row11_col0" class="data row11 col0" >HTC</td>
#       <td id="T_b8783_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_b8783_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_b8783_row11_col3" class="data row11 col3" >130,964</td>
#       <td id="T_b8783_row11_col4" class="data row11 col4" >129,264</td>
#       <td id="T_b8783_row11_col5" class="data row11 col5" >1,700</td>
#       <td id="T_b8783_row11_col6" class="data row11 col6" >1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_b8783_level0_row12" class="row_heading level0 row12" >26</th>
#       <td id="T_b8783_row12_col0" class="data row12 col0" >HMPRO</td>
#       <td id="T_b8783_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_b8783_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_b8783_row12_col3" class="data row12 col3" >1,303,567</td>
#       <td id="T_b8783

# %%
criteria_2 = df_aggr.y_amt > 100_000
df_aggr.loc[criteria_2, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_27df2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27df2_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_27df2_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_27df2_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_27df2_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_27df2_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_27df2_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_27df2_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27df2_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_27df2_row0_col0" class="data row0 col0" >TPIPP</td>
#       <td id="T_27df2_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_27df2_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_27df2_row0_col3" class="data row0 col3" >491,652</td>
#       <td id="T_27df2_row0_col4" class="data row0 col4" >833,341</td>
#       <td id="T_27df2_row0_col5" class="data row0 col5" >-341,689</td>
#       <td id="T_27df2_row0_col6" class="data row0 col6" >-41.00%</td>
#     </tr>
#     <tr>
#       <th id="T_27df2_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_27df2_row1_col0" class="data row1 col0" >TCAP</td>
#       <td id="T_27df2_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T
row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_27df2_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_27df2_row9_col3" class="data row9 col3" >182,184</td>
#       <td id="T_27df2_row9_col4" class="data row9 col4" >193,775</td>
#       <td id="T_27df2_row9_col5" class="data row9 col5" >-11,591</td>
#       <td id="T_27df2_row9_col6" class="data row9 col6" >-5.98%</td>
#     </tr>
#     <tr>
#       <th id="T_27df2_level0_row10" class="row_heading level0 row10" >24</th>
#       <td id="T_27df2_row10_col0" class="data row10 col0" >III</td>
#       <td id="T_27df2_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_27df2_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_27df2_row10_col3" class="data row10 col3" >101,220</td>
#       <td id="T_27df2_row10_col4" class="data row10 col4" >100,357</td>
#       <td id="T_27df2_row10_col5" class="data row10 col5" >863</td>
#       <td id="T_27df2_row10_col6" class="data row10 col6" >0.86%</td>
#     </tr>
#     <tr>
#       <th id="T_27df2_level0_row11" class="row_heading level0 row11" >25</th>
#       <td id="T_27df2_row11_col0" class="data row11 col0" >HTC</td>
#       <td id="T_27df2_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_27df2_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_27df2_row11_col3" class="data row11 col3" >130,964</td>
#       <td id="T_27df2_row11_col4" class="data row11 col4" >129,264</td>
#       <td id="T_27df2_row11_col5" class="data row11 col5" >1,700</td>
#       <td id="T_27df2_row11_col6" class="data row11 col6" >1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_27df2_level0_row12" class="row_heading level0 row12" >26</th>
#       <td id="T_27df2_row12_col0" class="data row12 col0" >HMPRO</td>
#       <td id="T_27df2_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_27df2_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_27df2_row12_col3" class="data row12 col3" >1,303,567</td>
#       <td id="T_27df2_row12_col4" cl

# %%
criteria_3 = df_aggr.yoy_pct > 10.00
df_aggr.loc[criteria_3, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4b9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4b9b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a4b9b_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_a4b9b_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_a4b9b_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_a4b9b_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_a4b9b_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_a4b9b_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4b9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4b9b_row0_col0" class="data row0 col0" >WORK</td>
#       <td id="T_a4b9b_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_a4b9b_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_a4b9b_row0_col3" class="data row0 col3" >34,578</td>
#       <td id="T_a4b9b_row0_col4" class="data row0 col4" >-17,343</td>
#       <td id="T_a4b9b_row0_col5" class="data row0 col5" >51,921</td>
#       <td id="T_a4b9b_row0_col6" class="data row0 col6" >299.38%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4b9b_row1_col0" class="data row1 col0" >WICE</td>
#       <td id="T_a4b9b_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_a4b9b_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_a4b9b_row1_col3" class="data row1 col3" >26,752</td>
#       <td id="T_a4b9b_row1_col4" class="data row1 col4" >18,162</td>
#       <td id="T_a4b9b_row1_col5" class="data row1 col5" >8,590</td>
#       <td id="T_a4b9b_row1_col6" class="data row1 col6" >47.30%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4b9b_row2_col0" class="data row2 col0" >TYCN</td>
#       <td id="T_a4b9b_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_a4b9b_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_a4b9b_row2_col3" class="data row2 col3" >64,622</td>
#       <td id="T_a4b9b_row2_col4" class="data row2 col4" >-185,712</td>
#       <td id="T_a4b9b_row2_col5" class="data row2 col5" >250,334</td>
#       <td id="T_a4b9b_row2_col6" class="data row2 col6" >134.80%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_a4b9b_row3_col0" class="data row3 col0" >TPIPL</td>
#       <td id="T_a4b9b_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_a4b9b_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_a4b9b_row3_col3" class="data row3 col3" >281,035</td>
#       <td id="T_a4b9b_row3_col4" class="data row3 col4" >-392,543</td>
#       <td id="T_a4b9b_row3_col5" class="data row3 col5" >673,578</td>
#       <td id="T_a4b9b_row3_col6" class="data row3 col6" >171.59%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_a4b9b_row4_col0" class="data row4 col0" >THANI</td>
#       <td id="T_a4b9b_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_a4b9b_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_a4b9b_row4_col3" class="data row4 col3" >300,620</td>
#       <td id="T_a4b9b_row4_col4" class="data row4 col4" >79,786</td>
#       <td id="T_a4b9b_row4_col5" class="data row4 col5" >220,834</td>
#       <td id="T_a4b9b_row4_col6" class="data row4 col6" >276.78%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_a4b9b_row5_col0" class="data row5 col0" >TCAP</td>
#       <td id="T_a4b9b_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_a4b9b_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_a4b9b_row5_col3" class="data row5 col3" >2,078,432</td>
#       <td id="T_a4b9b_row5_col4" class="data row5 col4" >1,645,736</td>
#       <td id="T_a4b9b_row5_col5" class="data row5 col5" >432,696</td>
#       <td id="T_a4b9b_row5_col6" class="data row5 col6" >26.29%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_a4b9b_row6_col0" class="data row6 col0" >SVI</td>
#       <td id="T_a4b9b_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_a4b9b_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_a4b9b_row6_col3" class="data row6 col3" >269,744</td>
#       <td id="T_a4b9b_row6_col4" class="data row6 col4" >164,791</td>
#       <td id="T_a4b9b_row6_col5" class="data row6 col5" >104,953</td>
#       <td id="T_a4b9b_row6_col6" class="data row6 col6" >63.69%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_a4b9b_row7_col0" class="data row7 col0" >SPRC</td>
#       <td id="T_a4b9b_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_a4b9b_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_a4b9b_row7_col3" class="data row7 col3" >1,578,587</td>
#       <td id="T_a4b9b_row7_col4" class="data row7 col4" >-2,216,364</td>
#       <td id="T_a4b9b_row7_col5" class="data row7 col5" >3,794,951</td>
#       <td id="T_a4b9b_row7_col6" class="data row7 col6" >171.22%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_a4b9b_row8_col0" class="data row8 col0" >SPCG</td>
#       <td id="T_a4b9b_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_a4b9b_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_a4b9b_row8_col3" class="data row8 col3" >76,941</td>
#       <td id="T_a4b9b_row8_col4" class="data row8 col4" >66,137</td>
#       <td id="T_a4b9b_row8_col5" class="data row8 col5" >10,804</td>
#       <td id="T_a4b9b_row8_col6" class="data row8 col6" >16.34%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row9" class="row_heading level0 row9" >14</th>
#       <td id="T_a4b9b_row9_col0" class="data row9 col0" >S11</td>
#       <td id="T_a4b9b_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_a4b9b_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_a4b9b_row9_col3" class="data row9 col3" >91,432</td>
#       <td id="T_a4b9b_row9_col4" class="data row9 col4" >60,095</td>
#       <td id="T_a4b9b_row9_col5" class="data row9 col5" >31,337</td>
#       <td id="T_a4b9b_row9_col6" class="data row9 col6" >52.15%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row10" class="row_heading level0 row10" >16</th>
#       <td id="T_a4b9b_row10_col0" class="data row10 col0" >PDG</td>
#       <td id="T_a4b9b_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_a4b9b_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_a4b9b_row10_col3" class="data row10 col3" >21,000</td>
#       <td id="T_a4b9b_row10_col4" class="data row10 col4" >13,673</td>
#       <td id="T_a4b9b_row10_col5" class="data row10 col5" >7,327</td>
#       <td id="T_a4b9b_row10_col6" class="data row10 col6" >53.59%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row11" class="row_heading level0 row11" >17</th>
#       <td id="T_a4b9b_row11_col0" class="data row11 col0" >PAP</td>
#       <td id="T_a4b9b_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_a4b9b_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_a4b9b_row11_col3" class="data row11 col3" >20,219</td>
#       <td id="T_a4b9b_row11_col4" class="data row11 col4" >-155,714</td>
#       <td id="T_a4b9b_row11_col5" class="data row11 col5" >175,933</td>
#       <td id="T_a4b9b_row11_col6" class="data row11 col6" >112.98%</td>
#     </tr>
#     <tr>
#       <th id="T_a4b9b_level0_row12" class="row_heading level0 row12" >18</th>
#       <td id="T_a4b9b_row12_col0" class="data row12 col0" >OR</td>
#       <td id="T_a4b9b_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_a4b9b_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_a4b9b_row12_col3" class="data row12 col3" >2,614,259</td>
#       <td id="T_a4b9b_row12_col4" class="da

# %%
df_aggr_criteria = criteria_1 & criteria_2 & criteria_3
#df_aggr_criteria = criteria_1 & criteria_3 
df_aggr.loc[df_aggr_criteria, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_54c85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54c85_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_54c85_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_54c85_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_54c85_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_54c85_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_54c85_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_54c85_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54c85_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_54c85_row0_col0" class="data row0 col0" >TCAP</td>
#       <td id="T_54c85_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_54c85_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_54c85_row0_col3" class="data row0 col3" >2,078,432</td>
#       <td id="T_54c85_row0_col4" class="data row0 col4" >1,645,736</td>
#       <td id="T_54c85_row0_col5" class="data row0 col5" >432,696</td>
#       <td id="T_54c85_row0_col6" class="data row0 col6" >26.29%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_54c85_row1_col0" class="data row1 col0" >SVI</td>
#       <td id="T_54c85_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_54c85_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_54c85_row1_col3" class="data row1 col3" >269,744</td>
#       <td id="T_54c85_row1_col4" class="data row1 col4" >164,791</td>
#       <td id="T_54c85_row1_col5" class="data row1 col5" >104,953</td>
#       <td id="T_54c85_row1_col6" class="data row1 col6" >63.69%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_54c85_row2_col0" class="data row2 col0" >ONEE</td>
#       <td id="T_54c85_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_54c85_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_54c85_row2_col3" class="data row2 col3" >205,566</td>
#       <td id="T_54c85_row2_col4" class="data row2 col4" >163,586</td>
#       <td id="T_54c85_row2_col5" class="data row2 col5" >41,980</td>
#       <td id="T_54c85_row2_col6" class="data row2 col6" >25.66%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_54c85_row3_col0" class="data row3 col0" >MEGA</td>
#       <td id="T_54c85_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_54c85_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_54c85_row3_col3" class="data row3 col3" >494,188</td>
#       <td id="T_54c85_row3_col4" class="data row3 col4" >382,592</td>
#       <td id="T_54c85_row3_col5" class="data row3 col5" >111,596</td>
#       <td id="T_54c85_row3_col6" class="data row3 col6" >29.17%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row4" class="row_heading level0 row4" >29</th>
#       <td id="T_54c85_row4_col0" class="data row4 col0" >GPSC</td>
#       <td id="T_54c85_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_54c85_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_54c85_row4_col3" class="data row4 col3" >1,741,877</td>
#       <td id="T_54c85_row4_col4" class="data row4 col4" >770,066</td>
#       <td id="T_54c85_row4_col5" class="data row4 col5" >971,811</td>
#       <td id="T_54c85_row4_col6" class="data row4 col6" >126.20%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row5" class="row_heading level0 row5" >45</th>
#       <td id="T_54c85_row5_col0" class="data row5 col0" >ADVANC</td>
#       <td id="T_54c85_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_54c85_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_54c85_row5_col3" class="data row5 col3" >12,038,861</td>
#       <td id="T_54c85_row5_col4" class="data row5 col4" >8,788,129</td>
#       <td id="T_54c85_row5_col5" class="data row5 col5" >3,250,732</td>
#       <td id="T_54c85_row5_col6" class="data row5 col6" >36.99%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row6" class="row_heading level0 row6" >46</th>
#       <td id="T_54c85_row6_col0" class="data row6 col0" >ACE</td>
#       <td id="T_54c85_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_54c85_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_54c85_row6_col3" class="data row6 col3" >210,777</td>
#       <td id="T_54c85_row6_col4" class="data row6 col4" >110,520</td>
#       <td id="T_54c85_row6_col5" class="data row6 col5" >100,257</td>
#       <td id="T_54c85_row6_col6" class="data row6 col6" >90.71%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row7" class="row_heading level0 row7" >50</th>
#       <td id="T_54c85_row7_col0" class="data row7 col0" >CPN</td>
#       <td id="T_54c85_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_54c85_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_54c85_row7_col3" class="data row7 col3" >5,424,336</td>
#       <td id="T_54c85_row7_col4" class="data row7 col4" >4,125,675</td>
#       <td id="T_54c85_row7_col5" class="data row7 col5" >1,298,661</td>
#       <td id="T_54c85_row7_col6" class="data row7 col6" >31.48%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row8" class="row_heading level0 row8" >55</th>
#       <td id="T_54c85_row8_col0" class="data row8 col0" >WHA</td>
#       <td id="T_54c85_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_54c85_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_54c85_row8_col3" class="data row8 col3" >634,251</td>
#       <td id="T_54c85_row8_col4" class="data row8 col4" >459,200</td>
#       <td id="T_54c85_row8_col5" class="data row8 col5" >175,051</td>
#       <td id="T_54c85_row8_col6" class="data row8 col6" >38.12%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row9" class="row_heading level0 row9" >58</th>
#       <td id="T_54c85_row9_col0" class="data row9 col0" >PRM</td>
#       <td id="T_54c85_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_54c85_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_54c85_row9_col3" class="data row9 col3" >563,386</td>
#       <td id="T_54c85_row9_col4" class="data row9 col4" >449,775</td>
#       <td id="T_54c85_row9_col5" class="data row9 col5" >113,611</td>
#       <td id="T_54c85_row9_col6" class="data row9 col6" >25.26%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row10" class="row_heading level0 row10" >59</th>
#       <td id="T_54c85_row10_col0" class="data row10 col0" >BGRIM</td>
#       <td id="T_54c85_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_54c85_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_54c85_row10_col3" class="data row10 col3" >520,997</td>
#       <td id="T_54c85_row10_col4" class="data row10 col4" >162,749</td>
#       <td id="T_54c85_row10_col5" class="data row10 col5" >358,248</td>
#       <td id="T_54c85_row10_col6" class="data row10 col6" >220.12%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row11" class="row_heading level0 row11" >61</th>
#       <td id="T_54c85_row11_col0" class="data row11 col0" >RATCH</td>
#       <td id="T_54c85_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_54c85_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_54c85_row11_col3" class="data row11 col3" >2,168,347</td>
#       <td id="T_54c85_row11_col4" class="data row11 col4" >1,658,122</td>
#       <td id="T_54c85_row11_col5" class="data row11 col5" >510,225</td>
#       <td id="T_54c85_row11_col6" class="data row11 col6" >30.77%</td>
#     </tr>
#     <tr>
#       <th id="T_54c85_level0_row12" class="row_heading level0 row12" >64</th>
#       <td id="T_54c85_row12_col0" class="data row12 col0" >CK</td>
#       <td id="T_54c85_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_54c85_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_54c85_row12_col3" class="data row12 col3" >1,738,865</td>
#       <td id="

# %%
df_aggr[df_aggr_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5783">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5783_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_f5783_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_f5783_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_f5783_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_f5783_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_f5783_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_f5783_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_f5783_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_f5783_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_f5783_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_f5783_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5783_level0_row0" class="row_heading level0 row0" >46</th>
#       <td id="T_f5783_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_f5783_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_f5783_row0_col2" class="data row0 col2" >3</td>
#       <td id="T
row4_col2" class="data row4 col2" >3</td>
#       <td id="T_f5783_row4_col3" class="data row4 col3" >520,997</td>
#       <td id="T_f5783_row4_col4" class="data row4 col4" >162,749</td>
#       <td id="T_f5783_row4_col5" class="data row4 col5" >358,248</td>
#       <td id="T_f5783_row4_col6" class="data row4 col6" >220.12%</td>
#       <td id="T_f5783_row4_col7" class="data row4 col7" >1,181,777</td>
#       <td id="T_f5783_row4_col8" class="data row4 col8" >769,917</td>
#       <td id="T_f5783_row4_col9" class="data row4 col9" >411,860</td>
#       <td id="T_f5783_row4_col10" class="data row4 col10" >53.49%</td>
#     </tr>
#     <tr>
#       <th id="T_f5783_level0_row5" class="row_heading level0 row5" >110</th>
#       <td id="T_f5783_row5_col0" class="data row5 col0" >BLA</td>
#       <td id="T_f5783_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_f5783_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_f5783_row5_col3" class="data row5 col3" >2,305,941</td>
#       <td id="T_f5783_row5_col4" class="data row5 col4" >1,497,610</td>
#       <td id="T_f5783_row5_col5" class="data row5 col5" >808,331</td>
#       <td id="T_f5783_row5_col6" class="data row5 col6" >53.97%</td>
#       <td id="T_f5783_row5_col7" class="data row5 col7" >5,623,411</td>
#       <td id="T_f5783_row5_col8" class="data row5 col8" >3,602,439</td>
#       <td id="T_f5783_row5_col9" class="data row5 col9" >2,020,972</td>
#       <td id="T_f5783_row5_col10" class="data row5 col10" >56.10%</td>
#     </tr>
#     <tr>
#       <th id="T_f5783_level0_row6" class="row_heading level0 row6" >64</th>
#       <td id="T_f5783_row6_col0" class="data row6 col0" >CK</td>
#       <td id="T_f5783_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_f5783_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_f5783_row6_col3" class="data row6 col3" >1,738,865</td>
#       <td id="T_f5783_row6_col4" class="data row6 col4" >1,007,708</td>
#       <td id="T_f5783_row6_col5" class="data row6 col5" >731,157</td>
#       <td id="T_f5783_row6_col6" class="data row6 col6" >72.56%</td>
#       <td id="T_f5783_row6_col7" class="data row6 col7" >2,883,871</td>
#       <td id="T_f5783_row6_col8" class="data row6 col8" >1,616,793</td>
#       <td id="T_f5783_row6_col9" class="data row6 col9" >1,267,078</td>
#       <td id="T_f5783_row6_col10" class="data row6 col10" >78.37%</td>
#     </tr>
#     <tr>
#       <th id="T_f5783_level0_row7" class="row_heading level0 row7" >113</th>
#       <td id="T_f5783_row7_col0" class="data row7 col0" >COM7</td>
#       <td id="T_f5783_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_f5783_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_f5783_row7_col3" class="data row7 col3" >872,025</td>
#       <td id="T_f5783_row7_col4" class="data row7 col4" >709,504</td>
#       <td id="T_f5783_row7_col5" class="data row7 col5" >162,521</td>
#       <td id="T_f5783_row7_col6" class="data row7 col6" >22.91%</td>
#       <td id="T_f5783_row7_col7" class="data row7 col7" >2,855,833</td>
#       <td id="T_f5783_row7_col8" class="data row7 col8" >2,293,479</td>
#       <td id="T_f5783_row7_col9" class="data row7 col9" >562,354</td>
#       <td id="T_f5783_row7_col10" class="data row7 col10" >24.52%</td>
#     </tr>
#     <tr>
#       <th id="T_f5783_level0_row8" class="row_heading level0 row8" >106</th>
#       <

# %%
names = df_epss_inp['name']
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'WORK', 'WICE', 'TYCN', 'TSE', 'TPIPP', 'TPIPL', 'THANI', 'TCAP', 'SVI', 'SUPER', 'SSP', 'SPRIME', 'SPRC', 'SPCG', 'S11', 'RBF', 'PDG', 'PAP', 'OR', 'ONEE', 'MEGA', 'LALIN', 'IMH', 'ILM', 'III', 'HTC', 'HMPRO', 'GULF', 'HFT', 'GPSC', 'GLOBAL', 'FORTH', 'DCC', 'BKIH', 'BH', 'BGC', 'BEC', 'BE8', 'BCPG', 'BCP', 'ASW', 'ASIAN', 'ANAN', 'AJ', 'AIT', 'ADVANC', 'ACE', 'POPF', 'SJWD', 'CHG', 'CPN', 'SAPPE', 'SIRI', 'ROJNA', 'LPH', 'WHA', 'WHAUP', 'PSH', 'PRM', 'BGRIM', 'TIPH', 'RATCH', 'VIBHA', 'CENTEL', 'CK', 'CBG', 'EGCO', 'TKS', 'ORI', '3BBIF', 'BCH', 'SENA', 'TVO', 'PCSGH', 'TQM', 'MINT', 'LPN', 'AP', 'GUNKUL', 'ASP', 'SC', 'SCCC', 'SNC', 'CPNCG', 'BEM', 'LH', 'TTA', 'SAWAD', 'PREB', 'NOBLE', 'TKN', 'FSMART', 'PTG', 'CPNREIT', 'CPF', 'SYNEX', 'TOA', 'DIF', 'VNG', 'DRT', 'MBAX', 'SUPEREIF', 'AWC', 'AIE', 'UTP', 'HANA', 'CPALL', 'CRC', 'BDMS', 'M', 'BLA', 'TK', 'KGI', 'COM7', 'OSP', 'RS', 'EASTW', 'TFG', 'EA', 'RJH', 'THG', 'GRAMMY', 'WHAIR', 'PTT', 'AH', 'BEAUTY', 'BA', 'GFPT', 'ICHI', 'SAT', 'TTW', 'TIPCO', 'KCE', 'PLANB', 'SIS', 'SPALI', 'DCON', 'CPAXT', 'SGP', 'IP', 'MAJOR', 'AMATA', 'BAM', 'TIDLOR', 'MTC', 'JMT', 'JMART', 'WHART', 'SINGER', 'BCT', 'SMPC', 'LIT', 'TTLPF', 'TASCO', 'CKP', 'EGATIF', 'BJC', 'QH', 'BANPU', 'BPP', 'IVL', 'PSL', 'NER', 'GGC', 'IRPC', 'TRUE', 'GC', 'LANNA', 'RCL', 'TOP', 'INOX', 'AIMIRT', 'ASK', 'DOHOME', 'TMT', 'STGT', 'STA', 'MCS', 'PTTGC', 'TU', 'DELTA', 'MST', 'SCC', 'PTTEP'"

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
sql = """
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN (%s)
ORDER BY E.name, year DESC, quarter DESC 
LIMIT 12
"""
sql = sql % (in_p)
print(sql)

epss_stocks = pd.read_sql(sql, conlt)
epss_stocks.style.format(format_dict)
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('WORK', 'WICE', 'TYCN', 'TSE', 'TPIPP', 'TPIPL', 'THANI', 'TCAP', 'SVI', 'SUPER', 'SSP', 'SPRIME', 'SPRC', 'SPCG', 'S11', 'RBF', 'PDG', 'PAP', 'OR', 'ONEE', 'MEGA', 'LALIN', 'IMH', 'ILM', 'III', 'HTC', 'HMPRO', 'GULF', 'HFT', 'GPSC', 'GLOBAL', 'FORTH', 'DCC', 'BKIH', 'BH', 'BGC', 'BEC', 'BE8', 'BCPG', 'BCP', 'ASW', 'ASIAN', 'ANAN', 'AJ', 'AIT', 'ADVANC', 'ACE', 'POPF', 'SJWD', 'CHG', 'CPN', 'SAPPE', 'SIRI', 'ROJNA', 'LPH', 'WHA', 'WHAUP', 'PSH', 'PRM', 'BGRIM', 'TIPH', 'RATCH', 'VIBHA', 'CENTEL', 'CK', 'CBG', 'EGCO', 'TKS', 'ORI', '3BBIF', 'BCH', 'SENA', 'TVO', 'PCSGH', 'TQM', 'MINT', 'LPN', 'AP', 'GUNKUL', 'ASP', 'SC', 'SCCC', 'SNC', 'CPNCG', 'BEM', 'LH', 'TTA', 'SAWAD', 'PREB', 'NOBLE', 'TKN', 'FSMART', 'PTG', 'CPNREIT', 'CPF', 'SYNEX', 'TOA', 'DIF', 'VNG', 'DRT', 'MBAX', 'SUPEREIF', 'AWC', 'AIE', 'UTP', 'HANA', 'CPALL', 'CRC', 'BDMS', 'M', 'BLA', 'TK', 'KGI', 'COM7', 'OSP', 'RS', 'EASTW', 'TFG', 'EA', 'RJH', 'THG', 'GRAMMY', 'WHAIR', 'PTT', 'AH', 'BEAUTY', 'BA', 'GFPT', 'ICHI', 'SAT', 'TTW', 'TIPCO', 'KCE', 'PLANB', 'SIS', 'SPALI', 'DCON', 'CPAXT', 'SGP', 'IP', 'MAJOR', 'AMATA', 'BAM', 'TIDLOR', 'MTC', 'JMT', 'JMART', 'WHART', 'SINGER', 'BCT', 'SMPC', 'LIT', 'TTLPF', 'TASCO', 'CKP', 'EGATIF', 'BJC', 'QH', 'BANPU', 'BPP', 'IVL', 'PSL', 'NER', 'GGC', 'IRPC', 'TRUE', 'GC', 'LANNA', 'RCL', 'TOP', 'INOX', 'AIMIRT', 'ASK', 'DOHOME', 'TMT', 'STGT', 'STA', 'MCS', 'PTTGC', 'TU', 'DELTA', 'MST', 'SCC', 'PTTEP')
# ORDER BY E.name, year DESC, quarter DESC
# LIMIT 12
# <style type="text/css">
# </style>
# <table id="T_34393">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34393_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_34393_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_34393_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_34393_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_34393_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_34393_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_34393_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_34393_level0_col7" class="col_heading level0 col7" >q_eps</th>
#       <th id="T_34393_level0_col8" class="col_heading level0 col8" >y_eps</th>
#       <th id="T_34393_level0_col9" class="col_heading level0 col9" >aq_eps</th>
#       <th id="T_34393_level0_col10" class="col_heading level0 col10" >ay_eps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34393_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34393_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_34393_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_34393_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_34393_row0_col3" class="data row0 col3" >183,813</td>
#       <td id="T_34393_row0_col4" class="data row0 col4" >402,143</td>
#       <td id="T_34393_row0_col5" class="data row0 col5" >614,784</td>
#       <td id="T_34393_row0_col6" class="data row0 col6" >1,317,935</td>
#       <td id="T_34393_row0_col7" class="data row0 col7" >0.0749</td>
#       <td id="T_34393_row0_col8" class="data row0 col8" >0.1638</td>
#       <td id="T_34393_row0_col9" class="data row0 col9" >0.2505</td>
#       <td id="T_34393_row0_col10" class="data row0 col10" >0.5370</td>
#     </tr>
#     <tr>
#       <th id="T_34393_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_34393_row6_col9" class="data row6 col9" >0.0000</td>
#       <td id="T_34393_row6_col10" class="data row6 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34393_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34393_row7_col0" class="data row7 col0" >3BBIF</td>
#       <td id="T_34393_row7_col1" class="data row7 col1" >2023</td>
#       <td id="T_34393_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_34393_row7_col3" class="data row7 col3" >485,501</td>
#       <td id="T_34393_row7_col4" class="data row7 col4" >-790,999</td>
#       <td id="T_34393_row7_col5" class="data row7 col5" >-11,139,183</td>
#       <td id="T_34393_row7_col6" class="data row7 col6" >3,650,406</td>
#       <td id="T_34393_row7_col7" class="data row7 col7" >0.0000</td>
#       <td id="T_34393_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_34393_row7_col9" class="data row7 col9" >0.0000</td>
#       <td id="T_34393_row7_col10" class="data row7 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34393_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34393_row8_col

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
in_p
# Out:
# "'WORK', 'WICE', 'TYCN', 'TSE', 'TPIPP', 'TPIPL', 'THANI', 'TCAP', 'SVI', 'SUPER', 'SSP', 'SPRIME', 'SPRC', 'SPCG', 'S11', 'RBF', 'PDG', 'PAP', 'OR', 'ONEE', 'MEGA', 'LALIN', 'IMH', 'ILM', 'III', 'HTC', 'HMPRO', 'GULF', 'HFT', 'GPSC', 'GLOBAL', 'FORTH', 'DCC', 'BKIH', 'BH', 'BGC', 'BEC', 'BE8', 'BCPG', 'BCP', 'ASW', 'ASIAN', 'ANAN', 'AJ', 'AIT', 'ADVANC', 'ACE', 'POPF', 'SJWD', 'CHG', 'CPN', 'SAPPE', 'SIRI', 'ROJNA', 'LPH', 'WHA', 'WHAUP', 'PSH', 'PRM', 'BGRIM', 'TIPH', 'RATCH', 'VIBHA', 'CENTEL', 'CK', 'CBG', 'EGCO', 'TKS', 'ORI', '3BBIF', 'BCH', 'SENA', 'TVO', 'PCSGH', 'TQM', 'MINT', 'LPN', 'AP', 'GUNKUL', 'ASP', 'SC', 'SCCC', 'SNC', 'CPNCG', 'BEM', 'LH', 'TTA', 'SAWAD', 'PREB', 'NOBLE', 'TKN', 'FSMART', 'PTG', 'CPNREIT', 'CPF', 'SYNEX', 'TOA', 'DIF', 'VNG', 'DRT', 'MBAX', 'SUPEREIF', 'AWC', 'AIE', 'UTP', 'HANA', 'CPALL', 'CRC', 'BDMS', 'M', 'BLA', 'TK', 'KGI', 'COM7', 'OSP', 'RS', 'EASTW', 'TFG', 'EA', 'RJH', 'THG', 'GRAMMY', 'WHAIR', 'PTT', 'AH', 'BEAUTY', 'BA', 'GFPT', 'ICHI', 'SAT', 'TTW', 'TIPCO', 'KCE', 'PLANB', 'SIS', 'SPALI', 'DCON', 'CPAXT', 'SGP', 'IP', 'MAJOR', 'AMATA', 'BAM', 'TIDLOR', 'MTC', 'JMT', 'JMART', 'WHART', 'SINGER', 'BCT', 'SMPC', 'LIT', 'TTLPF', 'TASCO', 'CKP', 'EGATIF', 'BJC', 'QH', 'BANPU', 'BPP', 'IVL', 'PSL', 'NER', 'GGC', 'IRPC', 'TRUE', 'GC', 'LANNA', 'RCL', 'TOP', 'INOX', 'AIMIRT', 'ASK', 'DOHOME', 'TMT', 'STGT', 'STA', 'MCS', 'PTTGC', 'TU', 'DELTA', 'MST', 'SCC', 'PTTEP'"

# %%
sqlDel = text("""
    DELETE FROM profits 
    WHERE name IN ({})
    AND quarter < :quarter
""".format(in_p))

# Execute with parameters
rp = conlt.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 3

# %%
rp = conmy.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 18

# %%
rp = conpg.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 16

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index
# Out:
# Index(['CKP', 'FPT', 'RCL'], dtype='object', name='name')

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index
# Out:
# Index(['CKP', 'FPT', 'RCL'], dtype='object', name='name')

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index
# Out:
# Index(['CKP', 'FPT', 'RCL'], dtype='object', name='name')

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = """
SELECT * 
FROM tickers
WHERE name IN (%s)
ORDER BY name"""
sql = sql % in_p
print(sql)

pg_tickers = pd.read_sql(sql, conpg)
pg_tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('WORK', 'WICE', 'TYCN', 'TSE', 'TPIPP', 'TPIPL', 'THANI', 'TCAP', 'SVI', 'SUPER', 'SSP', 'SPRIME', 'SPRC', 'SPCG', 'S11', 'RBF', 'PDG', 'PAP', 'OR', 'ONEE', 'MEGA', 'LALIN', 'IMH', 'ILM', 'III', 'HTC', 'HMPRO', 'GULF', 'HFT', 'GPSC', 'GLOBAL', 'FORTH', 'DCC', 'BKIH', 'BH', 'BGC', 'BEC', 'BE8', 'BCPG', 'BCP', 'ASW', 'ASIAN', 'ANAN', 'AJ', 'AIT', 'ADVANC', 'ACE', 'POPF', 'SJWD', 'CHG', 'CPN', 'SAPPE', 'SIRI', 'ROJNA', 'LPH', 'WHA', 'WHAUP', 'PSH', 'PRM', 'BGRIM', 'TIPH', 'RATCH', 'VIBHA', 'CENTEL', 'CK', 'CBG', 'EGCO', 'TKS', 'ORI', '3BBIF', 'BCH', 'SENA', 'TVO', 'PCSGH', 'TQM', 'MINT', 'LPN', 'AP', 'GUNKUL', 'ASP', 'SC', 'SCCC', 'SNC', 'CPNCG', 'BEM', 'LH', 'TTA', 'SAWAD', 'PREB', 'NOBLE', 'TKN', 'FSMART', 'PTG', 'CPNREIT', 'CPF', 'SYNEX', 'TOA', 'DIF', 'VNG', 'DRT', 'MBAX', 'SUPEREIF', 'AWC', 'AIE', 'UTP', 'HANA', 'CPALL', 'CRC', 'BDMS', 'M', 'BLA', 'TK', 'KGI', 'COM7', 'OSP', 'RS', 'EASTW', 'TFG', 'EA', 'RJH', 'THG', 'GRAMMY', 'WHAIR', 'PTT', 'AH', 'BEAUTY', 'BA', 'GFPT', 'ICHI', 'SAT', 'TTW', 'TIPCO', 'KCE', 'PLANB', 'SIS', 'SPALI', 'DCON', 'CPAXT', 'SGP', 'IP', 'MAJOR', 'AMATA', 'BAM', 'TIDLOR', 'MTC', 'JMT', 'JMART', 'WHART', 'SINGER', 'BCT', 'SMPC', 'LIT', 'TTLPF', 'TASCO', 'CKP', 'EGATIF', 'BJC', 'QH', 'BANPU', 'BPP', 'IVL', 'PSL', 'NER', 'GGC', 'IRPC', 'TRUE', 'GC', 'LANNA', 'RCL', 'TOP', 'INOX', 'AIMIRT', 'ASK', 'DOHOME', 'TMT', 'STGT', 'STA', 'MCS', 'PTTGC', 'TU', 'DELTA', 'MST', 'SCC', 'PTTEP')
# ORDER BY name
#        name   id
# 0     3BBIF  241
# 1       ACE  667
# 2    ADVANC    8
# 3        AH   11
# 4       AIE  691
# ..      ...  ...
# 179   WHAIR  217
# 180   WHART  630
# 181   WHAUP  631
# 182    WICE  632
# 183    WORK  636
#
# [184 rows x 2 columns]

# %%
sql = """
SELECT name 
FROM buy
"""
df_buy = pd.read_sql(sql, const)
df_buy.shape
# Out:
# (29, 1)

# %%
df_merge = pd.merge(pg_tickers, df_buy, on='name', how='inner')
df_merge
# Out:
#      id     name                                          full_name  \
# 0   241    3BBIF     JASMINE BROADBAND INTERNET INFRASTRUCTURE FUND
# 1    11       AH               AAPICO HITECH PUBLIC COMPANY LIMITED
# 2    13   AIMIRT  AIM INDUSTRIAL GROWTH FREEHOLD AND LEASEHOLD R...
# 3   668      AWC            ASSET WORLD CORP PUBLIC COMPANY LIMITED
# 4    55      BCH      BANGKOK CHAIN HOSPITAL PUBLIC COMPANY LIMITED
# 5   121      CPF      CHAROEN POKPHAND FOODS PUBLIC COMPANY LIMITED
# 6   127  CPNREIT                   CPN RETAIL GROWTH LEASEHOLD REIT
# 7   146      DIF     DIGITAL TELECOMMUNICATIONS INFRASTRUCTURE FUND
# 8   238      IVL           INDORAMA VENTURES PUBLIC COMPANY LIMITED
# 9   244    JMART                    JAY MART PUBLIC COMPANY LIMITED
# 10  245      JMT        JMT NETWORK SERVICES PUBLIC COMPANY LIMITED
# 11  301      MCS                 M.C.S.STEEL PUBLIC COMPANY LIMITED
# 12  649      NER           NORTH EAST RUBBER PUBLIC COMPANY LIMITED
# 13  347      ORI             ORIGIN PROPERTY PUBLIC COMPANY LIMITED
# 14  387      PTG                  PTG ENERGY PUBLIC COMPANY LIMITED
# 15  389      PTT                         PTT PUBLIC COMPANY LIMITED
# 16  391    PTTGC         PTT GLOBAL CHEMICAL PUBLIC COMPANY LIMITED
# 17  401      RCL    REGIONAL CONTAINER LINES PUBLIC COMPANY LIMITED
# 18  433      SCC             THE SIAM CEMENT PUBLIC COMPANY LIMITED
# 19  443     SENA             SENADEVELOPMENT PUBLIC COMPANY LIMITED
# 20  452   SINGER             SINGER THAILAND PUBLIC COMPANY LIMITED
# 21  489      STA     SRI TRANG AGRO-INDUSTRY PUBLIC COMPANY LIMITED
# 22  504    SYNEX           SYNNEX (THAILAND) PUBLIC COMPANY LIMITED
# 23  562      TOA        TOA PAINT (THAILAND) PUBLIC COMPANY LIMITED
# 24  594      TVO          THAI VEGETABLE OIL PUBLIC COMPANY LIMITED
# 25  217    WHAIR     HEMARAJ LEASEHOLD REAL ESTATE INVESTMENT TRUST
# 26  630    WHART  WHA PREMIUM GROWTH FREEHOLD AND LEASEHOLD REAL...
#
#                      sector                               subsector  \
# 0                Technology  Information & Communication Technology
# 1               Industrials                              Automotive
# 2   Property & Construction                   Property Fund & REITs
# 3   Property & Construction                    Property Development
# 4                  Services                    Health Care Services
# 5      Agro & Food Industry                         Food & Beverage
# 6   Property & Construction                   Property Fund & REITs
# 7                Technology  Information & Communication Technology
# 8               Industrials              Petrochemicals & Chemicals
# 9                Technology  Information & Communication Technology
# 10               Financials                    Finance & Securities
# 11              Industrials                Steel and Metal Products
# 12     Agro & Food Industry                            Agribusiness
# 13  Property & Construction                    Property Development
# 14                Resources                      Energy & Utilities
# 15                Resources                      Energy & Utilities
# 16              Industrials              Petrochemicals & Chemicals
# 17                 Services              Transportation & Logistics
# 18  Property & Construction                  Construction Materials
# 19  Property & Construction                    Property Development
# 20                 Services                                Commerce
# 21     Agro & Food Industry                            Agribusiness
# 22               Technology  Information & Communication Technology
# 23  Property & Construction                  Construction Materials
# 24     Agro & Food Industry                         Food & Beverage
# 25  Property & Construction                   Property Fund & REITs
# 26  Property & Construction                   Property Fund & REITs
#
#                                        market  \
# 0                                         SET
# 1                              sSET / SETTHSI
# 2                                         SET
# 3                             SET50 / SETTHSI
# 4                              SET100 / SETWB
# 5   SET50 / SETCLMV / SETHD / SETTHSI / SETWB
# 6                                         SET
# 7                                         SET
# 8                             SET50 / SETTHSI
# 9                                       SET50
# 10                                      SET50
# 11                                       sSET
# 12                                       sSET
# 13                   SET100 / SETHD / SETTHSI
# 14                   SET100 / SETHD / SETTHSI
# 15          SET50 / SETCLMV / SETHD / SETTHSI
# 16                  SET50 / SETCLMV / SETTHSI
# 17                           SET100 / SETCLMV
# 18          SET50 / SETCLMV / SETHD / SETTHSI
# 19                                       sSET
# 20                                     SET100
# 21                   SET100 / SETTHSI / SETWB
# 22                           SET100 / SETTHSI
# 23                                    SETTHSI
# 24                      SET / SETTHSI / SETWB
# 25                                        SET
# 26                                        SET
#
#                               website                 created_at  \
# 0                      www.jas-if.com 2018-04-22 04:29:37.600684
# 1                      www.aapico.com 2018-04-22 04:29:36.134601
# 2                     www.aimreit.com 2018-04-22 04:29:36.146073
# 3   https://www.assetworldcorp-th.com 2019-11-19 07:13:52.454317
# 4        www.bangkokchainhospital.com 2018-04-22 04:29:36.442067
# 5                www.cpfworldwide.com 2018-04-22 04:29:36.867977
# 6                     www.cpnreit.com 2018-04-22 04:29:36.900508
# 7                 www.digital-tif.com 2018-04-22 04:29:37.030748
# 8            www.indoramaventures.com 2018-04-22 04:29:37.583373
# 9                   www.jaymart.co.th 2018-04-22 04:29:37.616395
# 10               www.jmtnetwork.co.th 2018-04-22 04:29:37.621811
# 11                   www.mcssteel.com 2018-04-22 04:29:37.957104
# 12                   www.nerubber.com 2019-03-03 03:45:01.837764
# 13                   www.origin.co.th 2018-04-22 04:29:38.228072
# 14                www.ptgenergy.co.th 2018-04-22 04:29:38.474708
# 15                     www.pttplc.com 2018-04-22 04:29:38.484745
# 16                 www.pttgcgroup.com 2018-04-22 04:29:38.496779
# 17                   www.rclgroup.com 2018-04-22 04:29:38.554599
# 18                        www.scg.com 2018-04-22 04:29:38.768905
# 19                     www.sena.co.th 2018-04-22 04:29:38.825191
# 20               www.singerthai.co.th 2018-04-22 04:29:38.875668
# 21              www.sritranggroup.com 2018-04-22 04:29:39.085589
# 22                   www.synnex.co.th 2018-04-22 04:29:39.170664
# 23                   www.toagroup.com 2018-04-22 04:29:39.494571
# 24                    www.tvothai.com 2018-04-22 04:29:39.677962
# 25                www.hemarajreit.com 2018-04-22 04:29:37.460955
# 26                    www.whareit.com 2018-04-22 04:29:39.879467
#
#                    updated_at
# 0  2019-03-03 03:45:01.621634
# 1  2021-07-07 03:33:38.806441
# 2  2018-04-22 04:29:36.146073
# 3  2022-01-15 03:54:48.241937
# 4  2019-11-19 07:13:52.520896
# 5  2021-07-07 03:33:38.893396
# 6  2018-04-22 04:29:36.900508
# 7  2018-04-22 04:29:37.030748
# 8  2021-07-07 03:33:38.986666
# 9  2021-01-26 15:42:35.221412
# 10 2020-07-06 13:23:59.311892
# 11 2021-08-22 18:22:07.463483
# 12 2019-11-19 07:13:53.611284
# 13 2022-01-15 03:54:48.440923
# 14 2022-01-15 03:54:48.464340
# 15 2019-11-19 07:13:53.785316
# 16 2021-07-07 03:33:39.100623
# 17 2022-01-15 03:54:48.472788
# 18 2019-11-19 07:13:53.911910
# 19 2018-04-22 04:29:38.825191
# 20 2021-07-07 03:33:39.150064
# 21 2022-01-15 03:54:48.525517
# 22 2021-07-07 03:33:39.202279
# 23 2021-07-07 03:33:39.241053
# 24 2019-11-19 07:13:54.470342
# 25 2018-04-22 04:29:37.460955
# 26 2018-04-22 04:29:39.879467

# %%
file_name = 'pub_stock.xlsx'
xsl_file = xsl_path + '\\' + file_name
df_merge[['id','name','sector','market']].to_excel(xsl_file, index=False)

# %% [markdown]
# ### Portfolio that already published

# %%
	names = df_buy["name"].values.tolist()
	in_p = ", ".join(map(lambda name: "'%s'" % name, names))
	in_p
# Out:
# "'3BBIF', 'AH', 'AIMIRT', 'AWC', 'BCH', 'CPF', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTT', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TOA', 'TVO', 'WHAIR', 'WHART'"

# %%
sql = """
SELECT *
FROM epss
WHERE publish_date >= '%s'
AND name IN (%s)
ORDER BY publish_date DESC, name"""
sql = sql % (select_date, in_p)
df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b99ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b99ba_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b99ba_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_b99ba_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_b99ba_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_b99ba_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_b99ba_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_b99ba_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_b99ba_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_b99ba_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_b99ba_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_b99ba_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_b99ba_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_b99ba_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_b99ba_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b99ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_