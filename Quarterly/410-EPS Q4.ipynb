# %%
import pandas as pd
import os
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

year = "2025"
quarter = "4"
select_date = date.today()
select_date = select_date.strftime("%Y-%m-%d")
print(select_date)
# Out:
# 2026-03-02

# %%
select_date = date(2026, 2, 24)
select_date = select_date.strftime("%Y-%m-%d")
print(select_date)
# Out:
# 2026-02-24

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Excel path (xsl_path): {xsl_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Quarterly
# Base path: C:\Users\PC1\OneDrive\A4
# Data path (dat_path): C:\Users\PC1\OneDrive\A4\Data
# Excel path (xsl_path): C:\Users\PC1\OneDrive\A4\Excel
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Restart and Run All

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()

format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:.2f}%','acc_pct':'{:.2f}%'
              }

# %%
pd.read_sql_query('SELECT * FROM EPSS ORDER BY id DESC LIMIT 5', conlt).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2bec8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bec8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_2bec8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_2bec8_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_2bec8_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_2bec8_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_2bec8_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_2bec8_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_2bec8_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_2bec8_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_2bec8_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_2bec8_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_2bec8_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_2bec8_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_2bec8_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bec8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bec8_row0_col0" class="data row0 col0" >25021</td>
#       <td id="T_2bec8_row0_col1" class="data row0 col1" >IVL</td>
#       <td id="T_2bec8_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_2bec8_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_2bec8_row0_col4" class="data row0 col4" >-4,697,188</td>
#       <td id="T_2bec8_row0_col5" class="data row0 col5" >1,095,694</td>
#       <td id="T_2bec8_row0_col6" class="data row0 col6" >-7,348,393</td>
#       <td id="T_2bec8_row0_col7" class="data row0 col7" >-19,262,126</td>
#       <td id="T_2bec8_row0_col8" class="data row0 col8" >-0.8800</td>
#       <td id="T_2bec8_row0_col9" class="data row0 col9" >0.1200</td>
#       <td id="T_2bec8_row0_col10" class="data row0 col10" >-1.4700</td>
#       <td id="T_2bec8_row0_col11" class="data row0 col11" >-3.6500</td>
#       <td id="T_2bec8_row0_col12" class="data row0 col12" >231</td>
#       <td id="T_2bec8_row0_col13" class="data row0 col13" >2026-03-02</td>
#     </tr>
#     <tr>
#       <th id="T_2bec8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bec8_row1_col0" class="data row1 col0" >25020</td>
#       <td id="T_2bec8_row1_col1" class="data row1 col1" >ORI</td>
#       <td id="T_2bec8_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_2bec8_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_2bec8_row1_col4" class="data row1 col4" >105,152</td>
#       <td id="T_2bec8_row1_col5" class="data row1 col5" >-266,145</td>
#       <td id="T_2bec8_row1_col6" class="data row1 col6" >719,936</td>
#       <td id="T_2bec8_row1_col7" class="data row1 col7" >1,051,790</td>
#       <td id="T_2bec8_row1_col8" class="data row1 col8" >0.0428</td>
#       <td id="T_2bec8_row1_col9" class="data row1 col9" >-0.1084</td>
#       <td id="T_2bec8_row1_col10" class="data row1 col10" >0.2933</td>
#       <td id="T_2bec8_row1_col11" class="data row1 col11" >0.4286</td>
#       <td id="T_2bec8_row1_col12" class="data row1 col12" >339</td>
#       <td id="T_2bec8_row1_col13" class="data row1 col13" >2026-02-27</td>
#     </tr>
#     <tr>
#       <th id="T_2bec8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2bec8_row2_col0" class="data row2 col0" >25019</td>
#       <td id="T_2bec8_row2_col1" class="data row2 col1" >TVO</td>
#       <td id="T_2bec8_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_2bec8_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_2bec8_row2_col4" class="data row2 col4" >521,643</td>
#       <td id="T_2bec8_row2_col5" class="data row2 col5" >807,667</td>
#       <td id="T_2bec8_row2_col6" class="data row2 col6" >2,188,791</td>
#       <td id="T_2bec8_row2_col7" class="data row2 col7" >2,103,105</td>
#       <td id="T_2bec8_row2_col8" class="data row2 col8" >0.5900</td>
#       <td id="T_2bec8_row2_col9" class="data row2 col9" >0.9000</td>
#       <td id="T_2bec8_row2_col10" class="data row2 col10" >2.4600</td>
#       <td id="T_2bec8_row2_col11" class="data row2 col11" >2.3600</td>
#       <td id="T_2bec8_row2_col12" class="data row2 col12" >585</td>
#       <td id="T_2bec8_row2_col13" class="data row2 col13" >2026-02-27</td>
#     </tr>
#     <tr>
#       <th id="T_2bec8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2bec8_row3_col0" class="data row3 col0" >25018</td>
#       <td id="T_2bec8_row3_col1" class="data row3 col1" >TOA</td>
#       <td id="T_2bec8_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_2bec8_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_2bec8_row3_col4" class="data row3 col4" >844,394</td>
#       <td id="T_2bec8_row3_col5" class="data row3 col5" >450,683</td>
#       <td id="T_2bec8_row3_col6" class="data row3 col6" >2,917,013</td>
#       <td id="T_2bec8_row3_col7" class="data row3 col7" >1,919,604</td>
#       <td id="T_2bec8_row3_col8" class="data row3 col8" >0.4372</td>
#       <td id="T_2bec8_row3_col9" class="data row3 col9" >0.2318</td>
#       <td id="T_2bec8_row3_col10" class="data row3 col10" >1.5000</td>
#       <td id="T_2bec8_row3_col11" class="data row3 col11" >0.9600</td>
#       <td id="T_2bec8_row3_col12" class="data row3 col12" >645</td>
#       <td id="T_2bec8_row3_col13" class="data row3 col13" >2026-02-27</td>
#     </tr>
#     <tr>
#       <th id="T_2bec8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2bec8_row4_col0" class="data row4 col0" >25017</td>
#       <td id="T_2bec8_row4_col1" class="data row4 col1" >SENA</td>
#       <td id="T_2bec8_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_2bec8_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_2bec8_row4_col4" class="data row4 col4" >35,749</td>
#       <td id="T_2bec8_row4_col5" class="data row4 col5" >97,807</td>
#       <td id="T_2bec8_row4_col6" class="data row4 col6" >323,614</td>
#       <td id="T_2bec8_row4_col7" class="data row4 col7" >399,608</td>
#       <td id="T_2bec8_row4_col8" class="data row4 col8" >0.0248</td>
#       <td id="T_2bec8_row4_col9" class="data row4 col9" >0.0678</td>
#       <td id="T_2bec8_row4_col10" class="data row4 col10" >0.2244</td>
#       <td id="T_2bec8_row4_col11" class="data row4 col11" >0.2771</td>
#       <td id="T_2bec8_row4_col12" class="data row4 col12" >437</td>
#       <td id="T_2bec8_row4_col13" class="data row4 col13" >2026-02-27</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= '%s'
"""
sql = sql % (year, quarter, select_date)
print(sql)

epss = pd.read_sql(sql, conlt)
epss.head().style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 4
# AND publish_date >= '2026-02-24'
# <style type="text/css">
# </style>
# <table id="T_61741">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61741_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_61741_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_61741_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_61741_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_61741_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_61741_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_61741_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_61741_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_61741_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_61741_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_61741_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_61741_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_61741_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_61741_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61741_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61741_row0_col0" class="data row0 col0" >24957</td>
#       <td id="T_61741_row0_col1" class="data row0 col1" >SYNEX</td>
#       <td id="T_61741_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_61741_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_61741_row0_col4" class="data row0 col4" >193,273</td>
#       <td id="T_61741_row0_col5" class="data row0 col5" >146,914</td>
#       <td id="T_61741_row0_col6" class="data row0 col6" >769,786</td>
#       <td id="T_61741_row0_col7" class="data row0 col7" >627,721</td>
#       <td id="T_61741_row0_col8" class="data row0 col8" >0.2300</td>
#       <td id="T_61741_row0_col9" class="data row0 col9" >0.1700</td>
#       <td id="T_61741_row0_col10" class="data row0 col10" >0.9100</td>
#       <td id="T_61741_row0_col11" class="data row0 col11" >0.7400</td>
#       <td id="T_61741_row0_col12" class="data row0 col12" >495</td>
#       <td id="T_61741_row0_col13" class="data row0 col13" >2026-02-24</td>
#     </tr>
#     <tr>
#       <th id="T_61741_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61741_row1_col0" class="data row1 col0" >24966</td>
#       <td id="T_61741_row1_col1" class="data row1 col1" >SJWD</td>
#       <td id="T_61741_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_61741_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_61741_row1_col4" class="data row1 col4" >266,298</td>
#       <td id="T_61741_row1_col5" class="data row1 col5" >185,352</td>
#       <td id="T_61741_row1_col6" class="data row1 col6" >1,172,144</td>
#       <td id="T_61741_row1_col7" class="data row1 col7" >1,119,087</td>
#       <td id="T_61741_row1_col8" class="data row1 col8" >0.1500</td>
#       <td id="T_61741_row1_col9" class="data row1 col9" >0.1000</td>
#       <td id="T_61741_row1_col10" class="data row1 col10" >0.6500</td>
#       <td id="T_61741_row1_col11" class="data row1 col11" >0.6200</td>
#       <td id="T_61741_row1_col12" class="data row1 col12" >242</td>
#       <td id="T_61741_row1_col13" class="data row1 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_61741_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61741_row2_col0" class="data row2 col0" >24967</td>
#       <td id="T_61741_row2_col1" class="data row2 col1" >HMPRO</td>
#       <td id="T_61741_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_61741_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_61741_row2_col4" class="data row2 col4" >1,601,894</td>
#       <td id="T_61741_row2_col5" class="data row2 col5" >1,727,015</td>
#       <td id="T_61741_row2_col6" class="data row2 col6" >6,011,391</td>
#       <td id="T_61741_row2_col7" class="data row2 col7" >6,503,547</td>
#       <td id="T_61741_row2_col8" class="data row2 col8" >0.1200</td>
#       <td id="T_61741_row2_col9" class="data row2 col9" >0.1300</td>
#       <td id="T_61741_row2_col10" class="data row2 col10" >0.4600</td>
#       <td id="T_61741_row2_col11" class="data row2 col11" >0.4900</td>
#       <td id="T_61741_row2_col12" class="data row2 col12" >208</td>
#       <td id="T_61741_row2_col13" class="data row2 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_61741_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61741_row3_col0" class="data row3 col0" >24968</td>
#       <td id="T_61741_row3_col1" class="data row3 col1" >TKS</td>
#       <td id="T_61741_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_61741_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_61741_row3_col4" class="data row3 col4" >103,137</td>
#       <td id="T_61741_row3_col5" class="data row3 col5" >-73,829</td>
#       <td id="T_61741_row3_col6" class="data row3 col6" >277,266</td>
#       <td id="T_61741_row3_col7" class="data row3 col7" >-55,667</td>
#       <td id="T_61741_row3_col8" class="data row3 col8" >0.2100</td>
#       <td id="T_61741_row3_col9" class="data row3 col9" >-0.1500</td>
#       <td id="T_61741_row3_col10" class="data row3 col10" >0.5600</td>
#       <td id="T_61741_row3_col11" class="data row3 col11" >-0.1100</td>
#       <td id="T_61741_row3_col12" class="data row3 col12" >534</td>
#       <td id="T_61741_row3_col13" class="data row3 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_61741_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61741_row4_col0" class="data row4 col0" >24969</td>
#       <td id="T_61741_row4_col1" class="data row4 col1" >QH</td>
#       <td id="T_61741_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_61741_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_61741_row4_col4" class="data row4 col4" >511,209</td>
#       <td id="T_61741_row4_col5" class="data row4 col5" >467,150</td>
#       <td id="T_61741_row4_col6" class="data row4 col6" >1,727,819</td>
#       <td id="T_61741_row4_col7" class="data row4 col7" >2,150,105</td>
#       <td id="T_61741_row4_col8" class="data row4 col8" >0.0500</td>
#       <td id="T_61741_row4_col9" class="data row4 col9" >0.0400</td>
#       <td id="T_61741_row4_col10" class="data row4 col10" >0.1600</td>
#       <td id="T_61741_row4_col11" class="data row4 col11" >0.2000</td>
#       <td id="T_61741_row4_col12" class="data row4 col12" >388</td>
#       <td id="T_61741_row4_col13" class="data row4 col13" >2026-02-24</td>
#     </tr>
#   </tbody>
# </table>

# %%
epss["yoy_gain"] = epss["q_amt"] - epss["y_amt"]
epss["yoy_pct"] = round(epss["yoy_gain"] / abs(epss["y_amt"]) * 100, 2)
epss["acc_gain"] = epss["aq_amt"] - epss["ay_amt"]
epss["acc_pct"] = round(epss["acc_gain"] / abs(epss["ay_amt"]) * 100,2)

df_pct = epss[colt]
df_pct.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8cf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8cf4_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d8cf4_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_d8cf4_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_d8cf4_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_d8cf4_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_d8cf4_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_d8cf4_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_d8cf4_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_d8cf4_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_d8cf4_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_d8cf4_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8cf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8cf4_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_d8cf4_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_d8cf4_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_d8cf4_row0_col3" class="data row0 col3" >193,273</td>
#       <td id="T_d8cf4_row0_col4" class="data row0 col4" >146,914</td>
#       <td id="T_d8cf4_row0_col5" class="data row0 col5" >46,359</td>
#       <td id="T_d8cf4_row0_col6" class="data row0 col6" >31.56%</td>
#       <td id="T_d8cf4_row0_col7" class="data row0 col7" >769,786</td>
#       <td id="T_d8cf4_row0_col8" class="data row0 col8" >627,721</td>
#       <td id="T_d8cf4_row0_col9" class="data row0 col9" >142,065</td>
#       <td id="T_d8cf4_row0_col10" class="data row0 col10" >22.63%</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8cf4_row1_col0" class="data row1 col0" >SJWD</td>
#       <td id="T_d8cf4_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_d8cf4_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_d8cf4_row1_col3" class="data row1 col3" >266,298</td>
#       <td id="T_d8cf4_row1_col4" class="data row1 col4" >185,352</td>
#       <td id="T_d8cf4_row1_col5" class="data row1 col5" >80,946</td>
#       <td id="T_d8cf4_row1_col6" class="data row1 col6" >43.67%</td>
#       <td id="T_d8cf4_row1_col7" class="data row1 col7" >1,172,144</td>
#       <td id="T_d8cf4_row1_col8" class="data row1 col8" >1,119,087</td>
#       <td id="T_d8cf4_row1_col9" class="data row1 col9" >53,057</td>
#       <td id="T_d8cf4_row1_col10" class="data row1 col10" >4.74%</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8cf4_row2_col0" class="data row2 col0" >HMPRO</td>
#       <td id="T_d8cf4_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_d8cf4_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_d8cf4_row2_col3" class="data row2 col3" >1,601,894</td>
#       <td id="T_d8cf4_row2_col4" class="data row2 col4" >1,727,015</td>
#       <td id="T_d8cf4_row2_col5" class="data row2 col5" >-125,121</td>
#       <td id="T_d8cf4_row2_col6" class="data row2 col6" >-7.24%</td>
#       <td id="T_d8cf4_row2_col7" class="data row2 col7" >6,011,391</td>
#       <td id="T_d8cf4_row2_col8" class="data row2 col8" >6,503,547</td>
#       <td id="T_d8cf4_row2_col9" class="data row2 col9" >-492,156</td>
#       <td id="T_d8cf4_row2_col10" class="data row2 col10" >-7.57%</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8cf4_row3_col0" class="data row3 col0" >TKS</td>
#       <td id="T_d8cf4_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_d8cf4_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_d8cf4_row3_col3" class="data row3 col3" >103,137</td>
#       <td id="T_d8cf4_row3_col4" class="data row3 col4" >-73,829</td>
#       <td id="T_d8cf4_row3_col5" class="data row3 col5" >176,966</td>
#       <td id="T_d8cf4_row3_col6" class="data row3 col6" >239.70%</td>
#       <td id="T_d8cf4_row3_col7" class="data row3 col7" >277,266</td>
#       <td id="T_d8cf4_row3_col8" class="data row3 col8" >-55,667</td>
#       <td id="T_d8cf4_row3_col9" class="data row3 col9" >332,933</td>
#       <td id="T_d8cf4_row3_col10" class="data row3 col10" >598.08%</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8cf4_row4_col0" class="data row4 col0" >QH</td>
#       <td id="T_d8cf4_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_d8cf4_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_d8cf4_row4_col3" class="data row4 col3" >511,209</td>
#       <td id="T_d8cf4_row4_col4" class="data row4 col4" >467,150</td>
#       <td id="T_d8cf4_row4_col5" class="data row4 col5" >44,059</td>
#       <td id="T_d8cf4_row4_col6" class="data row4 col6" >9.43%</td>
#       <td id="T_d8cf4_row4_col7" class="data row4 col7" >1,727,819</td>
#       <td id="T_d8cf4_row4_col8" class="data row4 col8" >2,150,105</td>
#       <td id="T_d8cf4_row4_col9" class="data row4 col9" >-422,286</td>
#       <td id="T_d8cf4_row4_col10" class="data row4 col10" >-19.64%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_1 = df_pct.q_amt > 110_000
df_pct.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_62adc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62adc_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_62adc_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_62adc_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_62adc_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_62adc_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_62adc_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_62adc_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62adc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62adc_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_62adc_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_62adc_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_62adc_row0_col3" class="data row0 col3" >193,273</td>
#       <td id="T_62adc_row0_col4" class="data row0 col4" >146,914</td>
#       <td id="T_62adc_row0_col5" class="data row0 col5" >46,359</td>
#       <td id="T_62adc_row0_col6" class="data row0 col6" >31.56%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62adc_row1_col0" class="data row1 col0" >SJWD</td>
#       <td id="T_62adc_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_62adc_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_62adc_row1_col3" class="data row1 col3" >266,298</td>
#       <td id="T_62adc_row1_col4" class="data row1 col4" >185,352</td>
#       <td id="T_62adc_row1_col5" class="data row1 col5" >80,946</td>
#       <td id="T_62adc_row1_col6" class="data row1 col6" >43.67%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_62adc_row2_col0" class="data row2 col0" >HMPRO</td>
#       <td id="T_62adc_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_62adc_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_62adc_row2_col3" class="data row2 col3" >1,601,894</td>
#       <td id="T_62adc_row2_col4" class="data row2 col4" >1,727,015</td>
#       <td id="T_62adc_row2_col5" class="data row2 col5" >-125,121</td>
#       <td id="T_62adc_row2_col6" class="data row2 col6" >-7.24%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_62adc_row3_col0" class="data row3 col0" >QH</td>
#       <td id="T_62adc_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_62adc_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_62adc_row3_col3" class="data row3 col3" >511,209</td>
#       <td id="T_62adc_row3_col4" class="data row3 col4" >467,150</td>
#       <td id="T_62adc_row3_col5" class="data row3 col5" >44,059</td>
#       <td id="T_62adc_row3_col6" class="data row3 col6" >9.43%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_62adc_row4_col0" class="data row4 col0" >COM7</td>
#       <td id="T_62adc_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_62adc_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_62adc_row4_col3" class="data row4 col3" >1,207,698</td>
#       <td id="T_62adc_row4_col4" class="data row4 col4" >1,029,675</td>
#       <td id="T_62adc_row4_col5" class="data row4 col5" >178,023</td>
#       <td id="T_62adc_row4_col6" class="data row4 col6" >17.29%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_62adc_row5_col0" class="data row5 col0" >BJC</td>
#       <td id="T_62adc_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_62adc_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_62adc_row5_col3" class="data row5 col3" >1,293,253</td>
#       <td id="T_62adc_row5_col4" class="data row5 col4" >1,644,502</td>
#       <td id="T_62adc_row5_col5" class="data row5 col5" >-351,249</td>
#       <td id="T_62adc_row5_col6" class="data row5 col6" >-21.36%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_62adc_row6_col0" class="data row6 col0" >SC</td>
#       <td id="T_62adc_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_62adc_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_62adc_row6_col3" class="data row6 col3" >611,715</td>
#       <td id="T_62adc_row6_col4" class="data row6 col4" >485,971</td>
#       <td id="T_62adc_row6_col5" class="data row6 col5" >125,744</td>
#       <td id="T_62adc_row6_col6" class="data row6 col6" >25.87%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_62adc_row7_col0" class="data row7 col0" >CENTEL</td>
#       <td id="T_62adc_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_62adc_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_62adc_row7_col3" class="data row7 col3" >974,352</td>
#       <td id="T_62adc_row7_col4" class="data row7 col4" >667,053</td>
#       <td id="T_62adc_row7_col5" class="data row7 col5" >307,299</td>
#       <td id="T_62adc_row7_col6" class="data row7 col6" >46.07%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_62adc_row8_col0" class="data row8 col0" >SPALI</td>
#       <td id="T_62adc_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_62adc_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_62adc_row8_col3" class="data row8 col3" >1,337,932</td>
#       <td id="T_62adc_row8_col4" class="data row8 col4" >1,988,288</td>
#       <td id="T_62adc_row8_col5" class="data row8 col5" >-650,356</td>
#       <td id="T_62adc_row8_col6" class="data row8 col6" >-32.71%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_62adc_row9_col0" class="data row9 col0" >BGRIM</td>
#       <td id="T_62adc_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_62adc_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_62adc_row9_col3" class="data row9 col3" >493,710</td>
#       <td id="T_62adc_row9_col4" class="data row9 col4" >786,954</td>
#       <td id="T_62adc_row9_col5" class="data row9 col5" >-293,244</td>
#       <td id="T_62adc_row9_col6" class="data row9 col6" >-37.26%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_62adc_row10_col0" class="data row10 col0" >MEGA</td>
#       <td id="T_62adc_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_62adc_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_62adc_row10_col3" class="data row10 col3" >577,042</td>
#       <td id="T_62adc_row10_col4" class="data row10 col4" >639,425</td>
#       <td id="T_62adc_row10_col5" class="data row10 col5" >-62,383</td>
#       <td id="T_62adc_row10_col6" class="data row10 col6" >-9.76%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_62adc_row11_col0" class="data row11 col0" >TTW</td>
#       <td id="T_62adc_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_62adc_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_62adc_row11_col3" class="data row11 col3" >824,630</td>
#       <td id="T_62adc_row11_col4" class="data row11 col4" >749,519</td>
#       <td id="T_62adc_row11_col5" class="data row11 col5" >75,111</td>
#       <td id="T_62adc_row11_col6" class="data row11 col6" >10.02%</td>
#     </tr>
#     <tr>
#       <th id="T_62adc_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_62adc_row12_col0" class="data row12 col0" >TKN</td>
#       <td id="T_62adc_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_62adc_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_62adc_row12_col3" class="data row12 col3" >112,380</td>
#       <td id="T_62adc_row1

# %%
criteria_2 = df_pct.y_amt > 100_000
df_pct.loc[criteria_2, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6325b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6325b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_6325b_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_6325b_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_6325b_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_6325b_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_6325b_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_6325b_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6325b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6325b_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_6325b_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_6325b_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_6325b_row0_col3" class="data row0 col3" >193,273</td>
#       <td id="T_6325b_row0_col4" class="data row0 col4" >146,914</td>
#       <td id="T_6325b_row0_col5" class="data row0 col5" >46,359</td>
#       <td id="T_6325b_row0_col6" class="data row0 col6" >31.56%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6325b_row1_col0" class="data row1 col0" >SJWD</td>
#       <td id="T_6325b_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_6325b_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_6325b_row1_col3" class="data row1 col3" >266,298</td>
#       <td id="T_6325b_row1_col4" class="data row1 col4" >185,352</td>
#       <td id="T_6325b_row1_col5" class="data row1 col5" >80,946</td>
#       <td id="T_6325b_row1_col6" class="data row1 col6" >43.67%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6325b_row2_col0" class="data row2 col0" >HMPRO</td>
#       <td id="T_6325b_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_6325b_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_6325b_row2_col3" class="data row2 col3" >1,601,894</td>
#       <td id="T_6325b_row2_col4" class="data row2 col4" >1,727,015</td>
#       <td id="T_6325b_row2_col5" class="data row2 col5" >-125,121</td>
#       <td id="T_6325b_row2_col6" class="data row2 col6" >-7.24%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6325b_row3_col0" class="data row3 col0" >QH</td>
#       <td id="T_6325b_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_6325b_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_6325b_row3_col3" class="data row3 col3" >511,209</td>
#       <td id="T_6325b_row3_col4" class="data row3 col4" >467,150</td>
#       <td id="T_6325b_row3_col5" class="data row3 col5" >44,059</td>
#       <td id="T_6325b_row3_col6" class="data row3 col6" >9.43%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6325b_row4_col0" class="data row4 col0" >COM7</td>
#       <td id="T_6325b_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_6325b_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_6325b_row4_col3" class="data row4 col3" >1,207,698</td>
#       <td id="T_6325b_row4_col4" class="data row4 col4" >1,029,675</td>
#       <td id="T_6325b_row4_col5" class="data row4 col5" >178,023</td>
#       <td id="T_6325b_row4_col6" class="data row4 col6" >17.29%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6325b_row5_col0" class="data row5 col0" >BJC</td>
#       <td id="T_6325b_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_6325b_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_6325b_row5_col3" class="data row5 col3" >1,293,253</td>
#       <td id="T_6325b_row5_col4" class="data row5 col4" >1,644,502</td>
#       <td id="T_6325b_row5_col5" class="data row5 col5" >-351,249</td>
#       <td id="T_6325b_row5_col6" class="data row5 col6" >-21.36%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6325b_row6_col0" class="data row6 col0" >SPCG</td>
#       <td id="T_6325b_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_6325b_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_6325b_row6_col3" class="data row6 col3" >69,202</td>
#       <td id="T_6325b_row6_col4" class="data row6 col4" >117,764</td>
#       <td id="T_6325b_row6_col5" class="data row6 col5" >-48,562</td>
#       <td id="T_6325b_row6_col6" class="data row6 col6" >-41.24%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6325b_row7_col0" class="data row7 col0" >SC</td>
#       <td id="T_6325b_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_6325b_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_6325b_row7_col3" class="data row7 col3" >611,715</td>
#       <td id="T_6325b_row7_col4" class="data row7 col4" >485,971</td>
#       <td id="T_6325b_row7_col5" class="data row7 col5" >125,744</td>
#       <td id="T_6325b_row7_col6" class="data row7 col6" >25.87%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6325b_row8_col0" class="data row8 col0" >CENTEL</td>
#       <td id="T_6325b_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_6325b_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_6325b_row8_col3" class="data row8 col3" >974,352</td>
#       <td id="T_6325b_row8_col4" class="data row8 col4" >667,053</td>
#       <td id="T_6325b_row8_col5" class="data row8 col5" >307,299</td>
#       <td id="T_6325b_row8_col6" class="data row8 col6" >46.07%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_6325b_row9_col0" class="data row9 col0" >SPALI</td>
#       <td id="T_6325b_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_6325b_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_6325b_row9_col3" class="data row9 col3" >1,337,932</td>
#       <td id="T_6325b_row9_col4" class="data row9 col4" >1,988,288</td>
#       <td id="T_6325b_row9_col5" class="data row9 col5" >-650,356</td>
#       <td id="T_6325b_row9_col6" class="data row9 col6" >-32.71%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_6325b_row10_col0" class="data row10 col0" >BGRIM</td>
#       <td id="T_6325b_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_6325b_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_6325b_row10_col3" class="data row10 col3" >493,710</td>
#       <td id="T_6325b_row10_col4" class="data row10 col4" >786,954</td>
#       <td id="T_6325b_row10_col5" class="data row10 col5" >-293,244</td>
#       <td id="T_6325b_row10_col6" class="data row10 col6" >-37.26%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row11" class="row_heading level0 row11" >13</th>
#       <td id="T_6325b_row11_col0" class="data row11 col0" >MEGA</td>
#       <td id="T_6325b_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_6325b_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_6325b_row11_col3" class="data row11 col3" >577,042</td>
#       <td id="T_6325b_row11_col4" class="data row11 col4" >639,425</td>
#       <td id="T_6325b_row11_col5" class="data row11 col5" >-62,383</td>
#       <td id="T_6325b_row11_col6" class="data row11 col6" >-9.76%</td>
#     </tr>
#     <tr>
#       <th id="T_6325b_level0_row12" class="row_heading level0 row12" >14</th>
#       <td id="T_6325b_row12_col0" class="data row12 col0" >TTW</td>
#       <td id="T_6325b_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_6325b_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_6325b_row12_col3" class="data row12 col3" >824,630</td>
#       <td id="T_6325b_row

# %%
criteria_3 = df_pct.yoy_pct > 10.00
df_pct.loc[criteria_3, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9df1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9df1_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a9df1_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_a9df1_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_a9df1_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_a9df1_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_a9df1_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_a9df1_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9df1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9df1_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_a9df1_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_a9df1_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_a9df1_row0_col3" class="data row0 col3" >193,273</td>
#       <td id="T_a9df1_row0_col4" class="data row0 col4" >146,914</td>
#       <td id="T_a9df1_row0_col5" class="data row0 col5" >46,359</td>
#       <td id="T_a9df1_row0_col6" class="data row0 col6" >31.56%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9df1_row1_col0" class="data row1 col0" >SJWD</td>
#       <td id="T_a9df1_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_a9df1_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_a9df1_row1_col3" class="data row1 col3" >266,298</td>
#       <td id="T_a9df1_row1_col4" class="data row1 col4" >185,352</td>
#       <td id="T_a9df1_row1_col5" class="data row1 col5" >80,946</td>
#       <td id="T_a9df1_row1_col6" class="data row1 col6" >43.67%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a9df1_row2_col0" class="data row2 col0" >TKS</td>
#       <td id="T_a9df1_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_a9df1_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_a9df1_row2_col3" class="data row2 col3" >103,137</td>
#       <td id="T_a9df1_row2_col4" class="data row2 col4" >-73,829</td>
#       <td id="T_a9df1_row2_col5" class="data row2 col5" >176,966</td>
#       <td id="T_a9df1_row2_col6" class="data row2 col6" >239.70%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_a9df1_row3_col0" class="data row3 col0" >COM7</td>
#       <td id="T_a9df1_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_a9df1_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_a9df1_row3_col3" class="data row3 col3" >1,207,698</td>
#       <td id="T_a9df1_row3_col4" class="data row3 col4" >1,029,675</td>
#       <td id="T_a9df1_row3_col5" class="data row3 col5" >178,023</td>
#       <td id="T_a9df1_row3_col6" class="data row3 col6" >17.29%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_a9df1_row4_col0" class="data row4 col0" >SC</td>
#       <td id="T_a9df1_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_a9df1_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_a9df1_row4_col3" class="data row4 col3" >611,715</td>
#       <td id="T_a9df1_row4_col4" class="data row4 col4" >485,971</td>
#       <td id="T_a9df1_row4_col5" class="data row4 col5" >125,744</td>
#       <td id="T_a9df1_row4_col6" class="data row4 col6" >25.87%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_a9df1_row5_col0" class="data row5 col0" >CENTEL</td>
#       <td id="T_a9df1_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_a9df1_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_a9df1_row5_col3" class="data row5 col3" >974,352</td>
#       <td id="T_a9df1_row5_col4" class="data row5 col4" >667,053</td>
#       <td id="T_a9df1_row5_col5" class="data row5 col5" >307,299</td>
#       <td id="T_a9df1_row5_col6" class="data row5 col6" >46.07%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row6" class="row_heading level0 row6" >14</th>
#       <td id="T_a9df1_row6_col0" class="data row6 col0" >TTW</td>
#       <td id="T_a9df1_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_a9df1_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_a9df1_row6_col3" class="data row6 col3" >824,630</td>
#       <td id="T_a9df1_row6_col4" class="data row6 col4" >749,519</td>
#       <td id="T_a9df1_row6_col5" class="data row6 col5" >75,111</td>
#       <td id="T_a9df1_row6_col6" class="data row6 col6" >10.02%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row7" class="row_heading level0 row7" >16</th>
#       <td id="T_a9df1_row7_col0" class="data row7 col0" >PTG</td>
#       <td id="T_a9df1_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_a9df1_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_a9df1_row7_col3" class="data row7 col3" >314,288</td>
#       <td id="T_a9df1_row7_col4" class="data row7 col4" >228,393</td>
#       <td id="T_a9df1_row7_col5" class="data row7 col5" >85,895</td>
#       <td id="T_a9df1_row7_col6" class="data row7 col6" >37.61%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row8" class="row_heading level0 row8" >17</th>
#       <td id="T_a9df1_row8_col0" class="data row8 col0" >CPNREIT</td>
#       <td id="T_a9df1_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_a9df1_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_a9df1_row8_col3" class="data row8 col3" >1,484,839</td>
#       <td id="T_a9df1_row8_col4" class="data row8 col4" >357,438</td>
#       <td id="T_a9df1_row8_col5" class="data row8 col5" >1,127,401</td>
#       <td id="T_a9df1_row8_col6" class="data row8 col6" >315.41%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row9" class="row_heading level0 row9" >18</th>
#       <td id="T_a9df1_row9_col0" class="data row9 col0" >RJH</td>
#       <td id="T_a9df1_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_a9df1_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_a9df1_row9_col3" class="data row9 col3" >87,688</td>
#       <td id="T_a9df1_row9_col4" class="data row9 col4" >45,128</td>
#       <td id="T_a9df1_row9_col5" class="data row9 col5" >42,560</td>
#       <td id="T_a9df1_row9_col6" class="data row9 col6" >94.31%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_a9df1_row10_col0" class="data row10 col0" >SGP</td>
#       <td id="T_a9df1_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_a9df1_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_a9df1_row10_col3" class="data row10 col3" >667,107</td>
#       <td id="T_a9df1_row10_col4" class="data row10 col4" >273,010</td>
#       <td id="T_a9df1_row10_col5" class="data row10 col5" >394,097</td>
#       <td id="T_a9df1_row10_col6" class="data row10 col6" >144.35%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row11" class="row_heading level0 row11" >22</th>
#       <td id="T_a9df1_row11_col0" class="data row11 col0" >OSP</td>
#       <td id="T_a9df1_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_a9df1_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_a9df1_row11_col3" class="data row11 col3" >691,831</td>
#       <td id="T_a9df1_row11_col4" class="data row11 col4" >566,781</td>
#       <td id="T_a9df1_row11_col5" class="data row11 col5" >125,050</td>
#       <td id="T_a9df1_row11_col6" class="data row11 col6" >22.06%</td>
#     </tr>
#     <tr>
#       <th id="T_a9df1_level0_row12" class="row_heading level0 row12" >30</th>
#       <td id="T_a9df1_row12_col0" class="data row12 col0" >BCH</td>
#       <td id="T_a9df1_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_a9df1_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_a9df1_row12_col3" class="data row12 col3" >259,498</td>
#       <td id="T_a9df1_row12_col4" class=

# %%
df_pct_criteria = criteria_1 & criteria_2 & criteria_3
#df_pct_criteria = criteria_1 & criteria_2 
df_pct.loc[df_pct_criteria, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c0b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c0b5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_6c0b5_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_6c0b5_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_6c0b5_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_6c0b5_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_6c0b5_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_6c0b5_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c0b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c0b5_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_6c0b5_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_6c0b5_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_6c0b5_row0_col3" class="data row0 col3" >193,273</td>
#       <td id="T_6c0b5_row0_col4" class="data row0 col4" >146,914</td>
#       <td id="T_6c0b5_row0_col5" class="data row0 col5" >46,359</td>
#       <td id="T_6c0b5_row0_col6" class="data row0 col6" >31.56%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c0b5_row1_col0" class="data row1 col0" >SJWD</td>
#       <td id="T_6c0b5_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_6c0b5_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_6c0b5_row1_col3" class="data row1 col3" >266,298</td>
#       <td id="T_6c0b5_row1_col4" class="data row1 col4" >185,352</td>
#       <td id="T_6c0b5_row1_col5" class="data row1 col5" >80,946</td>
#       <td id="T_6c0b5_row1_col6" class="data row1 col6" >43.67%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_6c0b5_row2_col0" class="data row2 col0" >COM7</td>
#       <td id="T_6c0b5_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_6c0b5_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_6c0b5_row2_col3" class="data row2 col3" >1,207,698</td>
#       <td id="T_6c0b5_row2_col4" class="data row2 col4" >1,029,675</td>
#       <td id="T_6c0b5_row2_col5" class="data row2 col5" >178,023</td>
#       <td id="T_6c0b5_row2_col6" class="data row2 col6" >17.29%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_6c0b5_row3_col0" class="data row3 col0" >SC</td>
#       <td id="T_6c0b5_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_6c0b5_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_6c0b5_row3_col3" class="data row3 col3" >611,715</td>
#       <td id="T_6c0b5_row3_col4" class="data row3 col4" >485,971</td>
#       <td id="T_6c0b5_row3_col5" class="data row3 col5" >125,744</td>
#       <td id="T_6c0b5_row3_col6" class="data row3 col6" >25.87%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_6c0b5_row4_col0" class="data row4 col0" >CENTEL</td>
#       <td id="T_6c0b5_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_6c0b5_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_6c0b5_row4_col3" class="data row4 col3" >974,352</td>
#       <td id="T_6c0b5_row4_col4" class="data row4 col4" >667,053</td>
#       <td id="T_6c0b5_row4_col5" class="data row4 col5" >307,299</td>
#       <td id="T_6c0b5_row4_col6" class="data row4 col6" >46.07%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_6c0b5_row5_col0" class="data row5 col0" >TTW</td>
#       <td id="T_6c0b5_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_6c0b5_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_6c0b5_row5_col3" class="data row5 col3" >824,630</td>
#       <td id="T_6c0b5_row5_col4" class="data row5 col4" >749,519</td>
#       <td id="T_6c0b5_row5_col5" class="data row5 col5" >75,111</td>
#       <td id="T_6c0b5_row5_col6" class="data row5 col6" >10.02%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_6c0b5_row6_col0" class="data row6 col0" >PTG</td>
#       <td id="T_6c0b5_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_6c0b5_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_6c0b5_row6_col3" class="data row6 col3" >314,288</td>
#       <td id="T_6c0b5_row6_col4" class="data row6 col4" >228,393</td>
#       <td id="T_6c0b5_row6_col5" class="data row6 col5" >85,895</td>
#       <td id="T_6c0b5_row6_col6" class="data row6 col6" >37.61%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_6c0b5_row7_col0" class="data row7 col0" >CPNREIT</td>
#       <td id="T_6c0b5_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_6c0b5_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_6c0b5_row7_col3" class="data row7 col3" >1,484,839</td>
#       <td id="T_6c0b5_row7_col4" class="data row7 col4" >357,438</td>
#       <td id="T_6c0b5_row7_col5" class="data row7 col5" >1,127,401</td>
#       <td id="T_6c0b5_row7_col6" class="data row7 col6" >315.41%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_6c0b5_row8_col0" class="data row8 col0" >SGP</td>
#       <td id="T_6c0b5_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_6c0b5_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_6c0b5_row8_col3" class="data row8 col3" >667,107</td>
#       <td id="T_6c0b5_row8_col4" class="data row8 col4" >273,010</td>
#       <td id="T_6c0b5_row8_col5" class="data row8 col5" >394,097</td>
#       <td id="T_6c0b5_row8_col6" class="data row8 col6" >144.35%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row9" class="row_heading level0 row9" >22</th>
#       <td id="T_6c0b5_row9_col0" class="data row9 col0" >OSP</td>
#       <td id="T_6c0b5_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_6c0b5_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_6c0b5_row9_col3" class="data row9 col3" >691,831</td>
#       <td id="T_6c0b5_row9_col4" class="data row9 col4" >566,781</td>
#       <td id="T_6c0b5_row9_col5" class="data row9 col5" >125,050</td>
#       <td id="T_6c0b5_row9_col6" class="data row9 col6" >22.06%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row10" class="row_heading level0 row10" >30</th>
#       <td id="T_6c0b5_row10_col0" class="data row10 col0" >BCH</td>
#       <td id="T_6c0b5_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_6c0b5_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_6c0b5_row10_col3" class="data row10 col3" >259,498</td>
#       <td id="T_6c0b5_row10_col4" class="data row10 col4" >233,040</td>
#       <td id="T_6c0b5_row10_col5" class="data row10 col5" >26,458</td>
#       <td id="T_6c0b5_row10_col6" class="data row10 col6" >11.35%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row11" class="row_heading level0 row11" >34</th>
#       <td id="T_6c0b5_row11_col0" class="data row11 col0" >RATCH</td>
#       <td id="T_6c0b5_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_6c0b5_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_6c0b5_row11_col3" class="data row11 col3" >774,978</td>
#       <td id="T_6c0b5_row11_col4" class="data row11 col4" >641,576</td>
#       <td id="T_6c0b5_row11_col5" class="data row11 col5" >133,402</td>
#       <td id="T_6c0b5_row11_col6" class="data row11 col6" >20.79%</td>
#     </tr>
#     <tr>
#       <th id="T_6c0b5_level0_row12" class="row_heading level0 row12" >44</th>
#       <td id="T_6c0b5_row12_col0" class="data row12 col0" >FSMART</td>
#       <td id="T_6c0b5_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_6c0b5_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_6c0b5_row12_col3" class="data row12 col3" >138,822</td>
#       <td id="T_6c0b5_row12_col4"

# %%
df_pct[df_pct_criteria].sort_values(by=["yoy_pct"], ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_85419">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85419_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_85419_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_85419_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_85419_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_85419_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_85419_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_85419_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_85419_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_85419_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_85419_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_85419_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85419_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_85419_row0_col0" class="data row0 col0" >CPNREIT</td>
#       <td id="T_85419_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_85419_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_85419_row0_col3" class="data row0 col3" >1,484,839</td>
#       <td id="T_85419_row0_col4" class="data row0 col4" >357,438</td>
#       <td id="T_85419_row0_col5" class="data row0 col5" >1,127,401</td>
#       <td id="T_85419_row0_col6" class="data row0 col6" >315.41%</td>
#       <td id="T_85419_row0_col7" class="data row0 col7" >3,460,976</td>
#       <td id="T_85419_row0_col8" class="data row0 col8" >1,696,069</td>
#       <td id="T_85419_row0_col9" class="data row0 col9" >1,764,907</td>
#       <td id="T_85419_row0_col10" class="data row0 col10" >104.06%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_85419_row1_col0" class="data row1 col0" >SGP</td>
#       <td id="T_85419_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_85419_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_85419_row1_col3" class="data row1 col3" >667,107</td>
#       <td id="T_85419_row1_col4" class="data row1 col4" >273,010</td>
#       <td id="T_85419_row1_col5" class="data row1 col5" >394,097</td>
#       <td id="T_85419_row1_col6" class="data row1 col6" >144.35%</td>
#       <td id="T_85419_row1_col7" class="data row1 col7" >8,507</td>
#       <td id="T_85419_row1_col8" class="data row1 col8" >1,318,924</td>
#       <td id="T_85419_row1_col9" class="data row1 col9" >-1,310,417</td>
#       <td id="T_85419_row1_col10" class="data row1 col10" >-99.36%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row2" class="row_heading level0 row2" >53</th>
#       <td id="T_85419_row2_col0" class="data row2 col0" >TOA</td>
#       <td id="T_85419_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_85419_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_85419_row2_col3" class="data row2 col3" >844,394</td>
#       <td id="T_85419_row2_col4" class="data row2 col4" >450,683</td>
#       <td id="T_85419_row2_col5" class="data row2 col5" >393,711</td>
#       <td id="T_85419_row2_col6" class="data row2 col6" >87.36%</td>
#       <td id="T_85419_row2_col7" class="data row2 col7" >2,917,013</td>
#       <td id="T_85419_row2_col8" class="data row2 col8" >1,919,604</td>
#       <td id="T_85419_row2_col9" class="data row2 col9" >997,409</td>
#       <td id="T_85419_row2_col10" class="data row2 col10" >51.96%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_85419_row3_col0" class="data row3 col0" >CENTEL</td>
#       <td id="T_85419_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_85419_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_85419_row3_col3" class="data row3 col3" >974,352</td>
#       <td id="T_85419_row3_col4" class="data row3 col4" >667,053</td>
#       <td id="T_85419_row3_col5" class="data row3 col5" >307,299</td>
#       <td id="T_85419_row3_col6" class="data row3 col6" >46.07%</td>
#       <td id="T_85419_row3_col7" class="data row3 col7" >1,992,902</td>
#       <td id="T_85419_row3_col8" class="data row3 col8" >1,752,985</td>
#       <td id="T_85419_row3_col9" class="data row3 col9" >239,917</td>
#       <td id="T_85419_row3_col10" class="data row3 col10" >13.69%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_85419_row4_col0" class="data row4 col0" >SJWD</td>
#       <td id="T_85419_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_85419_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_85419_row4_col3" class="data row4 col3" >266,298</td>
#       <td id="T_85419_row4_col4" class="data row4 col4" >185,352</td>
#       <td id="T_85419_row4_col5" class="data row4 col5" >80,946</td>
#       <td id="T_85419_row4_col6" class="data row4 col6" >43.67%</td>
#       <td id="T_85419_row4_col7" class="data row4 col7" >1,172,144</td>
#       <td id="T_85419_row4_col8" class="data row4 col8" >1,119,087</td>
#       <td id="T_85419_row4_col9" class="data row4 col9" >53,057</td>
#       <td id="T_85419_row4_col10" class="data row4 col10" >4.74%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_85419_row5_col0" class="data row5 col0" >PTG</td>
#       <td id="T_85419_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_85419_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_85419_row5_col3" class="data row5 col3" >314,288</td>
#       <td id="T_85419_row5_col4" class="data row5 col4" >228,393</td>
#       <td id="T_85419_row5_col5" class="data row5 col5" >85,895</td>
#       <td id="T_85419_row5_col6" class="data row5 col6" >37.61%</td>
#       <td id="T_85419_row5_col7" class="data row5 col7" >1,021,441</td>
#       <td id="T_85419_row5_col8" class="data row5 col8" >1,021,805</td>
#       <td id="T_85419_row5_col9" class="data row5 col9" >-364</td>
#       <td id="T_85419_row5_col10" class="data row5 col10" >-0.04%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_85419_row6_col0" class="data row6 col0" >SYNEX</td>
#       <td id="T_85419_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_85419_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_85419_row6_col3" class="data row6 col3" >193,273</td>
#       <td id="T_85419_row6_col4" class="data row6 col4" >146,914</td>
#       <td id="T_85419_row6_col5" class="data row6 col5" >46,359</td>
#       <td id="T_85419_row6_col6" class="data row6 col6" >31.56%</td>
#       <td id="T_85419_row6_col7" class="data row6 col7" >769,786</td>
#       <td id="T_85419_row6_col8" class="data row6 col8" >627,721</td>
#       <td id="T_85419_row6_col9" class="data row6 col9" >142,065</td>
#       <td id="T_85419_row6_col10" class="data row6 col10" >22.63%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_85419_row7_col0" class="data row7 col0" >SC</td>
#       <td id="T_85419_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_85419_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_85419_row7_col3" class="data row7 col3" >611,715</td>
#       <td id="T_85419_row7_col4" class="data row7 col4" >485,971</td>
#       <td id="T_85419_row7_col5" class="data row7 col5" >125,744</td>
#       <td id="T_85419_row7_col6" class="data row7 col6" >25.87%</td>
#       <td id="T_85419_row7_col7" class="data row7 col7" >1,532,696</td>
#       <td id="T_85419_row7_col8" class="data row7 col8" >1,705,524</td>
#       <td id="T_85419_row7_col9" class="data row7 col9" >-172,828</td>
#       <td id="T_85419_row7_col10" class="data row7 col10" >-10.13%</td>
#     </tr>
#     <tr>
#       <th id="T_85419_level0_row8" class="row_heading level0 row8" >22</th>
#       <td id="T_85419_row8_col0"

# %%
df_pct[df_pct_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c6d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c6d8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7c6d8_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_7c6d8_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_7c6d8_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_7c6d8_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_7c6d8_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_7c6d8_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_7c6d8_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_7c6d8_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_7c6d8_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_7c6d8_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c6d8_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_7c6d8_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_7c6d8_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_7c6d8_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_7c6d8_row0_col3" class="data row0 col3" >259,498</td>
#       <td id="T_7c6d8_row0_col4" class="data row0 col4" >233,040</td>
#       <td id="T_7c6d8_row0_col5" class="data row0 col5" >26,458</td>
#       <td id="T_7c6d8_row0_col6" class="data row0 col6" >11.35%</td>
#       <td id="T_7c6d8_row0_col7" class="data row0 col7" >1,316,360</td>
#       <td id="T_7c6d8_row0_col8" class="data row0 col8" >1,282,371</td>
#       <td id="T_7c6d8_row0_col9" class="data row0 col9" >33,989</td>
#       <td id="T_7c6d8_row0_col10" class="data row0 col10" >2.65%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_7c6d8_row1_col0" class="data row1 col0" >CENTEL</td>
#       <td id="T_7c6d8_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_7c6d8_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_7c6d8_row1_col3" class="data row1 col3" >974,352</td>
#       <td id="T_7c6d8_row1_col4" class="data row1 col4" >667,053</td>
#       <td id="T_7c6d8_row1_col5" class="data row1 col5" >307,299</td>
#       <td id="T_7c6d8_row1_col6" class="data row1 col6" >46.07%</td>
#       <td id="T_7c6d8_row1_col7" class="data row1 col7" >1,992,902</td>
#       <td id="T_7c6d8_row1_col8" class="data row1 col8" >1,752,985</td>
#       <td id="T_7c6d8_row1_col9" class="data row1 col9" >239,917</td>
#       <td id="T_7c6d8_row1_col10" class="data row1 col10" >13.69%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_7c6d8_row2_col0" class="data row2 col0" >COM7</td>
#       <td id="T_7c6d8_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_7c6d8_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_7c6d8_row2_col3" class="data row2 col3" >1,207,698</td>
#       <td id="T_7c6d8_row2_col4" class="data row2 col4" >1,029,675</td>
#       <td id="T_7c6d8_row2_col5" class="data row2 col5" >178,023</td>
#       <td id="T_7c6d8_row2_col6" class="data row2 col6" >17.29%</td>
#       <td id="T_7c6d8_row2_col7" class="data row2 col7" >4,063,531</td>
#       <td id="T_7c6d8_row2_col8" class="data row2 col8" >3,323,154</td>
#       <td id="T_7c6d8_row2_col9" class="data row2 col9" >740,377</td>
#       <td id="T_7c6d8_row2_col10" class="data row2 col10" >22.28%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row3" class="row_heading level0 row3" >17</th>
#       <td id="T_7c6d8_row3_col0" class="data row3 col0" >CPNREIT</td>
#       <td id="T_7c6d8_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_7c6d8_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_7c6d8_row3_col3" class="data row3 col3" >1,484,839</td>
#       <td id="T_7c6d8_row3_col4" class="data row3 col4" >357,438</td>
#       <td id="T_7c6d8_row3_col5" class="data row3 col5" >1,127,401</td>
#       <td id="T_7c6d8_row3_col6" class="data row3 col6" >315.41%</td>
#       <td id="T_7c6d8_row3_col7" class="data row3 col7" >3,460,976</td>
#       <td id="T_7c6d8_row3_col8" class="data row3 col8" >1,696,069</td>
#       <td id="T_7c6d8_row3_col9" class="data row3 col9" >1,764,907</td>
#       <td id="T_7c6d8_row3_col10" class="data row3 col10" >104.06%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row4" class="row_heading level0 row4" >44</th>
#       <td id="T_7c6d8_row4_col0" class="data row4 col0" >FSMART</td>
#       <td id="T_7c6d8_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_7c6d8_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_7c6d8_row4_col3" class="data row4 col3" >138,822</td>
#       <td id="T_7c6d8_row4_col4" class="data row4 col4" >120,506</td>
#       <td id="T_7c6d8_row4_col5" class="data row4 col5" >18,316</td>
#       <td id="T_7c6d8_row4_col6" class="data row4 col6" >15.20%</td>
#       <td id="T_7c6d8_row4_col7" class="data row4 col7" >586,775</td>
#       <td id="T_7c6d8_row4_col8" class="data row4 col8" >430,448</td>
#       <td id="T_7c6d8_row4_col9" class="data row4 col9" >156,327</td>
#       <td id="T_7c6d8_row4_col10" class="data row4 col10" >36.32%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row5" class="row_heading level0 row5" >22</th>
#       <td id="T_7c6d8_row5_col0" class="data row5 col0" >OSP</td>
#       <td id="T_7c6d8_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_7c6d8_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_7c6d8_row5_col3" class="data row5 col3" >691,831</td>
#       <td id="T_7c6d8_row5_col4" class="data row5 col4" >566,781</td>
#       <td id="T_7c6d8_row5_col5" class="data row5 col5" >125,050</td>
#       <td id="T_7c6d8_row5_col6" class="data row5 col6" >22.06%</td>
#       <td id="T_7c6d8_row5_col7" class="data row5 col7" >3,666,567</td>
#       <td id="T_7c6d8_row5_col8" class="data row5 col8" >1,638,105</td>
#       <td id="T_7c6d8_row5_col9" class="data row5 col9" >2,028,462</td>
#       <td id="T_7c6d8_row5_col10" class="data row5 col10" >123.83%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_7c6d8_row6_col0" class="data row6 col0" >PTG</td>
#       <td id="T_7c6d8_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_7c6d8_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_7c6d8_row6_col3" class="data row6 col3" >314,288</td>
#       <td id="T_7c6d8_row6_col4" class="data row6 col4" >228,393</td>
#       <td id="T_7c6d8_row6_col5" class="data row6 col5" >85,895</td>
#       <td id="T_7c6d8_row6_col6" class="data row6 col6" >37.61%</td>
#       <td id="T_7c6d8_row6_col7" class="data row6 col7" >1,021,441</td>
#       <td id="T_7c6d8_row6_col8" class="data row6 col8" >1,021,805</td>
#       <td id="T_7c6d8_row6_col9" class="data row6 col9" >-364</td>
#       <td id="T_7c6d8_row6_col10" class="data row6 col10" >-0.04%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row7" class="row_heading level0 row7" >34</th>
#       <td id="T_7c6d8_row7_col0" class="data row7 col0" >RATCH</td>
#       <td id="T_7c6d8_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_7c6d8_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_7c6d8_row7_col3" class="data row7 col3" >774,978</td>
#       <td id="T_7c6d8_row7_col4" class="data row7 col4" >641,576</td>
#       <td id="T_7c6d8_row7_col5" class="data row7 col5" >133,402</td>
#       <td id="T_7c6d8_row7_col6" class="data row7 col6" >20.79%</td>
#       <td id="T_7c6d8_row7_col7" class="data row7 col7" >6,220,432</td>
#       <td id="T_7c6d8_row7_col8" class="data row7 col8" >6,126,779</td>
#       <td id="T_7c6d8_row7_col9" class="data row7 col9" >93,653</td>
#       <td id="T_7c6d8_row7_col10" class="data row7 col10" >1.53%</td>
#     </tr>
#     <tr>
#       <th id="T_7c6d8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c6d8_row

# %%
names = epss['name']
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'SYNEX', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL'"

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
sql = """
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN (%s)
ORDER BY E.name, year DESC, quarter DESC 
"""
sql = sql % (in_p)
print(sql)

epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('SYNEX', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL')
# ORDER BY E.name, year DESC, quarter DESC
# (2741, 11)

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
in_p
# Out:
# "'SYNEX', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL'"

# %%
sqlDel = text("""
    DELETE FROM profits 
    WHERE name IN ({})
    AND quarter < :quarter
""".format(in_p))
print(sqlDel)
# Execute with parameters
rp = conlt.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
#     DELETE FROM profits
#     WHERE name IN ('SYNEX', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL')
#     AND quarter < :quarter
# 0

# %%
rp = conmy.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 0

# %%
rp = conpg.execute(sqlDel, {'quarter': quarter})
rp.rowcount
# Out:
# 0

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index
# Out:
# Index(['3BBIF', 'ACE', 'ADVANC', 'AMATA', 'BCP', 'BKIH', 'DIF', 'FPT', 'GFPT',
#        'GULF', 'KKP', 'MTC', 'NER', 'SCGP', 'SSP', 'THANI'],
#       dtype='object', name='name')

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index
# Out:
# Index(['2842', '2843', '2844', '2845', '2846', '2847', '2848', '2849', '2850',
#        '2851', '2851', '2852', '2853', '2854', '2855', '2856', '3BBIF',
#        'ADVANC', 'BCP', 'DIF', 'FPT', 'GFPT', 'GULF', 'GUNKUL', 'KKP', 'MTC',
#        'NER', 'SCGP'],
#       dtype='object', name='name')

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index
# Out:
# Index(['3BBIF', 'ACE', 'ADVANC', 'AMATA', 'BCP', 'BKIH', 'FPT', 'GFPT', 'KKP',
#        'SCGP', 'SSP', 'THANI'],
#       dtype='object', name='name')

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = """
SELECT * 
FROM tickers
WHERE name IN (%s)
ORDER BY name"""
sql = sql % in_p
print(sql)
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('SYNEX', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL')
# ORDER BY name

# %%
tickers = pd.read_sql(sql, conpg)
tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])
# Out:
#        name   id
# 0        AH   11
# 1        AP   29
# 2       ASP   44
# 3       AWC  668
# 4        BA   49
# 5       BAM  680
# 6     BANPU   51
# 7       BCH   55
# 8      BDMS   58
# 9    BEAUTY   59
# 10      BEM   61
# 11    BGRIM   63
# 12      BJC   68
# 13      BPP   78
# 14   CENTEL   94
# 15       CK  109
# 16     COM7  118
# 17    CPALL  120
# 18      CPF  121
# 19  CPNREIT  127
# 20     DCON  141
# 21    EASTW  155
# 22   FSMART  183
# 23    HMPRO  214
# 24      III  226
# 25      ILM  702
# 26      IVL  238
# 27      LPN  284
# 28        M  287
# 29     MEGA  303
# 30      ORI  347
# 31      OSP  650
# 32      PAP  350
# 33      PRM  382
# 34      PTG  387
# 35       QH  394
# 36    RATCH  399
# 37      RJH  404
# 38    SAPPE  426
# 39       SC  431
# 40     SENA  443
# 41      SGP  447
# 42     SJWD  250
# 43    SPALI  470
# 44     SPCG  472
# 45    SYNEX  504
# 46       TK  541
# 47      TKN  542
# 48      TKS  543
# 49      TOA  562
# 50      TTA  588
# 51      TTW  590
# 52      TVO  594
# 53      VNG  703
# 54      WHA  628
# 55    WHAUP  631
# 56     WICE  632

# %%
sql = """
SELECT name 
FROM buy
"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (30, 1)

# %%
df_merge = pd.merge(tickers, buys, on='name', how='inner')
df_merge
# Out:
#      id     name                                      full_name  \
# 0    11       AH           AAPICO HITECH PUBLIC COMPANY LIMITED
# 1   668      AWC        ASSET WORLD CORP PUBLIC COMPANY LIMITED
# 2    55      BCH  BANGKOK CHAIN HOSPITAL PUBLIC COMPANY LIMITED
# 3   121      CPF  CHAROEN POKPHAND FOODS PUBLIC COMPANY LIMITED
# 4   127  CPNREIT               CPN RETAIL GROWTH LEASEHOLD REIT
# 5   238      IVL       INDORAMA VENTURES PUBLIC COMPANY LIMITED
# 6   347      ORI         ORIGIN PROPERTY PUBLIC COMPANY LIMITED
# 7   387      PTG              PTG ENERGY PUBLIC COMPANY LIMITED
# 8   443     SENA         SENADEVELOPMENT PUBLIC COMPANY LIMITED
# 9   504    SYNEX       SYNNEX (THAILAND) PUBLIC COMPANY LIMITED
# 10  562      TOA    TOA PAINT (THAILAND) PUBLIC COMPANY LIMITED
# 11  594      TVO      THAI VEGETABLE OIL PUBLIC COMPANY LIMITED
#
#                      sector                               subsector  \
# 0               Industrials                              Automotive
# 1   Property & Construction                    Property Development
# 2                  Services                    Health Care Services
# 3      Agro & Food Industry                         Food & Beverage
# 4   Property & Construction                   Property Fund & REITs
# 5               Industrials              Petrochemicals & Chemicals
# 6   Property & Construction                    Property Development
# 7                 Resources                      Energy & Utilities
# 8   Property & Construction                    Property Development
# 9                Technology  Information & Communication Technology
# 10  Property & Construction                  Construction Materials
# 11     Agro & Food Industry                         Food & Beverage
#
#                                        market  \
# 0                              sSET / SETTHSI
# 1                             SET50 / SETTHSI
# 2                              SET100 / SETWB
# 3   SET50 / SETCLMV / SETHD / SETTHSI / SETWB
# 4                                         SET
# 5                             SET50 / SETTHSI
# 6                    SET100 / SETHD / SETTHSI
# 7                    SET100 / SETHD / SETTHSI
# 8                                        sSET
# 9                            SET100 / SETTHSI
# 10                                    SETTHSI
# 11                      SET / SETTHSI / SETWB
#
#                               website                 created_at  \
# 0                      www.aapico.com 2018-04-22 04:29:36.134601
# 1   https://www.assetworldcorp-th.com 2019-11-19 07:13:52.454317
# 2        www.bangkokchainhospital.com 2018-04-22 04:29:36.442067
# 3                www.cpfworldwide.com 2018-04-22 04:29:36.867977
# 4                     www.cpnreit.com 2018-04-22 04:29:36.900508
# 5            www.indoramaventures.com 2018-04-22 04:29:37.583373
# 6                    www.origin.co.th 2018-04-22 04:29:38.228072
# 7                 www.ptgenergy.co.th 2018-04-22 04:29:38.474708
# 8                      www.sena.co.th 2018-04-22 04:29:38.825191
# 9                    www.synnex.co.th 2018-04-22 04:29:39.170664
# 10                   www.toagroup.com 2018-04-22 04:29:39.494571
# 11                    www.tvothai.com 2018-04-22 04:29:39.677962
#
#                    updated_at
# 0  2021-07-07 03:33:38.806441
# 1  2022-01-15 03:54:48.241937
# 2  2019-11-19 07:13:52.520896
# 3  2021-07-07 03:33:38.893396
# 4  2018-04-22 04:29:36.900508
# 5  2021-07-07 03:33:38.986666
# 6  2022-01-15 03:54:48.440923
# 7  2022-01-15 03:54:48.464340
# 8  2018-04-22 04:29:38.825191
# 9  2021-07-07 03:33:39.202279
# 10 2021-07-07 03:33:39.241053
# 11 2019-11-19 07:13:54.470342

# %%
file_name = 'pub_stock.xlsx'
output_file = os.path.join(dat_path, file_name)
print(f"Output file : {output_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\pub_stock.xlsx

# %%
df_merge[['id','name','sector','market']].to_excel(output_file, index=False)

# %% [markdown]
# ### Portfolio that already published

# %%
sql = """
SELECT * 
FROM buy"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (30, 10)

# %%
names = buys["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'STA', 'SINGER', 'PTG', 'PTT', 'MCS', 'DIF', 'ADVANC', 'JMT', 'WHART', 'BCH', 'SENA', 'TFFIF', '3BBIF', 'CPF', 'IVL', 'PTTGC', 'WHAIR', 'ORI', 'AH', 'GVREIT', 'NER', 'AIMIRT', 'TOA', 'AWC', 'SYNEX', 'SCC', 'RCL', 'JMART', 'CPNREIT', 'TVO'"

# %%
sql = """
SELECT *
FROM epss
WHERE publish_date >= '%s'
AND name IN (%s)
ORDER BY publish_date, name"""
sql = sql % (select_date, in_p)
df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_00c62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00c62_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_00c62_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_00c62_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_00c62_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_00c62_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_00c62_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_00c62_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_00c62_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_00c62_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_00c62_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_00c62_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_00c62_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_00c62_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_00c62_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00c62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00c62_row0_col0" class="data row0 col0" >24957</td>
#       <td id="T_00c62_row0_col1" class="data row0 col1" >SYNEX</td>
#       <td id="T_00c62_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_00c62_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_00c62_row0_col4" class="data row0 col4" >193,273</td>
#       <td id="T_00c62_row0_col5" class="data row0 col5" >146,914</td>
#       <td id="T_00c62_row0_col6" class="data row0 col6" >769,786</td>
#       <td id="T_00c62_row0_col7" class="data row0 col7" >627,721</td>
#       <td id="T_00c62_row0_col8" class="data row0 col8" >0.2300</td>
#       <td id="T_00c62_row0_col9" class="data row0 col9" >0.1700</td>
#       <td id="T_00c62_row0_col10" class="data row0 col10" >0.9100</td>
#       <td id="T_00c62_row0_col11" class="data row0 col11" >0.7400</td>
#       <td id="T_00c62_row0_col12" class="data row0 col12" >495</td>
#       <td id="T_00c62_row0_col13" class="data row0 col13" >2026-02-24</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00c62_row1_col0" class="data row1 col0" >24981</td>
#       <td id="T_00c62_row1_col1" class="data row1 col1" >PTG</td>
#       <td id="T_00c62_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_00c62_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_00c62_row1_col4" class="data row1 col4" >314,288</td>
#       <td id="T_00c62_row1_col5" class="data row1 col5" >228,393</td>
#       <td id="T_00c62_row1_col6" class="data row1 col6" >1,021,441</td>
#       <td id="T_00c62_row1_col7" class="data row1 col7" >1,021,805</td>
#       <td id="T_00c62_row1_col8" class="data row1 col8" >0.1900</td>
#       <td id="T_00c62_row1_col9" class="data row1 col9" >0.1300</td>
#       <td id="T_00c62_row1_col10" class="data row1 col10" >0.6100</td>
#       <td id="T_00c62_row1_col11" class="data row1 col11" >0.6100</td>
#       <td id="T_00c62_row1_col12" class="data row1 col12" >381</td>
#       <td id="T_00c62_row1_col13" class="data row1 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00c62_row2_col0" class="data row2 col0" >24993</td>
#       <td id="T_00c62_row2_col1" class="data row2 col1" >AWC</td>
#       <td id="T_00c62_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_00c62_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_00c62_row2_col4" class="data row2 col4" >1,866,088</td>
#       <td id="T_00c62_row2_col5" class="data row2 col5" >1,859,770</td>
#       <td id="T_00c62_row2_col6" class="data row2 col6" >6,388,002</td>
#       <td id="T_00c62_row2_col7" class="data row2 col7" >5,850,295</td>
#       <td id="T_00c62_row2_col8" class="data row2 col8" >0.0582</td>
#       <td id="T_00c62_row2_col9" class="data row2 col9" >0.0580</td>
#       <td id="T_00c62_row2_col10" class="data row2 col10" >0.1995</td>
#       <td id="T_00c62_row2_col11" class="data row2 col11" >0.1827</td>
#       <td id="T_00c62_row2_col12" class="data row2 col12" >699</td>
#       <td id="T_00c62_row2_col13" class="data row2 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00c62_row3_col0" class="data row3 col0" >24992</td>
#       <td id="T_00c62_row3_col1" class="data row3 col1" >CPF</td>
#       <td id="T_00c62_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_00c62_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_00c62_row3_col4" class="data row3 col4" >1,085,272</td>
#       <td id="T_00c62_row3_col5" class="data row3 col5" >4,172,528</td>
#       <td id="T_00c62_row3_col6" class="data row3 col6" >25,197,488</td>
#       <td id="T_00c62_row3_col7" class="data row3 col7" >19,558,133</td>
#       <td id="T_00c62_row3_col8" class="data row3 col8" >0.1100</td>
#       <td id="T_00c62_row3_col9" class="data row3 col9" >0.5100</td>
#       <td id="T_00c62_row3_col10" class="data row3 col10" >3.1200</td>
#       <td id="T_00c62_row3_col11" class="data row3 col11" >2.3900</td>
#       <td id="T_00c62_row3_col12" class="data row3 col12" >117</td>
#       <td id="T_00c62_row3_col13" class="data row3 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00c62_row4_col0" class="data row4 col0" >24982</td>
#       <td id="T_00c62_row4_col1" class="data row4 col1" >CPNREIT</td>
#       <td id="T_00c62_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_00c62_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_00c62_row4_col4" class="data row4 col4" >1,484,839</td>
#       <td id="T_00c62_row4_col5" class="data row4 col5" >357,438</td>
#       <td id="T_00c62_row4_col6" class="data row4 col6" >3,460,976</td>
#       <td id="T_00c62_row4_col7" class="data row4 col7" >1,696,069</td>
#       <td id="T_00c62_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_00c62_row4_col9" class="data row4 col9" >0.0000</td>
#       <td id="T_00c62_row4_col10" class="data row4 col10" >0.0000</td>
#       <td id="T_00c62_row4_col11" class="data row4 col11" >0.0000</td>
#       <td id="T_00c62_row4_col12" class="data row4 col12" >647</td>
#       <td id="T_00c62_row4_col13" class="data row4 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00c62_row5_col0" class="data row5 col0" >24994</td>
#       <td id="T_00c62_row5_col1" class="data row5 col1" >AH</td>
#       <td id="T_00c62_row5_col2" class="data row5 col2" >2025</td>
#       <td id="T_00c62_row5_col3" class="data row5 col3" >4</td>
#       <td id="T_00c62_row5_col4" class="data row5 col4" >105,562</td>
#       <td id="T_00c62_row5_col5" class="data row5 col5" >119,895</td>
#       <td id="T_00c62_row5_col6" class="data row5 col6" >731,428</td>
#       <td id="T_00c62_row5_col7" class="data row5 col7" >746,961</td>
#       <td id="T_00c62_row5_col8" class="data row5 col8" >0.3200</td>
#       <td id="T_00c62_row5_col9" class="data row5 col9" >0.3700</td>
#       <td id="T_00c62_row5_col10" class="data row5 col10" >2.1800</td>
#       <td id="T_00c62_row5_col11" class="data row5 col11" >2.1500</td>
#       <td id="T_00c62_row5_col12" class="data row5 col12" >9</td>
#       <td id="T_00c62_row5_col13" class="data row5 col13" >2026-02-27</td>
#     </tr>
#     <tr>
#       <th id="T_00c62_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00c62_row6_col0" class="data row6 col0" >24995</td>
#       <td id="T_00c62_row6_col1" class="data row6 col1" >BCH</td>
#       <td id="T_00c62_row6_col2" class="data row6 col2" >2025</td>
#       <td id="T_00c62_row6_col3" class

# %%
df_tmp.shape
# Out:
# (12, 14)

# %% [markdown]
# ### Not yet published

# %%
sql = """
SELECT name
FROM epss
WHERE publish_date >= '2026-01-01'
"""
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# (150, 1)

# %%
names = epss["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'SCGP', 'SCC', 'MST', 'KBANK', 'SCB', 'KTB', 'TTB', 'BBL', 'KKP', 'STANLY', 'TSTH', 'DCC', 'KCE', 'MBAX', 'OR', 'GGC', 'PTTGC', 'PTTEP', '3BBIF', 'ADVANC', 'EPG', 'BCP', 'BCPG', 'VGI', 'SPRC', 'PLANB', 'PTL', 'TOP', 'IMPACT', 'TFFIF', 'KYE', 'BLAND', 'AOT', 'DRT', 'SINGER', 'JMART', 'JMT', 'SVI', 'LHK', 'GPSC', 'INOX', 'SMPC', 'ASK', 'DELTA', 'PSL', 'EGATIF', 'TTLPF', 'TR', 'GVREIT', 'BTSGIF', 'MINT', 'TMW', 'MC', 'LANNA', 'BTS', 'DIF', 'STA', 'PTT', 'NER', 'RCL', 'BLA', 'AIMIRT', 'CBG', 'DOHOME', 'MAJOR', 'TMT', 'WORK', 'TPIPL', 'SCCC', 'TIPCO', 'LIT', 'PDG', 'ASIAN', 'BEC', 'TCAP', 'PREB', 'ASW', 'STGT', 'TASCO', 'TPIPP', 'MTC', 'IRPC', 'GULF', 'SUPEREIF', 'MCS', 'SYNEX', 'WHAIR', 'WHART', 'THG', 'SIS', 'CKP', 'CPN', 'CPAXT', 'PCSGH', 'SJWD', 'HMPRO', 'TKS', 'QH', 'COM7', 'BJC', 'SPCG', 'SC', 'CENTEL', 'DCON', 'SPALI', 'BGRIM', 'MEGA', 'TTW', 'TKN', 'PTG', 'CPNREIT', 'RJH', 'SGP', 'BDMS', 'WHAUP', 'OSP', 'TK', 'BEM', 'PAP', 'CPALL', 'CPF', 'AWC', 'AH', 'BCH', 'CK', 'BAM', 'TTA', 'RATCH', 'PRM', 'M', 'ILM', 'BA', 'ASP', 'LPN', 'AP', 'WICE', 'BEAUTY', 'FSMART', 'EASTW', 'WHA', 'BPP', 'BANPU', 'VNG', 'SAPPE', 'III', 'SENA', 'TOA', 'TVO', 'ORI', 'IVL'"

# %%
sql = """
SELECT *
FROM buy
WHERE name NOT IN (%s)
ORDER BY name
"""
sql = sql % in_p
df_tmp = pd.read_sql(sql, const)
df_tmp
# Out:
# Empty DataFrame
# Columns: [name, date, volbuy, price, volsell, volbal, active, dividend, period, grade]
# Index: []

# %%
df_tmp.shape
# Out:
# (0, 10)

# %% [markdown]
# ### Comparison check between EPS and Buy

# %%
sql = """
SELECT name FROM buy WHERE active = 1 ORDER BY name"""
buy = pd.read_sql(sql, const)
buy.shape
# Out:
# (30, 1)

# %%
sql = '''
SELECT * 
FROM epss 
WHERE publish_date >= '%s' 
AND quarter = %s
'''
sql = sql % (select_date, quarter)
print(sql)
tdy_df = pd.read_sql(sql, conlt)
tdy_df.shape
# Out:
# SELECT *
# FROM epss
# WHERE publish_date >= '2026-02-24'
# AND quarter = 4
# (57, 14)

# %%
tdy_buy_df = tdy_df.merge(buy, on='name', how='inner')
tdy_buy_df.sort_values(by='name')
# Out:
#        id     name  year  quarter    q_amt    y_amt    aq_amt    ay_amt  \
# 5   24994       AH  2025        4   105562   119895    731428    746961
# 4   24993      AWC  2025        4  1866088  1859770   6388002   5850295
# 6   24995      BCH  2025        4   259498   233040   1316360   1282371
# 3   24992      CPF  2025        4  1085272  4172528  25197488  19558133
# 2   24982  CPNREIT  2025        4  1484839   357438   3460976   1696069
# 11  25021      IVL  2025        4 -4697188  1095694  -7348393 -19262126
# 10  25020      ORI  2025        4   105152  -266145    719936   1051790
# 1   24981      PTG  2025        4   314288   228393   1021441   1021805
# 7   25017     SENA  2025        4    35749    97807    323614    399608
# 0   24957    SYNEX  2025        4   193273   146914    769786    627721
# 8   25018      TOA  2025        4   844394   450683   2917013   1919604
# 9   25019      TVO  2025        4   521643   807667   2188791   2103105
#
#       q_eps   y_eps  aq_eps  ay_eps  ticker_id publish_date
# 5   0.32000  0.3700  2.1800  2.1500          9   2026-02-27
# 4   0.05820  0.0580  0.1995  0.1827        699   2026-02-26
# 6   0.11000  0.0900  0.5300  0.5100         51   2026-02-27
# 3   0.11000  0.5100  3.1200  2.3900        117   2026-02-26
# 2   0.00000  0.0000  0.0000  0.0000        647   2026-02-26
# 11 -0.88000  0.1200 -1.4700 -3.6500        231   2026-03-02
# 10  0.04280 -0.1084  0.2933  0.4286        339   2026-02-27
# 1   0.19000  0.1300  0.6100  0.6100        381   2026-02-25
# 7   0.02480  0.0678  0.2244  0.2771        437   2026-02-27
# 0   0.23000  0.1700  0.9100  0.7400        495   2026-02-24
# 8   0.43719  0.2318  1.5000  0.9600        645   2026-02-27
# 9   0.59000  0.9000  2.4600  2.3600        585   2026-02-27

# %%
sql = """
SELECT * 
FROM tickers
ORDER BY name"""
print(sql)
tickers = pd.read_sql(sql, conpg)
tickers[['name','id','market']].shape
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
# (396, 3)

# %%
tmp_df = tdy_buy_df.merge(tickers, on='name', how='inner')
tmp_df.shape
# Out:
# (12, 22)

# %%
tmp_df[['name','id_y','market']].sort_values(by='name')
# Out:
#        name  id_y                                     market
# 5        AH    11                             sSET / SETTHSI
# 4       AWC   668                            SET50 / SETTHSI
# 6       BCH    55                             SET100 / SETWB
# 3       CPF   121  SET50 / SETCLMV / SETHD / SETTHSI / SETWB
# 2   CPNREIT   127                                        SET
# 11      IVL   238                            SET50 / SETTHSI
# 10      ORI   347                   SET100 / SETHD / SETTHSI
# 1       PTG   387                   SET100 / SETHD / SETTHSI
# 7      SENA   443                                       sSET
# 0     SYNEX   504                           SET100 / SETTHSI
# 8       TOA   562                                    SETTHSI
# 9       TVO   594                      SET / SETTHSI / SETWB

# %%
const.close()
conpg.commit()
conpg.close()
conmy.commit()
conmy.close()
conlt.commit()
conlt.close()

# %%
current_time = datetime.now()
formatted_time = current_time.strftime("%Y:%m:%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026:03:02 10:38:05
