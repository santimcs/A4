# %%
import pandas as pd
import os
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

year = "2025"
quarter = "4"
select_date = date.today()
select_date = select_date.strftime("%Y-%m-%d")
print(select_date)
# Out:
# 2026-03-12

# %%
select_date = date(2026, 1, 1)
select_date = select_date.strftime("%Y-%m-%d")
print(select_date)
# Out:
# 2026-01-01

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Excel path (xsl_path): {xsl_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Quarterly
# Base path: C:\Users\PC1\OneDrive\A4
# Data path (dat_path): C:\Users\PC1\OneDrive\A4\Data
# Excel path (xsl_path): C:\Users\PC1\OneDrive\A4\Excel
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Restart and Run All

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()

format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:.2f}%','acc_pct':'{:.2f}%'
              }

# %%
pd.read_sql_query('SELECT * FROM EPSS ORDER BY id DESC LIMIT 5', conlt).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_03436">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03436_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_03436_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_03436_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_03436_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_03436_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_03436_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_03436_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_03436_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_03436_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_03436_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_03436_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_03436_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_03436_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_03436_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03436_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03436_row0_col0" class="data row0 col0" >25099</td>
#       <td id="T_03436_row0_col1" class="data row0 col1" >VIBHA</td>
#       <td id="T_03436_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_03436_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_03436_row0_col4" class="data row0 col4" >1,226,409</td>
#       <td id="T_03436_row0_col5" class="data row0 col5" >-79,700</td>
#       <td id="T_03436_row0_col6" class="data row0 col6" >1,694,895</td>
#       <td id="T_03436_row0_col7" class="data row0 col7" >698,606</td>
#       <td id="T_03436_row0_col8" class="data row0 col8" >0.0909</td>
#       <td id="T_03436_row0_col9" class="data row0 col9" >-0.0058</td>
#       <td id="T_03436_row0_col10" class="data row0 col10" >0.1257</td>
#       <td id="T_03436_row0_col11" class="data row0 col11" >0.0517</td>
#       <td id="T_03436_row0_col12" class="data row0 col12" >610</td>
#       <td id="T_03436_row0_col13" class="data row0 col13" >2026-03-02</td>
#     </tr>
#     <tr>
#       <th id="T_03436_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03436_row1_col0" class="data row1 col0" >25098</td>
#       <td id="T_03436_row1_col1" class="data row1 col1" >UTP</td>
#       <td id="T_03436_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_03436_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_03436_row1_col4" class="data row1 col4" >112,363</td>
#       <td id="T_03436_row1_col5" class="data row1 col5" >132,127</td>
#       <td id="T_03436_row1_col6" class="data row1 col6" >511,579</td>
#       <td id="T_03436_row1_col7" class="data row1 col7" >619,691</td>
#       <td id="T_03436_row1_col8" class="data row1 col8" >0.1800</td>
#       <td id="T_03436_row1_col9" class="data row1 col9" >0.2000</td>
#       <td id="T_03436_row1_col10" class="data row1 col10" >0.7900</td>
#       <td id="T_03436_row1_col11" class="data row1 col11" >0.9500</td>
#       <td id="T_03436_row1_col12" class="data row1 col12" >605</td>
#       <td id="T_03436_row1_col13" class="data row1 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_03436_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03436_row2_col0" class="data row2 col0" >25097</td>
#       <td id="T_03436_row2_col1" class="data row2 col1" >TYCN</td>
#       <td id="T_03436_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_03436_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_03436_row2_col4" class="data row2 col4" >6,421</td>
#       <td id="T_03436_row2_col5" class="data row2 col5" >-76,073</td>
#       <td id="T_03436_row2_col6" class="data row2 col6" >133,090</td>
#       <td id="T_03436_row2_col7" class="data row2 col7" >-283,249</td>
#       <td id="T_03436_row2_col8" class="data row2 col8" >0.0100</td>
#       <td id="T_03436_row2_col9" class="data row2 col9" >-0.1200</td>
#       <td id="T_03436_row2_col10" class="data row2 col10" >0.2200</td>
#       <td id="T_03436_row2_col11" class="data row2 col11" >-0.4700</td>
#       <td id="T_03436_row2_col12" class="data row2 col12" >737</td>
#       <td id="T_03436_row2_col13" class="data row2 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_03436_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03436_row3_col0" class="data row3 col0" >25096</td>
#       <td id="T_03436_row3_col1" class="data row3 col1" >TU</td>
#       <td id="T_03436_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_03436_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_03436_row3_col4" class="data row3 col4" >1,013,243</td>
#       <td id="T_03436_row3_col5" class="data row3 col5" >1,212,989</td>
#       <td id="T_03436_row3_col6" class="data row3 col6" >4,609,416</td>
#       <td id="T_03436_row3_col7" class="data row3 col7" >4,984,894</td>
#       <td id="T_03436_row3_col8" class="data row3 col8" >0.2600</td>
#       <td id="T_03436_row3_col9" class="data row3 col9" >0.2700</td>
#       <td id="T_03436_row3_col10" class="data row3 col10" >1.1600</td>
#       <td id="T_03436_row3_col11" class="data row3 col11" >1.0800</td>
#       <td id="T_03436_row3_col12" class="data row3 col12" >582</td>
#       <td id="T_03436_row3_col13" class="data row3 col13" >2026-02-18</td>
#     </tr>
#     <tr>
#       <th id="T_03436_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03436_row4_col0" class="data row4 col0" >25095</td>
#       <td id="T_03436_row4_col1" class="data row4 col1" >TSE</td>
#       <td id="T_03436_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_03436_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_03436_row4_col4" class="data row4 col4" >-53,844</td>
#       <td id="T_03436_row4_col5" class="data row4 col5" >-756,623</td>
#       <td id="T_03436_row4_col6" class="data row4 col6" >46,735</td>
#       <td id="T_03436_row4_col7" class="data row4 col7" >-501,213</td>
#       <td id="T_03436_row4_col8" class="data row4 col8" >-0.0300</td>
#       <td id="T_03436_row4_col9" class="data row4 col9" >-0.3400</td>
#       <td id="T_03436_row4_col10" class="data row4 col10" >0.0200</td>
#       <td id="T_03436_row4_col11" class="data row4 col11" >-0.2400</td>
#       <td id="T_03436_row4_col12" class="data row4 col12" >573</td>
#       <td id="T_03436_row4_col13" class="data row4 col13" >2026-02-26</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = f"""
SELECT * 
FROM epss 
WHERE year = {year} AND quarter = {quarter}
AND publish_date >= '{select_date}'
"""
print(sql)

epss = pd.read_sql(sql, conlt)
epss.tail().style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2025 AND quarter = 4
# AND publish_date >= '2026-01-01'
# <style type="text/css">
# </style>
# <table id="T_c32fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c32fc_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_c32fc_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_c32fc_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_c32fc_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_c32fc_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_c32fc_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_c32fc_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_c32fc_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_c32fc_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_c32fc_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_c32fc_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_c32fc_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_c32fc_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_c32fc_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c32fc_level0_row0" class="row_heading level0 row0" >189</th>
#       <td id="T_c32fc_row0_col0" class="data row0 col0" >25095</td>
#       <td id="T_c32fc_row0_col1" class="data row0 col1" >TSE</td>
#       <td id="T_c32fc_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_c32fc_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_c32fc_row0_col4" class="data row0 col4" >-53,844</td>
#       <td id="T_c32fc_row0_col5" class="data row0 col5" >-756,623</td>
#       <td id="T_c32fc_row0_col6" class="data row0 col6" >46,735</td>
#       <td id="T_c32fc_row0_col7" class="data row0 col7" >-501,213</td>
#       <td id="T_c32fc_row0_col8" class="data row0 col8" >-0.0300</td>
#       <td id="T_c32fc_row0_col9" class="data row0 col9" >-0.3400</td>
#       <td id="T_c32fc_row0_col10" class="data row0 col10" >0.0200</td>
#       <td id="T_c32fc_row0_col11" class="data row0 col11" >-0.2400</td>
#       <td id="T_c32fc_row0_col12" class="data row0 col12" >573</td>
#       <td id="T_c32fc_row0_col13" class="data row0 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_c32fc_level0_row1" class="row_heading level0 row1" >190</th>
#       <td id="T_c32fc_row1_col0" class="data row1 col0" >25096</td>
#       <td id="T_c32fc_row1_col1" class="data row1 col1" >TU</td>
#       <td id="T_c32fc_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_c32fc_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_c32fc_row1_col4" class="data row1 col4" >1,013,243</td>
#       <td id="T_c32fc_row1_col5" class="data row1 col5" >1,212,989</td>
#       <td id="T_c32fc_row1_col6" class="data row1 col6" >4,609,416</td>
#       <td id="T_c32fc_row1_col7" class="data row1 col7" >4,984,894</td>
#       <td id="T_c32fc_row1_col8" class="data row1 col8" >0.2600</td>
#       <td id="T_c32fc_row1_col9" class="data row1 col9" >0.2700</td>
#       <td id="T_c32fc_row1_col10" class="data row1 col10" >1.1600</td>
#       <td id="T_c32fc_row1_col11" class="data row1 col11" >1.0800</td>
#       <td id="T_c32fc_row1_col12" class="data row1 col12" >582</td>
#       <td id="T_c32fc_row1_col13" class="data row1 col13" >2026-02-18</td>
#     </tr>
#     <tr>
#       <th id="T_c32fc_level0_row2" class="row_heading level0 row2" >191</th>
#       <td id="T_c32fc_row2_col0" class="data row2 col0" >25097</td>
#       <td id="T_c32fc_row2_col1" class="data row2 col1" >TYCN</td>
#       <td id="T_c32fc_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_c32fc_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_c32fc_row2_col4" class="data row2 col4" >6,421</td>
#       <td id="T_c32fc_row2_col5" class="data row2 col5" >-76,073</td>
#       <td id="T_c32fc_row2_col6" class="data row2 col6" >133,090</td>
#       <td id="T_c32fc_row2_col7" class="data row2 col7" >-283,249</td>
#       <td id="T_c32fc_row2_col8" class="data row2 col8" >0.0100</td>
#       <td id="T_c32fc_row2_col9" class="data row2 col9" >-0.1200</td>
#       <td id="T_c32fc_row2_col10" class="data row2 col10" >0.2200</td>
#       <td id="T_c32fc_row2_col11" class="data row2 col11" >-0.4700</td>
#       <td id="T_c32fc_row2_col12" class="data row2 col12" >737</td>
#       <td id="T_c32fc_row2_col13" class="data row2 col13" >2026-02-26</td>
#     </tr>
#     <tr>
#       <th id="T_c32fc_level0_row3" class="row_heading level0 row3" >192</th>
#       <td id="T_c32fc_row3_col0" class="data row3 col0" >25098</td>
#       <td id="T_c32fc_row3_col1" class="data row3 col1" >UTP</td>
#       <td id="T_c32fc_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_c32fc_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_c32fc_row3_col4" class="data row3 col4" >112,363</td>
#       <td id="T_c32fc_row3_col5" class="data row3 col5" >132,127</td>
#       <td id="T_c32fc_row3_col6" class="data row3 col6" >511,579</td>
#       <td id="T_c32fc_row3_col7" class="data row3 col7" >619,691</td>
#       <td id="T_c32fc_row3_col8" class="data row3 col8" >0.1800</td>
#       <td id="T_c32fc_row3_col9" class="data row3 col9" >0.2000</td>
#       <td id="T_c32fc_row3_col10" class="data row3 col10" >0.7900</td>
#       <td id="T_c32fc_row3_col11" class="data row3 col11" >0.9500</td>
#       <td id="T_c32fc_row3_col12" class="data row3 col12" >605</td>
#       <td id="T_c32fc_row3_col13" class="data row3 col13" >2026-02-25</td>
#     </tr>
#     <tr>
#       <th id="T_c32fc_level0_row4" class="row_heading level0 row4" >193</th>
#       <td id="T_c32fc_row4_col0" class="data row4 col0" >25099</td>
#       <td id="T_c32fc_row4_col1" class="data row4 col1" >VIBHA</td>
#       <td id="T_c32fc_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_c32fc_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_c32fc_row4_col4" class="data row4 col4" >1,226,409</td>
#       <td id="T_c32fc_row4_col5" class="data row4 col5" >-79,700</td>
#       <td id="T_c32fc_row4_col6" class="data row4 col6" >1,694,895</td>
#       <td id="T_c32fc_row4_col7" class="data row4 col7" >698,606</td>
#       <td id="T_c32fc_row4_col8" class="data row4 col8" >0.0909</td>
#       <td id="T_c32fc_row4_col9" class="data row4 col9" >-0.0058</td>
#       <td id="T_c32fc_row4_col10" class="data row4 col10" >0.1257</td>
#       <td id="T_c32fc_row4_col11" class="data row4 col11" >0.0517</td>
#       <td id="T_c32fc_row4_col12" class="data row4 col12" >610</td>
#       <td id="T_c32fc_row4_col13" class="data row4 col13" >2026-03-02</td>
#     </tr>
#   </tbody>
# </table>

# %%
epss["yoy_gain"] = epss["q_amt"] - epss["y_amt"]
epss["yoy_pct"] = round(epss["yoy_gain"] / abs(epss["y_amt"]) * 100, 2)
epss["acc_gain"] = epss["aq_amt"] - epss["ay_amt"]
epss["acc_pct"] = round(epss["acc_gain"] / abs(epss["ay_amt"]) * 100,2)

df_pct = epss[colt]
df_pct.tail().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_42827">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42827_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_42827_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_42827_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_42827_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_42827_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_42827_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_42827_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_42827_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_42827_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_42827_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_42827_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42827_level0_row0" class="row_heading level0 row0" >189</th>
#       <td id="T_42827_row0_col0" class="data row0 col0" >TSE</td>
#       <td id="T_42827_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_42827_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_42827_row0_col3" class="data row0 col3" >-53,844</td>
#       <td id="T_42827_row0_col4" class="data row0 col4" >-756,623</td>
#       <td id="T_42827_row0_col5" class="data row0 col5" >702,779</td>
#       <td id="T_42827_row0_col6" class="data row0 col6" >92.88%</td>
#       <td id="T_42827_row0_col7" class="data row0 col7" >46,735</td>
#       <td id="T_42827_row0_col8" class="data row0 col8" >-501,213</td>
#       <td id="T_42827_row0_col9" class="data row0 col9" >547,948</td>
#       <td id="T_42827_row0_col10" class="data row0 col10" >109.32%</td>
#     </tr>
#     <tr>
#       <th id="T_42827_level0_row1" class="row_heading level0 row1" >190</th>
#       <td id="T_42827_row1_col0" class="data row1 col0" >TU</td>
#       <td id="T_42827_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_42827_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_42827_row1_col3" class="data row1 col3" >1,013,243</td>
#       <td id="T_42827_row1_col4" class="data row1 col4" >1,212,989</td>
#       <td id="T_42827_row1_col5" class="data row1 col5" >-199,746</td>
#       <td id="T_42827_row1_col6" class="data row1 col6" >-16.47%</td>
#       <td id="T_42827_row1_col7" class="data row1 col7" >4,609,416</td>
#       <td id="T_42827_row1_col8" class="data row1 col8" >4,984,894</td>
#       <td id="T_42827_row1_col9" class="data row1 col9" >-375,478</td>
#       <td id="T_42827_row1_col10" class="data row1 col10" >-7.53%</td>
#     </tr>
#     <tr>
#       <th id="T_42827_level0_row2" class="row_heading level0 row2" >191</th>
#       <td id="T_42827_row2_col0" class="data row2 col0" >TYCN</td>
#       <td id="T_42827_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_42827_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_42827_row2_col3" class="data row2 col3" >6,421</td>
#       <td id="T_42827_row2_col4" class="data row2 col4" >-76,073</td>
#       <td id="T_42827_row2_col5" class="data row2 col5" >82,494</td>
#       <td id="T_42827_row2_col6" class="data row2 col6" >108.44%</td>
#       <td id="T_42827_row2_col7" class="data row2 col7" >133,090</td>
#       <td id="T_42827_row2_col8" class="data row2 col8" >-283,249</td>
#       <td id="T_42827_row2_col9" class="data row2 col9" >416,339</td>
#       <td id="T_42827_row2_col10" class="data row2 col10" >146.99%</td>
#     </tr>
#     <tr>
#       <th id="T_42827_level0_row3" class="row_heading level0 row3" >192</th>
#       <td id="T_42827_row3_col0" class="data row3 col0" >UTP</td>
#       <td id="T_42827_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_42827_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_42827_row3_col3" class="data row3 col3" >112,363</td>
#       <td id="T_42827_row3_col4" class="data row3 col4" >132,127</td>
#       <td id="T_42827_row3_col5" class="data row3 col5" >-19,764</td>
#       <td id="T_42827_row3_col6" class="data row3 col6" >-14.96%</td>
#       <td id="T_42827_row3_col7" class="data row3 col7" >511,579</td>
#       <td id="T_42827_row3_col8" class="data row3 col8" >619,691</td>
#       <td id="T_42827_row3_col9" class="data row3 col9" >-108,112</td>
#       <td id="T_42827_row3_col10" class="data row3 col10" >-17.45%</td>
#     </tr>
#     <tr>
#       <th id="T_42827_level0_row4" class="row_heading level0 row4" >193</th>
#       <td id="T_42827_row4_col0" class="data row4 col0" >VIBHA</td>
#       <td id="T_42827_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_42827_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_42827_row4_col3" class="data row4 col3" >1,226,409</td>
#       <td id="T_42827_row4_col4" class="data row4 col4" >-79,700</td>
#       <td id="T_42827_row4_col5" class="data row4 col5" >1,306,109</td>
#       <td id="T_42827_row4_col6" class="data row4 col6" >1638.78%</td>
#       <td id="T_42827_row4_col7" class="data row4 col7" >1,694,895</td>
#       <td id="T_42827_row4_col8" class="data row4 col8" >698,606</td>
#       <td id="T_42827_row4_col9" class="data row4 col9" >996,289</td>
#       <td id="T_42827_row4_col10" class="data row4 col10" >142.61%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_1 = df_pct.q_amt > 110_000
df_pct.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8073">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8073_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e8073_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_e8073_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_e8073_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_e8073_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_e8073_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_e8073_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8073_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8073_row0_col0" class="data row0 col0" >SCGP</td>
#       <td id="T_e8073_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_e8073_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_e8073_row0_col3" class="data row0 col3" >1,206,601</td>
#       <td id="T_e8073_row0_col4" class="data row0 col4" >-56,580</td>
#       <td id="T_e8073_row0_col5" class="data row0 col5" >1,263,181</td>
#       <td id="T_e8073_row0_col6" class="data row0 col6" >2232.56%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_e8073_row1_col0" class="data row1 col0" >KBANK</td>
#       <td id="T_e8073_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_e8073_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_e8073_row1_col3" class="data row1 col3" >10,277,938</td>
#       <td id="T_e8073_row1_col4" class="data row1 col4" >10,768,164</td>
#       <td id="T_e8073_row1_col5" class="data row1 col5" >-490,226</td>
#       <td id="T_e8073_row1_col6" class="data row1 col6" >-4.55%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_e8073_row2_col0" class="data row2 col0" >SCB</td>
#       <td id="T_e8073_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_e8073_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_e8073_row2_col3" class="data row2 col3" >10,143,570</td>
#       <td id="T_e8073_row2_col4" class="data row2 col4" >11,706,708</td>
#       <td id="T_e8073_row2_col5" class="data row2 col5" >-1,563,138</td>
#       <td id="T_e8073_row2_col6" class="data row2 col6" >-13.35%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_e8073_row3_col0" class="data row3 col0" >KTB</td>
#       <td id="T_e8073_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_e8073_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_e8073_row3_col3" class="data row3 col3" >10,772,802</td>
#       <td id="T_e8073_row3_col4" class="data row3 col4" >10,989,685</td>
#       <td id="T_e8073_row3_col5" class="data row3 col5" >-216,883</td>
#       <td id="T_e8073_row3_col6" class="data row3 col6" >-1.97%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_e8073_row4_col0" class="data row4 col0" >TTB</td>
#       <td id="T_e8073_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_e8073_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_e8073_row4_col3" class="data row4 col3" >5,240,051</td>
#       <td id="T_e8073_row4_col4" class="data row4 col4" >4,992,169</td>
#       <td id="T_e8073_row4_col5" class="data row4 col5" >247,882</td>
#       <td id="T_e8073_row4_col6" class="data row4 col6" >4.97%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_e8073_row5_col0" class="data row5 col0" >BBL</td>
#       <td id="T_e8073_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_e8073_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_e8073_row5_col3" class="data row5 col3" >7,759,383</td>
#       <td id="T_e8073_row5_col4" class="data row5 col4" >10,404,312</td>
#       <td id="T_e8073_row5_col5" class="data row5 col5" >-2,644,929</td>
#       <td id="T_e8073_row5_col6" class="data row5 col6" >-25.42%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_e8073_row6_col0" class="data row6 col0" >KKP</td>
#       <td id="T_e8073_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_e8073_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_e8073_row6_col3" class="data row6 col3" >1,772,010</td>
#       <td id="T_e8073_row6_col4" class="data row6 col4" >1,451,311</td>
#       <td id="T_e8073_row6_col5" class="data row6 col5" >320,699</td>
#       <td id="T_e8073_row6_col6" class="data row6 col6" >22.10%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_e8073_row7_col0" class="data row7 col0" >DCC</td>
#       <td id="T_e8073_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_e8073_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_e8073_row7_col3" class="data row7 col3" >179,725</td>
#       <td id="T_e8073_row7_col4" class="data row7 col4" >243,419</td>
#       <td id="T_e8073_row7_col5" class="data row7 col5" >-63,694</td>
#       <td id="T_e8073_row7_col6" class="data row7 col6" >-26.17%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_e8073_row8_col0" class="data row8 col0" >KCE</td>
#       <td id="T_e8073_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_e8073_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_e8073_row8_col3" class="data row8 col3" >123,338</td>
#       <td id="T_e8073_row8_col4" class="data row8 col4" >281,690</td>
#       <td id="T_e8073_row8_col5" class="data row8 col5" >-158,352</td>
#       <td id="T_e8073_row8_col6" class="data row8 col6" >-56.21%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_e8073_row9_col0" class="data row9 col0" >OR</td>
#       <td id="T_e8073_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_e8073_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_e8073_row9_col3" class="data row9 col3" >2,078,026</td>
#       <td id="T_e8073_row9_col4" class="data row9 col4" >2,999,371</td>
#       <td id="T_e8073_row9_col5" class="data row9 col5" >-921,345</td>
#       <td id="T_e8073_row9_col6" class="data row9 col6" >-30.72%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row10" class="row_heading level0 row10" >15</th>
#       <td id="T_e8073_row10_col0" class="data row10 col0" >PTTEP</td>
#       <td id="T_e8073_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_e8073_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_e8073_row10_col3" class="data row10 col3" >17,501,829</td>
#       <td id="T_e8073_row10_col4" class="data row10 col4" >18,299,177</td>
#       <td id="T_e8073_row10_col5" class="data row10 col5" >-797,348</td>
#       <td id="T_e8073_row10_col6" class="data row10 col6" >-4.36%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row11" class="row_heading level0 row11" >16</th>
#       <td id="T_e8073_row11_col0" class="data row11 col0" >3BBIF</td>
#       <td id="T_e8073_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_e8073_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_e8073_row11_col3" class="data row11 col3" >6,429,421</td>
#       <td id="T_e8073_row11_col4" class="data row11 col4" >3,961,184</td>
#       <td id="T_e8073_row11_col5" class="data row11 col5" >2,468,237</td>
#       <td id="T_e8073_row11_col6" class="data row11 col6" >62.31%</td>
#     </tr>
#     <tr>
#       <th id="T_e8073_level0_row12" class="row_heading level0 row12" >17</th>
#       <td id="T_e8073_row12_col0" class="data row12 col0" >ADVANC</td>
#       <td id="T_e8073_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_e8073_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_e8073_row12_col3" class="data row12

# %%
criteria_2 = df_pct.y_amt > 100_000
df_pct.loc[criteria_2, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4b4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4b4e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e4b4e_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_e4b4e_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_e4b4e_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_e4b4e_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_e4b4e_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_e4b4e_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4b4e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e4b4e_row0_col0" class="data row0 col0" >KBANK</td>
#       <td id="T_e4b4e_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_e4b4e_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_e4b4e_row0_col3" class="data row0 col3" >10,277,938</td>
#       <td id="T_e4b4e_row0_col4" class="data row0 col4" >10,768,164</td>
#       <td id="T_e4b4e_row0_col5" class="data row0 col5" >-490,226</td>
#       <td id="T_e4b4e_row0_col6" class="data row0 col6" >-4.55%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e4b4e_row1_col0" class="data row1 col0" >SCB</td>
#       <td id="T_e4b4e_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_e4b4e_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_e4b4e_row1_col3" class="data row1 col3" >10,143,570</td>
#       <td id="T_e4b4e_row1_col4" class="data row1 col4" >11,706,708</td>
#       <td id="T_e4b4e_row1_col5" class="data row1 col5" >-1,563,138</td>
#       <td id="T_e4b4e_row1_col6" class="data row1 col6" >-13.35%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e4b4e_row2_col0" class="data row2 col0" >KTB</td>
#       <td id="T_e4b4e_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_e4b4e_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_e4b4e_row2_col3" class="data row2 col3" >10,772,802</td>
#       <td id="T_e4b4e_row2_col4" class="data row2 col4" >10,989,685</td>
#       <td id="T_e4b4e_row2_col5" class="data row2 col5" >-216,883</td>
#       <td id="T_e4b4e_row2_col6" class="data row2 col6" >-1.97%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_e4b4e_row3_col0" class="data row3 col0" >TTB</td>
#       <td id="T_e4b4e_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_e4b4e_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_e4b4e_row3_col3" class="data row3 col3" >5,240,051</td>
#       <td id="T_e4b4e_row3_col4" class="data row3 col4" >4,992,169</td>
#       <td id="T_e4b4e_row3_col5" class="data row3 col5" >247,882</td>
#       <td id="T_e4b4e_row3_col6" class="data row3 col6" >4.97%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_e4b4e_row4_col0" class="data row4 col0" >BBL</td>
#       <td id="T_e4b4e_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_e4b4e_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_e4b4e_row4_col3" class="data row4 col3" >7,759,383</td>
#       <td id="T_e4b4e_row4_col4" class="data row4 col4" >10,404,312</td>
#       <td id="T_e4b4e_row4_col5" class="data row4 col5" >-2,644,929</td>
#       <td id="T_e4b4e_row4_col6" class="data row4 col6" >-25.42%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_e4b4e_row5_col0" class="data row5 col0" >KKP</td>
#       <td id="T_e4b4e_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_e4b4e_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_e4b4e_row5_col3" class="data row5 col3" >1,772,010</td>
#       <td id="T_e4b4e_row5_col4" class="data row5 col4" >1,451,311</td>
#       <td id="T_e4b4e_row5_col5" class="data row5 col5" >320,699</td>
#       <td id="T_e4b4e_row5_col6" class="data row5 col6" >22.10%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_e4b4e_row6_col0" class="data row6 col0" >DCC</td>
#       <td id="T_e4b4e_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_e4b4e_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_e4b4e_row6_col3" class="data row6 col3" >179,725</td>
#       <td id="T_e4b4e_row6_col4" class="data row6 col4" >243,419</td>
#       <td id="T_e4b4e_row6_col5" class="data row6 col5" >-63,694</td>
#       <td id="T_e4b4e_row6_col6" class="data row6 col6" >-26.17%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_e4b4e_row7_col0" class="data row7 col0" >KCE</td>
#       <td id="T_e4b4e_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_e4b4e_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_e4b4e_row7_col3" class="data row7 col3" >123,338</td>
#       <td id="T_e4b4e_row7_col4" class="data row7 col4" >281,690</td>
#       <td id="T_e4b4e_row7_col5" class="data row7 col5" >-158,352</td>
#       <td id="T_e4b4e_row7_col6" class="data row7 col6" >-56.21%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_e4b4e_row8_col0" class="data row8 col0" >OR</td>
#       <td id="T_e4b4e_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_e4b4e_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_e4b4e_row8_col3" class="data row8 col3" >2,078,026</td>
#       <td id="T_e4b4e_row8_col4" class="data row8 col4" >2,999,371</td>
#       <td id="T_e4b4e_row8_col5" class="data row8 col5" >-921,345</td>
#       <td id="T_e4b4e_row8_col6" class="data row8 col6" >-30.72%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_e4b4e_row9_col0" class="data row9 col0" >GGC</td>
#       <td id="T_e4b4e_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_e4b4e_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_e4b4e_row9_col3" class="data row9 col3" >75,467</td>
#       <td id="T_e4b4e_row9_col4" class="data row9 col4" >150,303</td>
#       <td id="T_e4b4e_row9_col5" class="data row9 col5" >-74,836</td>
#       <td id="T_e4b4e_row9_col6" class="data row9 col6" >-49.79%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row10" class="row_heading level0 row10" >15</th>
#       <td id="T_e4b4e_row10_col0" class="data row10 col0" >PTTEP</td>
#       <td id="T_e4b4e_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_e4b4e_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_e4b4e_row10_col3" class="data row10 col3" >17,501,829</td>
#       <td id="T_e4b4e_row10_col4" class="data row10 col4" >18,299,177</td>
#       <td id="T_e4b4e_row10_col5" class="data row10 col5" >-797,348</td>
#       <td id="T_e4b4e_row10_col6" class="data row10 col6" >-4.36%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row11" class="row_heading level0 row11" >16</th>
#       <td id="T_e4b4e_row11_col0" class="data row11 col0" >3BBIF</td>
#       <td id="T_e4b4e_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_e4b4e_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_e4b4e_row11_col3" class="data row11 col3" >6,429,421</td>
#       <td id="T_e4b4e_row11_col4" class="data row11 col4" >3,961,184</td>
#       <td id="T_e4b4e_row11_col5" class="data row11 col5" >2,468,237</td>
#       <td id="T_e4b4e_row11_col6" class="data row11 col6" >62.31%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b4e_level0_row12" class="row_heading level0 row12" >17</th>
#       <td id="T_e4b4e_row12_col0" class="data row12 col0" >ADVANC</td>
#       <td id="T_e4b4e_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_e4b4e_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_e4b4e_row12_col3" class="data row12 col3"

# %%
criteria_3 = df_pct.yoy_pct > 10.00
df_pct.loc[criteria_3, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd089">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd089_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bd089_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_bd089_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_bd089_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_bd089_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_bd089_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_bd089_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd089_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd089_row0_col0" class="data row0 col0" >SCGP</td>
#       <td id="T_bd089_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_bd089_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_bd089_row0_col3" class="data row0 col3" >1,206,601</td>
#       <td id="T_bd089_row0_col4" class="data row0 col4" >-56,580</td>
#       <td id="T_bd089_row0_col5" class="data row0 col5" >1,263,181</td>
#       <td id="T_bd089_row0_col6" class="data row0 col6" >2232.56%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_bd089_row1_col0" class="data row1 col0" >KKP</td>
#       <td id="T_bd089_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_bd089_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_bd089_row1_col3" class="data row1 col3" >1,772,010</td>
#       <td id="T_bd089_row1_col4" class="data row1 col4" >1,451,311</td>
#       <td id="T_bd089_row1_col5" class="data row1 col5" >320,699</td>
#       <td id="T_bd089_row1_col6" class="data row1 col6" >22.10%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_bd089_row2_col0" class="data row2 col0" >MBAX</td>
#       <td id="T_bd089_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_bd089_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_bd089_row2_col3" class="data row2 col3" >9,741</td>
#       <td id="T_bd089_row2_col4" class="data row2 col4" >-13,289</td>
#       <td id="T_bd089_row2_col5" class="data row2 col5" >23,030</td>
#       <td id="T_bd089_row2_col6" class="data row2 col6" >173.30%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_bd089_row3_col0" class="data row3 col0" >PTTGC</td>
#       <td id="T_bd089_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_bd089_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_bd089_row3_col3" class="data row3 col3" >-5,501,682</td>
#       <td id="T_bd089_row3_col4" class="data row3 col4" >-11,738,129</td>
#       <td id="T_bd089_row3_col5" class="data row3 col5" >6,236,447</td>
#       <td id="T_bd089_row3_col6" class="data row3 col6" >53.13%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_bd089_row4_col0" class="data row4 col0" >3BBIF</td>
#       <td id="T_bd089_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_bd089_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_bd089_row4_col3" class="data row4 col3" >6,429,421</td>
#       <td id="T_bd089_row4_col4" class="data row4 col4" >3,961,184</td>
#       <td id="T_bd089_row4_col5" class="data row4 col5" >2,468,237</td>
#       <td id="T_bd089_row4_col6" class="data row4 col6" >62.31%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_bd089_row5_col0" class="data row5 col0" >ADVANC</td>
#       <td id="T_bd089_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_bd089_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_bd089_row5_col3" class="data row5 col3" >14,281,630</td>
#       <td id="T_bd089_row5_col4" class="data row5 col4" >9,258,911</td>
#       <td id="T_bd089_row5_col5" class="data row5 col5" >5,022,719</td>
#       <td id="T_bd089_row5_col6" class="data row5 col6" >54.25%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_bd089_row6_col0" class="data row6 col0" >BCP</td>
#       <td id="T_bd089_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_bd089_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_bd089_row6_col3" class="data row6 col3" >2,216,608</td>
#       <td id="T_bd089_row6_col4" class="data row6 col4" >16,577</td>
#       <td id="T_bd089_row6_col5" class="data row6 col5" >2,200,031</td>
#       <td id="T_bd089_row6_col6" class="data row6 col6" >13271.59%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row7" class="row_heading level0 row7" >19</th>
#       <td id="T_bd089_row7_col0" class="data row7 col0" >BCPG</td>
#       <td id="T_bd089_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_bd089_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_bd089_row7_col3" class="data row7 col3" >727,248</td>
#       <td id="T_bd089_row7_col4" class="data row7 col4" >163,822</td>
#       <td id="T_bd089_row7_col5" class="data row7 col5" >563,426</td>
#       <td id="T_bd089_row7_col6" class="data row7 col6" >343.93%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row8" class="row_heading level0 row8" >20</th>
#       <td id="T_bd089_row8_col0" class="data row8 col0" >SPRC</td>
#       <td id="T_bd089_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_bd089_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_bd089_row8_col3" class="data row8 col3" >1,089,586</td>
#       <td id="T_bd089_row8_col4" class="data row8 col4" >162,121</td>
#       <td id="T_bd089_row8_col5" class="data row8 col5" >927,465</td>
#       <td id="T_bd089_row8_col6" class="data row8 col6" >572.08%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_bd089_row9_col0" class="data row9 col0" >DRT</td>
#       <td id="T_bd089_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_bd089_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_bd089_row9_col3" class="data row9 col3" >73,395</td>
#       <td id="T_bd089_row9_col4" class="data row9 col4" >65,825</td>
#       <td id="T_bd089_row9_col5" class="data row9 col5" >7,570</td>
#       <td id="T_bd089_row9_col6" class="data row9 col6" >11.50%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row10" class="row_heading level0 row10" >24</th>
#       <td id="T_bd089_row10_col0" class="data row10 col0" >SINGER</td>
#       <td id="T_bd089_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_bd089_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_bd089_row10_col3" class="data row10 col3" >59,940</td>
#       <td id="T_bd089_row10_col4" class="data row10 col4" >-103,465</td>
#       <td id="T_bd089_row10_col5" class="data row10 col5" >163,405</td>
#       <td id="T_bd089_row10_col6" class="data row10 col6" >157.93%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row11" class="row_heading level0 row11" >28</th>
#       <td id="T_bd089_row11_col0" class="data row11 col0" >GPSC</td>
#       <td id="T_bd089_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_bd089_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_bd089_row11_col3" class="data row11 col3" >1,497,839</td>
#       <td id="T_bd089_row11_col4" class="data row11 col4" >999,768</td>
#       <td id="T_bd089_row11_col5" class="data row11 col5" >498,071</td>
#       <td id="T_bd089_row11_col6" class="data row11 col6" >49.82%</td>
#     </tr>
#     <tr>
#       <th id="T_bd089_level0_row12" class="row_heading level0 row12" >31</th>
#       <td id="T_bd089_row12_col0" class="data row12 col0" >ASK</td>
#       <td id="T_bd089_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_bd089_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_bd089_row12_col3" class="data row12 col3" >160,073</

# %%
df_pct_criteria = criteria_1 & criteria_2 & criteria_3
#df_pct_criteria = criteria_1 & criteria_2 
df_pct.loc[df_pct_criteria, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_78333">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78333_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_78333_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_78333_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_78333_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_78333_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_78333_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_78333_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78333_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_78333_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_78333_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_78333_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_78333_row0_col3" class="data row0 col3" >1,772,010</td>
#       <td id="T_78333_row0_col4" class="data row0 col4" >1,451,311</td>
#       <td id="T_78333_row0_col5" class="data row0 col5" >320,699</td>
#       <td id="T_78333_row0_col6" class="data row0 col6" >22.10%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row1" class="row_heading level0 row1" >16</th>
#       <td id="T_78333_row1_col0" class="data row1 col0" >3BBIF</td>
#       <td id="T_78333_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_78333_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_78333_row1_col3" class="data row1 col3" >6,429,421</td>
#       <td id="T_78333_row1_col4" class="data row1 col4" >3,961,184</td>
#       <td id="T_78333_row1_col5" class="data row1 col5" >2,468,237</td>
#       <td id="T_78333_row1_col6" class="data row1 col6" >62.31%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_78333_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_78333_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_78333_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_78333_row2_col3" class="data row2 col3" >14,281,630</td>
#       <td id="T_78333_row2_col4" class="data row2 col4" >9,258,911</td>
#       <td id="T_78333_row2_col5" class="data row2 col5" >5,022,719</td>
#       <td id="T_78333_row2_col6" class="data row2 col6" >54.25%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_78333_row3_col0" class="data row3 col0" >BCPG</td>
#       <td id="T_78333_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_78333_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_78333_row3_col3" class="data row3 col3" >727,248</td>
#       <td id="T_78333_row3_col4" class="data row3 col4" >163,822</td>
#       <td id="T_78333_row3_col5" class="data row3 col5" >563,426</td>
#       <td id="T_78333_row3_col6" class="data row3 col6" >343.93%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_78333_row4_col0" class="data row4 col0" >SPRC</td>
#       <td id="T_78333_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_78333_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_78333_row4_col3" class="data row4 col3" >1,089,586</td>
#       <td id="T_78333_row4_col4" class="data row4 col4" >162,121</td>
#       <td id="T_78333_row4_col5" class="data row4 col5" >927,465</td>
#       <td id="T_78333_row4_col6" class="data row4 col6" >572.08%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row5" class="row_heading level0 row5" >28</th>
#       <td id="T_78333_row5_col0" class="data row5 col0" >GPSC</td>
#       <td id="T_78333_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_78333_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_78333_row5_col3" class="data row5 col3" >1,497,839</td>
#       <td id="T_78333_row5_col4" class="data row5 col4" >999,768</td>
#       <td id="T_78333_row5_col5" class="data row5 col5" >498,071</td>
#       <td id="T_78333_row5_col6" class="data row5 col6" >49.82%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row6" class="row_heading level0 row6" >32</th>
#       <td id="T_78333_row6_col0" class="data row6 col0" >DELTA</td>
#       <td id="T_78333_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_78333_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_78333_row6_col3" class="data row6 col3" >7,255,767</td>
#       <td id="T_78333_row6_col4" class="data row6 col4" >2,155,152</td>
#       <td id="T_78333_row6_col5" class="data row6 col5" >5,100,615</td>
#       <td id="T_78333_row6_col6" class="data row6 col6" >236.67%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row7" class="row_heading level0 row7" >33</th>
#       <td id="T_78333_row7_col0" class="data row7 col0" >PSL</td>
#       <td id="T_78333_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_78333_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_78333_row7_col3" class="data row7 col3" >345,009</td>
#       <td id="T_78333_row7_col4" class="data row7 col4" >249,387</td>
#       <td id="T_78333_row7_col5" class="data row7 col5" >95,622</td>
#       <td id="T_78333_row7_col6" class="data row7 col6" >38.34%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row8" class="row_heading level0 row8" >40</th>
#       <td id="T_78333_row8_col0" class="data row8 col0" >PTT</td>
#       <td id="T_78333_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_78333_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_78333_row8_col3" class="data row8 col3" >25,534,645</td>
#       <td id="T_78333_row8_col4" class="data row8 col4" >9,311,516</td>
#       <td id="T_78333_row8_col5" class="data row8 col5" >16,223,129</td>
#       <td id="T_78333_row8_col6" class="data row8 col6" >174.23%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row9" class="row_heading level0 row9" >43</th>
#       <td id="T_78333_row9_col0" class="data row9 col0" >BLA</td>
#       <td id="T_78333_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_78333_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_78333_row9_col3" class="data row9 col3" >1,344,964</td>
#       <td id="T_78333_row9_col4" class="data row9 col4" >1,031,417</td>
#       <td id="T_78333_row9_col5" class="data row9 col5" >313,547</td>
#       <td id="T_78333_row9_col6" class="data row9 col6" >30.40%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row10" class="row_heading level0 row10" >55</th>
#       <td id="T_78333_row10_col0" class="data row10 col0" >ASIAN</td>
#       <td id="T_78333_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_78333_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_78333_row10_col3" class="data row10 col3" >147,647</td>
#       <td id="T_78333_row10_col4" class="data row10 col4" >113,639</td>
#       <td id="T_78333_row10_col5" class="data row10 col5" >34,008</td>
#       <td id="T_78333_row10_col6" class="data row10 col6" >29.93%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row11" class="row_heading level0 row11" >57</th>
#       <td id="T_78333_row11_col0" class="data row11 col0" >TCAP</td>
#       <td id="T_78333_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_78333_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_78333_row11_col3" class="data row11 col3" >1,894,351</td>
#       <td id="T_78333_row11_col4" class="data row11 col4" >1,437,877</td>
#       <td id="T_78333_row11_col5" class="data row11 col5" >456,474</td>
#       <td id="T_78333_row11_col6" class="data row11 col6" >31.75%</td>
#     </tr>
#     <tr>
#       <th id="T_78333_level0_row12" class="row_heading level0 row12" >59</th>
#       <td id="T_78333_row12_col0" class="data row12 col0" >ASW</td>
#       <td id="T_78333_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_78333_row12_col2" class="data row12 col2" >4</td>
#       <td id="T_78333_row12_col3" class="data row12 col3" >388,

# %%
df_pct[df_pct_criteria].sort_values(by=["yoy_pct"], ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1abb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1abb_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c1abb_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_c1abb_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_c1abb_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_c1abb_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_c1abb_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_c1abb_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_c1abb_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_c1abb_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_c1abb_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_c1abb_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1abb_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_c1abb_row0_col0" class="data row0 col0" >SPRC</td>
#       <td id="T_c1abb_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_c1abb_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_c1abb_row0_col3" class="data row0 col3" >1,089,586</td>
#       <td id="T_c1abb_row0_col4" class="data row0 col4" >162,121</td>
#       <td id="T_c1abb_row0_col5" class="data row0 col5" >927,465</td>
#       <td id="T_c1abb_row0_col6" class="data row0 col6" >572.08%</td>
#       <td id="T_c1abb_row0_col7" class="data row0 col7" >2,569,355</td>
#       <td id="T_c1abb_row0_col8" class="data row0 col8" >2,234,887</td>
#       <td id="T_c1abb_row0_col9" class="data row0 col9" >334,468</td>
#       <td id="T_c1abb_row0_col10" class="data row0 col10" >14.97%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_c1abb_row1_col0" class="data row1 col0" >BCPG</td>
#       <td id="T_c1abb_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_c1abb_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_c1abb_row1_col3" class="data row1 col3" >727,248</td>
#       <td id="T_c1abb_row1_col4" class="data row1 col4" >163,822</td>
#       <td id="T_c1abb_row1_col5" class="data row1 col5" >563,426</td>
#       <td id="T_c1abb_row1_col6" class="data row1 col6" >343.93%</td>
#       <td id="T_c1abb_row1_col7" class="data row1 col7" >855,451</td>
#       <td id="T_c1abb_row1_col8" class="data row1 col8" >1,819,389</td>
#       <td id="T_c1abb_row1_col9" class="data row1 col9" >-963,938</td>
#       <td id="T_c1abb_row1_col10" class="data row1 col10" >-52.98%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row2" class="row_heading level0 row2" >93</th>
#       <td id="T_c1abb_row2_col0" class="data row2 col0" >CPNREIT</td>
#       <td id="T_c1abb_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_c1abb_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_c1abb_row2_col3" class="data row2 col3" >1,484,839</td>
#       <td id="T_c1abb_row2_col4" class="data row2 col4" >357,438</td>
#       <td id="T_c1abb_row2_col5" class="data row2 col5" >1,127,401</td>
#       <td id="T_c1abb_row2_col6" class="data row2 col6" >315.41%</td>
#       <td id="T_c1abb_row2_col7" class="data row2 col7" >3,460,976</td>
#       <td id="T_c1abb_row2_col8" class="data row2 col8" >1,696,069</td>
#       <td id="T_c1abb_row2_col9" class="data row2 col9" >1,764,907</td>
#       <td id="T_c1abb_row2_col10" class="data row2 col10" >104.06%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row3" class="row_heading level0 row3" >32</th>
#       <td id="T_c1abb_row3_col0" class="data row3 col0" >DELTA</td>
#       <td id="T_c1abb_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_c1abb_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_c1abb_row3_col3" class="data row3 col3" >7,255,767</td>
#       <td id="T_c1abb_row3_col4" class="data row3 col4" >2,155,152</td>
#       <td id="T_c1abb_row3_col5" class="data row3 col5" >5,100,615</td>
#       <td id="T_c1abb_row3_col6" class="data row3 col6" >236.67%</td>
#       <td id="T_c1abb_row3_col7" class="data row3 col7" >24,814,324</td>
#       <td id="T_c1abb_row3_col8" class="data row3 col8" >18,938,580</td>
#       <td id="T_c1abb_row3_col9" class="data row3 col9" >5,875,744</td>
#       <td id="T_c1abb_row3_col10" class="data row3 col10" >31.03%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row4" class="row_heading level0 row4" >40</th>
#       <td id="T_c1abb_row4_col0" class="data row4 col0" >PTT</td>
#       <td id="T_c1abb_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_c1abb_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_c1abb_row4_col3" class="data row4 col3" >25,534,645</td>
#       <td id="T_c1abb_row4_col4" class="data row4 col4" >9,311,516</td>
#       <td id="T_c1abb_row4_col5" class="data row4 col5" >16,223,129</td>
#       <td id="T_c1abb_row4_col6" class="data row4 col6" >174.23%</td>
#       <td id="T_c1abb_row4_col7" class="data row4 col7" >90,166,373</td>
#       <td id="T_c1abb_row4_col8" class="data row4 col8" >90,072,026</td>
#       <td id="T_c1abb_row4_col9" class="data row4 col9" >94,347</td>
#       <td id="T_c1abb_row4_col10" class="data row4 col10" >0.10%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row5" class="row_heading level0 row5" >184</th>
#       <td id="T_c1abb_row5_col0" class="data row5 col0" >THANI</td>
#       <td id="T_c1abb_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_c1abb_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_c1abb_row5_col3" class="data row5 col3" >314,934</td>
#       <td id="T_c1abb_row5_col4" class="data row5 col4" >122,701</td>
#       <td id="T_c1abb_row5_col5" class="data row5 col5" >192,233</td>
#       <td id="T_c1abb_row5_col6" class="data row5 col6" >156.67%</td>
#       <td id="T_c1abb_row5_col7" class="data row5 col7" >1,147,837</td>
#       <td id="T_c1abb_row5_col8" class="data row5 col8" >800,211</td>
#       <td id="T_c1abb_row5_col9" class="data row5 col9" >347,626</td>
#       <td id="T_c1abb_row5_col10" class="data row5 col10" >43.44%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row6" class="row_heading level0 row6" >59</th>
#       <td id="T_c1abb_row6_col0" class="data row6 col0" >ASW</td>
#       <td id="T_c1abb_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_c1abb_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_c1abb_row6_col3" class="data row6 col3" >388,304</td>
#       <td id="T_c1abb_row6_col4" class="data row6 col4" >156,717</td>
#       <td id="T_c1abb_row6_col5" class="data row6 col5" >231,587</td>
#       <td id="T_c1abb_row6_col6" class="data row6 col6" >147.77%</td>
#       <td id="T_c1abb_row6_col7" class="data row6 col7" >1,077,662</td>
#       <td id="T_c1abb_row6_col8" class="data row6 col8" >1,456,720</td>
#       <td id="T_c1abb_row6_col9" class="data row6 col9" >-379,058</td>
#       <td id="T_c1abb_row6_col10" class="data row6 col10" >-26.02%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row7" class="row_heading level0 row7" >95</th>
#       <td id="T_c1abb_row7_col0" class="data row7 col0" >SGP</td>
#       <td id="T_c1abb_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_c1abb_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_c1abb_row7_col3" class="data row7 col3" >667,107</td>
#       <td id="T_c1abb_row7_col4" class="data row7 col4" >273,010</td>
#       <td id="T_c1abb_row7_col5" class="data row7 col5" >394,097</td>
#       <td id="T_c1abb_row7_col6" class="data row7 col6" >144.35%</td>
#       <td id="T_c1abb_row7_col7" class="data row7 col7" >8,507</td>
#       <td id="T_c1abb_row7_col8" class="data row7 col8" >1,318,924</td>
#       <td id="T_c1abb_row7_col9" class="data row7 col9" >-1,310,417</td>
#       <td id="T_c1abb_row7_col10" class="data row7 col10" >-99.36%</td>
#     </tr>
#     <tr>
#       <th id="T_c1abb_level0_row8" class="row_heading level0 row8"

# %%
df_pct[df_pct_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_127c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_127c3_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_127c3_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_127c3_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_127c3_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_127c3_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_127c3_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_127c3_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_127c3_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_127c3_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_127c3_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_127c3_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_127c3_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_127c3_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_127c3_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_127c3_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_127c3_row0_col3" class="data row0 col3" >6,429,421</td>
#       <td id="T_127c3_row0_col4" class="data row0 col4" >3,961,184</td>
#       <td id="T_127c3_row0_col5" class="data row0 col5" >2,468,237</td>
#       <td id="T_127c3_row0_col6" class="data row0 col6" >62.31%</td>
#       <td id="T_127c3_row0_col7" class="data row0 col7" >7,044,205</td>
#       <td id="T_127c3_row0_col8" class="data row0 col8" >5,279,119</td>
#       <td id="T_127c3_row0_col9" class="data row0 col9" >1,765,086</td>
#       <td id="T_127c3_row0_col10" class="data row0 col10" >33.44%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_127c3_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_127c3_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_127c3_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_127c3_row1_col3" class="data row1 col3" >14,281,630</td>
#       <td id="T_127c3_row1_col4" class="data row1 col4" >9,258,911</td>
#       <td id="T_127c3_row1_col5" class="data row1 col5" >5,022,719</td>
#       <td id="T_127c3_row1_col6" class="data row1 col6" >54.25%</td>
#       <td id="T_127c3_row1_col7" class="data row1 col7" >47,885,902</td>
#       <td id="T_127c3_row1_col8" class="data row1 col8" >35,075,357</td>
#       <td id="T_127c3_row1_col9" class="data row1 col9" >12,810,545</td>
#       <td id="T_127c3_row1_col10" class="data row1 col10" >36.52%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row2" class="row_heading level0 row2" >55</th>
#       <td id="T_127c3_row2_col0" class="data row2 col0" >ASIAN</td>
#       <td id="T_127c3_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_127c3_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_127c3_row2_col3" class="data row2 col3" >147,647</td>
#       <td id="T_127c3_row2_col4" class="data row2 col4" >113,639</td>
#       <td id="T_127c3_row2_col5" class="data row2 col5" >34,008</td>
#       <td id="T_127c3_row2_col6" class="data row2 col6" >29.93%</td>
#       <td id="T_127c3_row2_col7" class="data row2 col7" >681,832</td>
#       <td id="T_127c3_row2_col8" class="data row2 col8" >848,397</td>
#       <td id="T_127c3_row2_col9" class="data row2 col9" >-166,565</td>
#       <td id="T_127c3_row2_col10" class="data row2 col10" >-19.63%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row3" class="row_heading level0 row3" >59</th>
#       <td id="T_127c3_row3_col0" class="data row3 col0" >ASW</td>
#       <td id="T_127c3_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_127c3_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_127c3_row3_col3" class="data row3 col3" >388,304</td>
#       <td id="T_127c3_row3_col4" class="data row3 col4" >156,717</td>
#       <td id="T_127c3_row3_col5" class="data row3 col5" >231,587</td>
#       <td id="T_127c3_row3_col6" class="data row3 col6" >147.77%</td>
#       <td id="T_127c3_row3_col7" class="data row3 col7" >1,077,662</td>
#       <td id="T_127c3_row3_col8" class="data row3 col8" >1,456,720</td>
#       <td id="T_127c3_row3_col9" class="data row3 col9" >-379,058</td>
#       <td id="T_127c3_row3_col10" class="data row3 col10" >-26.02%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row4" class="row_heading level0 row4" >139</th>
#       <td id="T_127c3_row4_col0" class="data row4 col0" >BAY</td>
#       <td id="T_127c3_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_127c3_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_127c3_row4_col3" class="data row4 col3" >7,126,696</td>
#       <td id="T_127c3_row4_col4" class="data row4 col4" >6,276,008</td>
#       <td id="T_127c3_row4_col5" class="data row4 col5" >850,688</td>
#       <td id="T_127c3_row4_col6" class="data row4 col6" >13.55%</td>
#       <td id="T_127c3_row4_col7" class="data row4 col7" >31,738,438</td>
#       <td id="T_127c3_row4_col8" class="data row4 col8" >29,699,751</td>
#       <td id="T_127c3_row4_col9" class="data row4 col9" >2,038,687</td>
#       <td id="T_127c3_row4_col10" class="data row4 col10" >6.86%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row5" class="row_heading level0 row5" >106</th>
#       <td id="T_127c3_row5_col0" class="data row5 col0" >BCH</td>
#       <td id="T_127c3_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_127c3_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_127c3_row5_col3" class="data row5 col3" >259,498</td>
#       <td id="T_127c3_row5_col4" class="data row5 col4" >233,040</td>
#       <td id="T_127c3_row5_col5" class="data row5 col5" >26,458</td>
#       <td id="T_127c3_row5_col6" class="data row5 col6" >11.35%</td>
#       <td id="T_127c3_row5_col7" class="data row5 col7" >1,316,360</td>
#       <td id="T_127c3_row5_col8" class="data row5 col8" >1,282,371</td>
#       <td id="T_127c3_row5_col9" class="data row5 col9" >33,989</td>
#       <td id="T_127c3_row5_col10" class="data row5 col10" >2.65%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_127c3_row6_col0" class="data row6 col0" >BCPG</td>
#       <td id="T_127c3_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_127c3_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_127c3_row6_col3" class="data row6 col3" >727,248</td>
#       <td id="T_127c3_row6_col4" class="data row6 col4" >163,822</td>
#       <td id="T_127c3_row6_col5" class="data row6 col5" >563,426</td>
#       <td id="T_127c3_row6_col6" class="data row6 col6" >343.93%</td>
#       <td id="T_127c3_row6_col7" class="data row6 col7" >855,451</td>
#       <td id="T_127c3_row6_col8" class="data row6 col8" >1,819,389</td>
#       <td id="T_127c3_row6_col9" class="data row6 col9" >-963,938</td>
#       <td id="T_127c3_row6_col10" class="data row6 col10" >-52.98%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row7" class="row_heading level0 row7" >43</th>
#       <td id="T_127c3_row7_col0" class="data row7 col0" >BLA</td>
#       <td id="T_127c3_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_127c3_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_127c3_row7_col3" class="data row7 col3" >1,344,964</td>
#       <td id="T_127c3_row7_col4" class="data row7 col4" >1,031,417</td>
#       <td id="T_127c3_row7_col5" class="data row7 col5" >313,547</td>
#       <td id="T_127c3_row7_col6" class="data row7 col6" >30.40%</td>
#       <td id="T_127c3_row7_col7" class="data row7 col7" >6,968,375</td>
#       <td id="T_127c3_row7_col8" class="data row7 col8" >4,633,856</td>
#       <td id="T_127c3_row7_col9" class="data row7 col9" >2,334,519</td>
#       <td id="T_127c3_row7_col10" class="data row7 col10" >50.38%</td>
#     </tr>
#     <tr>
#       <th id="T_127c3_level0_row8" class="row_heading level0 row8" >85<

# %%
stock_list = epss['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','BCP','BCPG','SPRC','PLANB','TOP','DRT','SINGER','JMART','JMT','SVI','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','MINT','LANNA','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
sql = f"""
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN ('{stock_list_str}')
ORDER BY E.name, year DESC, quarter DESC 
"""
print(sql)

epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','BCP','BCPG','SPRC','PLANB','TOP','DRT','SINGER','JMART','JMT','SVI','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','MINT','LANNA','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA')
# ORDER BY E.name, year DESC, quarter DESC
# (8951, 11)

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
print(stock_list_str)
# Out:
# SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','BCP','BCPG','SPRC','PLANB','TOP','DRT','SINGER','JMART','JMT','SVI','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','MINT','LANNA','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA

# %%
sqlDel = f"""
    DELETE FROM profits 
    WHERE name IN ('{stock_list_str}')
    AND quarter < {quarter}
"""
print(sqlDel)
# Execute with parameters
rp = conlt.execute(text(sqlDel))
rp.rowcount
# Out:
#     DELETE FROM profits
#     WHERE name IN ('SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','BCP','BCPG','SPRC','PLANB','TOP','DRT','SINGER','JMART','JMT','SVI','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','MINT','LANNA','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA')
#     AND quarter < 4
# 6

# %%
rp = conmy.execute(text(sqlDel))
rp.rowcount
# Out:
# 2

# %%
rp = conpg.execute(text(sqlDel))
rp.rowcount
# Out:
# 6

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index
# Out:
# Index(['3BBIF', 'ADVANC', 'BCP', 'DIF', 'FPT', 'GULF', 'KKP', 'MTC', 'NER',
#        'SCGP'],
#       dtype='object', name='name')

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index
# Out:
# Index(['2842', '2843', '2844', '2845', '2846', '2847', '2848', '2849', '2850',
#        '2851', '2851', '2852', '2853', '2854', '2855', '2856', '3BBIF',
#        'ADVANC', 'BCP', 'DIF', 'FPT', 'GULF', 'KKP', 'MTC', 'NER', 'SCGP'],
#       dtype='object', name='name')

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index
# Out:
# Index(['3BBIF', 'ADVANC', 'BCP', 'FPT', 'KKP', 'SCGP'], dtype='object', name='name')

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = f"""
SELECT * 
FROM tickers
WHERE name IN ('{stock_list_str}')
ORDER BY name"""
print(sql)
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','BCP','BCPG','SPRC','PLANB','TOP','DRT','SINGER','JMART','JMT','SVI','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','MINT','LANNA','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA')
# ORDER BY name

# %%
tickers = pd.read_sql(sql, conpg)
tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])
# Out:
#        name   id
# 0     3BBIF  241
# 1       ACE  667
# 2    ADVANC    8
# 3        AH   11
# 4       AIE  691
# ..      ...  ...
# 189   WHAIR  217
# 190   WHART  630
# 191   WHAUP  631
# 192    WICE  632
# 193    WORK  636
#
# [194 rows x 2 columns]

# %%
sql = """
SELECT name 
FROM buy
"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (27, 1)

# %%
df_merge = pd.merge(tickers, buys, on='name', how='inner')
df_merge
# Out:
#      id     name                                          full_name  \
# 0   241    3BBIF     JASMINE BROADBAND INTERNET INFRASTRUCTURE FUND
# 1     8   ADVANC       ADVANCED INFO SERVICE PUBLIC COMPANY LIMITED
# 2    11       AH               AAPICO HITECH PUBLIC COMPANY LIMITED
# 3   668      AWC            ASSET WORLD CORP PUBLIC COMPANY LIMITED
# 4    55      BCH      BANGKOK CHAIN HOSPITAL PUBLIC COMPANY LIMITED
# 5   121      CPF      CHAROEN POKPHAND FOODS PUBLIC COMPANY LIMITED
# 6   127  CPNREIT                   CPN RETAIL GROWTH LEASEHOLD REIT
# 7   146      DIF     DIGITAL TELECOMMUNICATIONS INFRASTRUCTURE FUND
# 8   238      IVL           INDORAMA VENTURES PUBLIC COMPANY LIMITED
# 9   245      JMT        JMT NETWORK SERVICES PUBLIC COMPANY LIMITED
# 10  301      MCS                 M.C.S.STEEL PUBLIC COMPANY LIMITED
# 11  649      NER           NORTH EAST RUBBER PUBLIC COMPANY LIMITED
# 12  347      ORI             ORIGIN PROPERTY PUBLIC COMPANY LIMITED
# 13  387      PTG                  PTG ENERGY PUBLIC COMPANY LIMITED
# 14  389      PTT                         PTT PUBLIC COMPANY LIMITED
# 15  391    PTTGC         PTT GLOBAL CHEMICAL PUBLIC COMPANY LIMITED
# 16  401      RCL    REGIONAL CONTAINER LINES PUBLIC COMPANY LIMITED
# 17  443     SENA             SENADEVELOPMENT PUBLIC COMPANY LIMITED
# 18  452   SINGER             SINGER THAILAND PUBLIC COMPANY LIMITED
# 19  489      STA     SRI TRANG AGRO-INDUSTRY PUBLIC COMPANY LIMITED
# 20  504    SYNEX           SYNNEX (THAILAND) PUBLIC COMPANY LIMITED
# 21  562      TOA        TOA PAINT (THAILAND) PUBLIC COMPANY LIMITED
# 22  594      TVO          THAI VEGETABLE OIL PUBLIC COMPANY LIMITED
# 23  217    WHAIR     HEMARAJ LEASEHOLD REAL ESTATE INVESTMENT TRUST
# 24  630    WHART  WHA PREMIUM GROWTH FREEHOLD AND LEASEHOLD REAL...
#
#                      sector                               subsector  \
# 0                Technology  Information & Communication Technology
# 1                Technology  Information & Communication Technology
# 2               Industrials                              Automotive
# 3   Property & Construction                    Property Development
# 4                  Services                    Health Care Services
# 5      Agro & Food Industry                         Food & Beverage
# 6   Property & Construction                   Property Fund & REITs
# 7                Technology  Information & Communication Technology
# 8               Industrials              Petrochemicals & Chemicals
# 9                Financials                    Finance & Securities
# 10              Industrials                Steel and Metal Products
# 11     Agro & Food Industry                            Agribusiness
# 12  Property & Construction                    Property Development
# 13                Resources                      Energy & Utilities
# 14                Resources                      Energy & Utilities
# 15              Industrials              Petrochemicals & Chemicals
# 16                 Services              Transportation & Logistics
# 17  Property & Construction                    Property Development
# 18                 Services                                Commerce
# 19     Agro & Food Industry                            Agribusiness
# 20               Technology  Information & Communication Technology
# 21  Property & Construction                  Construction Materials
# 22     Agro & Food Industry                         Food & Beverage
# 23  Property & Construction                   Property Fund & REITs
# 24  Property & Construction                   Property Fund & REITs
#
#                                        market  \
# 0                                         SET
# 1                     SET50 / SETHD / SETTHSI
# 2                              sSET / SETTHSI
# 3                             SET50 / SETTHSI
# 4                              SET100 / SETWB
# 5   SET50 / SETCLMV / SETHD / SETTHSI / SETWB
# 6                                         SET
# 7                                         SET
# 8                             SET50 / SETTHSI
# 9                                       SET50
# 10                                       sSET
# 11                                       sSET
# 12                   SET100 / SETHD / SETTHSI
# 13                   SET100 / SETHD / SETTHSI
# 14          SET50 / SETCLMV / SETHD / SETTHSI
# 15                  SET50 / SETCLMV / SETTHSI
# 16                           SET100 / SETCLMV
# 17                                       sSET
# 18                                     SET100
# 19                   SET100 / SETTHSI / SETWB
# 20                           SET100 / SETTHSI
# 21                                    SETTHSI
# 22                      SET / SETTHSI / SETWB
# 23                                        SET
# 24                                        SET
#
#                               website                 created_at  \
# 0                      www.jas-if.com 2018-04-22 04:29:37.600684
# 1                  investor.ais.co.th 2018-04-22 04:29:36.118727
# 2                      www.aapico.com 2018-04-22 04:29:36.134601
# 3   https://www.assetworldcorp-th.com 2019-11-19 07:13:52.454317
# 4        www.bangkokchainhospital.com 2018-04-22 04:29:36.442067
# 5                www.cpfworldwide.com 2018-04-22 04:29:36.867977
# 6                     www.cpnreit.com 2018-04-22 04:29:36.900508
# 7                 www.digital-tif.com 2018-04-22 04:29:37.030748
# 8            www.indoramaventures.com 2018-04-22 04:29:37.583373
# 9                www.jmtnetwork.co.th 2018-04-22 04:29:37.621811
# 10                   www.mcssteel.com 2018-04-22 04:29:37.957104
# 11                   www.nerubber.com 2019-03-03 03:45:01.837764
# 12                   www.origin.co.th 2018-04-22 04:29:38.228072
# 13                www.ptgenergy.co.th 2018-04-22 04:29:38.474708
# 14                     www.pttplc.com 2018-04-22 04:29:38.484745
# 15                 www.pttgcgroup.com 2018-04-22 04:29:38.496779
# 16                   www.rclgroup.com 2018-04-22 04:29:38.554599
# 17                     www.sena.co.th 2018-04-22 04:29:38.825191
# 18               www.singerthai.co.th 2018-04-22 04:29:38.875668
# 19              www.sritranggroup.com 2018-04-22 04:29:39.085589
# 20                   www.synnex.co.th 2018-04-22 04:29:39.170664
# 21                   www.toagroup.com 2018-04-22 04:29:39.494571
# 22                    www.tvothai.com 2018-04-22 04:29:39.677962
# 23                www.hemarajreit.com 2018-04-22 04:29:37.460955
# 24                    www.whareit.com 2018-04-22 04:29:39.879467
#
#                    updated_at
# 0  2019-03-03 03:45:01.621634
# 1  2021-07-07 03:33:38.798595
# 2  2021-07-07 03:33:38.806441
# 3  2022-01-15 03:54:48.241937
# 4  2019-11-19 07:13:52.520896
# 5  2021-07-07 03:33:38.893396
# 6  2018-04-22 04:29:36.900508
# 7  2018-04-22 04:29:37.030748
# 8  2021-07-07 03:33:38.986666
# 9  2020-07-06 13:23:59.311892
# 10 2021-08-22 18:22:07.463483
# 11 2019-11-19 07:13:53.611284
# 12 2022-01-15 03:54:48.440923
# 13 2022-01-15 03:54:48.464340
# 14 2019-11-19 07:13:53.785316
# 15 2021-07-07 03:33:39.100623
# 16 2022-01-15 03:54:48.472788
# 17 2018-04-22 04:29:38.825191
# 18 2021-07-07 03:33:39.150064
# 19 2022-01-15 03:54:48.525517
# 20 2021-07-07 03:33:39.202279
# 21 2021-07-07 03:33:39.241053
# 22 2019-11-19 07:13:54.470342
# 23 2018-04-22 04:29:37.460955
# 24 2018-04-22 04:29:39.879467

# %%
file_name = 'pub_stock.xlsx'
output_file = os.path.join(dat_path, file_name)
print(f"Output file : {output_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\pub_stock.xlsx

# %%
df_merge[['id','name','sector','market']].to_excel(output_file, index=False)

# %% [markdown]
# ### Portfolio that already published

# %%
sql = """
SELECT * 
FROM buy"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (27, 10)

# %%
stock_list = buys['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# STA','SINGER','PTG','PTT','MCS','DIF','ADVANC','JMT','WHART','BCH','SENA','TFFIF','3BBIF','CPF','IVL','PTTGC','WHAIR','ORI','AH','GVREIT','NER','TOA','AWC','SYNEX','RCL','CPNREIT','TVO

# %%
sql = f"""
SELECT *
FROM epss
WHERE publish_date >= '{select_date}'
AND name IN ('{stock_list_str}')
ORDER BY publish_date, name"""
print(sql)
df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE publish_date >= '2026-01-01'
# AND name IN ('STA','SINGER','PTG','PTT','MCS','DIF','ADVANC','JMT','WHART','BCH','SENA','TFFIF','3BBIF','CPF','IVL','PTTGC','WHAIR','ORI','AH','GVREIT','NER','TOA','AWC','SYNEX','RCL','CPNREIT','TVO')
# ORDER BY publish_date, name
# <style type="text/css">
# </style>
# <table id="T_83bac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83bac_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_83bac_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_83bac_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_83bac_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_83bac_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_83bac_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_83bac_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_83bac_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_83bac_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_83bac_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_83bac_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_83bac_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_83bac_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_83bac_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83bac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83bac_row0_col0" class="data row0 col0" >24890</td>
#       <td id="T_83bac_row0_col1" class="data row0 col1" >3BBIF</td>
#       <td id="T_83bac_row0_col2" class="data row0 col2" >2025</td>
#       <td id="T_83bac_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_83bac_row0_col4" class="data row0 col4" >6,429,421</td>
#       <td id="T_83bac_row0_col5" class="data row0 col5" >3,961,184</td>
#       <td id="T_83bac_row0_col6" class="data row0 col6" >7,044,205</td>
#       <td id="T_83bac_row0_col7" class="data row0 col7" >5,279,119</td>
#       <td id="T_83bac_row0_col8" class="data row0 col8" >-0.2505</td>
#       <td id="T_83bac_row0_col9" class="data row0 col9" >-0.5370</td>
#       <td id="T_83bac_row0_col10" class="data row0 col10" >0.0000</td>
#       <td id="T_83bac_row0_col11" class="data row0 col11" >0.0000</td>
#       <td id="T_83bac_row0_col12" class="data row0 col12" >234</td>
#       <td id="T_83bac_row0_col13" class="data row0 col13" >2026-02-03</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83bac_row1_col0" class="data row1 col0" >24891</td>
#       <td id="T_83bac_row1_col1" class="data row1 col1" >ADVANC</td>
#       <td id="T_83bac_row1_col2" class="data row1 col2" >2025</td>
#       <td id="T_83bac_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_83bac_row1_col4" class="data row1 col4" >14,281,630</td>
#       <td id="T_83bac_row1_col5" class="data row1 col5" >9,258,911</td>
#       <td id="T_83bac_row1_col6" class="data row1 col6" >47,885,902</td>
#       <td id="T_83bac_row1_col7" class="data row1 col7" >35,075,357</td>
#       <td id="T_83bac_row1_col8" class="data row1 col8" >4.8000</td>
#       <td id="T_83bac_row1_col9" class="data row1 col9" >3.1100</td>
#       <td id="T_83bac_row1_col10" class="data row1 col10" >16.1000</td>
#       <td id="T_83bac_row1_col11" class="data row1 col11" >11.7900</td>
#       <td id="T_83bac_row1_col12" class="data row1 col12" >6</td>
#       <td id="T_83bac_row1_col13" class="data row1 col13" >2026-02-03</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83bac_row2_col0" class="data row2 col0" >24888</td>
#       <td id="T_83bac_row2_col1" class="data row2 col1" >PTTGC</td>
#       <td id="T_83bac_row2_col2" class="data row2 col2" >2025</td>
#       <td id="T_83bac_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_83bac_row2_col4" class="data row2 col4" >-5,501,682</td>
#       <td id="T_83bac_row2_col5" class="data row2 col5" >-11,738,129</td>
#       <td id="T_83bac_row2_col6" class="data row2 col6" >-14,600,390</td>
#       <td id="T_83bac_row2_col7" class="data row2 col7" >-29,810,548</td>
#       <td id="T_83bac_row2_col8" class="data row2 col8" >-1.4100</td>
#       <td id="T_83bac_row2_col9" class="data row2 col9" >-2.6100</td>
#       <td id="T_83bac_row2_col10" class="data row2 col10" >-3.6100</td>
#       <td id="T_83bac_row2_col11" class="data row2 col11" >-6.6200</td>
#       <td id="T_83bac_row2_col12" class="data row2 col12" >385</td>
#       <td id="T_83bac_row2_col13" class="data row2 col13" >2026-02-09</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83bac_row3_col0" class="data row3 col0" >24908</td>
#       <td id="T_83bac_row3_col1" class="data row3 col1" >JMT</td>
#       <td id="T_83bac_row3_col2" class="data row3 col2" >2025</td>
#       <td id="T_83bac_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_83bac_row3_col4" class="data row3 col4" >221,722</td>
#       <td id="T_83bac_row3_col5" class="data row3 col5" >400,174</td>
#       <td id="T_83bac_row3_col6" class="data row3 col6" >1,029,560</td>
#       <td id="T_83bac_row3_col7" class="data row3 col7" >1,615,223</td>
#       <td id="T_83bac_row3_col8" class="data row3 col8" >0.1600</td>
#       <td id="T_83bac_row3_col9" class="data row3 col9" >0.2800</td>
#       <td id="T_83bac_row3_col10" class="data row3 col10" >0.7100</td>
#       <td id="T_83bac_row3_col11" class="data row3 col11" >1.1100</td>
#       <td id="T_83bac_row3_col12" class="data row3 col12" >237</td>
#       <td id="T_83bac_row3_col13" class="data row3 col13" >2026-02-11</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83bac_row4_col0" class="data row4 col0" >24906</td>
#       <td id="T_83bac_row4_col1" class="data row4 col1" >SINGER</td>
#       <td id="T_83bac_row4_col2" class="data row4 col2" >2025</td>
#       <td id="T_83bac_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_83bac_row4_col4" class="data row4 col4" >59,940</td>
#       <td id="T_83bac_row4_col5" class="data row4 col5" >-103,465</td>
#       <td id="T_83bac_row4_col6" class="data row4 col6" >105,084</td>
#       <td id="T_83bac_row4_col7" class="data row4 col7" >-42,960</td>
#       <td id="T_83bac_row4_col8" class="data row4 col8" >0.0700</td>
#       <td id="T_83bac_row4_col9" class="data row4 col9" >-0.1200</td>
#       <td id="T_83bac_row4_col10" class="data row4 col10" >0.1300</td>
#       <td id="T_83bac_row4_col11" class="data row4 col11" >-0.0500</td>
#       <td id="T_83bac_row4_col12" class="data row4 col12" >446</td>
#       <td id="T_83bac_row4_col13" class="data row4 col13" >2026-02-12</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83bac_row5_col0" class="data row5 col0" >24901</td>
#       <td id="T_83bac_row5_col1" class="data row5 col1" >TFFIF</td>
#       <td id="T_83bac_row5_col2" class="data row5 col2" >2026</td>
#       <td id="T_83bac_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_83bac_row5_col4" class="data row5 col4" >557,399</td>
#       <td id="T_83bac_row5_col5" class="data row5 col5" >543,467</td>
#       <td id="T_83bac_row5_col6" class="data row5 col6" >557,399</td>
#       <td id="T_83bac_row5_col7" class="data row5 col7" >543,467</td>
#       <td id="T_83bac_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_83bac_row5_col9" class="data row5 col9" >0.0000</td>
#       <td id="T_83bac_row5_col10" class="data row5 col10" >0.0000</td>
#       <td id="T_83bac_row5_col11" class="data row5 col11" >0.0000</td>
#       <td id="T_83bac_row5_col12" class="data row5 col12" >686</td>
#       <td id="T_83bac_row5_col13" class="data row5 col13" >2026-02-12</td>
#     </tr>
#     <tr>
#       <th id="T_83bac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83bac_row6_col0" class="data row6 col0" >24920</td>
#       <td id="T_83bac_row6_col1" class="data row6 col1" >GVREIT</td>
#       <td id="T_83bac_row6_col2" class="data row6 col2" >2026</td>
#       <t

# %%
df_tmp.shape
# Out:
# (27, 14)

# %% [markdown]
# ### Not yet published

# %%
sql = f"""
SELECT name
FROM epss
WHERE publish_date >= '{select_date}'
"""
print(sql)
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# SELECT name
# FROM epss
# WHERE publish_date >= '2026-01-01'
# (211, 1)

# %%
stock_list = epss['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','STANLY','TSTH','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','EPG','BCP','BCPG','VGI','SPRC','PLANB','PTL','TOP','IMPACT','TFFIF','KYE','BLAND','AOT','DRT','SINGER','JMART','JMT','SVI','LHK','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','TR','GVREIT','BTSGIF','MINT','TMW','MC','LANNA','BTS','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA

# %%
sql = f"""
SELECT *
FROM buy
WHERE name NOT IN ('{stock_list_str}')
ORDER BY name
"""
print(sql)
df_tmp = pd.read_sql(sql, const)
df_tmp
# Out:
# SELECT *
# FROM buy
# WHERE name NOT IN ('SCGP','SCC','MST','KBANK','SCB','KTB','TTB','BBL','KKP','STANLY','TSTH','DCC','KCE','MBAX','OR','GGC','PTTGC','PTTEP','3BBIF','ADVANC','EPG','BCP','BCPG','VGI','SPRC','PLANB','PTL','TOP','IMPACT','TFFIF','KYE','BLAND','AOT','DRT','SINGER','JMART','JMT','SVI','LHK','GPSC','INOX','SMPC','ASK','DELTA','PSL','EGATIF','TTLPF','TR','GVREIT','BTSGIF','MINT','TMW','MC','LANNA','BTS','DIF','STA','PTT','NER','RCL','BLA','AIMIRT','CBG','DOHOME','MAJOR','TMT','WORK','TPIPL','SCCC','TIPCO','LIT','PDG','ASIAN','BEC','TCAP','PREB','ASW','STGT','TASCO','TPIPP','MTC','IRPC','GULF','SUPEREIF','MCS','SYNEX','WHAIR','WHART','THG','SIS','CKP','CPN','CPAXT','PCSGH','SJWD','HMPRO','TKS','QH','COM7','BJC','SPCG','SC','CENTEL','DCON','SPALI','BGRIM','MEGA','TTW','TKN','PTG','CPNREIT','RJH','SGP','BDMS','WHAUP','OSP','TK','BEM','PAP','CPALL','CPF','AWC','AH','BCH','CK','BAM','TTA','RATCH','PRM','M','ILM','BA','ASP','LPN','AP','WICE','BEAUTY','FSMART','EASTW','WHA','BPP','BANPU','VNG','SAPPE','III','SENA','TOA','TVO','ORI','IVL','ACE','AIE','AIT','AJ','AMATA','ANAN','BAY','BE8','BGC','BH','BKIH','CHG','CPNCG','CRC','EA','EGCO','FORTH','GC','GFPT','GLOBAL','GRAMMY','RS','S11','SAT','GUNKUL','HANA','HFT','HTC','ICHI','IMH','IP','KGI','LALIN','LH','LPH','NOBLE','ONEE','POPF','PSH','RBF','ROJNA','SAWAD','SIRI','SKN','SKR','SNC','SPC','SPRIME','SSP','SUPER','TFG','THANI','TIDLOR','TIPH','TQM','TRUE','TSE','TU','TYCN','UTP','VIBHA')
# ORDER BY name
# Empty DataFrame
# Columns: [name, date, volbuy, price, volsell, volbal, active, dividend, period, grade]
# Index: []

# %%
df_tmp.shape
# Out:
# (0, 10)

# %% [markdown]
# ### Comparison check between EPS and Buy

# %%
sql = """
SELECT name FROM buy WHERE active = 1 ORDER BY name"""
buy = pd.read_sql(sql, const)
buy.shape
# Out:
# (27, 1)

# %%
sql = f'''
SELECT * 
FROM epss 
WHERE publish_date >= '{select_date}' 
AND quarter = {quarter}
'''
print(sql)
tdy_df = pd.read_sql(sql, conlt)
tdy_df.shape
# Out:
# SELECT *
# FROM epss
# WHERE publish_date >= '2026-01-01'
# AND quarter = 4
# (194, 14)

# %%
tdy_buy_df = tdy_df.merge(buy, on='name', how='inner')
tdy_buy_df.sort_values(by='name')
# Out:
#        id     name  year  quarter     q_amt     y_amt    aq_amt    ay_amt  \
# 1   24890    3BBIF  2025        4   6429421   3961184   7044205   5279119
# 2   24891   ADVANC  2025        4  14281630   9258911  47885902  35075357
# 18  24994       AH  2025        4    105562    119895    731428    746961
# 17  24993      AWC  2025        4   1866088   1859770   6388002   5850295
# 19  24995      BCH  2025        4    259498    233040   1316360   1282371
# 16  24992      CPF  2025        4   1085272   4172528  25197488  19558133
# 15  24982  CPNREIT  2025        4   1484839    357438   3460976   1696069
# 5   24927      DIF  2025        4   5589388  -7397987  13855643    656288
# 24  25021      IVL  2025        4  -4697188   1095694  -7348393 -19262126
# 4   24908      JMT  2025        4    221722    400174   1029560   1615223
# 10  24956      MCS  2025        4    263400    346777    960010    678604
# 8   24930      NER  2025        4    395108    359321   1884525   1652466
# 23  25020      ORI  2025        4    105152   -266145    719936   1051790
# 14  24981      PTG  2025        4    314288    228393   1021441   1021805
# 7   24929      PTT  2025        4  25534645   9311516  90166373  90072026
# 0   24888    PTTGC  2025        4  -5501682 -11738129 -14600390 -29810548
# 9   24931      RCL  2025        4   1803382   3318461   8166901   9170542
# 20  25017     SENA  2025        4     35749     97807    323614    399608
# 3   24906   SINGER  2025        4     59940   -103465    105084    -42960
# 6   24928      STA  2025        4   -325739    854339  -1265710   1670375
# 11  24957    SYNEX  2025        4    193273    146914    769786    627721
# 21  25018      TOA  2025        4    844394    450683   2917013   1919604
# 22  25019      TVO  2025        4    521643    807667   2188791   2103105
# 12  24958    WHAIR  2025        4   -176793   -116575    413649    316443
# 13  24959    WHART  2025        4    390358    204671   2349806   1920947
#
#       q_eps   y_eps   aq_eps   ay_eps  ticker_id publish_date
# 1  -0.25050 -0.5370   0.0000   0.0000        234   2026-02-03
# 2   4.80000  3.1100  16.1000  11.7900          6   2026-02-03
# 18  0.32000  0.3700   2.1800   2.1500          9   2026-02-27
# 17  0.05820  0.0580   0.1995   0.1827        699   2026-02-26
# 19  0.11000  0.0900   0.5300   0.5100         51   2026-02-27
# 16  0.11000  0.5100   3.1200   2.3900        117   2026-02-26
# 15  0.00000  0.0000   0.0000   0.0000        647   2026-02-26
# 5   0.00000  0.0000   0.0000   0.0000        140   2026-02-18
# 24 -0.88000  0.1200  -1.4700  -3.6500        231   2026-03-02
# 4   0.16000  0.2800   0.7100   1.1100        237   2026-02-11
# 10  0.55000  0.7200   2.0100   1.4200        293   2026-02-23
# 8   0.21380  0.1945   1.0199   0.8943        680   2026-02-19
# 23  0.04280 -0.1084   0.2933   0.4286        339   2026-02-27
# 14  0.19000  0.1300   0.6100   0.6100        381   2026-02-25
# 7   0.89000  0.3200   3.1500   3.1500        383   2026-02-19
# 0  -1.41000 -2.6100  -3.6100  -6.6200        385   2026-02-09
# 9   2.17000  4.0100   9.8500  11.0700        396   2026-02-20
# 20  0.02480  0.0678   0.2244   0.2771        437   2026-02-27
# 3   0.07000 -0.1200   0.1300  -0.0500        446   2026-02-12
# 6  -0.21000  0.5600  -0.8200   1.0900        481   2026-02-19
# 11  0.23000  0.1700   0.9100   0.7400        495   2026-02-24
# 21  0.43719  0.2318   1.5000   0.9600        645   2026-02-27
# 22  0.59000  0.9000   2.4600   2.3600        585   2026-02-27
# 12  0.00000  0.0000   0.0000   0.0000        211   2026-02-23
# 13  0.00000  0.0000   0.0000   0.0000        622   2026-02-23

# %%
sql = """
SELECT * 
FROM tickers
ORDER BY name"""
print(sql)
tickers = pd.read_sql(sql, conpg)
tickers[['name','id','market']].shape
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
# (396, 3)

# %%
tmp_df = tdy_buy_df.merge(tickers, on='name', how='inner')
tmp_df.shape
# Out:
# (25, 22)

# %%
tmp_df[['name','id_y','market']].sort_values(by='name')
# Out:
#        name  id_y                                     market
# 1     3BBIF   241                                        SET
# 2    ADVANC     8                    SET50 / SETHD / SETTHSI
# 18       AH    11                             sSET / SETTHSI
# 17      AWC   668                            SET50 / SETTHSI
# 19      BCH    55                             SET100 / SETWB
# 16      CPF   121  SET50 / SETCLMV / SETHD / SETTHSI / SETWB
# 15  CPNREIT   127                                        SET
# 5       DIF   146                                        SET
# 24      IVL   238                            SET50 / SETTHSI
# 4       JMT   245                                      SET50
# 10      MCS   301                                       sSET
# 8       NER   649                                       sSET
# 23      ORI   347                   SET100 / SETHD / SETTHSI
# 14      PTG   387                   SET100 / SETHD / SETTHSI
# 7       PTT   389          SET50 / SETCLMV / SETHD / SETTHSI
# 0     PTTGC   391                  SET50 / SETCLMV / SETTHSI
# 9       RCL   401                           SET100 / SETCLMV
# 20     SENA   443                                       sSET
# 3    SINGER   452                                     SET100
# 6       STA   489                   SET100 / SETTHSI / SETWB
# 11    SYNEX   504                           SET100 / SETTHSI
# 21      TOA   562                                    SETTHSI
# 22      TVO   594                      SET / SETTHSI / SETWB
# 12    WHAIR   217                                        SET
# 13    WHART   630                                        SET

# %%
const.close()
conpg.commit()
conpg.close()
conmy.commit()
conmy.close()
conlt.commit()
conlt.close()

# %%
current_time = datetime.now()
formatted_time = current_time.strftime("%Y:%m:%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026:03:12 13:26:06
