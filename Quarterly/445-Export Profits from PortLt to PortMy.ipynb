# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

year = 2025
quarter = 4

current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2026-03-12 14:53:16

# %% [markdown]
# ### Insert Profits from PortLt to PortMy

# %%
sql = f"""
SELECT * 
FROM profits 
WHERE  year = {year} AND quarter = {quarter}"""
print(sql)

lt_profits = pd.read_sql(sql, conlt)
lt_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#       id     name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   2842    3BBIF  2025        4     1      10827771         5279119
# 1   2843   ADVANC  2025        4     1      47885902        35075357
# 2   2844      BCP  2025        4     1       2879701         2184088
# 3   2845      KKP  2025        4     1       5912913         4985068
# 4   2846     SCGP  2025        4     1       4069495         3699083
# 5   2847      DIF  2025        4     1      13855643          656288
# 6   2848     GULF  2025        4     1     101380618        18170334
# 7   2849      MTC  2025        4     1       6723275         5867308
# 8   2850      NER  2025        4     1       1884525         1652466
# 9   2851   CENTEL  2025        4     1       1992901         1752985
# 10  2852     COM7  2025        4     1       4063532         3307162
# 11  2853    CPALL  2025        4     1      28206100        25345841
# 12  2854  CPNREIT  2025        4     1       3460976         1696069
# 13  2855      SIS  2025        4     1        876418          697604
# 14  2856    THANI  2025        4     1       1147837          800211
# 15  2857      TOA  2025        4     1       2917013         1919604
# 16  2858    VIBHA  2025        4     1       1694894          698606
# 17  2859      WHA  2025        4     1       5135026         4359376
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  \
# 0     5548652     105.11      10827771  ...   6429421  3961184     2468237
# 1    12810545      36.52      47885902  ...  14281630  9258911     5022719
# 2      695613      31.85       2879701  ...   2216608    16577     2200031
# 3      927845      18.61       5912913  ...   1772010  1451311      320699
# 4      370412      10.01       4069495  ...   1206601   -56580     1263181
# 5    13199355    2011.21      13855643  ...   5589388 -7397987    12987375
# 6    83210284     457.95     101380618  ...   8851992        0     8851992
# 7      855967      14.59       6723275  ...   1781096  1542634      238462
# 8      232059      14.04       1884525  ...    395108   359321       35787
# 9      239916      13.69       1992901  ...    974352   667053      307299
# 10     756370      22.87       4063532  ...   1207698  1029675      178023
# 11    2860259      11.28      28206100  ...   7255879  7179100       76779
# 12    1764907     104.06       3460976  ...   1484839   357438     1127401
# 13     178814      25.63        876418  ...    264524   231949       32575
# 14     347626      43.44       1147837  ...    314934   122701      192233
# 15     997409      51.96       2917013  ...    844394   450683      393711
# 16     996288     142.61       1694894  ...   1226409   -79700     1306109
# 17     775650      17.79       5135026  ...   1445231  1246705      198526
#
#       inc_pct_py   q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id     mean_pct  \
# 0   6.231059e+01    183813     6245608  3397.805378        234   901.373991
# 1   5.424741e+01  12038861     2242769    18.629412          6    30.279204
# 2   1.327159e+04   1107896     1108712   100.073653         52  3431.800198
# 3   2.209719e+01   1669882      102128     6.115881        255    13.358269
# 4   2.232557e+03    953229      253372    26.580391        713   578.539458
# 5   1.755528e+02   2769459     2819929   101.822378        140   946.091300
# 6            inf   7274297     1577695    21.688625        653          inf
# 7   1.545811e+01   1723953       57143     3.314650        315     9.260689
# 8   9.959618e+00    326583       68525    20.982415        680    11.730508
# 9   4.606815e+01    160361      813991   507.599105         92   146.396815
# 10  1.728924e+01    872025      335673    38.493506        114    20.843187
# 11  1.069479e+00   6596528      659351     9.995425        116     5.653726
# 12  3.154116e+02    250530     1234309   492.679120        647   240.115186
# 13  1.404404e+01    218826       45698    20.883259        449    16.104324
# 14  1.566678e+02    300620       14314     4.761493        522    56.247332
# 15  8.735874e+01    687726      156668    22.780584        645    44.424832
# 16  1.638782e+03    226930      999479   440.434936        610   639.444154
# 17  1.592406e+01    634251      810980   127.864205        619    41.399565
#
#         std_pct
# 0   1664.505281
# 1     19.092616
# 2   6561.042071
# 3      8.204486
# 4   1102.771316
# 5    956.234816
# 6           NaN
# 7      6.666059
# 8      7.956583
# 9    241.226564
# 10    14.002731
# 11     5.788066
# 12   203.926733
# 13     9.447133
# 14    68.809594
# 15    32.657025
# 16   677.552714
# 17    57.964872
#
# [18 rows x 23 columns]

# %%
#still don't know why has to drop id
lt_profits = lt_profits.drop(columns=['id'])
lt_profits.shape
# Out:
# (18, 22)

# %%
sql = f"""
SELECT * 
FROM profits 
WHERE  year = {year} AND quarter = {quarter}"""
print(sql)

my_profits = pd.read_sql(sql, conmy)
my_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#      id     name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   333    3BBIF  2025        4     1      10827771         5279119
# 1   334   ADVANC  2025        4     1      47885902        35075357
# 2   335      BCP  2025        4     1       2879701         2184088
# 3   336      KKP  2025        4     1       5912913         4985068
# 4   337     SCGP  2025        4     1       4069495         3699083
# 5   338      DIF  2025        4     1      13855643          656288
# 6   339     GULF  2025        4     1     101380618        18170334
# 7   340      MTC  2025        4     1       6723275         5867308
# 8   341      NER  2025        4     1       1884525         1652466
# 9   342   CENTEL  2025        4     1       1992901         1752985
# 10  343     COM7  2025        4     1       4063532         3307162
# 11  344    CPALL  2025        4     1      28206100        25345841
# 12  345  CPNREIT  2025        4     1       3460976         1696069
# 13  346      SIS  2025        4     1        876418          697604
# 14  347    THANI  2025        4     1       1147837          800211
# 15  348      TOA  2025        4     1       2917013         1919604
# 16  349    VIBHA  2025        4     1       1694894          698606
# 17  350      WHA  2025        4     1       5135026         4359376
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  \
# 0     5548652     105.11      10827771  ...   6429421  3961184     2468237
# 1    12810545      36.52      47885902  ...  14281630  9258911     5022719
# 2      695613      31.85       2879701  ...   2216608    16577     2200031
# 3      927845      18.61       5912913  ...   1772010  1451311      320699
# 4      370412      10.01       4069495  ...   1206601   -56580     1263181
# 5    13199355    2011.21      13855643  ...   5589388 -7397987    12987375
# 6    83210284     457.95     101380618  ...   8851992        0     8851992
# 7      855967      14.59       6723275  ...   1781096  1542634      238462
# 8      232059      14.04       1884525  ...    395108   359321       35787
# 9      239916      13.69       1992901  ...    974352   667053      307299
# 10     756370      22.87       4063532  ...   1207698  1029675      178023
# 11    2860259      11.28      28206100  ...   7255879  7179100       76779
# 12    1764907     104.06       3460976  ...   1484839   357438     1127401
# 13     178814      25.63        876418  ...    264524   231949       32575
# 14     347626      43.44       1147837  ...    314934   122701      192233
# 15     997409      51.96       2917013  ...    844394   450683      393711
# 16     996288     142.61       1694894  ...   1226409   -79700     1306109
# 17     775650      17.79       5135026  ...   1445231  1246705      198526
#
#       inc_pct_py   q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id     mean_pct  \
# 0   6.231059e+01    183813     6245608  3397.805378        234   901.373991
# 1   5.424741e+01  12038861     2242769    18.629412          6    30.279204
# 2   1.327159e+04   1107896     1108712   100.073653         52  3431.800198
# 3   2.209719e+01   1669882      102128     6.115881        255    13.358269
# 4   2.232557e+03    953229      253372    26.580391        713   578.539458
# 5   1.755528e+02   2769459     2819929   101.822378        140   946.091300
# 6            inf   7274297     1577695    21.688625        653          inf
# 7   1.545811e+01   1723953       57143     3.314650        315     9.260689
# 8   9.959618e+00    326583       68525    20.982415        680    11.730508
# 9   4.606815e+01    160361      813991   507.599105         92   146.396815
# 10  1.728924e+01    872025      335673    38.493506        114    20.843187
# 11  1.069479e+00   6596528      659351     9.995425        116     5.653726
# 12  3.154116e+02    250530     1234309   492.679120        647   240.115186
# 13  1.404404e+01    218826       45698    20.883259        449    16.104324
# 14  1.566678e+02    300620       14314     4.761493        522    56.247332
# 15  8.735874e+01    687726      156668    22.780584        645    44.424832
# 16  1.638782e+03    226930      999479   440.434936        610   639.444154
# 17  1.592406e+01    634251      810980   127.864205        619    41.399565
#
#         std_pct
# 0   1664.505281
# 1     19.092616
# 2   6561.042071
# 3      8.204486
# 4   1102.771316
# 5    956.234816
# 6           NaN
# 7      6.666059
# 8      7.956583
# 9    241.226564
# 10    14.002731
# 11     5.788066
# 12   203.926733
# 13     9.447133
# 14    68.809594
# 15    32.657025
# 16   677.552714
# 17    57.964872
#
# [18 rows x 23 columns]

# %%
sqlDel = f"DELETE FROM profits WHERE year = {year} AND quarter = {quarter}"
print(sqlDel)  # Shows the uncompiled SQL with placeholders
# Execute and get the result
result = conmy.execute(text(sqlDel))
rows_deleted = result.rowcount  # Get the number of rows deleted
#conmy.commit()  # Commit the transaction
print(f"Number of rows deleted: {rows_deleted}")
# Out:
# DELETE FROM profits WHERE year = 2025 AND quarter = 4
# Number of rows deleted: 18

# %%
# Define SQL statement using named placeholders
sqlInsMy = text("""
INSERT INTO profits (name, year, quarter, kind,
latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
q_amt_c, y_amt, inc_amt_py, inc_pct_py,
q_amt_p, inc_amt_pq, inc_pct_pq,
ticker_id, mean_pct, std_pct)
VALUES (:name, :year, :quarter, :kind,
:latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
:latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
:q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
:q_amt_p, :inc_amt_pq, :inc_pct_pq,
:ticker_id, :mean_pct, :std_pct)
""")
print(sqlInsMy)
# Out:
# INSERT INTO profits (name, year, quarter, kind,
# latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
# latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
# q_amt_c, y_amt, inc_amt_py, inc_pct_py,
# q_amt_p, inc_amt_pq, inc_pct_pq,
# ticker_id, mean_pct, std_pct)
# VALUES (:name, :year, :quarter, :kind,
# :latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
# :latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
# :q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
# :q_amt_p, :inc_amt_pq, :inc_pct_pq,
# :ticker_id, :mean_pct, :std_pct)

# %%
rcds = lt_profits.values.tolist()
print(f"Number of rows to insert: {len(rcds)}")
# Out:
# Number of rows to insert: 18

# %%
# Convert list data to dictionaries for named parameters
columns = [
    "name", "year", "quarter", "kind",
    "latest_amt_y", "previous_amt_y", "inc_amt_y", "inc_pct_y",
    "latest_amt_q", "previous_amt_q", "inc_amt_q", "inc_pct_q",
    "q_amt_c", "y_amt", "inc_amt_py", "inc_pct_py",
    "q_amt_p", "inc_amt_pq", "inc_pct_pq",
    "ticker_id", "mean_pct", "std_pct"
]

records_dicts = [dict(zip(columns, rcd)) for rcd in rcds]
#print(records_dicts)

# Check for empty records before attempting insertion
if not rcds:
    print("No records to insert - skipping database operation")
    # In notebook/script context, just proceed to next cell instead of 'return'
else:    
    try:
        result = conmy.execute(sqlInsMy, records_dicts)  # Bulk insert using named parameters
        rows_insert = result.rowcount
        print(f"{rows_insert} rows inserted successfully!")
    except Exception as e:
        print("Error inserting data:", e)
    finally:
        conmy.commit()
# Out:
# 18 rows inserted successfully!

# %%
sql = f"""
SELECT * 
FROM profits 
WHERE  year = {year} AND quarter = {quarter}"""
print(sql)

my_profits = pd.read_sql(sql, conmy)
my_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#      id     name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   351    3BBIF  2025        4     1      10827771         5279119
# 1   352   ADVANC  2025        4     1      47885902        35075357
# 2   353      BCP  2025        4     1       2879701         2184088
# 3   354      KKP  2025        4     1       5912913         4985068
# 4   355     SCGP  2025        4     1       4069495         3699083
# 5   356      DIF  2025        4     1      13855643          656288
# 6   357     GULF  2025        4     1     101380618        18170334
# 7   358      MTC  2025        4     1       6723275         5867308
# 8   359      NER  2025        4     1       1884525         1652466
# 9   360   CENTEL  2025        4     1       1992901         1752985
# 10  361     COM7  2025        4     1       4063532         3307162
# 11  362    CPALL  2025        4     1      28206100        25345841
# 12  363  CPNREIT  2025        4     1       3460976         1696069
# 13  364      SIS  2025        4     1        876418          697604
# 14  365    THANI  2025        4     1       1147837          800211
# 15  366      TOA  2025        4     1       2917013         1919604
# 16  367    VIBHA  2025        4     1       1694894          698606
# 17  368      WHA  2025        4     1       5135026         4359376
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  \
# 0     5548652     105.11      10827771  ...   6429421  3961184     2468237
# 1    12810545      36.52      47885902  ...  14281630  9258911     5022719
# 2      695613      31.85       2879701  ...   2216608    16577     2200031
# 3      927845      18.61       5912913  ...   1772010  1451311      320699
# 4      370412      10.01       4069495  ...   1206601   -56580     1263181
# 5    13199355    2011.21      13855643  ...   5589388 -7397987    12987375
# 6    83210284     457.95     101380618  ...   8851992        0     8851992
# 7      855967      14.59       6723275  ...   1781096  1542634      238462
# 8      232059      14.04       1884525  ...    395108   359321       35787
# 9      239916      13.69       1992901  ...    974352   667053      307299
# 10     756370      22.87       4063532  ...   1207698  1029675      178023
# 11    2860259      11.28      28206100  ...   7255879  7179100       76779
# 12    1764907     104.06       3460976  ...   1484839   357438     1127401
# 13     178814      25.63        876418  ...    264524   231949       32575
# 14     347626      43.44       1147837  ...    314934   122701      192233
# 15     997409      51.96       2917013  ...    844394   450683      393711
# 16     996288     142.61       1694894  ...   1226409   -79700     1306109
# 17     775650      17.79       5135026  ...   1445231  1246705      198526
#
#       inc_pct_py   q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id     mean_pct  \
# 0   6.231059e+01    183813     6245608  3397.805378        234   901.373991
# 1   5.424741e+01  12038861     2242769    18.629412          6    30.279204
# 2   1.327159e+04   1107896     1108712   100.073653         52  3431.800198
# 3   2.209719e+01   1669882      102128     6.115881        255    13.358269
# 4   2.232557e+03    953229      253372    26.580391        713   578.539458
# 5   1.755528e+02   2769459     2819929   101.822378        140   946.091300
# 6            inf   7274297     1577695    21.688625        653          inf
# 7   1.545811e+01   1723953       57143     3.314650        315     9.260689
# 8   9.959618e+00    326583       68525    20.982415        680    11.730508
# 9   4.606815e+01    160361      813991   507.599105         92   146.396815
# 10  1.728924e+01    872025      335673    38.493506        114    20.843187
# 11  1.069479e+00   6596528      659351     9.995425        116     5.653726
# 12  3.154116e+02    250530     1234309   492.679120        647   240.115186
# 13  1.404404e+01    218826       45698    20.883259        449    16.104324
# 14  1.566678e+02    300620       14314     4.761493        522    56.247332
# 15  8.735874e+01    687726      156668    22.780584        645    44.424832
# 16  1.638782e+03    226930      999479   440.434936        610   639.444154
# 17  1.592406e+01    634251      810980   127.864205        619    41.399565
#
#         std_pct
# 0   1664.505281
# 1     19.092616
# 2   6561.042071
# 3      8.204486
# 4   1102.771316
# 5    956.234816
# 6           NaN
# 7      6.666059
# 8      7.956583
# 9    241.226564
# 10    14.002731
# 11     5.788066
# 12   203.926733
# 13     9.447133
# 14    68.809594
# 15    32.657025
# 16   677.552714
# 17    57.964872
#
# [18 rows x 23 columns]

# %% [markdown]
# ### PortPg Process

# %%
sql = f"""
SELECT * 
FROM profits 
WHERE  year = {year} AND quarter = {quarter}"""
print(sql)
pg_profits = pd.read_sql(sql, conpg)
pg_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#       id    name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0  67963    SCGP  2025        4     1       4069495         3699083
# 1  67965     KKP  2025        4     1       5912913         4985068
# 2  67973     BCP  2025        4     1       2879701         2184088
# 3  67976  ADVANC  2025        4     1      47885902        35075357
# 4  67978   3BBIF  2025        4     1      10827771         5279119
#
#    inc_amt_y  inc_pct_y  latest_amt_q  ...    y_amt  inc_amt_py    inc_pct_py  \
# 0     370412      10.01       4069495  ...   -56580     1263181   2232.557441
# 1     927845      18.61       5912913  ...  1451311      320699     22.097194
# 2     695613      31.85       2879701  ...    16577     2200031  13271.587139
# 3   12810545      36.52      47885902  ...  9258911     5022719     54.247406
# 4    5548652     105.11      10827771  ...  3961184     2468237     62.310587
#
#     q_amt_p  inc_amt_pq   inc_pct_pq     mean_pct      std_pct  publish_date  \
# 0    953229      253372    26.580391   578.539458  1102.771316    2026-01-28
# 1   1669882      102128     6.115881    13.358269     8.204486    2026-01-19
# 2   1107896     1108712   100.073653  3431.800198  6561.042071    2026-02-12
# 3  12038861     2242769    18.629412    30.279204    19.092616    2026-02-03
# 4    183813     6245608  3397.805378   901.373991  1664.505281    2026-02-03
#
#    ticker_id
# 0        684
# 1        262
# 2         56
# 3          8
# 4        241
#
# [5 rows x 24 columns]

# %%
sqlDel = text("DELETE FROM profits WHERE year = :year AND quarter = :quarter")
print(sqlDel)  # Shows the uncompiled SQL with placeholders

# Execute and get the result
result = conpg.execute(sqlDel, {"year": year, "quarter": quarter})
rows_deleted = result.rowcount  # Get the number of rows deleted

print(f"Number of rows deleted: {rows_deleted}")
# Out:
# DELETE FROM profits WHERE year = :year AND quarter = :quarter
# Number of rows deleted: 5

# %%
sql = 'SELECT name, id FROM tickers'
pg_tickers = pd.read_sql(sql, conpg)
pg_tickers.shape
# Out:
# (396, 2)

# %%
df_merge = pd.merge(my_profits, pg_tickers, on="name", how="inner")
df_merge
# Out:
#     id_x     name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0    351    3BBIF  2025        4     1      10827771         5279119
# 1    352   ADVANC  2025        4     1      47885902        35075357
# 2    353      BCP  2025        4     1       2879701         2184088
# 3    354      KKP  2025        4     1       5912913         4985068
# 4    355     SCGP  2025        4     1       4069495         3699083
# 5    356      DIF  2025        4     1      13855643          656288
# 6    357     GULF  2025        4     1     101380618        18170334
# 7    358      MTC  2025        4     1       6723275         5867308
# 8    359      NER  2025        4     1       1884525         1652466
# 9    360   CENTEL  2025        4     1       1992901         1752985
# 10   361     COM7  2025        4     1       4063532         3307162
# 11   362    CPALL  2025        4     1      28206100        25345841
# 12   363  CPNREIT  2025        4     1       3460976         1696069
# 13   364      SIS  2025        4     1        876418          697604
# 14   365    THANI  2025        4     1       1147837          800211
# 15   366      TOA  2025        4     1       2917013         1919604
# 16   367    VIBHA  2025        4     1       1694894          698606
# 17   368      WHA  2025        4     1       5135026         4359376
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...    y_amt  inc_amt_py  \
# 0     5548652     105.11      10827771  ...  3961184     2468237
# 1    12810545      36.52      47885902  ...  9258911     5022719
# 2      695613      31.85       2879701  ...    16577     2200031
# 3      927845      18.61       5912913  ...  1451311      320699
# 4      370412      10.01       4069495  ...   -56580     1263181
# 5    13199355    2011.21      13855643  ... -7397987    12987375
# 6    83210284     457.95     101380618  ...        0     8851992
# 7      855967      14.59       6723275  ...  1542634      238462
# 8      232059      14.04       1884525  ...   359321       35787
# 9      239916      13.69       1992901  ...   667053      307299
# 10     756370      22.87       4063532  ...  1029675      178023
# 11    2860259      11.28      28206100  ...  7179100       76779
# 12    1764907     104.06       3460976  ...   357438     1127401
# 13     178814      25.63        876418  ...   231949       32575
# 14     347626      43.44       1147837  ...   122701      192233
# 15     997409      51.96       2917013  ...   450683      393711
# 16     996288     142.61       1694894  ...   -79700     1306109
# 17     775650      17.79       5135026  ...  1246705      198526
#
#       inc_pct_py   q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id     mean_pct  \
# 0   6.231059e+01    183813     6245608  3397.805378        234   901.373991
# 1   5.424741e+01  12038861     2242769    18.629412          6    30.279204
# 2   1.327159e+04   1107896     1108712   100.073653         52  3431.800198
# 3   2.209719e+01   1669882      102128     6.115881        255    13.358269
# 4   2.232557e+03    953229      253372    26.580391        713   578.539458
# 5   1.755528e+02   2769459     2819929   101.822378        140   946.091300
# 6            inf   7274297     1577695    21.688625        653          inf
# 7   1.545811e+01   1723953       57143     3.314650        315     9.260689
# 8   9.959618e+00    326583       68525    20.982415        680    11.730508
# 9   4.606815e+01    160361      813991   507.599105         92   146.396815
# 10  1.728924e+01    872025      335673    38.493506        114    20.843187
# 11  1.069479e+00   6596528      659351     9.995425        116     5.653726
# 12  3.154116e+02    250530     1234309   492.679120        647   240.115186
# 13  1.404404e+01    218826       45698    20.883259        449    16.104324
# 14  1.566678e+02    300620       14314     4.761493        522    56.247332
# 15  8.735874e+01    687726      156668    22.780584        645    44.424832
# 16  1.638782e+03    226930      999479   440.434936        610   639.444154
# 17  1.592406e+01    634251      810980   127.864205        619    41.399565
#
#         std_pct  id_y
# 0   1664.505281   241
# 1     19.092616     8
# 2   6561.042071    56
# 3      8.204486   262
# 4   1102.771316   684
# 5    956.234816   146
# 6           NaN   207
# 7      6.666059   323
# 8      7.956583   649
# 9    241.226564    94
# 10    14.002731   118
# 11     5.788066   120
# 12   203.926733   127
# 13     9.447133   455
# 14    68.809594   528
# 15    32.657025   562
# 16   677.552714   619
# 17    57.964872   628
#
# [18 rows x 24 columns]

# %%
df_merge = df_merge.drop(columns=['ticker_id']).rename(columns={'id_y': 'ticker_id'})

# %%
columns = 'name ticker_id'.split()
df_merge[columns]
# Out:
#        name  ticker_id
# 0     3BBIF        241
# 1    ADVANC          8
# 2       BCP         56
# 3       KKP        262
# 4      SCGP        684
# 5       DIF        146
# 6      GULF        207
# 7       MTC        323
# 8       NER        649
# 9    CENTEL         94
# 10     COM7        118
# 11    CPALL        120
# 12  CPNREIT        127
# 13      SIS        455
# 14    THANI        528
# 15      TOA        562
# 16    VIBHA        619
# 17      WHA        628

# %%
colv = 'name year quarter kind latest_amt_y previous_amt_y inc_amt_y inc_pct_y \
        latest_amt_q previous_amt_q inc_amt_q inc_pct_q q_amt_c y_amt \
        inc_amt_py inc_pct_py q_amt_p inc_amt_pq inc_pct_pq \
        ticker_id mean_pct std_pct'.split()
format_dict = {
    'q_amt': '{:,}',
    'y_amt': '{:,}',
    'yoy_gain': '{:,}',
    'q_amt_c': '{:,}',
    'q_amt_p': '{:,}',
    'aq_amt': '{:,}',
    'ay_amt': '{:,}',
    'acc_gain': '{:,}',
    'latest_amt': '{:,}',
    'previous_amt': '{:,}',
    'inc_amt': '{:,}',
    'inc_amt_pq': '{:,}',
    'inc_amt_py': '{:,}',    
    'latest_amt_q': '{:,}',
    'previous_amt_q': '{:,}',
    'inc_amt_q': '{:,}',
    'latest_amt_y': '{:,}',
    'previous_amt_y': '{:,}',
    'inc_amt_y': '{:,}',
    'kind_x': '{:,}',
    'inc_pct': '{:.2f}%',
    'inc_pct_q': '{:.2f}%',
    'inc_pct_y': '{:.2f}%',
    'inc_pct_pq': '{:.2f}%',
    'inc_pct_py': '{:.2f}%',   
    'mean_pct': '{:.2f}%',
    'std_pct': '{:.2f}%',      
}

# %%
final = df_merge[colv].copy()
final.sort_values(by=['ticker_id'],ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_43889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43889_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_43889_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_43889_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_43889_level0_col3" class="col_heading level0 col3" >kind</th>
#       <th id="T_43889_level0_col4" class="col_heading level0 col4" >latest_amt_y</th>
#       <th id="T_43889_level0_col5" class="col_heading level0 col5" >previous_amt_y</th>
#       <th id="T_43889_level0_col6" class="col_heading level0 col6" >inc_amt_y</th>
#       <th id="T_43889_level0_col7" class="col_heading level0 col7" >inc_pct_y</th>
#       <th id="T_43889_level0_col8" class="col_heading level0 col8" >latest_amt_q</th>
#       <th id="T_43889_level0_col9" class="col_heading level0 col9" >previous_amt_q</th>
#       <th id="T_43889_level0_col10" class="col_heading level0 col10" >inc_amt_q</th>
#       <th id="T_43889_level0_col11" class="col_heading level0 col11" >inc_pct_q</th>
#       <th id="T_43889_level0_col12" class="col_heading level0 col12" >q_amt_c</th>
#       <th id="T_43889_level0_col13" class="col_heading level0 col13" >y_amt</th>
#       <th id="T_43889_level0_col14" class="col_heading level0 col14" >inc_amt_py</th>
#       <th id="T_43889_level0_col15" class="col_heading level0 col15" >inc_pct_py</th>
#       <th id="T_43889_level0_col16" class="col_heading level0 col16" >q_amt_p</th>
#       <th id="T_43889_level0_col17" class="col_heading level0 col17" >inc_amt_pq</th>
#       <th id="T_43889_level0_col18" class="col_heading level0 col18" >inc_pct_pq</th>
#       <th id="T_43889_level0_col19" class="col_heading level0 col19" >ticker_id</th>
#       <th id="T_43889_level0_col20" class="col_heading level0 col20" >mean_pct</th>
#       <th id="T_43889_level0_col21" class="col_heading level0 col21" >std_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43889_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_43889_row0_col0" class="data row0 col0" >ADVANC</td>
#       <td id="T_43889_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_43889_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_43889_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_43889_row0_col4" class="data row0 col4" >47,885,902</td>
#       <td id="T_43889_row0_col5" class="data row0 col5" >35,075,357</td>
#       <td id="T_43889_row0_col6" class="data row0 col6" >12,810,545</td>
#       <td id="T_43889_row0_col7" class="data row0 col7" >36.52%</td>
#       <td id="T_43889_row0_col8" class="data row0 col8" >47,885,902</td>
#       <td id="T_43889_row0_col9" class="data row0 col9" >42,863,183</td>
#       <td id="T_43889_row0_col10" class="data row0 col10" >5,022,719</td>
#       <td id="T_43889_row0_col11" class="data row0 col11" >11.72%</td>
#       <td id="T_43889_row0_col12" class="data row0 col12" >14,281,630</td>
#       <td id="T_43889_row0_col13" class="data row0 col13" >9,258,911</td>
#       <td id="T_43889_row0_col14" class="data row0 col14" >5,022,719</td>
#       <td id="T_43889_row0_col15" class="data row0 col15" >54.25%</td>
#       <td id="T_43889_row0_col16" class="data row0 col16" >12,038,861</td>
#       <td id="T_43889_row0_col17" class="data row0 col17" >2,242,769</td>
#       <td id="T_43889_row0_col18" class="data row0 col18" >18.63%</td>
#       <td id="T_43889_row0_col19" class="data row0 col19" >8</td>
#       <td id="T_43889_row0_col20" class="data row0 col20" >30.28%</td>
#       <td id="T_43889_row0_col21" class="data row0 col21" >19.09%</td>
#     </tr>
#     <tr>
#       <th id="T_43889_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_43889_row1_col0" class="data row1 col0" >BCP</td>
#       <td id="T_43889_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_43889_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_43889_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_43889_row1_col4" class="data row1 col4" >2,879,701</td>
#       <td id="T_43889_row1_col5" class="data row1 col5" >2,184,088</td>
#       <td id="T_43889_row1_col6" class="data row1 col6" >695,613</td>
#       <td id="T_43889_row1_col7" class="data row1 col7" >31.85%</td>
#       <td id="T_43889_row1_col8" class="data row1 col8" >2,879,701</td>
#       <td id="T_43889_row1_col9" class="data row1 col9" >679,670</td>
#       <td id="T_43889_row1_col10" class="data row1 col10" >2,200,031</td>
#       <td id="T_43889_row1_col11" class="data row1 col11" >323.69%</td>
#       <td id="T_43889_row1_col12" class="data row1 col12" >2,216,608</td>
#       <td id="T_43889_row1_col13" class="data row1 col13" >16,577</td>
#       <td id="T_43889_row1_col14" class="data row1 col14" >2,200,031</td>
#       <td id="T_43889_row1_col15" class="data row1 col15" >13271.59%</td>
#       <td id="T_43889_row1_col16" class="data row1 col16" >1,107,896</td>
#       <td id="T_43889_row1_col17" class="data row1 col17" >1,108,712</td>
#       <td id="T_43889_row1_col18" class="data row1 col18" >100.07%</td>
#       <td id="T_43889_row1_col19" class="data row1 col19" >56</td>
#       <td id="T_43889_row1_col20" class="data row1 col20" >3431.80%</td>
#       <td id="T_43889_row1_col21" class="data row1 col21" >6561.04%</td>
#     </tr>
#     <tr>
#       <th id="T_43889_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_43889_row2_col0" class="data row2 col0" >CENTEL</td>
#       <td id="T_43889_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_43889_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_43889_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_43889_row2_col4" class="data row2 col4" >1,992,901</td>
#       <td id="T_43889_row2_col5" class="data row2 col5" >1,752,985</td>
#       <td id="T_43889_row2_col6" class="data row2 col6" >239,916</td>
#       <td id="T_43889_row2_col7" class="data row2 col7" >13.69%</td>
#       <td id="T_43889_row2_col8" class="data row2 col8" >1,992,901</td>
#       <td id="T_43889_row2_col9" class="data row2 col9" >1,685,602</td>
#       <td id="T_43889_row2_col10" class="data row2 col10" >307,299</td>
#       <td id="T_43889_row2_col11" class="data row2 col11" >18.23%</td>
#       <td id="T_43889_row2_col12" class="data row2 col12" >974,352</td>
#       <td id="T_43889_row2_col13" class="data row2 col13" >667,053</td>
#       <td id="T_43889_row2_col14" class="data row2 col14" >307,299</td>
#       <td id="T_43889_row2_col15" class="data row2 col15" >46.07%</td>
#       <td id="T_43889_row2_col16" class="data row2 col16" >160,361</td>
#       <td id="T_43889_row2_col17" class="data row2 col17" >813,991</td>
#       <td id="T_43889_row2_col18" class="data row2 col18" >507.60%</td>
#       <td id="T_43889_row2_col19" class="data row2 col19" >94</td>
#       <td id="T_43889_row2_col20" class="data row2 col20" >146.40%</td>
#       <td id="T_43889_row2_col21" class="data row2 col21" >241.23%</td>
#     </tr>
#     <tr>
#       <th id="T_43889_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_43889_row3_col0" class="data row3 col0" >COM7</td>
#       <td id="T_43889_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_43889_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_43889_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_43889_row3_col4" class="data row3 col4" >4,063,532</td>
#       <td id="T_43889_row3_col5" class="data row3 col5" >3,307,162</td>
#       <td id="T_43889_row3_col6" class="data row3 col6" >756,370</td>
#       <td id="T_43889_row3_col7" class="data row3 col7" >22.87%</td>
#       <td id="T_43889_row3_col8" class="data row3 col8" >4,063,532</td>
#       <td id="T_43889_row3_col9" class="data row3 col9" >3,880,193</td>
#       <td id="T_43889_row3_col10" class="data row3 col10" >183,339</td>
#       <td id="T_43889_row3_col11" class="data row3 col11" >4.72%</td>
#       <td id="T_43889_row3_col12" class="data row3 col12" >1,207,698</td>
#       <td id="T_43889_row3_col13" class="data row3 col13" >1,029,67

# %%
# Define SQL statement using named placeholders
sqlInsPg = text("""
INSERT INTO profits (name, year, quarter, kind,
latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
q_amt_c, y_amt, inc_amt_py, inc_pct_py,
q_amt_p, inc_amt_pq, inc_pct_pq,
ticker_id, mean_pct, std_pct)
VALUES (:name, :year, :quarter, :kind,
:latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
:latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
:q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
:q_amt_p, :inc_amt_pq, :inc_pct_pq,
:ticker_id, :mean_pct, :std_pct)
""")

# Convert list data to dictionaries for named parameters
columns = [
    "name", "year", "quarter", "kind",
    "latest_amt_y", "previous_amt_y", "inc_amt_y", "inc_pct_y",
    "latest_amt_q", "previous_amt_q", "inc_amt_q", "inc_pct_q",
    "q_amt_c", "y_amt", "inc_amt_py", "inc_pct_py",
    "q_amt_p", "inc_amt_pq", "inc_pct_pq",
    "ticker_id", "mean_pct", "std_pct"
]
print(sqlInsPg)
# Out:
# INSERT INTO profits (name, year, quarter, kind,
# latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
# latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
# q_amt_c, y_amt, inc_amt_py, inc_pct_py,
# q_amt_p, inc_amt_pq, inc_pct_pq,
# ticker_id, mean_pct, std_pct)
# VALUES (:name, :year, :quarter, :kind,
# :latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
# :latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
# :q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
# :q_amt_p, :inc_amt_pq, :inc_pct_pq,
# :ticker_id, :mean_pct, :std_pct)

# %%
rcds = final.values.tolist()
print(f"Number of rows to insert: {len(rcds)}")
# Out:
# Number of rows to insert: 18

# %%
records_dicts = [dict(zip(columns, rcd)) for rcd in rcds]
#print(records_dicts)

# Check for empty records before attempting insertion
if not rcds:
    print("No records to insert - skipping database operation")
    # In notebook/script context, just proceed to next cell instead of 'return'
else:
    try:
        result = conpg.execute(sqlInsPg, records_dicts)  # Bulk insert using named parameters
        rows_insert = result.rowcount
        print(f"{rows_insert} rows inserted successfully!")
    except Exception as e:
        print("Error inserting data:", e)
    finally:
        conpg.commit()
# Out:
# Error inserting data: (psycopg2.errors.FeatureNotSupported) cannot convert infinity to numeric
#
# [SQL:
# INSERT INTO profits (name, year, quarter, kind,
# latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
# latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
# q_amt_c, y_amt, inc_amt_py, inc_pct_py,
# q_amt_p, inc_amt_pq, inc_pct_pq,
# ticker_id, mean_pct, std_pct)
# VALUES (%(name)s, %(year)s, %(quarter)s, %(kind)s,
# %(latest_amt_y)s, %(previous_amt_y)s, %(inc_amt_y)s, %(inc_pct_y)s,
# %(latest_amt_q)s, %(previous_amt_q)s, %(inc_amt_q)s, %(inc_pct_q)s,
# %(q_amt_c)s, %(y_amt)s, %(inc_amt_py)s, %(inc_pct_py)s,
# %(q_amt_p)s, %(inc_amt_pq)s, %(inc_pct_pq)s,
# %(ticker_id)s, %(mean_pct)s, %(std_pct)s)
# ]
# [parameters: [{'name': '3BBIF', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 10827771, 'previous_amt_y': 5279119, 'inc_amt_y': 5548652, 'inc_pct_y': 105.11, 'latest_amt_q': 10827771, 'previous_amt_q': 7719299, 'inc_amt_q': 3108472, 'inc_pct_q': 40.27, 'q_amt_c': 6429421, 'y_amt': 3961184, 'inc_amt_py': 2468237, 'inc_pct_py': 62.31058693562329, 'q_amt_p': 183813, 'inc_amt_pq': 6245608, 'inc_pct_pq': 3397.805378292069, 'ticker_id': 241, 'mean_pct': 901.373991306923, 'std_pct': 1664.5052812749377}, {'name': 'ADVANC', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 47885902, 'previous_amt_y': 35075357, 'inc_amt_y': 12810545, 'inc_pct_y': 36.52, 'latest_amt_q': 47885902, 'previous_amt_q': 42863183, 'inc_amt_q': 5022719, 'inc_pct_q': 11.72, 'q_amt_c': 14281630, 'y_amt': 9258911, 'inc_amt_py': 5022719, 'inc_pct_py': 54.24740555341767, 'q_amt_p': 12038861, 'inc_amt_pq': 2242769, 'inc_pct_pq': 18.62941186878061, 'ticker_id': 8, 'mean_pct': 30.27920435554957, 'std_pct': 19.09261576485445}, {'name': 'BCP', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 2879701, 'previous_amt_y': 2184088, 'inc_amt_y': 695613, 'inc_pct_y': 31.85, 'latest_amt_q': 2879701, 'previous_amt_q': 679670, 'inc_amt_q': 2200031, 'inc_pct_q': 323.69, 'q_amt_c': 2216608, 'y_amt': 16577, 'inc_amt_py': 2200031, 'inc_pct_py': 13271.587138806779, 'q_amt_p': 1107896, 'inc_amt_pq': 1108712, 'inc_pct_pq': 100.07365312267578, 'ticker_id': 56, 'mean_pct': 3431.800197982364, 'std_pct': 6561.042070741092}, {'name': 'KKP', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 5912913, 'previous_amt_y': 4985068, 'inc_amt_y': 927845, 'inc_pct_y': 18.61, 'latest_amt_q': 5912913, 'previous_amt_q': 5546534, 'inc_amt_q': 366379, 'inc_pct_q': 6.61, 'q_amt_c': 1772010, 'y_amt': 1451311, 'inc_amt_py': 320699, 'inc_pct_py': 22.097193502977653, 'q_amt_p': 1669882, 'inc_amt_pq': 102128, 'inc_pct_pq': 6.115881241908111, 'ticker_id': 262, 'mean_pct': 13.358268686221441, 'std_pct': 8.20448647387562}, {'name': 'SCGP', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 4069495, 'previous_amt_y': 3699083, 'inc_amt_y': 370412, 'inc_pct_y': 10.01, 'latest_amt_q': 4069495, 'previous_amt_q': 2806314, 'inc_amt_q': 1263181, 'inc_pct_q': 45.01, 'q_amt_c': 1206601, 'y_amt': -56580, 'inc_amt_py': 1263181, 'inc_pct_py': 2232.557440791799, 'q_amt_p': 953229, 'inc_amt_pq': 253372, 'inc_pct_pq': 26.580391490397375, 'ticker_id': 684, 'mean_pct': 578.539458070549, 'std_pct': 1102.7713159231082}, {'name': 'DIF', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 13855643, 'previous_amt_y': 656288, 'inc_amt_y': 13199355, 'inc_pct_y': 2011.21, 'latest_amt_q': 13855643, 'previous_amt_q': 868268, 'inc_amt_q': 12987375, 'inc_pct_q': 1495.78, 'q_amt_c': 5589388, 'y_amt': -7397987, 'inc_amt_py': 12987375, 'inc_pct_py': 175.5528226800074, 'q_amt_p': 2769459, 'inc_amt_pq': 2819929, 'inc_pct_pq': 101.82237758349193, 'ticker_id': 146, 'mean_pct': 946.0913000658747, 'std_pct': 956.2348160687877}, {'name': 'GULF', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 101380618, 'previous_amt_y': 18170334, 'inc_amt_y': 83210284, 'inc_pct_y': 457.95, 'latest_amt_q': 101380618, 'previous_amt_q': 96429425, 'inc_amt_q': 4951193, 'inc_pct_q': 5.13, 'q_amt_c': 8851992, 'y_amt': 0, 'inc_amt_py': 8851992, 'inc_pct_py': inf, 'q_amt_p': 7274297, 'inc_amt_pq': 1577695, 'inc_pct_pq': 21.688625031394785, 'ticker_id': 207, 'mean_pct': inf, 'std_pct': nan}, {'name': 'MTC', 'year': 2025, 'quarter': 4, 'kind': 1, 'latest_amt_y': 6723275, 'previous_amt_y': 5867308, 'inc_amt_y': 855967, 'inc_pct_y': 14.59, 'latest_amt_q': 6723275, 'previous_amt_q': 6484813, 'inc_amt_q': 238462, 'inc_pct_q': 3.68, 'q_amt_c': 1781096, 'y_amt': 1542634, 'inc_amt_py': 238462, 'inc_pct_py': 15.458106070526126, 'q_amt_p': 1723953, 'inc_amt_pq': 57143, 'inc_pct_pq': 3.3146495293085136, 'ticker_id': 323, 'mean_pct': 9.260688899958659, 'std_pct': 6.666058535159331}  ... displaying 10 of 18 total bound parameter sets ...  {'name': 'VIBHA' ...
# (Background on this error at: https://sqlalche.me/e/20/tw8g)

# %%
sql = """
SELECT * 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

pg_profits = pd.read_sql(sql, conpg)
pg_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#       id    name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0  67963    SCGP  2025        4     1       4069495         3699083
# 1  67965     KKP  2025        4     1       5912913         4985068
# 2  67973     BCP  2025        4     1       2879701         2184088
# 3  67976  ADVANC  2025        4     1      47885902        35075357
# 4  67978   3BBIF  2025        4     1      10827771         5279119
#
#    inc_amt_y  inc_pct_y  latest_amt_q  ...    y_amt  inc_amt_py    inc_pct_py  \
# 0     370412      10.01       4069495  ...   -56580     1263181   2232.557441
# 1     927845      18.61       5912913  ...  1451311      320699     22.097194
# 2     695613      31.85       2879701  ...    16577     2200031  13271.587139
# 3   12810545      36.52      47885902  ...  9258911     5022719     54.247406
# 4    5548652     105.11      10827771  ...  3961184     2468237     62.310587
#
#     q_amt_p  inc_amt_pq   inc_pct_pq     mean_pct      std_pct  publish_date  \
# 0    953229      253372    26.580391   578.539458  1102.771316    2026-01-28
# 1   1669882      102128     6.115881    13.358269     8.204486    2026-01-19
# 2   1107896     1108712   100.073653  3431.800198  6561.042071    2026-02-12
# 3  12038861     2242769    18.629412    30.279204    19.092616    2026-02-03
# 4    183813     6245608  3397.805378   901.373991  1664.505281    2026-02-03
#
#    ticker_id
# 0        684
# 1        262
# 2         56
# 3          8
# 4        241
#
# [5 rows x 24 columns]

# %%
stock_list = pg_profits['name'].unique().tolist()
stock_list_str = ("','").join(stock_list)
print(stock_list_str)
# Out:
# SCGP','KKP','BCP','ADVANC','3BBIF

# %%
sql = f"SELECT name, year, quarter, publish_date FROM epss WHERE year = {year} AND quarter = {quarter} AND name IN ('{stock_list_str}')"
print(sql)
df_epss_profits = pd.read_sql(sql, conlt)
df_epss_profits
# Out:
# SELECT name, year, quarter, publish_date FROM epss WHERE year = 2025 AND quarter = 4 AND name IN ('SCGP','KKP','BCP','ADVANC','3BBIF')
#      name  year  quarter publish_date
# 0   3BBIF  2025        4   2026-02-03
# 1  ADVANC  2025        4   2026-02-03
# 2     BCP  2025        4   2026-02-12
# 3     KKP  2025        4   2026-01-19
# 4    SCGP  2025        4   2026-01-28

# %%
sql = f"""
SELECT name, year, quarter, publish_date 
FROM epss 
WHERE year = {year} AND quarter = {quarter} AND name IN ('{stock_list_str}')"""

df_epss_profits = pd.read_sql(sql, conlt)

if not df_epss_profits.empty:
    update_sql = text("""
        UPDATE profits 
        SET publish_date = :publish_date
        WHERE name = :name AND year = :year AND quarter = :quarter
    """)
    
    # Execute update for each row in df_epss_profits
    for _, row in df_epss_profits.iterrows():
        conpg.execute(update_sql, {
            'publish_date': row['publish_date'],
            'name': row['name'],
            'year': row['year'],
            'quarter': row['quarter']
        })

# %%
#After update publish_date from epss to profits
sql = """
SELECT name, year, quarter, publish_date 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

pg_profits = pd.read_sql(sql, conpg)
pg_profits
# Out:
# SELECT name, year, quarter, publish_date
# FROM profits
# WHERE  year = 2025 AND quarter = 4
#      name  year  quarter publish_date
# 0   3BBIF  2025        4   2026-02-03
# 1  ADVANC  2025        4   2026-02-03
# 2     BCP  2025        4   2026-02-12
# 3     KKP  2025        4   2026-01-19
# 4    SCGP  2025        4   2026-01-28
