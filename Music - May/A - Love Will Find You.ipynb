# %%
from moviepy.editor import AudioFileClip, VideoClip, ImageClip
from sqlalchemy import create_engine
from datetime import datetime
import pandas as pd
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Your database connection
engine = create_engine('mysql+pymysql://root@localhost:3306/music_development')
data_path = '../data/'

# Get song data
sql = '''
SELECT S.id, rank, name, artist_id, A.first_name, A.last_name , youtube_code 
FROM songs S
JOIN artists A
ON S.artist_id = A.id
WHERE LOWER(TRIM(name)) LIKE LOWER(TRIM('Love Will Find You'))
'''
songs = pd.read_sql(sql, engine)
songs
# Out:
#     id  rank                name  artist_id first_name last_name youtube_code
# 0  699  1204  Love Will Find You        364      Avril   Lavigne  D45xnse-FPw

# %%
songId = songs['id'].iloc[0]
songId
# Out:
# 699

# %%
sql = f'''
SELECT S.id, rank, name, artist_id, A.first_name, A.last_name , youtube_code 
FROM songs S
JOIN artists A
ON S.artist_id = A.id
WHERE S.id = {songId}
'''
song = pd.read_sql(sql, engine)
song
# Out:
#     id  rank                name  artist_id first_name last_name youtube_code
# 0  699  1204  Love Will Find You        364      Avril   Lavigne  D45xnse-FPw

# %%
# Get artist name as a string (not pandas Series)
artist_name = f"{song['first_name'].iloc[0]} {song['last_name'].iloc[0]}"
print(f"🎤 Artist: {artist_name}")
# Out:
# 🎤 Artist: Avril Lavigne

# %%
# Get lyrics
sql = f"""
SELECT id, song_id, content 
FROM lyrics 
WHERE song_id = {songId}
"""
lyrics = pd.read_sql(sql, engine)
lyrics
# Out:
#     id  song_id                                            content
# 0  631      699  8|Light will find you again.\r\n16|I wake up a...

# %%
# Get the lyrics content
lyrics_content = lyrics.content.iloc[0]

# Print with proper line breaks (replace \r\n with actual newlines)
print("Full lyrics content:")
print("-" * 50)
print(lyrics_content.replace('\r\n', '\n'))
print("=" * 50)
# Out:
# Full lyrics content:
# --------------------------------------------------
# 8|Light will find you again.
# 16|I wake up and the ceiling
# 18|feels like it's closing in.
# 22|Can't remember when the noise outside
# 25|got under my skin.
# 29|I smile for the world, but inside it's a
# 32|different place.
# 36|Like I'm running out of room inside
# 38|my own head space.
# 43|The days blur together, gray on
# 45|gray on gray. I keep saying
# 47|I'm fine, but I'm slowly fading away.
# 50|There's a version of me that I
# 52|used to know so well.
#
# 56|And I'm trying to reach her, but I'm
# 59|stuck inside this shell.
# 63|But then you called and you sat with me
# 66|a while. Didn't try to fix it, you just
# 69|stayed and made me smile.
# 70|And something in that moment
# 72|cracked the dark into I don't have to
# 75|carry this. I have me and I have you.
#
# 79|After every storm,
# 81|the sky breaks open wide.
# 85|After every fall,
# 87|there's still a reason left inside.
#
# 92|I've been down before and I came back
# 95|every time.
# 98|I won't let the darkness tell me
# 103|this is where I die.
#
# 106|Cuz the light
# 107|the light will find you even
# 110|when you've lost the way.
# 112|Hold on to
# 114|the ones who know you.
# 116|Let them help you find the day.
# 119|Never give up.
# 121|Never give in. The high comes back after
# 124|the low sets in. Light will find you.
# 128|Light will find you again.
# 133|I know it doesn't look like it
# 134|from where you're standing now, like the
# 137|tunnel has no ending and you can't see
# 139|through the clouds.
#
# 143|But I've sat in that same darkness.
# 145|I felt that same weight. And I promise you
# 147|the morning always finds a way.
# 150|Pick up the phone to say the words out
# 152|loud. You don't have to be strong. Just
# 154|don't disappear in a crowd. Your people
# 156|need you here. They need you
# 158|breathing and real. You don't have to
# 160|explain it. Just let yourself feel.
# 163|Because I called and you sat with me a
# 166|while. Didn't try to fix it, you just
# 169|stayed and made me smile.
# 170|And something in that moment
# 172|cracked the dark into I don't
# 174|have to carry this. I have me and I have you.
# 179|After every storm,
# 181|the sky breaks open wide.
#
# 185|After every fall,
# 187|there's still a reason left inside.
# 192|I've been down before
# 194|and I came back every time.
# 198|I won't let the darkness tell me
# 203|this is where I die.
# 206|Cuz the light
# 207|the light will find you even when you've
# 211|lost the way.
# 212|Hold on to
# 214|the ones who know you. Let them help you
# 217|find the day. Never give up.
# 220|Never give in. The high comes back after
# 224|the low sets in. Light will find you.
# 227|Light will find you again.
# 231|It's okay to not be okay.
#
# 234|It's okay to need a hand. You don't have
# 238|to have it all together. You just
# 240|have to let someone understand.
# 242|Talk to me. Talk to them.
# 246|Say the thing you can't say in your head.
# 250|Voices in the dark get quieter when
# 253|they're finally heard instead.
# 256|After every storm,
# 258|the sky breaks open wide.
# 262|After every fall,
# 264|there's still a reason left inside.
# 269|I've been down before
# 271|and I came back every time.
# 275|I won't let the darkness tell me
# 280|this is where I die.
# 283|Cuz the light
# 284|the light will find you even when you've
# 288|lost the way.
# 289|Hold on to
# 291|the ones who know you. Let them help you
# 294|find the day. Never give up.
# 297|Never give in. The high comes
# 300|back after the low sets in. Light will
# 303|find you.
# 306|Light will find you.
# 309|Light will find you again.
# ==================================================

# %%
def parse_timestamp_lyrics(lyrics_text, font=None, max_width=None):
    """Parse lyrics with timestamp format from YouTube transcripts using pipe separator"""
    lines = [line.strip() for line in lyrics_text.split('\n') if line.strip()]
    
    lyrics_with_timing = []
    
    for line in lines:
        # Split by the first pipe to separate timestamp from text
        if '|' in line:
            timestamp_str, text = line.split('|', 1)
            try:
                # Convert timestamp to float (seconds)
                timestamp = float(timestamp_str.strip())
                lyrics_with_timing.append({
                    'timestamp': timestamp,
                    'text': text.strip(),
                    'start_time': timestamp,
                    'end_time': None,
                    'duration_seconds': None,
                    'word_count': None,
                    'spaces_count': None,
                    'char_count': None
                })
            except ValueError:
                print(f"⚠️ Skipping line with invalid timestamp: {line}")
                continue
        else:
            print(f"⚠️ Skipping line without Pipe separator: {line}")
    
    # Sort by timestamp
    lyrics_with_timing.sort(key=lambda x: x['timestamp'])
    
    # Calculate end times and additional metrics
    for i in range(len(lyrics_with_timing)):
        if i < len(lyrics_with_timing) - 1:
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i + 1]['timestamp']
        else:
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i]['timestamp'] + 5
        
        lyrics_with_timing[i]['duration_seconds'] = lyrics_with_timing[i]['end_time'] - lyrics_with_timing[i]['start_time']
        
        words = [word for word in lyrics_with_timing[i]['text'].split() if word]
        lyrics_with_timing[i]['word_count'] = len(words)
        lyrics_with_timing[i]['spaces_count'] = max(0, lyrics_with_timing[i]['word_count'] - 1)
        lyrics_with_timing[i]['char_count'] = len(lyrics_with_timing[i]['text'])
        
        # We'll split later after font is loaded in the main function
        lyrics_with_timing[i]['line1'] = lyrics_with_timing[i]['text']
        lyrics_with_timing[i]['line2'] = ''
        lyrics_with_timing[i]['line3'] = ''
        lyrics_with_timing[i]['num_lines'] = 1
        lyrics_with_timing[i]['is_split'] = False
    
    return lyrics_with_timing

def split_text_to_fit_width(text, font, max_width, draw, max_lines=3):
    """Split text into multiple lines to fit within max_width"""
    if not text:
        return ['']
    
    # Check if text fits in one line
    try:
        bbox = draw.textbbox((0, 0), text, font=font)
    except AttributeError:
        # For older PIL versions
        text_width, text_height = draw.textsize(text, font=font)
    else:
        text_width = bbox[2] - bbox[0]
    
    if text_width <= max_width:
        return [text]
    
    # Text doesn't fit - need to split
    words = text.split()
    lines = []
    current_line = []
    
    for word in words:
        # Try adding the word to current line
        test_line = ' '.join(current_line + [word])
        try:
            bbox = draw.textbbox((0, 0), test_line, font=font)
        except AttributeError:
            test_width, _ = draw.textsize(test_line, font=font)
        else:
            test_width = bbox[2] - bbox[0]
        
        if test_width <= max_width:
            # Word fits, add it
            current_line.append(word)
        else:
            # Word doesn't fit
            if current_line:
                # Save current line and start new one with this word
                lines.append(' '.join(current_line))
                current_line = [word]
            else:
                # Single word is too long - need character split
                # Find where to split the word
                for i in range(len(word), 0, -1):
                    test_part = word[:i]
                    try:
                        bbox = draw.textbbox((0, 0), test_part, font=font)
                    except AttributeError:
                        test_width, _ = draw.textsize(test_part, font=font)
                    else:
                        test_width = bbox[2] - bbox[0]
                    
                    if test_width <= max_width:
                        lines.append(word[:i])
                        current_line = [word[i:]]
                        break
                else:
                    # If even single character doesn't fit, just add the word
                    lines.append(word)
                    current_line = []
        
        # Check if we've reached max_lines
        if len(lines) == max_lines - 1 and current_line:
            # Add the remaining words as the last line, possibly with ellipsis
            remaining = ' '.join(current_line)
            try:
                bbox = draw.textbbox((0, 0), remaining, font=font)
            except AttributeError:
                remaining_width, _ = draw.textsize(remaining, font=font)
            else:
                remaining_width = bbox[2] - bbox[0]
            
            if remaining_width > max_width:
                # Need to truncate with ellipsis
                while remaining_width > max_width and len(remaining) > 4:
                    remaining = remaining[:-4] + "..."
                    try:
                        bbox = draw.textbbox((0, 0), remaining, font=font)
                    except AttributeError:
                        remaining_width, _ = draw.textsize(remaining, font=font)
                    else:
                        remaining_width = bbox[2] - bbox[0]
            
            lines.append(remaining)
            current_line = []
            break
    
    # Add remaining words if we haven't hit max_lines
    if current_line and len(lines) < max_lines:
        lines.append(' '.join(current_line))
    
    # If we still have more than max_lines, truncate
    if len(lines) > max_lines:
        lines = lines[:max_lines]
        # Add ellipsis to last line if needed
        try:
            bbox = draw.textbbox((0, 0), lines[-1], font=font)
        except AttributeError:
            last_width, _ = draw.textsize(lines[-1], font=font)
        else:
            last_width = bbox[2] - bbox[0]
        
        if last_width > max_width * 0.9:
            lines[-1] = lines[-1][:int(len(lines[-1]) * 0.8)] + "..."
    
    return lines

def get_current_lyric(current_time, lyrics_with_timing):
    """Find which lyric should be displayed at current time"""
    for lyric in lyrics_with_timing:
        if lyric['start_time'] <= current_time < lyric['end_time']:
            return lyric
    return None

def create_timestamp_synced_video(song_id=songId, max_duration=None):
    """Create video using timestamp-based lyrics from YouTube transcripts"""
    
    try:
        # Get song data - use %s parameter syntax for PyMySQL
        query = """
        SELECT s.name as song_name, s.location as audio_file,
               l.content as lyrics, a.first_name, a.last_name
        FROM songs s 
        JOIN lyrics l ON s.id = l.song_id 
        JOIN artists a ON s.artist_id = a.id 
        WHERE s.id = %s
        """
        
        df = pd.read_sql(query, engine, params=(song_id,))
        
        if df.empty:
            print(f"❌ No song found with ID: {song_id}")
            return None
            
        song_data = df.iloc[0]
        
        print(f"🎵 Creating TIMESTAMP-SYNCED video for: {song_data['song_name']}")
        
        # Construct file paths
        audio_dir = os.path.join(r"C:\ruby\music\public\uploads\song\location", str(song_id))
        
        if os.path.exists(audio_dir):
            print(f"📁 Directory contents: {os.listdir(audio_dir)}")
        else:
            print(f"❌ Directory doesn't exist: {audio_dir}")
            return None
            
        audio_path = os.path.join(audio_dir, song_data['audio_file'])
        
        print(f"🔊 Audio path: {audio_path}")
        print(f"🔊 Audio file from DB: {song_data['audio_file']}")

        background_image_path = os.path.join(audio_dir, "Folder.jpg")
        print(f"🖼️ Background image: {background_image_path}")        
        
        if not os.path.exists(audio_path):
            print(f"❌ Audio file not found at: {audio_path}")
            all_files = os.listdir(audio_dir)
            print(f"📁 Available files: {all_files}")
            for file in all_files:
                if "I_Don" in file and "Want_to_Talk" in file:
                    print(f"🔍 Found alternative file: {file}")
                    audio_path = os.path.join(audio_dir, file)
                    break
            else:
                return None
        
        # Video settings (defined early for text width calculation)
        fps = 24
        width, height = 640, 480
        
        # Load fonts early for text width calculation
        try:
            font_main = ImageFont.truetype("arial.ttf", 32)
        except:
            try:
                font_main = ImageFont.truetype("C:/Windows/Fonts/arial.ttf", 32)
            except:
                font_main = ImageFont.load_default()
        
        # Create a temporary draw object for text measurement
        temp_img = Image.new('RGB', (width, height), color='black')
        temp_draw = ImageDraw.Draw(temp_img)
        
        # Define margins (text won't go edge to edge)
        left_margin = 40
        right_margin = 40
        max_text_width = width - left_margin - right_margin
        
        print(f"📏 Max text width: {max_text_width}px (with {left_margin}px margins)")
        
        # Parse timestamp-based lyrics
        lyrics_with_timing = parse_timestamp_lyrics(song_data['lyrics'])
        
        if not lyrics_with_timing:
            print("❌ Could not parse timestamp lyrics")
            return None
        
        # Now split long lines based on actual font metrics (up to 3 lines)
        split_count = 0
        three_line_count = 0
        for lyric in lyrics_with_timing:
            text = lyric['text']
            lines = split_text_to_fit_width(text, font_main, max_text_width, temp_draw, max_lines=3)
            
            lyric['num_lines'] = len(lines)
            lyric['line1'] = lines[0] if len(lines) > 0 else ''
            lyric['line2'] = lines[1] if len(lines) > 1 else ''
            lyric['line3'] = lines[2] if len(lines) > 2 else ''
            lyric['is_split'] = len(lines) > 1
            
            if len(lines) > 1:
                split_count += 1
            if len(lines) > 2:
                three_line_count += 1
        
        print(f"📝 Parsed {len(lyrics_with_timing)} timestamped lyrics lines")
        print(f"✂️ Split {split_count} lines (including {three_line_count} with 3 lines)")
        
        # Load audio clip
        audio_clip = AudioFileClip(audio_path)
        full_duration = audio_clip.duration
        
        if max_duration:
            duration = min(max_duration, full_duration)
            print(f"⏱️ Using LIMITED duration: {duration:.1f}s (max_duration={max_duration}s)")
        else:
            duration = full_duration
            print(f"⏱️ Using FULL duration: {duration:.1f}s")
        
        if max_duration and full_duration > max_duration:
            audio_clip = audio_clip.subclip(0, duration)
        
        if max_duration:
            lyrics_with_timing = [lyric for lyric in lyrics_with_timing if lyric['start_time'] < duration]
            if lyrics_with_timing and lyrics_with_timing[-1]['end_time'] > duration:
                lyrics_with_timing[-1]['end_time'] = duration
        
        print(f"📝 Final timing: {len(lyrics_with_timing)} lyrics lines")
        print(f"⏱️ Video duration: {duration:.1f}s ({duration/60:.1f} minutes)")

        print("\n📋 Parsed Lyrics Timing:")
        print("-" * 95)
        for i, lyric in enumerate(lyrics_with_timing):
            display_text = lyric['text'][:40] + ('...' if len(lyric['text']) > 40 else '')
            if lyric['num_lines'] == 3:
                split_indicator = "✂️✂️"
            elif lyric['num_lines'] == 2:
                split_indicator = "✂️"
            else:
                split_indicator = "  "
            
            # Calculate approximate width percentage for info
            try:
                bbox = temp_draw.textbbox((0, 0), lyric['text'], font=font_main)
                text_width = bbox[2] - bbox[0]
                width_percent = (text_width / max_text_width) * 100
                width_info = f"{width_percent:3.0f}%"
            except:
                width_info = "N/A"
            
            print(f"{i+1:2d}. {split_indicator} {lyric['start_time']:5.1f}s - {lyric['end_time']:5.1f}s: "
                  f"{display_text:<42} | {lyric['duration_seconds']:4.1f}s | {lyric['num_lines']}L | {width_info}")
        
        def make_synced_frame(t):
            try:
                # Load background
                if os.path.exists(background_image_path):
                    bg_image = Image.open(background_image_path)
                    bg_image = bg_image.resize((width, height), Image.Resampling.LANCZOS)
                    frame = np.array(bg_image)
                else:
                    frame = np.full((height, width, 3), [40, 40, 80], dtype=np.uint8)
                
                pil_img = Image.fromarray(frame)
                draw = ImageDraw.Draw(pil_img)
                
                # Get current lyric
                current_lyric = get_current_lyric(t, lyrics_with_timing)
                
                if current_lyric:
                    text_color = (255, 255, 255)  # White
                    line_spacing = 8  # Space between lines
                    y_start = height - 60  # Base position from bottom for the LOWEST line
                    
                    if current_lyric['num_lines'] == 3:
                        # Draw three lines
                        line1 = current_lyric['line1']
                        line2 = current_lyric['line2']
                        line3 = current_lyric['line3']
                        
                        # Calculate text dimensions
                        try:
                            bbox1 = draw.textbbox((0, 0), line1, font=font_main)
                            bbox2 = draw.textbbox((0, 0), line2, font=font_main)
                            bbox3 = draw.textbbox((0, 0), line3, font=font_main)
                        except AttributeError:
                            text_width1, text_height1 = draw.textsize(line1, font=font_main)
                            text_width2, text_height2 = draw.textsize(line2, font=font_main)
                            text_width3, text_height3 = draw.textsize(line3, font=font_main)
                            bbox1 = (0, 0, text_width1, text_height1)
                            bbox2 = (0, 0, text_width2, text_height2)
                            bbox3 = (0, 0, text_width3, text_height3)
                        
                        text_width1 = bbox1[2] - bbox1[0]
                        text_height1 = bbox1[3] - bbox1[1]
                        text_width2 = bbox2[2] - bbox2[0]
                        text_height2 = bbox2[3] - bbox2[1]
                        text_width3 = bbox3[2] - bbox3[0]
                        text_height3 = bbox3[3] - bbox3[1]
                        
                        # Center all lines horizontally
                        x1 = (width - text_width1) // 2
                        x2 = (width - text_width2) // 2
                        x3 = (width - text_width3) // 2
                        
                        # Position lines vertically - lowest line at y_start
                        y3 = y_start
                        y2 = y3 - text_height3 - line_spacing
                        y1 = y2 - text_height2 - line_spacing
                        
                        # Draw three lines
                        draw.text((x1, y1), line1, font=font_main, fill=text_color)
                        draw.text((x2, y2), line2, font=font_main, fill=text_color)
                        draw.text((x3, y3), line3, font=font_main, fill=text_color)
                        
                    elif current_lyric['num_lines'] == 2:
                        # Draw two lines
                        line1 = current_lyric['line1']
                        line2 = current_lyric['line2']
                        
                        # Calculate positions for both lines
                        try:
                            bbox1 = draw.textbbox((0, 0), line1, font=font_main)
                            bbox2 = draw.textbbox((0, 0), line2, font=font_main)
                        except AttributeError:
                            text_width1, text_height1 = draw.textsize(line1, font=font_main)
                            text_width2, text_height2 = draw.textsize(line2, font=font_main)
                            bbox1 = (0, 0, text_width1, text_height1)
                            bbox2 = (0, 0, text_width2, text_height2)
                        
                        text_width1 = bbox1[2] - bbox1[0]
                        text_height1 = bbox1[3] - bbox1[1]
                        text_width2 = bbox2[2] - bbox2[0]
                        text_height2 = bbox2[3] - bbox2[1]
                        
                        # Center both lines horizontally
                        x1 = (width - text_width1) // 2
                        x2 = (width - text_width2) // 2
                        
                        # Position lines vertically - lowest line at y_start
                        y2 = y_start
                        y1 = y2 - text_height2 - line_spacing
                        
                        # Draw both lines
                        draw.text((x1, y1), line1, font=font_main, fill=text_color)
                        draw.text((x2, y2), line2, font=font_main, fill=text_color)
                    else:
                        # Draw single line - POSITIONED AT LOWEST LINE POSITION
                        current_line = current_lyric['text']
                        
                        try:
                            bbox = draw.textbbox((0, 0), current_line, font=font_main)
                        except AttributeError:
                            text_width, text_height = draw.textsize(current_line, font=font_main)
                            bbox = (0, 0, text_width, text_height)
                        
                        text_width = bbox[2] - bbox[0]
                        text_height = bbox[3] - bbox[1]
                        
                        # Center horizontally
                        x = (width - text_width) // 2
                        
                        # Position at the lowest line position
                        y = y_start
                        
                        draw.text((x, y), current_line, font=font_main, fill=text_color)
                
                return np.array(pil_img)
                
            except Exception as e:
                print(f"❌ Frame error at {t:.1f}s: {e}")
                return np.zeros((height, width, 3), dtype=np.uint8)
        
        # Create video
        print("🎬 Creating timestamp-synced video frames...")
        video = VideoClip(make_synced_frame, duration=duration)
        video = video.set_audio(audio_clip)
        
        # Export
        output_dir = '../data/videos'
        os.makedirs(output_dir, exist_ok=True)
        
        clean_artist_name = f"{song_data['first_name']} {song_data['last_name']}"
        output_file = os.path.join(output_dir, f"{song_data['song_name']}_{clean_artist_name}.mp4")
        
        print("📹 Exporting video...")
        video.write_videofile(
            output_file, 
            fps=fps, 
            codec='libx264',
            audio_codec='aac',
            verbose=False,
            logger=None
        )
        
        print(f"✅ TIMESTAMP-SYNCED VIDEO CREATED: {output_file}")
        print(f"📊 File size: {os.path.getsize(output_file) / (1024*1024):.1f} MB")
        
        # Clean up
        video.close()
        audio_clip.close()
        
        return output_file
        
    except Exception as e:
        print(f"❌ Video creation error: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the timestamp-synced version
if __name__ == "__main__":
    print("=" * 70)
    print("🎬 CREATING TIMESTAMP-SYNCED VIDEO")
    print("=" * 70)
    
    result = create_timestamp_synced_video(song_id=songId, max_duration=None)
    
    if result:
        print(f"\n🎉 SUCCESS! Timestamp-synced video created: {result}")
        print("\n✨ Features:")
        print("   ✅ YouTube transcript timestamp parsing")
        print("   ✅ Intelligent text overflow detection")
        print("   ✅ Dynamic line splitting (up to 3 lines)")
        print("   ✅ Single lines positioned at lowest line height")
        print("   ✅ Perfect synchronization with original timestamps")
        
    else:
        print("\n❌ Timestamp-synced video creation failed")
# Out:
# ======================================================================
# 🎬 CREATING TIMESTAMP-SYNCED VIDEO
# ======================================================================
# 🎵 Creating TIMESTAMP-SYNCED video for: Love Will Find You
# 📁 Directory contents: ['Avril_Lavigne_-_Love_Will_Find_You.mp3', 'Folder.jpg']
# 🔊 Audio path: C:\ruby\music\public\uploads\song\location\699\Avril_Lavigne_-_Love_Will_Find_You.mp3
# 🔊 Audio file from DB: Avril_Lavigne_-_Love_Will_Find_You.mp3
# 🖼️ Background image: C:\ruby\music\public\uploads\song\location\699\Folder.jpg
# 📏 Max text width: 560px (with 40px margins)
# 📝 Parsed 103 timestamped lyrics lines
# ✂️ Split 14 lines (including 0 with 3 lines)
# ⏱️ Using FULL duration: 314.4s
# 📝 Final timing: 103 lyrics lines
# ⏱️ Video duration: 314.4s (5.2 minutes)
#
# 📋 Parsed Lyrics Timing:
# -----------------------------------------------------------------------------------------------
#  1.      8.0s -  16.0s: Light will find you again.                 |  8.0s | 1L |  61%
#  2.     16.0s -  18.0s: I wake up and the ceiling                  |  2.0s | 1L |  63%
#  3.     18.0s -  22.0s: feels like it's closing in.                |  4.0s | 1L |  58%
#  4. ✂️  22.0s -  25.0s: Can't remember when the noise outside      |  3.0s | 2L | 102%
#  5.     25.0s -  29.0s: got under my skin.                         |  4.0s | 1L |  47%
#  6.     29.0s -  32.0s: I smile for the world, but inside it's a   |  3.0s | 1L |  91%
#  7.     32.0s -  36.0s: different place.                           |  4.0s | 1L |  38%
#  8.     36.0s -  38.0s: Like I'm running out of room inside        |  2.0s | 1L |  88%
#  9.     38.0s -  43.0s: my own head space.                         |  5.0s | 1L |  53%
# 10.     43.0s -  45.0s: The days blur together, gray on            |  2.0s | 1L |  80%
# 11.     45.0s -  47.0s: gray on gray. I keep saying                |  2.0s | 1L |  69%
# 12.     47.0s -  50.0s: I'm fine, but I'm slowly fading away.      |  3.0s | 1L |  90%
# 13.     50.0s -  52.0s: There's a version of me that I             |  2.0s | 1L |  75%
# 14.     52.0s -  56.0s: used to know so well.                      |  4.0s | 1L |  55%
# 15.     56.0s -  59.0s: And I'm trying to reach her, but I'm       |  3.0s | 1L |  88%
# 16.     59.0s -  63.0s: stuck inside this shell.                   |  4.0s | 1L |  56%
# 17. ✂️  63.0s -  66.0s: But then you called and you sat with me    |  3.0s | 2L | 102%
# 18.     66.0s -  69.0s: a while. Didn't try to fix it, you just    |  3.0s | 1L |  85%
# 19.     69.0s -  70.0s: stayed and made me smile.                  |  1.0s | 1L |  71%
# 20.     70.0s -  72.0s: And something in that moment               |  2.0s | 1L |  78%
# 21.     72.0s -  75.0s: cracked the dark into I don't have to      |  3.0s | 1L |  91%
# 22.     75.0s -  79.0s: carry this. I have me and I have you.      |  4.0s | 1L |  93%
# 23.     79.0s -  81.0s: After every storm,                         |  2.0s | 1L |  46%
# 24.     81.0s -  85.0s: the sky breaks open wide.                  |  4.0s | 1L |  67%
# 25.     85.0s -  87.0s: After every fall,                          |  2.0s | 1L |  39%
# 26.     87.0s -  92.0s: there's still a reason left inside.        |  5.0s | 1L |  79%
# 27. ✂️  92.0s -  95.0s: I've been down before and I came back      |  3.0s | 2L | 101%
# 28.     95.0s -  98.0s: every time.                                |  3.0s | 1L |  28%
# 29.     98.0s - 103.0s: I won't let the darkness tell me           |  5.0s | 1L |  77%
# 30.    103.0s - 106.0s: this is where I die.                       |  3.0s | 1L |  46%
# 31.    106.0s - 107.0s: Cuz the light                              |  1.0s | 1L |  32%
# 32.    107.0s - 110.0s: the light will find you even               |  3.0s | 1L |  66%
# 33.    110.0s - 112.0s: when you've lost the way.                  |  2.0s | 1L |  65%
# 34.    112.0s - 114.0s: Hold on to                                 |  2.0s | 1L |  26%
# 35.    114.0s - 116.0s: the ones who know you.                     |  2.0s | 1L |  62%
# 36.    116.0s - 119.0s: Let them help you find the day.            |  3.0s | 1L |  79%
# 37.    119.0s - 121.0s: Never give up.                             |  2.0s | 1L |  37%
# 38. ✂️ 121.0s - 124.0s: Never give in. The high comes back after   |  3.0s | 2L | 105%
# 39.    124.0s - 128.0s: the low sets in. Light will find you.      |  4.0s | 1L |  85%
# 40.    128.0s - 133.0s: Light will find you again.                 |  5.0s | 1L |  61%
# 41.    133.0s - 134.0s: I know it doesn't look like it             |  1.0s | 1L |  68%
# 42. ✂️ 134.0s - 137.0s: from where you're standing now, like the   |  3.0s | 2L | 103%
# 43. ✂️ 137.0s - 139.0s: tunnel has no ending and you can't see     |  2.0s | 2L | 100%
# 44.    139.0s - 143.0s: through the clouds.                        |  4.0s | 1L |  49%
# 45.    143.0s - 145.0s: But I've sat in that same darkness.        |  2.0s | 1L |  88%
# 46. ✂️ 145.0s - 147.0s: I felt that same weight. And I promise y... |  2.0s | 2L | 106%
# 47.    147.0s - 150.0s: the morning always finds a way.            |  3.0s | 1L |  82%
# 48.    150.0s - 152.0s: Pick up the phone to say the words out     |  2.0s | 1L |  99%
# 49.    152.0s - 154.0s: loud. You don't have to be strong. Just    |  2.0s | 1L |  98%
# 50. ✂️ 154.0s - 156.0s: don't disappear in a crowd. Your people    |  2.0s | 2L | 101%
# 51.    156.0s - 158.0s: need you here. They need you               |  2.0s | 1L |  78%
# 52.    158.0s - 160.0s: breathing and real. You don't have to      |  2.0s | 1L |  94%
# 53.    160.0s - 163.0s: explain it. Just let yourself feel.        |  3.0s | 1L |  78%
# 54.    163.0s - 166.0s: Because I called and you sat with me a     |  3.0s | 1L | 100%
# 55.    166.0s - 169.0s: while. Didn't try to fix it, you just      |  3.0s | 1L |  80%
# 56.    169.0s - 170.0s: stayed and made me smile.                  |  1.0s | 1L |  71%
# 57.    170.0s - 172.0s: And something in that moment               |  2.0s | 1L |  78%
# 58.    172.0s - 174.0s: cracked the dark into I don't              |  2.0s | 1L |  71%
# 59. ✂️ 174.0s - 179.0s: have to carry this. I have me and I have... |  5.0s | 2L | 114%
# 60.    179.0s - 181.0s: After every storm,                         |  2.0s | 1L |  46%
# 61.    181.0s - 185.0s: the sky breaks open wide.                  |  4.0s | 1L |  67%
# 62.    185.0s - 187.0s: After every fall,                          |  2.0s | 1L |  39%
# 63.    187.0s - 192.0s: there's still a reason left inside.        |  5.0s | 1L |  79%
# 64.    192.0s - 194.0s: I've been down before                      |  2.0s | 1L |  57%
# 65.    194.0s - 198.0s: and I came back every time.                |  4.0s | 1L |  72%
# 66.    198.0s - 203.0s: I won't let the darkness tell me           |  5.0s | 1L |  77%
# 67.    203.0s - 206.0s: this is where I die.                       |  3.0s | 1L |  46%
# 68.    206.0s - 207.0s: Cuz the light                              |  1.0s | 1L |  32%
# 69.    207.0s - 211.0s: the light will find you even when you've   |  4.0s | 1L |  99%
# 70.    211.0s - 212.0s: lost the way.                              |  1.0s | 1L |  32%
# 71.    212.0s - 214.0s: Hold on to                                 |  2.0s | 1L |  26%
# 72. ✂️ 214.0s - 217.0s: the ones who know you. Let them help you   |  3.0s | 2L | 109%
# 73.    217.0s - 220.0s: find the day. Never give up.               |  3.0s | 1L |  70%
# 74. ✂️ 220.0s - 224.0s: Never give in. The high comes back after   |  4.0s | 2L | 105%
# 75.    224.0s - 227.0s: the low sets in. Light will find you.      |  3.0s | 1L |  85%
# 76.    227.0s - 231.0s: Light will find you again.                 |  4.0s | 1L |  61%
# 77.    231.0s - 234.0s: It's okay to not be okay.                  |  3.0s | 1L |  60%
# 78. ✂️ 234.0s - 238.0s: It's okay to need a hand. You don't have   |  4.0s | 2L | 102%
# 79.    238.0s - 240.0s: to have it all together. You just          |  2.0s | 1L |  78%
# 80.    240.0s - 242.0s: have to let someone understand.            |  2.0s | 1L |  84%
# 81.    242.0s - 246.0s: Talk to me. Talk to them.                  |  4.0s | 1L |  64%
# 82. ✂️ 246.0s - 250.0s: Say the thing you can't say in your head... |  4.0s | 2L | 104%
# 83.    250.0s - 253.0s: Voices in the dark get quieter when        |  3.0s | 1L |  90%
# 84.    253.0s - 256.0s: they're finally heard instead.             |  3.0s | 1L |  72%
# 85.    256.0s - 258.0s: After every storm,                         |  2.0s | 1L |  46%
# 86.    258.0s - 262.0s: the sky breaks open wide.                  |  4.0s | 1L |  67%
# 87.    262.0s - 264.0s: After every fall,                          |  2.0s | 1L |  39%
# 88.    264.0s - 269.0s: there's still a reason left inside.        |  5.0s | 1L |  79%
# 89.    269.0s - 271.0s: I've been down before                      |  2.0s | 1L |  57%
# 90.    271.0s - 275.0s: and I came back every time.                |  4.0s | 1L |  72%
# 91.    275.0s - 280.0s: I won't let the darkness tell me           |  5.0s | 1L |  77%
# 92.    280.0s - 283.0s: this is where I die.                       |  3.0s | 1L |  46%
# 93.    283.0s - 284.0s: Cuz the light                              |  1.0s | 1L |  32%
# 94.    284.0s - 288.0s: the light will find you even when you've   |  4.0s | 1L |  99%
# 95.    288.0s - 289.0s: lost the way.                              |  1.0s | 1L |  32%
# 96.    289.0s - 291.0s: Hold on to                                 |  2.0s | 1L |  26%
# 97. ✂️ 291.0s - 294.0s: the ones who know you. Let them help you   |  3.0s | 2L | 109%
# 98.    294.0s - 297.0s: find the day. Never give up.               |  3.0s | 1L |  70%
# 99.    297.0s - 300.0s: Never give in. The high comes              |  3.0s | 1L |  78%
# 100.    300.0s - 303.0s: back after the low sets in. Light will     |  3.0s | 1L |  89%
# 101.    303.0s - 306.0s: find you.                                  |  3.0s | 1L |  22%
# 102.    306.0s - 309.0s: Light will find you.                       |  3.0s | 1L |  45%
# 103.    309.0s - 314.0s: Light will find you again.                 |  5.0s | 1L |  61%
# 🎬 Creating timestamp-synced video frames...
# 📹 Exporting video...
# ✅ TIMESTAMP-SYNCED VIDEO CREATED: ../data/videos\Love Will Find You_Avril Lavigne.mp4
# 📊 File size: 6.3 MB
#
# 🎉 SUCCESS! Timestamp-synced video created: ../data/videos\Love Will Find You_Avril Lavigne.mp4
#
# ✨ Features:
#    ✅ YouTube transcript timestamp parsing
#    ✅ Intelligent text overflow detection
#    ✅ Dynamic line splitting (up to 3 lines)
#    ✅ Single lines positioned at lowest line height
#    ✅ Perfect synchronization with original timestamps
