# %%
import pandas as pd
import numpy as np
import os
from sqlalchemy import create_engine, text
from glob import glob

# Database connections
engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

pd.options.display.max_rows = None
data_path = "../data/"
format_dict = {
               'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}','shares':'{:,}'
}

# %%
year = 2025
quarter = 4
print(f"Year: {year}, Quarter: {quarter}")
# Out:
# Year: 2025, Quarter: 4

# %%
sql = f"""
SELECT name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id
FROM epss
WHERE year = {year} AND quarter = {quarter}
ORDER BY name
"""
print(sql)
epss_df = pd.read_sql(sql, conlt)
epss_df.shape
# Out:
# SELECT name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id
# FROM epss
# WHERE year = 2025 AND quarter = 4
# ORDER BY name
# (140, 8)

# %%
epss_df['grade'] = 0
epss_df.columns
# Out:
# Index(['name', 'year', 'quarter', 'q_amt', 'y_amt', 'aq_amt', 'ay_amt',
#        'ticker_id', 'grade'],
#       dtype='object')

# %%
def grade(vals):
    qc, qp, aqc, aqp = vals
    if aqc >= aqp:
        if qc >= qp:
            return 1
        else:
            return 2
    else:
        if qc < qp:
            return 4
        else:
            return 3

# %%
epss_df["grade"] = epss_df[["q_amt", "y_amt","aq_amt", "ay_amt"]].apply(grade, axis=1)
epss_df.shape
# Out:
# (140, 9)

# %%
g1 = epss_df[epss_df["grade"] == 1]
g1.shape
# Out:
# (54, 9)

# %%
g2 = epss_df[epss_df["grade"] == 2]
g2.shape
# Out:
# (27, 9)

# %%
g3 = epss_df[epss_df["grade"] == 3]
g3.shape
# Out:
# (16, 9)

# %%
g4 = epss_df[epss_df["grade"] == 4]
g4.shape
# Out:
# (43, 9)

# %%
#g4.style.format(format_dict)

# %%
#g3.style.format(format_dict)

# %%
#g2.style.format(format_dict)

# %%
g1.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c241f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c241f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c241f_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_c241f_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_c241f_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_c241f_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_c241f_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_c241f_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_c241f_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_c241f_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c241f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c241f_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_c241f_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_c241f_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_c241f_row0_col3" class="data row0 col3" >6,429,421</td>
#       <td id="T_c241f_row0_col4" class="data row0 col4" >3,961,184</td>
#       <td id="T_c241f_row0_col5" class="data row0 col5" >7,044,205</td>
#       <td id="T_c241f_row0_col6" class="data row0 col6" >5,279,119</td>
#       <td id="T_c241f_row0_col7" class="data row0 col7" >234</td>
#       <td id="T_c241f_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c241f_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_c241f_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_c241f_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_c241f_row1_col3" class="data row1 col3" >14,281,630</td>
#       <td id="T_c241f_row1_col4" class="data row1 col4" >9,258,911</td>
#       <td id="T_c241f_row1_col5" class="data row1 col5" >47,885,902</td>
#       <td id="T_c241f_row1_col6" class="data row1 col6" >35,075,357</td>
#       <td id="T_c241f_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_c241f_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_c241f_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_c241f_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_c241f_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_c241f_row2_col3" class="data row2 col3" >160,073</td>
#       <td id="T_c241f_row2_col4" class="data row2 col4" >16,777</td>
#       <td id="T_c241f_row2_col5" class="data row2 col5" >531,545</td>
#       <td id="T_c241f_row2_col6" class="data row2 col6" >331,797</td>
#       <td id="T_c241f_row2_col7" class="data row2 col7" >38</td>
#       <td id="T_c241f_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_c241f_row3_col0" class="data row3 col0" >AWC</td>
#       <td id="T_c241f_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_c241f_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_c241f_row3_col3" class="data row3 col3" >1,866,088</td>
#       <td id="T_c241f_row3_col4" class="data row3 col4" >1,859,770</td>
#       <td id="T_c241f_row3_col5" class="data row3 col5" >6,388,002</td>
#       <td id="T_c241f_row3_col6" class="data row3 col6" >5,850,295</td>
#       <td id="T_c241f_row3_col7" class="data row3 col7" >699</td>
#       <td id="T_c241f_row3_col8" class="data row3 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row4" class="row_heading level0 row4" >15</th>
#       <td id="T_c241f_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_c241f_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_c241f_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_c241f_row4_col3" class="data row4 col3" >259,498</td>
#       <td id="T_c241f_row4_col4" class="data row4 col4" >233,040</td>
#       <td id="T_c241f_row4_col5" class="data row4 col5" >1,316,360</td>
#       <td id="T_c241f_row4_col6" class="data row4 col6" >1,282,371</td>
#       <td id="T_c241f_row4_col7" class="data row4 col7" >51</td>
#       <td id="T_c241f_row4_col8" class="data row4 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_c241f_row5_col0" class="data row5 col0" >BCP</td>
#       <td id="T_c241f_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_c241f_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_c241f_row5_col3" class="data row5 col3" >2,216,608</td>
#       <td id="T_c241f_row5_col4" class="data row5 col4" >16,577</td>
#       <td id="T_c241f_row5_col5" class="data row5 col5" >2,879,701</td>
#       <td id="T_c241f_row5_col6" class="data row5 col6" >2,184,088</td>
#       <td id="T_c241f_row5_col7" class="data row5 col7" >52</td>
#       <td id="T_c241f_row5_col8" class="data row5 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_c241f_row6_col0" class="data row6 col0" >BEAUTY</td>
#       <td id="T_c241f_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_c241f_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_c241f_row6_col3" class="data row6 col3" >-12,163</td>
#       <td id="T_c241f_row6_col4" class="data row6 col4" >-70,274</td>
#       <td id="T_c241f_row6_col5" class="data row6 col5" >-59,045</td>
#       <td id="T_c241f_row6_col6" class="data row6 col6" >-115,822</td>
#       <td id="T_c241f_row6_col7" class="data row6 col7" >55</td>
#       <td id="T_c241f_row6_col8" class="data row6 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_c241f_row7_col0" class="data row7 col0" >BEC</td>
#       <td id="T_c241f_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_c241f_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_c241f_row7_col3" class="data row7 col3" >159,828</td>
#       <td id="T_c241f_row7_col4" class="data row7 col4" >-35,279</td>
#       <td id="T_c241f_row7_col5" class="data row7 col5" >205,766</td>
#       <td id="T_c241f_row7_col6" class="data row7 col6" >96,284</td>
#       <td id="T_c241f_row7_col7" class="data row7 col7" >56</td>
#       <td id="T_c241f_row7_col8" class="data row7 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_c241f_row8_col0" class="data row8 col0" >BLA</td>
#       <td id="T_c241f_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_c241f_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_c241f_row8_col3" class="data row8 col3" >1,344,964</td>
#       <td id="T_c241f_row8_col4" class="data row8 col4" >1,031,417</td>
#       <td id="T_c241f_row8_col5" class="data row8 col5" >6,968,375</td>
#       <td id="T_c241f_row8_col6" class="data row8 col6" >4,633,856</td>
#       <td id="T_c241f_row8_col7" class="data row8 col7" >70</td>
#       <td id="T_c241f_row8_col8" class="data row8 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row9" class="row_heading level0 row9" >25</th>
#       <td id="T_c241f_row9_col0" class="data row9 col0" >BPP</td>
#       <td id="T_c241f_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_c241f_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_c241f_row9_col3" class="data row9 col3" >19,210</td>
#       <td id="T_c241f_row9_col4" class="data row9 col4" >-1,046,562</td>
#       <td id="T_c241f_row9_col5" class="data row9 col5" >3,026,277</td>
#       <td id="T_c241f_row9_col6" class="data row9 col6" >1,746,321</td>
#       <td id="T_c241f_row9_col7" class="data row9 col7" >74</td>
#       <td id="T_c241f_row9_col8" class="data row9 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c241f_level0_row10" class="row_heading level0

# %%
# Get active stocks in portfolio
sql = '''
SELECT period, name, volbuy AS shares
FROM buy
WHERE active = 1
ORDER BY period, name
'''
df_buy = pd.read_sql(sql, const)
df_buy['shares'] = df_buy['shares'].astype('int64')
print("\nActive stocks:")
print(df_buy)
# Out:
# Active stocks:
#    period     name  shares
# 0       1    PTTGC    6000
# 1       1      SCC     600
# 2       1   SINGER    6000
# 3       1      STA   10000
# 4       2    3BBIF  120000
# 5       2  CPNREIT   55000
# 6       2      DIF   45000
# 7       2   GVREIT   69000
# 8       2      MCS   75000
# 9       2      NER   27000
# 10      2      PTT    7500
# 11      2     SENA  105000
# 12      2    TFFIF   20000
# 13      2    WHAIR   50000
# 14      2    WHART   20000
# 15      3   ADVANC     100
# 16      3       AH    1200
# 17      3      AWC    9000
# 18      3      BCH    4000
# 19      3      CPF   10000
# 20      3      PTG    3600
# 21      3      RCL   27000
# 22      3    SYNEX   17500
# 23      3      TOA    1000
# 24      3      TVO    4000
# 25      4   AIMIRT   17500
# 26      4      IVL    7200
# 27      4    JMART    6800
# 28      4      JMT    7000
# 29      4      ORI   50000

# %%
df_merge  = pd.merge(g1, df_buy, on = 'name', how='inner')
df_merge.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_32e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32e26_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_32e26_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_32e26_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_32e26_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_32e26_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_32e26_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_32e26_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_32e26_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_32e26_level0_col8" class="col_heading level0 col8" >grade</th>
#       <th id="T_32e26_level0_col9" class="col_heading level0 col9" >period</th>
#       <th id="T_32e26_level0_col10" class="col_heading level0 col10" >shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32e26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32e26_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_32e26_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_32e26_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_32e26_row0_col3" class="data row0 col3" >6,429,421</td>
#       <td id="T_32e26_row0_col4" class="data row0 col4" >3,961,184</td>
#       <td id="T_32e26_row0_col5" class="data row0 col5" >7,044,205</td>
#       <td id="T_32e26_row0_col6" class="data row0 col6" >5,279,119</td>
#       <td id="T_32e26_row0_col7" class="data row0 col7" >234</td>
#       <td id="T_32e26_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_32e26_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_32e26_row0_col10" class="data row0 col10" >120,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32e26_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_32e26_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_32e26_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_32e26_row1_col3" class="data row1 col3" >14,281,630</td>
#       <td id="T_32e26_row1_col4" class="data row1 col4" >9,258,911</td>
#       <td id="T_32e26_row1_col5" class="data row1 col5" >47,885,902</td>
#       <td id="T_32e26_row1_col6" class="data row1 col6" >35,075,357</td>
#       <td id="T_32e26_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_32e26_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_32e26_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_32e26_row1_col10" class="data row1 col10" >100</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32e26_row2_col0" class="data row2 col0" >AWC</td>
#       <td id="T_32e26_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_32e26_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_32e26_row2_col3" class="data row2 col3" >1,866,088</td>
#       <td id="T_32e26_row2_col4" class="data row2 col4" >1,859,770</td>
#       <td id="T_32e26_row2_col5" class="data row2 col5" >6,388,002</td>
#       <td id="T_32e26_row2_col6" class="data row2 col6" >5,850,295</td>
#       <td id="T_32e26_row2_col7" class="data row2 col7" >699</td>
#       <td id="T_32e26_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_32e26_row2_col9" class="data row2 col9" >3</td>
#       <td id="T_32e26_row2_col10" class="data row2 col10" >9,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32e26_row3_col0" class="data row3 col0" >BCH</td>
#       <td id="T_32e26_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_32e26_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_32e26_row3_col3" class="data row3 col3" >259,498</td>
#       <td id="T_32e26_row3_col4" class="data row3 col4" >233,040</td>
#       <td id="T_32e26_row3_col5" class="data row3 col5" >1,316,360</td>
#       <td id="T_32e26_row3_col6" class="data row3 col6" >1,282,371</td>
#       <td id="T_32e26_row3_col7" class="data row3 col7" >51</td>
#       <td id="T_32e26_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_32e26_row3_col9" class="data row3 col9" >3</td>
#       <td id="T_32e26_row3_col10" class="data row3 col10" >4,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32e26_row4_col0" class="data row4 col0" >CPNREIT</td>
#       <td id="T_32e26_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_32e26_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_32e26_row4_col3" class="data row4 col3" >1,484,839</td>
#       <td id="T_32e26_row4_col4" class="data row4 col4" >357,438</td>
#       <td id="T_32e26_row4_col5" class="data row4 col5" >3,460,976</td>
#       <td id="T_32e26_row4_col6" class="data row4 col6" >1,696,069</td>
#       <td id="T_32e26_row4_col7" class="data row4 col7" >647</td>
#       <td id="T_32e26_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_32e26_row4_col9" class="data row4 col9" >2</td>
#       <td id="T_32e26_row4_col10" class="data row4 col10" >55,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32e26_row5_col0" class="data row5 col0" >DIF</td>
#       <td id="T_32e26_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_32e26_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_32e26_row5_col3" class="data row5 col3" >5,589,388</td>
#       <td id="T_32e26_row5_col4" class="data row5 col4" >-7,397,987</td>
#       <td id="T_32e26_row5_col5" class="data row5 col5" >13,855,643</td>
#       <td id="T_32e26_row5_col6" class="data row5 col6" >656,288</td>
#       <td id="T_32e26_row5_col7" class="data row5 col7" >140</td>
#       <td id="T_32e26_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_32e26_row5_col9" class="data row5 col9" >2</td>
#       <td id="T_32e26_row5_col10" class="data row5 col10" >45,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32e26_row6_col0" class="data row6 col0" >NER</td>
#       <td id="T_32e26_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_32e26_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_32e26_row6_col3" class="data row6 col3" >395,108</td>
#       <td id="T_32e26_row6_col4" class="data row6 col4" >359,321</td>
#       <td id="T_32e26_row6_col5" class="data row6 col5" >1,884,525</td>
#       <td id="T_32e26_row6_col6" class="data row6 col6" >1,652,466</td>
#       <td id="T_32e26_row6_col7" class="data row6 col7" >680</td>
#       <td id="T_32e26_row6_col8" class="data row6 col8" >1</td>
#       <td id="T_32e26_row6_col9" class="data row6 col9" >2</td>
#       <td id="T_32e26_row6_col10" class="data row6 col10" >27,000</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_32e26_row7_col0" class="data row7 col0" >PTT</td>
#       <td id="T_32e26_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_32e26_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_32e26_row7_col3" class="data row7 col3" >25,534,645</td>
#       <td id="T_32e26_row7_col4" class="data row7 col4" >9,311,516</td>
#       <td id="T_32e26_row7_col5" class="data row7 col5" >90,166,373</td>
#       <td id="T_32e26_row7_col6" class="data row7 col6" >90,072,026</td>
#       <td id="T_32e26_row7_col7" class="data row7 col7" >383</td>
#       <td id="T_32e26_row7_col8" class="data row7 col8" >1</td>
#       <td id="T_32e26_row7_col9" class="data row7 col9" >2</td>
#       <td id="T_32e26_row7_col10" class="data row7 col10" >7,500</td>
#     </tr>
#     <tr>
#       <th id="T_32e26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_32e26_row8_col0" class="data row8 col0" >PTTGC</td>
#       <td id="T_32e26_row8_col1" class="data row8 col1" >2025</td>

# %%
df_merge  = pd.merge(g4, df_buy, on = 'name', how='inner')
df_merge.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af2f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af2f6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_af2f6_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_af2f6_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_af2f6_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_af2f6_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_af2f6_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_af2f6_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_af2f6_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_af2f6_level0_col8" class="col_heading level0 col8" >grade</th>
#       <th id="T_af2f6_level0_col9" class="col_heading level0 col9" >period</th>
#       <th id="T_af2f6_level0_col10" class="col_heading level0 col10" >shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af2f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af2f6_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_af2f6_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_af2f6_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_af2f6_row0_col3" class="data row0 col3" >105,562</td>
#       <td id="T_af2f6_row0_col4" class="data row0 col4" >119,895</td>
#       <td id="T_af2f6_row0_col5" class="data row0 col5" >731,428</td>
#       <td id="T_af2f6_row0_col6" class="data row0 col6" >746,961</td>
#       <td id="T_af2f6_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_af2f6_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_af2f6_row0_col9" class="data row0 col9" >3</td>
#       <td id="T_af2f6_row0_col10" class="data row0 col10" >1,200</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af2f6_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_af2f6_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_af2f6_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_af2f6_row1_col3" class="data row1 col3" >195,932</td>
#       <td id="T_af2f6_row1_col4" class="data row1 col4" >342,254</td>
#       <td id="T_af2f6_row1_col5" class="data row1 col5" >684,130</td>
#       <td id="T_af2f6_row1_col6" class="data row1 col6" >948,697</td>
#       <td id="T_af2f6_row1_col7" class="data row1 col7" >669</td>
#       <td id="T_af2f6_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_af2f6_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_af2f6_row1_col10" class="data row1 col10" >17,500</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af2f6_row2_col0" class="data row2 col0" >GVREIT</td>
#       <td id="T_af2f6_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_af2f6_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_af2f6_row2_col3" class="data row2 col3" >-432,165</td>
#       <td id="T_af2f6_row2_col4" class="data row2 col4" >-87,267</td>
#       <td id="T_af2f6_row2_col5" class="data row2 col5" >167,756</td>
#       <td id="T_af2f6_row2_col6" class="data row2 col6" >457,671</td>
#       <td id="T_af2f6_row2_col7" class="data row2 col7" >654</td>
#       <td id="T_af2f6_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_af2f6_row2_col9" class="data row2 col9" >2</td>
#       <td id="T_af2f6_row2_col10" class="data row2 col10" >69,000</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af2f6_row3_col0" class="data row3 col0" >JMART</td>
#       <td id="T_af2f6_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_af2f6_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_af2f6_row3_col3" class="data row3 col3" >-495,677</td>
#       <td id="T_af2f6_row3_col4" class="data row3 col4" >310,052</td>
#       <td id="T_af2f6_row3_col5" class="data row3 col5" >-161,839</td>
#       <td id="T_af2f6_row3_col6" class="data row3 col6" >1,140,849</td>
#       <td id="T_af2f6_row3_col7" class="data row3 col7" >236</td>
#       <td id="T_af2f6_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_af2f6_row3_col9" class="data row3 col9" >4</td>
#       <td id="T_af2f6_row3_col10" class="data row3 col10" >6,800</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af2f6_row4_col0" class="data row4 col0" >JMT</td>
#       <td id="T_af2f6_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_af2f6_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_af2f6_row4_col3" class="data row4 col3" >221,722</td>
#       <td id="T_af2f6_row4_col4" class="data row4 col4" >400,174</td>
#       <td id="T_af2f6_row4_col5" class="data row4 col5" >1,029,560</td>
#       <td id="T_af2f6_row4_col6" class="data row4 col6" >1,615,223</td>
#       <td id="T_af2f6_row4_col7" class="data row4 col7" >237</td>
#       <td id="T_af2f6_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_af2f6_row4_col9" class="data row4 col9" >4</td>
#       <td id="T_af2f6_row4_col10" class="data row4 col10" >7,000</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_af2f6_row5_col0" class="data row5 col0" >RCL</td>
#       <td id="T_af2f6_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_af2f6_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_af2f6_row5_col3" class="data row5 col3" >1,803,382</td>
#       <td id="T_af2f6_row5_col4" class="data row5 col4" >3,318,461</td>
#       <td id="T_af2f6_row5_col5" class="data row5 col5" >8,166,901</td>
#       <td id="T_af2f6_row5_col6" class="data row5 col6" >9,170,542</td>
#       <td id="T_af2f6_row5_col7" class="data row5 col7" >396</td>
#       <td id="T_af2f6_row5_col8" class="data row5 col8" >4</td>
#       <td id="T_af2f6_row5_col9" class="data row5 col9" >3</td>
#       <td id="T_af2f6_row5_col10" class="data row5 col10" >27,000</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_af2f6_row6_col0" class="data row6 col0" >SENA</td>
#       <td id="T_af2f6_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_af2f6_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_af2f6_row6_col3" class="data row6 col3" >35,749</td>
#       <td id="T_af2f6_row6_col4" class="data row6 col4" >97,807</td>
#       <td id="T_af2f6_row6_col5" class="data row6 col5" >323,614</td>
#       <td id="T_af2f6_row6_col6" class="data row6 col6" >399,608</td>
#       <td id="T_af2f6_row6_col7" class="data row6 col7" >437</td>
#       <td id="T_af2f6_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_af2f6_row6_col9" class="data row6 col9" >2</td>
#       <td id="T_af2f6_row6_col10" class="data row6 col10" >105,000</td>
#     </tr>
#     <tr>
#       <th id="T_af2f6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_af2f6_row7_col0" class="data row7 col0" >STA</td>
#       <td id="T_af2f6_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_af2f6_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_af2f6_row7_col3" class="data row7 col3" >-325,739</td>
#       <td id="T_af2f6_row7_col4" class="data row7 col4" >854,339</td>
#       <td id="T_af2f6_row7_col5" class="data row7 col5" >-1,265,710</td>
#       <td id="T_af2f6_row7_col6" class="data row7 col6" >1,670,375</td>
#       <td id="T_af2f6_row7_col7" class="data row7 col7" >481</td>
#       <td id="T_af2f6_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_af2f6_row7_col9" class="data row7 col9" >1</td>
#       <td id="T_af2f6_row7_col10" class="data row7 col10" >10,000</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = '254-worse.csv'
data_file = data_path + file_name
df_merge.to_csv(data_file, index=False, header=True)

# %% [markdown]
# ### New feature: Exempt SET50 & SET100

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
# Get the user's home directory
user_path = os.path.expanduser('~')
dts_path = os.path.join(user_path, "OneDrive", "Downloads", "Datasets")
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
#df_S100 = df_S100[df_S100['Total Volume'] != '-']
df_S100[colu].shape
# Out:
# (100, 9)

# %%
# --- Delete SET100 stocks from g4 group ---

# Get the list of SET100 symbols from df_S100
set100_symbols = df_S100['Symbol'].tolist()
print(f"SET100 symbols (first 10): {set100_symbols[:10]} ...")

# Find stocks in g4 that are also in SET100
deleted_stocks = g4[g4['name'].isin(set100_symbols)]
print(f"\nNumber of stocks deleted from g4 (in SET100): {len(deleted_stocks)}")
print("Deleted stocks:")
display(deleted_stocks[['name', 'grade']])  # Show only relevant columns, or use print(deleted_stocks)

# Create the remaining g4 group (exclude SET100 stocks)
g4_remaining = g4[~g4['name'].isin(set100_symbols)]
print(f"\nNumber of stocks remaining in g4 after deleting SET100: {len(g4_remaining)}")
print("Remaining stocks:")
display(g4_remaining[['name', 'grade']])   # Or display the full DataFrame
# Out:
# SET100 symbols (first 10): ['AAV', 'ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'AURA', 'AWC', 'BA', 'BAM'] ...
#
# Number of stocks deleted from g4 (in SET100): 20
# Deleted stocks:
#        name  grade
# 4       AOT      4
# 5        AP      4
# 11       BA      4
# 18     BDMS      4
# 26      CBG      4
# 40   DOHOME      4
# 50    HMPRO      4
# 55    JMART      4
# 56      JMT      4
# 57    KBANK      4
# 58      KCE      4
# 66        M      4
# 71     MEGA      4
# 88    PTTEP      4
# 92      RCL      4
# 106   SPALI      4
# 109     STA      4
# 110    STGT      4
# 114   TASCO      4
# 119   TISCO      4
# Number of stocks remaining in g4 after deleting SET100: 23
# Remaining stocks:
#        name  grade
# 2        AH      4
# 3    AIMIRT      4
# 8       ASP      4
# 32    CPAXT      4
# 36      DCC      4
# 37     DCON      4
# 42    EASTW      4
# 46      GGC      4
# 49   GVREIT      4
# 51      III      4
# 53     INOX      4
# 62    LANNA      4
# 73      MST      4
# 80    PCSGH      4
# 94    SAPPE      4
# 98     SCCC      4
# 100    SENA      4
# 107    SPCG      4
# 112     SVI      4
# 121     TKN      4
# 127   TPIPP      4
# 133     VNG      4
# 137   WHAUP      4

# %%
g4.shape
# Out:
# (43, 9)

# %%
deleted_stocks.shape
# Out:
# (20, 9)

# %%
g4_remaining.shape
# Out:
# (23, 9)

# %% [markdown]
# ### End of New feature

# %%
mask41 = g4_remaining.aq_amt < 200_000
g4_remaining[mask41].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_538a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_538a5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_538a5_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_538a5_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_538a5_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_538a5_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_538a5_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_538a5_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_538a5_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_538a5_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_538a5_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_538a5_row0_col0" class="data row0 col0" >ASP</td>
#       <td id="T_538a5_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_538a5_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_538a5_row0_col3" class="data row0 col3" >17,075</td>
#       <td id="T_538a5_row0_col4" class="data row0 col4" >62,989</td>
#       <td id="T_538a5_row0_col5" class="data row0 col5" >195,647</td>
#       <td id="T_538a5_row0_col6" class="data row0 col6" >356,421</td>
#       <td id="T_538a5_row0_col7" class="data row0 col7" >40</td>
#       <td id="T_538a5_row0_col8" class="data row0 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row1" class="row_heading level0 row1" >37</th>
#       <td id="T_538a5_row1_col0" class="data row1 col0" >DCON</td>
#       <td id="T_538a5_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_538a5_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_538a5_row1_col3" class="data row1 col3" >15,777</td>
#       <td id="T_538a5_row1_col4" class="data row1 col4" >20,349</td>
#       <td id="T_538a5_row1_col5" class="data row1 col5" >8,291</td>
#       <td id="T_538a5_row1_col6" class="data row1 col6" >59,173</td>
#       <td id="T_538a5_row1_col7" class="data row1 col7" >136</td>
#       <td id="T_538a5_row1_col8" class="data row1 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row2" class="row_heading level0 row2" >42</th>
#       <td id="T_538a5_row2_col0" class="data row2 col0" >EASTW</td>
#       <td id="T_538a5_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_538a5_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_538a5_row2_col3" class="data row2 col3" >13,854</td>
#       <td id="T_538a5_row2_col4" class="data row2 col4" >20,576</td>
#       <td id="T_538a5_row2_col5" class="data row2 col5" >9,500</td>
#       <td id="T_538a5_row2_col6" class="data row2 col6" >46,605</td>
#       <td id="T_538a5_row2_col7" class="data row2 col7" >151</td>
#       <td id="T_538a5_row2_col8" class="data row2 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row3" class="row_heading level0 row3" >46</th>
#       <td id="T_538a5_row3_col0" class="data row3 col0" >GGC</td>
#       <td id="T_538a5_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_538a5_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_538a5_row3_col3" class="data row3 col3" >75,467</td>
#       <td id="T_538a5_row3_col4" class="data row3 col4" >150,303</td>
#       <td id="T_538a5_row3_col5" class="data row3 col5" >-683,837</td>
#       <td id="T_538a5_row3_col6" class="data row3 col6" >-264,932</td>
#       <td id="T_538a5_row3_col7" class="data row3 col7" >188</td>
#       <td id="T_538a5_row3_col8" class="data row3 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row4" class="row_heading level0 row4" >49</th>
#       <td id="T_538a5_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_538a5_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_538a5_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_538a5_row4_col3" class="data row4 col3" >-432,165</td>
#       <td id="T_538a5_row4_col4" class="data row4 col4" >-87,267</td>
#       <td id="T_538a5_row4_col5" class="data row4 col5" >167,756</td>
#       <td id="T_538a5_row4_col6" class="data row4 col6" >457,671</td>
#       <td id="T_538a5_row4_col7" class="data row4 col7" >654</td>
#       <td id="T_538a5_row4_col8" class="data row4 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row5" class="row_heading level0 row5" >53</th>
#       <td id="T_538a5_row5_col0" class="data row5 col0" >INOX</td>
#       <td id="T_538a5_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_538a5_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_538a5_row5_col3" class="data row5 col3" >-26,606</td>
#       <td id="T_538a5_row5_col4" class="data row5 col4" >94,117</td>
#       <td id="T_538a5_row5_col5" class="data row5 col5" >-62,044</td>
#       <td id="T_538a5_row5_col6" class="data row5 col6" >350,831</td>
#       <td id="T_538a5_row5_col7" class="data row5 col7" >674</td>
#       <td id="T_538a5_row5_col8" class="data row5 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_538a5_level0_row6" class="row_heading level0 row6" >133</th>
#       <td id="T_538a5_row6_col0" class="data row6 col0" >VNG</td>
#       <td id="T_538a5_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_538a5_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_538a5_row6_col3" class="data row6 col3" >-386,008</td>
#       <td id="T_538a5_row6_col4" class="data row6 col4" >-217,916</td>
#       <td id="T_538a5_row6_col5" class="data row6 col5" >-601,723</td>
#       <td id="T_538a5_row6_col6" class="data row6 col6" >230,202</td>
#       <td id="T_538a5_row6_col7" class="data row6 col7" >726</td>
#       <td id="T_538a5_row6_col8" class="data row6 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
g4_remaining[mask41].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9963a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9963a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9963a_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_9963a_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_9963a_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_9963a_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_9963a_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_9963a_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_9963a_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_9963a_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9963a_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_9963a_row0_col0" class="data row0 col0" >ASP</td>
#       <td id="T_9963a_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_9963a_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_9963a_row0_col3" class="data row0 col3" >17,075</td>
#       <td id="T_9963a_row0_col4" class="data row0 col4" >62,989</td>
#       <td id="T_9963a_row0_col5" class="data row0 col5" >195,647</td>
#       <td id="T_9963a_row0_col6" class="data row0 col6" >356,421</td>
#       <td id="T_9963a_row0_col7" class="data row0 col7" >40</td>
#       <td id="T_9963a_row0_col8" class="data row0 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row1" class="row_heading level0 row1" >37</th>
#       <td id="T_9963a_row1_col0" class="data row1 col0" >DCON</td>
#       <td id="T_9963a_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_9963a_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_9963a_row1_col3" class="data row1 col3" >15,777</td>
#       <td id="T_9963a_row1_col4" class="data row1 col4" >20,349</td>
#       <td id="T_9963a_row1_col5" class="data row1 col5" >8,291</td>
#       <td id="T_9963a_row1_col6" class="data row1 col6" >59,173</td>
#       <td id="T_9963a_row1_col7" class="data row1 col7" >136</td>
#       <td id="T_9963a_row1_col8" class="data row1 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row2" class="row_heading level0 row2" >42</th>
#       <td id="T_9963a_row2_col0" class="data row2 col0" >EASTW</td>
#       <td id="T_9963a_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_9963a_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_9963a_row2_col3" class="data row2 col3" >13,854</td>
#       <td id="T_9963a_row2_col4" class="data row2 col4" >20,576</td>
#       <td id="T_9963a_row2_col5" class="data row2 col5" >9,500</td>
#       <td id="T_9963a_row2_col6" class="data row2 col6" >46,605</td>
#       <td id="T_9963a_row2_col7" class="data row2 col7" >151</td>
#       <td id="T_9963a_row2_col8" class="data row2 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row3" class="row_heading level0 row3" >46</th>
#       <td id="T_9963a_row3_col0" class="data row3 col0" >GGC</td>
#       <td id="T_9963a_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_9963a_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_9963a_row3_col3" class="data row3 col3" >75,467</td>
#       <td id="T_9963a_row3_col4" class="data row3 col4" >150,303</td>
#       <td id="T_9963a_row3_col5" class="data row3 col5" >-683,837</td>
#       <td id="T_9963a_row3_col6" class="data row3 col6" >-264,932</td>
#       <td id="T_9963a_row3_col7" class="data row3 col7" >188</td>
#       <td id="T_9963a_row3_col8" class="data row3 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row4" class="row_heading level0 row4" >49</th>
#       <td id="T_9963a_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_9963a_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_9963a_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_9963a_row4_col3" class="data row4 col3" >-432,165</td>
#       <td id="T_9963a_row4_col4" class="data row4 col4" >-87,267</td>
#       <td id="T_9963a_row4_col5" class="data row4 col5" >167,756</td>
#       <td id="T_9963a_row4_col6" class="data row4 col6" >457,671</td>
#       <td id="T_9963a_row4_col7" class="data row4 col7" >654</td>
#       <td id="T_9963a_row4_col8" class="data row4 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row5" class="row_heading level0 row5" >53</th>
#       <td id="T_9963a_row5_col0" class="data row5 col0" >INOX</td>
#       <td id="T_9963a_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_9963a_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_9963a_row5_col3" class="data row5 col3" >-26,606</td>
#       <td id="T_9963a_row5_col4" class="data row5 col4" >94,117</td>
#       <td id="T_9963a_row5_col5" class="data row5 col5" >-62,044</td>
#       <td id="T_9963a_row5_col6" class="data row5 col6" >350,831</td>
#       <td id="T_9963a_row5_col7" class="data row5 col7" >674</td>
#       <td id="T_9963a_row5_col8" class="data row5 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9963a_level0_row6" class="row_heading level0 row6" >133</th>
#       <td id="T_9963a_row6_col0" class="data row6 col0" >VNG</td>
#       <td id="T_9963a_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_9963a_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_9963a_row6_col3" class="data row6 col3" >-386,008</td>
#       <td id="T_9963a_row6_col4" class="data row6 col4" >-217,916</td>
#       <td id="T_9963a_row6_col5" class="data row6 col5" >-601,723</td>
#       <td id="T_9963a_row6_col6" class="data row6 col6" >230,202</td>
#       <td id="T_9963a_row6_col7" class="data row6 col7" >726</td>
#       <td id="T_9963a_row6_col8" class="data row6 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
mask42 = g4_remaining.q_amt < 100_000
g4_remaining[mask42].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_660b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_660b2_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_660b2_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_660b2_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_660b2_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_660b2_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_660b2_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_660b2_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_660b2_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_660b2_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_660b2_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_660b2_row0_col0" class="data row0 col0" >ASP</td>
#       <td id="T_660b2_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_660b2_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_660b2_row0_col3" class="data row0 col3" >17,075</td>
#       <td id="T_660b2_row0_col4" class="data row0 col4" >62,989</td>
#       <td id="T_660b2_row0_col5" class="data row0 col5" >195,647</td>
#       <td id="T_660b2_row0_col6" class="data row0 col6" >356,421</td>
#       <td id="T_660b2_row0_col7" class="data row0 col7" >40</td>
#       <td id="T_660b2_row0_col8" class="data row0 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row1" class="row_heading level0 row1" >37</th>
#       <td id="T_660b2_row1_col0" class="data row1 col0" >DCON</td>
#       <td id="T_660b2_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_660b2_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_660b2_row1_col3" class="data row1 col3" >15,777</td>
#       <td id="T_660b2_row1_col4" class="data row1 col4" >20,349</td>
#       <td id="T_660b2_row1_col5" class="data row1 col5" >8,291</td>
#       <td id="T_660b2_row1_col6" class="data row1 col6" >59,173</td>
#       <td id="T_660b2_row1_col7" class="data row1 col7" >136</td>
#       <td id="T_660b2_row1_col8" class="data row1 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row2" class="row_heading level0 row2" >42</th>
#       <td id="T_660b2_row2_col0" class="data row2 col0" >EASTW</td>
#       <td id="T_660b2_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_660b2_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_660b2_row2_col3" class="data row2 col3" >13,854</td>
#       <td id="T_660b2_row2_col4" class="data row2 col4" >20,576</td>
#       <td id="T_660b2_row2_col5" class="data row2 col5" >9,500</td>
#       <td id="T_660b2_row2_col6" class="data row2 col6" >46,605</td>
#       <td id="T_660b2_row2_col7" class="data row2 col7" >151</td>
#       <td id="T_660b2_row2_col8" class="data row2 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row3" class="row_heading level0 row3" >46</th>
#       <td id="T_660b2_row3_col0" class="data row3 col0" >GGC</td>
#       <td id="T_660b2_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_660b2_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_660b2_row3_col3" class="data row3 col3" >75,467</td>
#       <td id="T_660b2_row3_col4" class="data row3 col4" >150,303</td>
#       <td id="T_660b2_row3_col5" class="data row3 col5" >-683,837</td>
#       <td id="T_660b2_row3_col6" class="data row3 col6" >-264,932</td>
#       <td id="T_660b2_row3_col7" class="data row3 col7" >188</td>
#       <td id="T_660b2_row3_col8" class="data row3 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row4" class="row_heading level0 row4" >49</th>
#       <td id="T_660b2_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_660b2_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_660b2_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_660b2_row4_col3" class="data row4 col3" >-432,165</td>
#       <td id="T_660b2_row4_col4" class="data row4 col4" >-87,267</td>
#       <td id="T_660b2_row4_col5" class="data row4 col5" >167,756</td>
#       <td id="T_660b2_row4_col6" class="data row4 col6" >457,671</td>
#       <td id="T_660b2_row4_col7" class="data row4 col7" >654</td>
#       <td id="T_660b2_row4_col8" class="data row4 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row5" class="row_heading level0 row5" >53</th>
#       <td id="T_660b2_row5_col0" class="data row5 col0" >INOX</td>
#       <td id="T_660b2_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_660b2_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_660b2_row5_col3" class="data row5 col3" >-26,606</td>
#       <td id="T_660b2_row5_col4" class="data row5 col4" >94,117</td>
#       <td id="T_660b2_row5_col5" class="data row5 col5" >-62,044</td>
#       <td id="T_660b2_row5_col6" class="data row5 col6" >350,831</td>
#       <td id="T_660b2_row5_col7" class="data row5 col7" >674</td>
#       <td id="T_660b2_row5_col8" class="data row5 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row6" class="row_heading level0 row6" >73</th>
#       <td id="T_660b2_row6_col0" class="data row6 col0" >MST</td>
#       <td id="T_660b2_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_660b2_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_660b2_row6_col3" class="data row6 col3" >22,513</td>
#       <td id="T_660b2_row6_col4" class="data row6 col4" >97,416</td>
#       <td id="T_660b2_row6_col5" class="data row6 col5" >220,509</td>
#       <td id="T_660b2_row6_col6" class="data row6 col6" >462,133</td>
#       <td id="T_660b2_row6_col7" class="data row6 col7" >290</td>
#       <td id="T_660b2_row6_col8" class="data row6 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row7" class="row_heading level0 row7" >100</th>
#       <td id="T_660b2_row7_col0" class="data row7 col0" >SENA</td>
#       <td id="T_660b2_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_660b2_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_660b2_row7_col3" class="data row7 col3" >35,749</td>
#       <td id="T_660b2_row7_col4" class="data row7 col4" >97,807</td>
#       <td id="T_660b2_row7_col5" class="data row7 col5" >323,614</td>
#       <td id="T_660b2_row7_col6" class="data row7 col6" >399,608</td>
#       <td id="T_660b2_row7_col7" class="data row7 col7" >437</td>
#       <td id="T_660b2_row7_col8" class="data row7 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row8" class="row_heading level0 row8" >107</th>
#       <td id="T_660b2_row8_col0" class="data row8 col0" >SPCG</td>
#       <td id="T_660b2_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_660b2_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_660b2_row8_col3" class="data row8 col3" >69,202</td>
#       <td id="T_660b2_row8_col4" class="data row8 col4" >117,764</td>
#       <td id="T_660b2_row8_col5" class="data row8 col5" >378,335</td>
#       <td id="T_660b2_row8_col6" class="data row8 col6" >682,506</td>
#       <td id="T_660b2_row8_col7" class="data row8 col7" >464</td>
#       <td id="T_660b2_row8_col8" class="data row8 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_660b2_level0_row9" class="row_heading level0 row9" >133</th>
#       <td id="T_660b2_row9_col0" class="data row9 col0" >VNG</td>
#       <td id="T_660b2_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_660b2_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_660b2_row9_col3" class="data row9 col3" >-386,008</td>
#       <td id="T_660b2_row9_col4" class="data row9 col4" >-217,916</td>
#       <td id="T_660b2_row9_col5" class="data row9 col5" >-601,723</td>
#       <td id="T_660b2_row9_col6" class="data row9 col6" >230,202</td>
#       <td id="T_660b2_row9_col7" class="data row9 col7" >726</td>
#       <td id="T_660b2_row9_col8" class="data row9 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
mask43 = g4_remaining.ay_amt < 200_000
g4_remaining[mask43].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef35a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef35a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ef35a_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_ef35a_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_ef35a_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_ef35a_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_ef35a_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_ef35a_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_ef35a_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_ef35a_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef35a_level0_row0" class="row_heading level0 row0" >37</th>
#       <td id="T_ef35a_row0_col0" class="data row0 col0" >DCON</td>
#       <td id="T_ef35a_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_ef35a_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_ef35a_row0_col3" class="data row0 col3" >15,777</td>
#       <td id="T_ef35a_row0_col4" class="data row0 col4" >20,349</td>
#       <td id="T_ef35a_row0_col5" class="data row0 col5" >8,291</td>
#       <td id="T_ef35a_row0_col6" class="data row0 col6" >59,173</td>
#       <td id="T_ef35a_row0_col7" class="data row0 col7" >136</td>
#       <td id="T_ef35a_row0_col8" class="data row0 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ef35a_level0_row1" class="row_heading level0 row1" >42</th>
#       <td id="T_ef35a_row1_col0" class="data row1 col0" >EASTW</td>
#       <td id="T_ef35a_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_ef35a_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_ef35a_row1_col3" class="data row1 col3" >13,854</td>
#       <td id="T_ef35a_row1_col4" class="data row1 col4" >20,576</td>
#       <td id="T_ef35a_row1_col5" class="data row1 col5" >9,500</td>
#       <td id="T_ef35a_row1_col6" class="data row1 col6" >46,605</td>
#       <td id="T_ef35a_row1_col7" class="data row1 col7" >151</td>
#       <td id="T_ef35a_row1_col8" class="data row1 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ef35a_level0_row2" class="row_heading level0 row2" >46</th>
#       <td id="T_ef35a_row2_col0" class="data row2 col0" >GGC</td>
#       <td id="T_ef35a_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_ef35a_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_ef35a_row2_col3" class="data row2 col3" >75,467</td>
#       <td id="T_ef35a_row2_col4" class="data row2 col4" >150,303</td>
#       <td id="T_ef35a_row2_col5" class="data row2 col5" >-683,837</td>
#       <td id="T_ef35a_row2_col6" class="data row2 col6" >-264,932</td>
#       <td id="T_ef35a_row2_col7" class="data row2 col7" >188</td>
#       <td id="T_ef35a_row2_col8" class="data row2 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
filter1 = g4_remaining[mask41 & mask42 & mask43]
filter1.sort_values(by='name',ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_16e50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e50_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_16e50_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_16e50_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_16e50_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_16e50_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_16e50_level0_col5" class="col_heading level0 col5" >aq_amt</th>
#       <th id="T_16e50_level0_col6" class="col_heading level0 col6" >ay_amt</th>
#       <th id="T_16e50_level0_col7" class="col_heading level0 col7" >ticker_id</th>
#       <th id="T_16e50_level0_col8" class="col_heading level0 col8" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e50_level0_row0" class="row_heading level0 row0" >37</th>
#       <td id="T_16e50_row0_col0" class="data row0 col0" >DCON</td>
#       <td id="T_16e50_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_16e50_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_16e50_row0_col3" class="data row0 col3" >15,777</td>
#       <td id="T_16e50_row0_col4" class="data row0 col4" >20,349</td>
#       <td id="T_16e50_row0_col5" class="data row0 col5" >8,291</td>
#       <td id="T_16e50_row0_col6" class="data row0 col6" >59,173</td>
#       <td id="T_16e50_row0_col7" class="data row0 col7" >136</td>
#       <td id="T_16e50_row0_col8" class="data row0 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_16e50_level0_row1" class="row_heading level0 row1" >42</th>
#       <td id="T_16e50_row1_col0" class="data row1 col0" >EASTW</td>
#       <td id="T_16e50_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_16e50_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_16e50_row1_col3" class="data row1 col3" >13,854</td>
#       <td id="T_16e50_row1_col4" class="data row1 col4" >20,576</td>
#       <td id="T_16e50_row1_col5" class="data row1 col5" >9,500</td>
#       <td id="T_16e50_row1_col6" class="data row1 col6" >46,605</td>
#       <td id="T_16e50_row1_col7" class="data row1 col7" >151</td>
#       <td id="T_16e50_row1_col8" class="data row1 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_16e50_level0_row2" class="row_heading level0 row2" >46</th>
#       <td id="T_16e50_row2_col0" class="data row2 col0" >GGC</td>
#       <td id="T_16e50_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_16e50_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_16e50_row2_col3" class="data row2 col3" >75,467</td>
#       <td id="T_16e50_row2_col4" class="data row2 col4" >150,303</td>
#       <td id="T_16e50_row2_col5" class="data row2 col5" >-683,837</td>
#       <td id="T_16e50_row2_col6" class="data row2 col6" >-264,932</td>
#       <td id="T_16e50_row2_col7" class="data row2 col7" >188</td>
#       <td id="T_16e50_row2_col8" class="data row2 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
filter1.shape
# Out:
# (3, 9)

# %%
loss = filter1['name']
file_name = 'loss.csv'
data_file = data_path + file_name
loss.to_csv(data_file, index=False, header=False)

# %%
sql = '''
SELECT name
FROM exempts
ORDER BY name'''
exempts = pd.read_sql(sql, conlt)
exempts.shape
# Out:
# (405, 1)

# %%
stock_list = exempts['name'].unique().tolist()
stock_list_str = "','".join(stock_list)
len(stock_list)
# Out:
# 405

# %%
file_name = 'exempts-25q4.csv'
data_file = data_path + file_name
data_file
# Out:
# '../data/exempts-25q4.csv'

# %%
exempts.to_csv(data_file, index=False, header=False)

# %%
df_merge = pd.merge(filter1, exempts, on='name', how='outer', indicator=True)
df_merge1 = df_merge[df_merge['_merge'] == 'left_only']
df_merge1
# Out:
#     name    year  quarter    q_amt    y_amt  aq_amt   ay_amt  ticker_id  \
# 91  DCON  2025.0      4.0  15777.0  20349.0  8291.0  59173.0      136.0
#
#     grade     _merge
# 91    4.0  left_only

# %%
sql = '''
SELECT DISTINCT name 
FROM buys B
JOIN stocks S
ON B.stock_id = S.id
ORDER BY name'''
buys = pd.read_sql(sql, conpf)
buys.shape
# Out:
# (150, 1)

# %%
df_merge1 = df_merge1.drop(columns=['_merge'])
df_merge1.shape
# Out:
# (1, 9)

# %%
df_merge2 = pd.merge(df_merge1, buys, on='name', how='outer', indicator=True)
final2 = df_merge2[df_merge2['_merge'] == 'left_only']
final2
# Out:
# Empty DataFrame
# Columns: [name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id, grade, _merge]
# Index: []

# %%
sr = final2['name']
file_name = 'loss.csv'
data_file = data_path + file_name
sr.to_csv(data_file, index=False, header=False)

# %%
rcds = sr.values.tolist()
rcds
# Out:
# []

# %%
for rcd in rcds:
    print(rcd)

# %%
sql = '''
SELECT COUNT(*)
FROM exempts'''
tmp_bf = pd.read_sql(sql, conlt)
tmp_bf
# Out:
#    COUNT(*)
# 0       405

# %%
from sqlalchemy import text

for rcd in rcds:
    conlt.execute(text("INSERT INTO exempts (name) VALUES(:name)"), {"name": rcd})
conlt.commit()

# %%
sql = "SELECT COUNT(*) FROM exempts"
tmp_af = pd.read_sql(sql, conlt)
tmp_af
# Out:
#    COUNT(*)
# 0       405
