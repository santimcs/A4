# %%
import numpy as np
import os
import pandas as pd
from sqlalchemy import create_engine, text
from glob import glob

# Database connections
engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "OneDrive", "Downloads", "Datasets")
print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
# Out:
# Datasets path: C:\Users\User\OneDrive\Downloads\Datasets

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\User
# Current path: C:\Users\User\OneDrive\A4\Data Cleansing
# Base path: C:\Users\User\OneDrive\A4
# Datasets path : C:\Users\User\OneDrive\Downloads\Datasets
# Data path : C:\Users\User\OneDrive\A4\Data
# Google Drive path : C:\Users\User\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\User\iCloudDrive\Data
# Obsidian path : C:\Users\User\OneDrive\Documents\obsidian-git-sync\Data

# %%
sql = f"""
SELECT *
FROM tickers
ORDER BY name
"""
print(sql)
df_tickers_lt = pd.read_sql(sql, conlt)
print(df_tickers_lt.shape)
print(df_tickers_lt.dtypes)
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
#
# (399, 9)
# id             int64
# name          object
# full_name     object
# sector        object
# subsector     object
# market        object
# website       object
# created_at    object
# updated_at    object
# dtype: object

# %%
sql = f"""
SELECT *
FROM tickers
ORDER BY name
"""
print(sql)
df_tickers_my = pd.read_sql(sql, conmy)
print(df_tickers_my.shape)
print(df_tickers_my.dtypes)
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
#
# (401, 9)
# id             int64
# name          object
# full_name     object
# sector        object
# subsector     object
# market        object
# website       object
# created_at    object
# updated_at    object
# dtype: object

# %%
tickers_lt_set = set(df_tickers_lt['name'].to_list())
tickers_my_set = set(df_tickers_my['name'].to_list())
lt_my_dif_set = tickers_lt_set - tickers_my_set
lt_my_dif_set
# Out:
# set()

# %%
sql = f"""
SELECT *
FROM tickers
ORDER BY name
"""
print(sql)
df_tickers_pg = pd.read_sql(sql, conpg)
print(df_tickers_pg.shape)
print(df_tickers_pg.dtypes)
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
#
# (401, 9)
# id                     int64
# name                  object
# full_name             object
# sector                object
# subsector             object
# market                object
# website               object
# created_at    datetime64[ns]
# updated_at    datetime64[ns]
# dtype: object

# %%
tickers_pg_set = set(df_tickers_pg['name'].to_list())
lt_pg_dif_set = tickers_lt_set - tickers_my_set
lt_pg_dif_set
# Out:
# set()

# %%
# --- Add missing tickers to MySQL (conmy) and PostgreSQL (conpg) databases ---

print("\n" + "="*80)
print("ADD MISSING TICKERS TO MySQL AND PostgreSQL DATABASES")
print("="*80)

# 1. Add missing tickers to MySQL (conmy)
print("\n" + "-"*60)
print("Processing MySQL database (conmy)...")
print("-"*60)

if lt_my_dif_set:
    missing_list = sorted(list(lt_my_dif_set))
    print(f"Missing tickers in MySQL: {len(missing_list)}")
    print(f"Tickers to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, full_name, sector, subsector, market, website, created_at, updated_at
    FROM tickers
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # Insert into MySQL
            df_missing.to_sql('tickers', conmy, if_exists='append', index=False)
            print(f"Successfully added {len(df_missing)} tickers to MySQL database")
        else:
            print("No source data found for the missing tickers in MySQL")
            
    except Exception as e:
        print(f"Error adding tickers to MySQL: {e}")
else:
    print("No missing tickers to add to MySQL")

# 2. Add missing tickers to PostgreSQL (conpg)
print("\n" + "-"*60)
print("Processing PostgreSQL database (conpg)...")
print("-"*60)

if lt_pg_dif_set:
    missing_list = sorted(list(lt_pg_dif_set))
    print(f"Missing tickers in PostgreSQL: {len(missing_list)}")
    print(f"Tickers to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, full_name, sector, subsector, market, website, created_at, updated_at
    FROM tickers
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # For PostgreSQL, remove the 'id' column to let it auto-generate
            # to avoid primary key conflicts
            df_insert = df_missing.drop(columns=['id'])
            
            # Insert into PostgreSQL
            df_insert.to_sql('tickers', conpg, if_exists='append', index=False)
            print(f"Successfully added {len(df_insert)} tickers to PostgreSQL database")
        else:
            print("No source data found for the missing tickers in PostgreSQL")
            
    except Exception as e:
        print(f"Error adding tickers to PostgreSQL: {e}")
else:
    print("No missing tickers to add to PostgreSQL")

# 3. Verification - Check if the tickers were added successfully
print("\n" + "="*80)
print("VERIFICATION")
print("="*80)

# Re-query MySQL to verify
try:
    df_tickers_my_after = pd.read_sql("SELECT name FROM tickers ORDER BY name", conmy)
    tickers_my_after_set = set(df_tickers_my_after['name'].tolist())
    still_missing_my = lt_my_dif_set - tickers_my_after_set

    print(f"\nMySQL verification:")
    print(f"  - Target missing tickers: {len(lt_my_dif_set)}")
    print(f"  - Successfully added: {len(lt_my_dif_set) - len(still_missing_my)}")
    if still_missing_my:
        print(f"  - Still missing: {sorted(still_missing_my)}")
    else:
        print(f"  - All tickers successfully added to MySQL!")
except Exception as e:
    print(f"Error verifying MySQL: {e}")

# Re-query PostgreSQL to verify
try:
    df_tickers_pg_after = pd.read_sql("SELECT name FROM tickers ORDER BY name", conpg)
    tickers_pg_after_set = set(df_tickers_pg_after['name'].tolist())
    still_missing_pg = lt_pg_dif_set - tickers_pg_after_set

    print(f"\nPostgreSQL verification:")
    print(f"  - Target missing tickers: {len(lt_pg_dif_set)}")
    print(f"  - Successfully added: {len(lt_pg_dif_set) - len(still_missing_pg)}")
    if still_missing_pg:
        print(f"  - Still missing: {sorted(still_missing_pg)}")
    else:
        print(f"  - All tickers successfully added to PostgreSQL!")
except Exception as e:
    print(f"Error verifying PostgreSQL: {e}")

print("\n" + "="*80)
print("SYNC OPERATION COMPLETED")
print("="*80)
# Out:
# ...
# ADD MISSING TICKERS TO MySQL AND PostgreSQL DATABASES
# ...
#
# ------------------------------------------------------------
# Processing MySQL database (conmy)...
# ------------------------------------------------------------
# Missing tickers in MySQL: 5
# Tickers to add: ['AURA', 'BTG', 'MOSHI', 'STECON', 'TLI']
# Retrieved 5 records from SQLite source database
# Successfully added 5 tickers to MySQL database
#
# ------------------------------------------------------------
# Processing PostgreSQL database (conpg)...
# ------------------------------------------------------------
# Missing tickers in PostgreSQL: 5
# Tickers to add: ['AURA', 'BTG', 'MOSHI', 'STECON', 'TLI']
# Retrieved 5 records from SQLite source database
# Successfully added 5 tickers to PostgreSQL database
#
# ...
# VERIFICATION
# ...
#
# MySQL verification:
#   - Target missing tickers: 5
#   - Successfully added: 5
#   - All tickers successfully added to MySQL!
#
# PostgreSQL verification:
#   - Target missing tickers: 5
# ...
