# %%
import numpy as np
import os
import pandas as pd
from sqlalchemy import create_engine, text
from glob import glob

# Database connections
engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "OneDrive", "Downloads", "Datasets")
print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")
# Out:
# Datasets path: C:\Users\User\OneDrive\Downloads\Datasets

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Data Cleansing
# Base path: C:\Users\PC1\OneDrive\A4
# Datasets path : C:\Users\PC1\OneDrive\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A4\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
sql = f"""
SELECT *
FROM stocks
ORDER BY name
"""
print(sql)
df_stocks_lt = pd.read_sql(sql, conlt)
print(df_stocks_lt.shape)
print(df_stocks_lt.dtypes)
# Out:
# SELECT *
# FROM stocks
# ORDER BY name
#
# (231, 15)
# id                int64
# name             object
# market           object
# price           float64
# max_price       float64
# min_price       float64
# pe              float64
# pbv             float64
# paid_up         float64
# market_cap      float64
# daily_volume    float64
# beta            float64
# ticker_id         int64
# created_at       object
# updated_at       object
# dtype: object

# %%
sql = f"""
SELECT *
FROM stocks
ORDER BY name
"""
print(sql)
df_stocks_my = pd.read_sql(sql, conmy)
print(df_stocks_my.shape)
print(df_stocks_my.dtypes)
# Out:
# SELECT *
# FROM stocks
# ORDER BY name
#
# (246, 15)
# id                int64
# name             object
# market           object
# price           float64
# max_price       float64
# min_price       float64
# pe              float64
# pbv             float64
# paid_up         float64
# market_cap      float64
# daily_volume    float64
# beta            float64
# ticker_id         int64
# created_at       object
# updated_at       object
# dtype: object

# %%
stocks_lt_set = set(df_stocks_lt['name'].to_list())
stocks_my_set = set(df_stocks_my['name'].to_list())
lt_my_dif_set = stocks_lt_set - stocks_my_set
lt_my_dif_set
# Out:
# {'AURA', 'BTG', 'MOSHI', 'STECON', 'TLI'}

# %%
sql = f"""
SELECT *
FROM stocks
ORDER BY name
"""
print(sql)
df_stocks_pg = pd.read_sql(sql, conpg)
print(df_stocks_pg.shape)
print(df_stocks_pg.dtypes)
# Out:
# SELECT *
# FROM stocks
# ORDER BY name
#
# (226, 15)
# id                       int64
# name                    object
# market                  object
# price                  float64
# max_price              float64
# min_price              float64
# pe                     float64
# pbv                    float64
# paid_up                float64
# market_cap             float64
# daily_volume           float64
# beta                   float64
# ticker_id                int64
# created_at      datetime64[ns]
# updated_at      datetime64[ns]
# dtype: object

# %%
stocks_pg_set = set(df_stocks_pg['name'].to_list())
lt_pg_dif_set = stocks_lt_set - stocks_my_set
lt_pg_dif_set
# Out:
# {'AURA', 'BTG', 'MOSHI', 'STECON', 'TLI'}

# %%
# --- Add missing stocks to SQLite (conmy) and PostgreSQL (conpg) databases ---

print("\n" + "="*80)
print("ADD MISSING stocks TO SQLite AND PostgreSQL DATABASES")
print("="*80)

# 1. Add missing stocks to SQLite (conmy)
print("\n" + "-"*60)
print("Processing SQLite database (conmy)...")
print("-"*60)

if lt_my_dif_set:
    missing_list = sorted(list(lt_my_dif_set))
    print(f"Missing stocks in SQLite: {len(missing_list)}")
    print(f"stocks to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, market, price, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at
    FROM stocks
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # Insert into SQLite
            df_missing.to_sql('stocks', conmy, if_exists='append', index=False)
            print(f"Successfully added {len(df_missing)} stocks to SQLite database")
        else:
            print("No source data found for the missing stocks in SQLite")
            
    except Exception as e:
        print(f"Error adding stocks to SQLite: {e}")
else:
    print("No missing stocks to add to SQLite")

# 2. Add missing stocks to PostgreSQL (conpg)
print("\n" + "-"*60)
print("Processing PostgreSQL database (conpg)...")
print("-"*60)

if lt_pg_dif_set:
    missing_list = sorted(list(lt_pg_dif_set))
    print(f"Missing stocks in PostgreSQL: {len(missing_list)}")
    print(f"stocks to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, market, price, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at
    FROM stocks
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # For PostgreSQL, remove the 'id' column to let it auto-generate
            # to avoid primary key conflicts
            df_insert = df_missing.drop(columns=['id'])
            
            # Insert into PostgreSQL
            df_insert.to_sql('stocks', conpg, if_exists='append', index=False)
            print(f"Successfully added {len(df_insert)} stocks to PostgreSQL database")
        else:
            print("No source data found for the missing stocks in PostgreSQL")
            
    except Exception as e:
        print(f"Error adding stocks to PostgreSQL: {e}")
else:
    print("No missing stocks to add to PostgreSQL")

# 3. Verification - Check if the stocks were added successfully
print("\n" + "="*80)
print("VERIFICATION")
print("="*80)

# Re-query SQLite to verify
try:
    df_stocks_my_after = pd.read_sql("SELECT name FROM stocks ORDER BY name", conmy)
    stocks_my_after_set = set(df_stocks_my_after['name'].tolist())
    still_missing_my = lt_my_dif_set - stocks_my_after_set

    print(f"\nSQLite verification:")
    print(f"  - Target missing stocks: {len(lt_my_dif_set)}")
    print(f"  - Successfully added: {len(lt_my_dif_set) - len(still_missing_my)}")
    if still_missing_my:
        print(f"  - Still missing: {sorted(still_missing_my)}")
    else:
        print(f"  - All stocks successfully added to SQLite!")
except Exception as e:
    print(f"Error verifying SQLite: {e}")

# Re-query PostgreSQL to verify
try:
    df_stocks_pg_after = pd.read_sql("SELECT name FROM stocks ORDER BY name", conpg)
    stocks_pg_after_set = set(df_stocks_pg_after['name'].tolist())
    still_missing_pg = lt_pg_dif_set - stocks_pg_after_set

    print(f"\nPostgreSQL verification:")
    print(f"  - Target missing stocks: {len(lt_pg_dif_set)}")
    print(f"  - Successfully added: {len(lt_pg_dif_set) - len(still_missing_pg)}")
    if still_missing_pg:
        print(f"  - Still missing: {sorted(still_missing_pg)}")
    else:
        print(f"  - All stocks successfully added to PostgreSQL!")
except Exception as e:
    print(f"Error verifying PostgreSQL: {e}")

print("\n" + "="*80)
print("SYNC OPERATION COMPLETED")
print("="*80)
# Out:
# ...
# ADD MISSING stocks TO SQLite AND PostgreSQL DATABASES
# ...
#
# ------------------------------------------------------------
# Processing SQLite database (conmy)...
# ------------------------------------------------------------
# Missing stocks in SQLite: 5
# stocks to add: ['AURA', 'BTG', 'MOSHI', 'STECON', 'TLI']
# Retrieved 5 records from SQLite source database
# Successfully added 5 stocks to SQLite database
#
# ------------------------------------------------------------
# Processing PostgreSQL database (conpg)...
# ------------------------------------------------------------
# Missing stocks in PostgreSQL: 5
# stocks to add: ['AURA', 'BTG', 'MOSHI', 'STECON', 'TLI']
# Retrieved 5 records from SQLite source database
# Error adding stocks to PostgreSQL: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT pg_catalog.pg_class.relname
# ...

# %%
# --- Add missing stocks to SQLite (conmy) and PostgreSQL (conpg) databases ---

print("\n" + "="*80)
print("ADD MISSING stocks TO SQLite AND PostgreSQL DATABASES")
print("="*80)

# 1. Add missing stocks to SQLite (conmy)
print("\n" + "-"*60)
print("Processing SQLite database (conmy)...")
print("-"*60)

if lt_my_dif_set:
    missing_list = sorted(list(lt_my_dif_set))
    print(f"Missing stocks in SQLite: {len(missing_list)}")
    print(f"stocks to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, market, price, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at
    FROM stocks
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # Insert into SQLite
            df_missing.to_sql('stocks', conmy, if_exists='append', index=False)
            print(f"Successfully added {len(df_missing)} stocks to SQLite database")
        else:
            print("No source data found for the missing stocks in SQLite")
            
    except Exception as e:
        print(f"Error adding stocks to SQLite: {e}")
else:
    print("No missing stocks to add to SQLite")

# 2. Add missing stocks to PostgreSQL (conpg)
print("\n" + "-"*60)
print("Processing PostgreSQL database (conpg)...")
print("-"*60)

# Rollback any existing failed transaction on PostgreSQL connection
try:
    conpg.rollback()
    print("Rolled back any existing transaction on PostgreSQL")
except Exception as e:
    print(f"Note: {e}")

if lt_pg_dif_set:
    missing_list = sorted(list(lt_pg_dif_set))
    print(f"Missing stocks in PostgreSQL: {len(missing_list)}")
    print(f"stocks to add: {missing_list}")
    
    # For SQLite source, use ? placeholders
    placeholders = ','.join(['?'] * len(missing_list))
    sql = f"""
    SELECT id, name, market, price, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at
    FROM stocks
    WHERE name IN ({placeholders})
    """
    
    try:
        # Execute query on SQLite source to get data
        df_missing = pd.read_sql(sql, conlt, params=tuple(missing_list))
        print(f"Retrieved {len(df_missing)} records from SQLite source database")
        
        if len(df_missing) > 0:
            # For PostgreSQL, remove the 'id' column to let it auto-generate
            # to avoid primary key conflicts
            df_insert = df_missing.drop(columns=['id'])
            
            # Use a transaction for PostgreSQL insertion
            with conpg.begin() as trans:
                try:
                    # Insert into PostgreSQL
                    df_insert.to_sql('stocks', conpg, if_exists='append', index=False)
                    print(f"Successfully added {len(df_insert)} stocks to PostgreSQL database")
                except Exception as e:
                    print(f"Error during insertion, rolling back: {e}")
                    trans.rollback()
                    raise
        else:
            print("No source data found for the missing stocks in PostgreSQL")
            
    except Exception as e:
        print(f"Error adding stocks to PostgreSQL: {e}")
        # Rollback any failed transaction
        try:
            conpg.rollback()
        except:
            pass
else:
    print("No missing stocks to add to PostgreSQL")

# 3. Verification - Check if the stocks were added successfully
print("\n" + "="*80)
print("VERIFICATION")
print("="*80)

# Rollback any pending transactions before verification
try:
    conpg.rollback()
except:
    pass

# Re-query SQLite to verify
try:
    df_stocks_my_after = pd.read_sql("SELECT name FROM stocks ORDER BY name", conmy)
    stocks_my_after_set = set(df_stocks_my_after['name'].tolist())
    still_missing_my = lt_my_dif_set - stocks_my_after_set

    print(f"\nSQLite verification:")
    print(f"  - Target missing stocks: {len(lt_my_dif_set)}")
    print(f"  - Successfully added: {len(lt_my_dif_set) - len(still_missing_my)}")
    if still_missing_my:
        print(f"  - Still missing: {sorted(still_missing_my)}")
    else:
        print(f"  - All stocks successfully added to SQLite!")
except Exception as e:
    print(f"Error verifying SQLite: {e}")

# Re-query PostgreSQL to verify
try:
    df_stocks_pg_after = pd.read_sql("SELECT name FROM stocks ORDER BY name", conpg)
    stocks_pg_after_set = set(df_stocks_pg_after['name'].tolist())
    still_missing_pg = lt_pg_dif_set - stocks_pg_after_set

    print(f"\nPostgreSQL verification:")
    print(f"  - Target missing stocks: {len(lt_pg_dif_set)}")
    print(f"  - Successfully added: {len(lt_pg_dif_set) - len(still_missing_pg)}")
    if still_missing_pg:
        print(f"  - Still missing: {sorted(still_missing_pg)}")
    else:
        print(f"  - All stocks successfully added to PostgreSQL!")
except Exception as e:
    print(f"Error verifying PostgreSQL: {e}")

print("\n" + "="*80)
print("SYNC OPERATION COMPLETED")
print("="*80)
# Out:
# ...
# ADD MISSING stocks TO SQLite AND PostgreSQL DATABASES
# ...
#
# ------------------------------------------------------------
# Processing SQLite database (conmy)...
# ------------------------------------------------------------
# Missing stocks in SQLite: 5
# stocks to add: ['AURA', 'BTG', 'MOSHI', 'STECON', 'TLI']
# Retrieved 5 records from SQLite source database
# Error adding stocks to SQLite: (sqlite3.IntegrityError) UNIQUE constraint failed: stocks.id
# [SQL: INSERT INTO stocks (id, name, market, price, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# ...

# %%
lt_pg_dif_list = sorted(list(lt_pg_dif_set))
lt_pg_dif_str = "','".join(lt_pg_dif_list)
print(lt_pg_dif_str)
# Out:
# AURA','BTG','MOSHI','STECON','TLI

# %%
sql = f"""
SELECT *
FROM stocks
WHERE name IN ('{lt_pg_dif_str}')
ORDER BY name
"""
print(sql)
df_stocks_lt_pg_dif = pd.read_sql(sql, conlt)
df_stocks_lt_pg_dif
# Out:
# SELECT *
# FROM stocks
# WHERE name IN ('AURA','BTG','MOSHI','STECON','TLI')
# ORDER BY name
#     id    name                                             market  price  \
# 0  747    AURA                 SET100 / SET100FF / SETESG / SETWB   13.0
# 1  748     BTG                 SET100 / SET100FF / SETESG / SETWB   20.4
# 2  749   MOSHI                 SET100 / SET100FF / SETESG / SETWB   33.5
# 3  750  STECON                         SET100 / SET100FF / SETESG   11.5
# 4  751     TLI  SET50 / SET50FF / SET100 / SET100FF / SETHD / ...   10.4
#
#    max_price  min_price     pe   pbv   paid_up  market_cap  daily_volume  \
# 0      17.80      12.10  11.89  2.37   1335.84    17365.92         32.30
# 1      24.80      15.40   5.82  1.21   9674.00       39.00        128.11
# 2      45.25      30.25  16.49  4.05    330.00    11055.00         25.20
# 3      13.60       5.00   8.87  1.04   1519.08    17469.42        331.55
# ...

# %%
sql = f"""
SELECT *
FROM tickers
WHERE name IN ('{lt_pg_dif_str}')
"""
print(sql)
df_tmp = pd.read_sql(sql, conpg)
df_tmp
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('AURA','BTG','MOSHI','STECON','TLI')
# Empty DataFrame
# Columns: [id, name, full_name, sector, subsector, market, website, created_at, updated_at]
# Index: []
