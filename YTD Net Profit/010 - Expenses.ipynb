# %% [markdown]
# ### Restart and run all

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine, text
from datetime import date, datetime, timedelta
import calendar

engine = create_engine("sqlite:///c:\\ruby\\expense\\db\\development.sqlite3")
con_exp = engine.connect()

pd.set_option('display.max_rows', 11)
format_dict = {'amount':'{:,}','y_amt':'{:,}','yoy_gain':'{:,}',
               'q_amt_c':'{:,}','q_amt_p':'{:,}',
               'aq_amt':'{:,}','ay_amt':'{:,}','acc_gain':'{:,}',
               'latest_amt':'{:,}','previous_amt':'{:,}','inc_amt':'{:,}',
               'latest_amt_q':'{:,}','previous_amt_q':'{:,}','inc_amt_q':'{:,}',
               'latest_amt_y':'{:,}','previous_amt_y':'{:,}','inc_amt_y':'{:,}',
               'inc_pct':'{:.2f}','inc_pct_q':'{:.2f}','inc_pct_y':'{:.2f}'}
year = "2026"
today = date.today()
today
# Out:
# datetime.date(2026, 3, 1)

# %%
# Establish a connection
with engine.connect() as con_exp:
    sql = text("""
    SELECT date, amount, C.name AS item, G.name AS kind, strftime('%m', date) as Month 
    FROM transactions T 
    JOIN categories C ON category_id = C.id 
    JOIN groups G ON group_id = G.id 
    WHERE strftime('%Y', date) = :year
    ORDER BY date DESC
    """)
    
    # Execute query and fetch results
    result = con_exp.execute(sql, {"year": year})
    
    # Convert result to DataFrame
    df_t = pd.DataFrame(result.fetchall(), columns=result.keys())

# Display the DataFrame
print(df_t)
# Out:
#           date  amount               item           kind Month
# 0   2026-02-28    5000             Parent         Parent    02
# 1   2026-02-28     640            ChatGPT    Edutainment    02
# 2   2026-02-28     520            Netflix    Edutainment    02
# 3   2026-02-28     510      Internet Home  Communication    02
# 4   2026-02-28     320     Telephone Dtac  Communication    02
# ..         ...     ...                ...            ...   ...
# 29  2026-01-07    1300  Computer Hardware         Others    01
# 30  2026-01-07    2000  Computer Hardware         Others    01
# 31  2026-01-06    3160           Medicine       Medicine    01
# 32  2026-01-06    3170           Medicine       Medicine    01
# 33  2026-01-03    1410               Food           Food    01
#
# [34 rows x 5 columns]

# %%
df_t.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_72477">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72477_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_72477_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_72477_level0_col2" class="col_heading level0 col2" >item</th>
#       <th id="T_72477_level0_col3" class="col_heading level0 col3" >kind</th>
#       <th id="T_72477_level0_col4" class="col_heading level0 col4" >Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72477_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72477_row0_col0" class="data row0 col0" >2026-02-28</td>
#       <td id="T_72477_row0_col1" class="data row0 col1" >5,000</td>
#       <td id="T_72477_row0_col2" class="data row0 col2" >Parent</td>
#       <td id="T_72477_row0_col3" class="data row0 col3" >Parent</td>
#       <td id="T_72477_row0_col4" class="data row0 col4" >02</td>
#     </tr>
#     <tr>
#       <th id="T_72477_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72477_row1_col0" class="data row1 col0" >2026-02-28</td>
#       <td id="T_72477_row1_col1" class="data row1 col1" >640</td>
#       <td id="T_72477_row1_col2" class="data row1 col2" >ChatGPT</td>
#       <td id="T_72477_row1_col3" class="data row1 col3" >Edutainment</td>
#       <td id="T_72477_row1_col4" class="data row1 col4" >02</td>
#     </tr>
#     <tr>
#       <th id="T_72477_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72477_row2_col0" class="data row2 col0" >2026-02-28</td>
#       <td id="T_72477_row2_col1" class="data row2 col1" >520</td>
#       <td id="T_72477_row2_col2" class="data row2 col2" >Netflix</td>
#       <td id="T_72477_row2_col3" class="data row2 col3" >Edutainment</td>
#       <td id="T_72477_row2_col4" class="data row2 col4" >02</td>
#     </tr>
#     <tr>
#       <th id="T_72477_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72477_row3_col0" class="data row3 col0" >2026-02-28</td>
#       <td id="T_72477_row3_col1" class="data row3 col1" >510</td>
#       <td id="T_72477_row3_col2" class="data row3 col2" >Internet Home</td>
#       <td id="T_72477_row3_col3" class="data row3 col3" >Communication</td>
#       <td id="T_72477_row3_col4" class="data row3 col4" >02</td>
#     </tr>
#     <tr>
#       <th id="T_72477_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72477_row4_col0" class="data row4 col0" >2026-02-28</td>
#       <td id="T_72477_row4_col1" class="data row4 col1" >320</td>
#       <td id="T_72477_row4_col2" class="data row4 col2" >Telephone Dtac</td>
#       <td id="T_72477_row4_col3" class="data row4 col3" >Communication</td>
#       <td id="T_72477_row4_col4" class="data row4 col4" >02</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_t.columns
# Out:
# Index(['date', 'amount', 'item', 'kind', 'Month'], dtype='object')

# %%
grouped = df_t.groupby("item")
#grouped.sum().style.format(format_dict)

# %%
grouped = df_t.groupby("kind")
#grouped.sum().style.format(format_dict)

# %%
monthly = df_t.groupby("Month")
#monthly.sum().style.format(format_dict)
monthly['amount'].sum()
# Out:
# Month
# 01    38040
# 02    33220
# Name: amount, dtype: int64

# %%
expense = monthly.amount.sum()
print(sum(expense))
# Out:
# 71260

# %%
current_time = datetime.now()
formatted_time = current_time.strftime("%Y:%m:%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026:03:01 15:42:19
