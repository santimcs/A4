# %%
channel_name = 'TheAiGrid'

# %%
import pandas as pd
from datetime import datetime, timedelta
from googleapiclient.discovery import build
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

# Retrieve API key from environment variables
YOUTUBE_DEVELOPER_KEY = os.getenv('YOUTUBE_DEVELOPER_KEY')

# Verify API key is loaded
if not YOUTUBE_DEVELOPER_KEY:
    raise ValueError("YouTube API key not found. Please create a .env file with YOUTUBE_API_KEY=")
    
youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_quota_reset_info():
    """Get information about when quota resets and suggest action"""
    from datetime import datetime, timezone, timedelta
    import pytz
    
    pacific = pytz.timezone('America/Los_Angeles')
    now_pt = datetime.now(pacific)
    
    # Calculate next reset time (midnight PT)
    reset_time = now_pt.replace(hour=0, minute=0, second=0, microsecond=0)
    if now_pt >= reset_time:
        reset_time += timedelta(days=1)
    
    time_until_reset = reset_time - now_pt
    hours_until_reset = time_until_reset.total_seconds() / 3600
    
    print(f"Current PT time: {now_pt.strftime('%H:%M')}")
    print(f"Quota resets in: {hours_until_reset:.1f} hours")
    
    if hours_until_reset < 4:
        print("⚠️  Caution: Limited time until quota reset")
        if hours_until_reset < 1:
            print("✅ Consider waiting for fresh quota")
    
    return hours_until_reset

# Use it like this:
if get_quota_reset_info() < 2:
    # Very little time until reset
    print("You might want to wait for quota reset")
# Out:
# Current PT time: 07:18
# Quota resets in: 16.7 hours

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]

channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCbY9xX3_jW5c2fjlZVBI4cg'

# %% [markdown]
# # Diving into YouTube Analytics
# Deepnote presented a live stream featuring a showcase of how to use Google's YouTube API. We had a few Deepnote coders and a Deepnote user Allan who helped crack the API and start getting data. Below is a project inspired from that stream!
#
# In this notebook we are going to dive in and check out the popular YouTube channel Good Mythical Morning.

# %% [markdown]
# ## API Functions
# In this section we setup some API functions to help us gather data. We create a function to gather channel stats and video stats. To do this in a effecient way and save API calls we do not use the search function. We pull in GMM's upload playlist ( containing all of their videos ) and use that to build a video list. Then grab the data from each video.

# %%
# Function to get the channels stats
# It will also contain the upload playlist ID we can use to grab videos.
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    
    return response['items']

# %%
# This will get us a list of videos from a playlist.
# Note a page of results has a max value of 50 so we will
# need to loop over our results with a pageToken

def get_video_list(youtube, upload_id):
    video_list = []
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=upload_id,
        maxResults=50
    )
    next_page = True
    while next_page:
        response = request.execute()
        data = response['items']

        for video in data:
            video_id = video['contentDetails']['videoId']
            if video_id not in video_list:
                video_list.append(video_id)

        # Do we have more pages?
        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=upload_id,
                pageToken=response['nextPageToken'],
                maxResults=50
            )
        else:
            next_page = False

    return video_list

# %%
# new function
def get_video_details(youtube, video_list):
    stats_list = []

    # Can only get 50 videos at a time.
    for i in range(0, len(video_list), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_list[i:i+50]
        )

        data = request.execute()
        for video in data['items']:
            video_id = video['id']  # Extract video_id 
            title = video['snippet']['title']
            published = video['snippet']['publishedAt']
            description = video['snippet']['description']
            view_count = video['statistics'].get('viewCount', 0)
            like_count = video['statistics'].get('likeCount', 0)
            dislike_count = video['statistics'].get('dislikeCount', 0)
            comment_count = video['statistics'].get('commentCount', 0)
            duration = video['contentDetails'].get('duration', 'Unknown')  # Use .get() with a default value

            # Include video_id in the dictionary
            stats_dict = dict(
                video_id=video_id,
                title=title,
                description=description,
                published=published,
                view_count=view_count,
                like_count=like_count,
                dislike_count=dislike_count,
                comment_count=comment_count,
                duration=duration             
            )
            stats_list.append(stats_dict)

    return stats_list

# %%
def convert_iso_duration_to_hms(duration):
    """
    Converts an ISO 8601 duration string (e.g., 'PT3M54S') to 'H:M:S' format.
    
    Args:
        duration (str): The ISO 8601 duration string (e.g., 'PT3M54S').
    
    Returns:
        str: The duration in 'H:M:S' format.
    """
    # Regex to extract hours, minutes, and seconds from the ISO 8601 duration
    pattern = re.compile(r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?')
    match = pattern.match(duration)
    
    if not match:
        return "0:00:00"  # Default if the format is invalid
    
    # Extract hours, minutes, and seconds
    hours = int(match.group(1)) if match.group(1) else 0
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    
    # Create a timedelta object
    delta = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    
    # Convert to total seconds
    total_seconds = int(delta.total_seconds())
    
    # Convert total seconds to H:M:S format
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    
    return f"{hours}:{minutes:02d}:{seconds:02d}"

# %% [markdown]
# ## Create our Channel Stats

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %% [markdown]
# ## Find our Upload Playlist ( will contain all video uploads )

# %%
upload_id = channel_stats[0]['contentDetails']['relatedPlaylists']['uploads']
upload_id
# Out:
# 'UUbY9xX3_jW5c2fjlZVBI4cg'

# %% [markdown]
# ## Get our Video List

# %%
video_list = get_video_list(youtube, upload_id)

# %% [markdown]
# ## Get our Video Details
# Finally we will get all of our videos details returned in a dictionary.

# %%
video_data = get_video_details(youtube, video_list)
'Number 0f Videos: ' + str(len(video_data))
# Out:
# 'Number 0f Videos: 870'

# %% [markdown]
# ## Pause and think what to do next

# %%
df=pd.DataFrame(video_data)
df.shape
# Out:
# (870, 9)

# %%
df['title_length'] = df['title'].str.len()
df["view_count"] = pd.to_numeric(df["view_count"])
df["like_count"] = pd.to_numeric(df["like_count"])
df["dislike_count"] = pd.to_numeric(df["dislike_count"])
df["comment_count"] = pd.to_numeric(df["comment_count"])
df["published"] = pd.to_datetime(df["published"])
# Format the 'published' column to "%Y-%m-%d"
df["published"] = df["published"].dt.strftime("%Y-%m-%d")
# reaction used later add up likes + dislikes + comments
df["reactions"] = df["like_count"] + df["dislike_count"] + df["comment_count"] + df["comment_count"]
df['hms_format'] = df['duration'].apply(convert_iso_duration_to_hms)

# %%
# Select rows where the title contains "Animation Maker"
#result = df
result = df.query('title.str.lower().str.contains("gemini|canvas|ai studio|google ai tools|notebooklm")', engine='python')
result.shape
# Out:
# (45, 12)

# %%
cols = 'video_id title published view_count title_length hms_format'.split()

# %%
# Retrieve the maximum value from the title_length column
max_title_length = result['title_length'].max()
print("Maximum title length:", max_title_length)
# Set pandas column display width to the maximum title_length value
pd.set_option('display.max_colwidth', max_title_length)
result[cols].sort_values(by='published', ascending=False).head(30)
# Out:
# Maximum title length: 100
#         video_id  \
# 3    1Sxxscn4Vfk
# 7    QYr0yFXvn-o
# 8    OFb3f3RnxRk
# 22   cF4CuxaNzAc
# 37   5oEsC-lhhuM
# 78   aobQxcoUlNo
# 94   tMYCaX2uidg
# 102  cLyfqQTjE5c
# 124  Q2Api6HH7UI
# 166  --eVtP5oVcU
# 214  a9-_HqyjKEc
# 226  MapsWdyanGk
# 242  N8eC4zoeOfk
# 301  _mpD0dDL66g
# 304  LoVktJUS1zg
# 326  rDooa0wJhhw
# 330  whrxrXbA3xM
# 345  jlnpn0SXpHA
# 381  cCJFq3Ul0yI
# 397  1A9o-MalN0k
# 407  2oIoPx_LlPs
# 411  OhWPmVCeVs0
# 433  hJHfZ1PpBnY
# 443  45rouvDVxcs
# 448  wDUhZ7xj4Dk
# 464  -NQw6NIN4wU
# 486  DCcMQdppW8A
# 542  -W7QdaO1Q3Q
# 547  XAUScNfVvh8
# 549  TcKCQnaxRXY
#
#                                                                                                    title  \
# 3                    Gemini 3.1 Pro For Beginners - All New Features Explained (Gemini 3.1 Pro Tutorial)
# 7                         Gemini 3 Deepthink For Beginners - Gemini 3 Deepthink Full Guide With Usecases
# 8                                          Google Gemini 3 DeepThink Is Now the Smartest AI In The World
# 22                       Google Gemini Agentic Vision Tutorial - How To Use Google Gemini Agentic Vision
# 37                                                    RIP OpenAI? Apple Dumps ChatGPT for Google Gemini!
# 78                   Gemini 3 Shows a Level of Intelligence We Haven’t Seen Before. (Gemini 3 Explained)
# 94   Big AI News : Gemini 3, AI Music Ban, New Humanoid Robot, Groks AGI, UBI Starts and OpenAI Changes!
# 102                OpenAI on NOTICE: Google's Gemini 3 is Coming to Change EVERYTHING (Gemini 3 Details)
# 124                                    15 New Use Cases With Nano Banana (Gemini 2.5 Flash Image Editor)
# 166                                    How To Use Google AI Studio For Beginners (2025 Tutorial Updated)
# 214                                        Googles NEW Gemini 2.5 Pro BEATS Everything! (Gemini 2.5 Pro)
# 226                                       Googles New Humanoid Robots Are Incredible - Gemini 2 Robotics
# 242          Massive AI News : MAJOR AI Breakthrough, New AI Agent, Gemini 2, Claude 4, Deepseek BANNED!
# 301             How To Use Gemini Deep Research (BEATS Perplexity!) Google Gemini Deep Research Tutorial
# 304                  Googles GEMINI 2.0 Just SHOCKED The ENTIRE INDUSTRY! (OpenAI Beaten) Full Breakdown
# 326             Big AI News: Google Gemini 2.0 Date LEAKED! OpenAis New AI Project, New Robots, And More
# 330  AI News: Google Surpasses OpenAI, Gemini Gets MEMORY, Claude Gets Unleashed,Gpt4o Gets Worse? An...
# 345              AI NEWS : Googles Gemini 2 , New Incredible Humanoids, AI Gets UNLEASHED, And RoboTaxis
# 381                                                Googles NEW AI Gemini 2.0  Details  Were Just LEAKED!
# 397                                    How To Use NotebookLM For Beginners In 2024 (NotebookLM Tutorial)
# 407            Big AI News : Googles Gemini -2 , Claude 3.5 Opus, GPT 4.5 Soon, Apples Stunning Research
# 411                             How To Use ChatGPT Canvas - Complete Guide With Advanced Tips and Tricks
# 433       AI NEWS: OpenAI's Agents Surprise Even me! Google Gemini Comes Alive. New Robotics World Model
# 443             Huge AI NEWS : OpenAI's GPT NEXT, Gemini 2, GPT-6  and 1000 Agents Explore Virtual World
# 448              HUGE AI NEWS : MAJOR BREAKTHROUGH!, 2x Faster Inference Than GROQ, 3 NEW GEMINI Models!
# 464     AI News : Google Gemini -2 Released? New Google Robots, Sam Altman Sued, Secret Details Revealed
# 486  AI News : GPT5 Will Be Better Than We Think , Gemini 2 China Takes The Lead , , Googles New Robo...
# 542              How To Use New Google AI Studio (GoogleAI Tutorial) Complete Guide With Tips and Tricks
# 547                How To Use New Google Gemini (Gemini AI Tutorial) Complete Guide With Tips and Tricks
# 549   AI News: AGI Is Closer Than You Think! Opus BEATS GPT-4o World Spirals into Doomerism, GeminiLEAKS
#
#       published  view_count  title_length hms_format
# 3    2026-02-20       28324            83    0:12:43
# 7    2026-02-16        9084            78    0:10:32
# 8    2026-02-14       57799            61    0:22:33
# 22   2026-02-04        3937            79    0:05:19
# 37   2026-01-20       13781            50    0:09:31
# 78   2025-11-19       71630            83    0:23:40
# 94   2025-11-01       22441            99    0:36:05
# 102  2025-10-20       38024            85    0:14:28
# 124  2025-08-29        4706            65    0:14:34
# 166  2025-05-09       41715            65    0:17:08
# 214  2025-03-26       29893            61    0:12:45
# 226  2025-03-13      100672            62    0:11:58
# 242  2025-02-16       72943            91    0:30:45
# 301  2024-12-13       76905            88    0:08:50
# 304  2024-12-11      650177            83    0:31:01
# 326  2024-11-24       37712            88    0:31:55
# 330  2024-11-22       20552           100    0:22:36
# 345  2024-11-10       22364            87    0:24:20
# 381  2024-10-26       18154            53    0:11:49
# 397  2024-10-20      137766            65    0:11:10
# 407  2024-10-15       49001            89    0:26:45
# 411  2024-10-12       47007            72    0:13:51
# 433  2024-09-19       59214            94    0:27:29
# 443  2024-09-04       30485            88    0:21:30
# 448  2024-08-30       39383            87    0:24:45
# 464  2024-08-13       15306            96    0:20:00
# 486  2024-07-21       45897           100    0:20:01
# 542  2024-05-22       21227            87    0:20:28
# 547  2024-05-18       62967            85    0:21:30
# 549  2024-05-17       39871            98    0:23:57

# %% [markdown]
# ## Most Viewed Videos

# %%
df_highest_views = result.nlargest(10, 'view_count')
df_highest_views['title'] = df_highest_views['title'].str[:94]
df_highest_views['view_count_millions'] = df_highest_views['view_count'] / 5000
df_highest_views[cols]
# Out:
#         video_id  \
# 714  -a6E-r8W2Bs
# 304  LoVktJUS1zg
# 716  Lft0J8sgwS4
# 650  GwaPwLrqwis
# 397  1A9o-MalN0k
# 634  x13wGyYzlJo
# 226  MapsWdyanGk
# 813  wkNAxp3dXFY
# 301  _mpD0dDL66g
# 242  N8eC4zoeOfk
#
#                                                                                               title  \
# 714  Googles GEMINI Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 Beaten) Full Breakdown + Technical Rep
# 304             Googles GEMINI 2.0 Just SHOCKED The ENTIRE INDUSTRY! (OpenAI Beaten) Full Breakdown
# 716                              How to Use NEW Google Gemini Bard (Full Google Gemini AI Tutorial)
# 650              Googles GEMINI 1.5 Just Surprised EVERYONE! (GPT-4 Beaten Again) Finally RELEASED!
# 397                               How To Use NotebookLM For Beginners In 2024 (NotebookLM Tutorial)
# 634   CLAUDE 3 Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 +Gemini BEATEN)  AI AGENTS + FULL Breakdown
# 226                                  Googles New Humanoid Robots Are Incredible - Gemini 2 Robotics
# 813                              Google's  NEW GEMINI Takes the Industry By STORM! (NOW ANNOUNCED!)
# 301        How To Use Gemini Deep Research (BEATS Perplexity!) Google Gemini Deep Research Tutorial
# 242     Massive AI News : MAJOR AI Breakthrough, New AI Agent, Gemini 2, Claude 4, Deepseek BANNED!
#
#       published  view_count  title_length hms_format
# 714  2023-12-06     3939934            97    0:30:43
# 304  2024-12-11      650177            83    0:31:01
# 716  2023-12-04      166410            66    0:14:45
# 650  2024-02-15      145189            82    0:18:00
# 397  2024-10-20      137766            65    0:11:10
# 634  2024-03-04      123230            93    0:23:45
# 226  2025-03-13      100672            62    0:11:58
# 813  2023-05-14       99263            66    0:10:49
# 301  2024-12-13       76905            88    0:08:50
# 242  2025-02-16       72943            91    0:30:45

# %%
df_highest_views[cols].sort_values(by="published",ascending=False)
# Out:
#         video_id  \
# 226  MapsWdyanGk
# 242  N8eC4zoeOfk
# 301  _mpD0dDL66g
# 304  LoVktJUS1zg
# 397  1A9o-MalN0k
# 634  x13wGyYzlJo
# 650  GwaPwLrqwis
# 714  -a6E-r8W2Bs
# 716  Lft0J8sgwS4
# 813  wkNAxp3dXFY
#
#                                                                                               title  \
# 226                                  Googles New Humanoid Robots Are Incredible - Gemini 2 Robotics
# 242     Massive AI News : MAJOR AI Breakthrough, New AI Agent, Gemini 2, Claude 4, Deepseek BANNED!
# 301        How To Use Gemini Deep Research (BEATS Perplexity!) Google Gemini Deep Research Tutorial
# 304             Googles GEMINI 2.0 Just SHOCKED The ENTIRE INDUSTRY! (OpenAI Beaten) Full Breakdown
# 397                               How To Use NotebookLM For Beginners In 2024 (NotebookLM Tutorial)
# 634   CLAUDE 3 Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 +Gemini BEATEN)  AI AGENTS + FULL Breakdown
# 650              Googles GEMINI 1.5 Just Surprised EVERYONE! (GPT-4 Beaten Again) Finally RELEASED!
# 714  Googles GEMINI Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 Beaten) Full Breakdown + Technical Rep
# 716                              How to Use NEW Google Gemini Bard (Full Google Gemini AI Tutorial)
# 813                              Google's  NEW GEMINI Takes the Industry By STORM! (NOW ANNOUNCED!)
#
#       published  view_count  title_length hms_format
# 226  2025-03-13      100672            62    0:11:58
# 242  2025-02-16       72943            91    0:30:45
# 301  2024-12-13       76905            88    0:08:50
# 304  2024-12-11      650177            83    0:31:01
# 397  2024-10-20      137766            65    0:11:10
# 634  2024-03-04      123230            93    0:23:45
# 650  2024-02-15      145189            82    0:18:00
# 714  2023-12-06     3939934            97    0:30:43
# 716  2023-12-04      166410            66    0:14:45
# 813  2023-05-14       99263            66    0:10:49

# %%
# Set the figure size
sns.set(rc={'figure.figsize': (20, 10)})

# Create the barplot
plot = sns.barplot(
    x="view_count_millions", 
    y="title", 
    hue="title",  # Assign y variable to hue
    data=df_highest_views, 
    palette="bright", 
    legend=False  # Disable the legend
)

# Set labels and title
plot.set(xlabel='Millions of Views', ylabel='')
plot.set_title('Most Viewed Videos')

# Set x-axis limits
plt.xlim(20, 32)

# Show the plot
plt.show()

# %%
colt = 'video_id title published view_count hms_format'.split()
output_file = channel_name + '.csv'
result[colt].to_csv(output_file, index=None)
result[colt].sort_values(by="published",ascending=False)
# Out:
#         video_id  \
# 3    1Sxxscn4Vfk
# 7    QYr0yFXvn-o
# 8    OFb3f3RnxRk
# 22   cF4CuxaNzAc
# 37   5oEsC-lhhuM
# 78   aobQxcoUlNo
# 94   tMYCaX2uidg
# 102  cLyfqQTjE5c
# 124  Q2Api6HH7UI
# 166  --eVtP5oVcU
# 214  a9-_HqyjKEc
# 226  MapsWdyanGk
# 242  N8eC4zoeOfk
# 301  _mpD0dDL66g
# 304  LoVktJUS1zg
# 326  rDooa0wJhhw
# 330  whrxrXbA3xM
# 345  jlnpn0SXpHA
# 381  cCJFq3Ul0yI
# 397  1A9o-MalN0k
# 407  2oIoPx_LlPs
# 411  OhWPmVCeVs0
# 433  hJHfZ1PpBnY
# 443  45rouvDVxcs
# 448  wDUhZ7xj4Dk
# 464  -NQw6NIN4wU
# 486  DCcMQdppW8A
# 542  -W7QdaO1Q3Q
# 547  XAUScNfVvh8
# 549  TcKCQnaxRXY
# 567  SZS5WD1du3A
# 591  9FgiovYyAXU
# 623  1qThZ69kP7c
# 634  x13wGyYzlJo
# 650  GwaPwLrqwis
# 657  0OR9ur43r1E
# 662  l0LW6djeeAk
# 665  EtRfEJ0B3mw
# 685  wW2owzHe9rk
# 704  PxrYD9x3V4E
# 714  -a6E-r8W2Bs
# 716  Lft0J8sgwS4
# 742  eBE4GNsyDng
# 762  oIxw_rYvAuc
# 813  wkNAxp3dXFY
#
#                                                                                                    title  \
# 3                    Gemini 3.1 Pro For Beginners - All New Features Explained (Gemini 3.1 Pro Tutorial)
# 7                         Gemini 3 Deepthink For Beginners - Gemini 3 Deepthink Full Guide With Usecases
# 8                                          Google Gemini 3 DeepThink Is Now the Smartest AI In The World
# 22                       Google Gemini Agentic Vision Tutorial - How To Use Google Gemini Agentic Vision
# 37                                                    RIP OpenAI? Apple Dumps ChatGPT for Google Gemini!
# 78                   Gemini 3 Shows a Level of Intelligence We Haven’t Seen Before. (Gemini 3 Explained)
# 94   Big AI News : Gemini 3, AI Music Ban, New Humanoid Robot, Groks AGI, UBI Starts and OpenAI Changes!
# 102                OpenAI on NOTICE: Google's Gemini 3 is Coming to Change EVERYTHING (Gemini 3 Details)
# 124                                    15 New Use Cases With Nano Banana (Gemini 2.5 Flash Image Editor)
# 166                                    How To Use Google AI Studio For Beginners (2025 Tutorial Updated)
# 214                                        Googles NEW Gemini 2.5 Pro BEATS Everything! (Gemini 2.5 Pro)
# 226                                       Googles New Humanoid Robots Are Incredible - Gemini 2 Robotics
# 242          Massive AI News : MAJOR AI Breakthrough, New AI Agent, Gemini 2, Claude 4, Deepseek BANNED!
# 301             How To Use Gemini Deep Research (BEATS Perplexity!) Google Gemini Deep Research Tutorial
# 304                  Googles GEMINI 2.0 Just SHOCKED The ENTIRE INDUSTRY! (OpenAI Beaten) Full Breakdown
# 326             Big AI News: Google Gemini 2.0 Date LEAKED! OpenAis New AI Project, New Robots, And More
# 330  AI News: Google Surpasses OpenAI, Gemini Gets MEMORY, Claude Gets Unleashed,Gpt4o Gets Worse? An...
# 345              AI NEWS : Googles Gemini 2 , New Incredible Humanoids, AI Gets UNLEASHED, And RoboTaxis
# 381                                                Googles NEW AI Gemini 2.0  Details  Were Just LEAKED!
# 397                                    How To Use NotebookLM For Beginners In 2024 (NotebookLM Tutorial)
# 407            Big AI News : Googles Gemini -2 , Claude 3.5 Opus, GPT 4.5 Soon, Apples Stunning Research
# 411                             How To Use ChatGPT Canvas - Complete Guide With Advanced Tips and Tricks
# 433       AI NEWS: OpenAI's Agents Surprise Even me! Google Gemini Comes Alive. New Robotics World Model
# 443             Huge AI NEWS : OpenAI's GPT NEXT, Gemini 2, GPT-6  and 1000 Agents Explore Virtual World
# 448              HUGE AI NEWS : MAJOR BREAKTHROUGH!, 2x Faster Inference Than GROQ, 3 NEW GEMINI Models!
# 464     AI News : Google Gemini -2 Released? New Google Robots, Sam Altman Sued, Secret Details Revealed
# 486  AI News : GPT5 Will Be Better Than We Think , Gemini 2 China Takes The Lead , , Googles New Robo...
# 542              How To Use New Google AI Studio (GoogleAI Tutorial) Complete Guide With Tips and Tricks
# 547                How To Use New Google Gemini (Gemini AI Tutorial) Complete Guide With Tips and Tricks
# 549   AI News: AGI Is Closer Than You Think! Opus BEATS GPT-4o World Spirals into Doomerism, GeminiLEAKS
# 567                                 Googles NEW "Med-Gemini" SURPRISES Doctors! (Googles New Medical AI)
# 591                          Googles 6 NEW AI AGENTS Takes The INUDSTRY BY STORM! (Google Gemini AGENTS)
# 623             Worlds NEWEST AGI AGENT Just SURPISED EVERYONE! (Beats CLAUDE, GPT-4, Gemini) (Maisa AI)
# 634        CLAUDE 3 Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 +Gemini BEATEN)  AI AGENTS + FULL Breakdown
# 650                   Googles GEMINI 1.5 Just Surprised EVERYONE! (GPT-4 Beaten Again) Finally RELEASED!
# 657              Googles GEMINI ULTRA Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 Beaten) Finally RELEASED!
# 662      Major AI News #28 - Sam Altman's Surprising Comment, Gemini Ultra Release Date, AGI "Achieved?"
# 665     Major AI News #27 - Sam Altmans AGI Shocker, Apples ChatGPT Update, Gemini Pro's New Features...
# 685                Major AI News #25 - Gemini Upgrades, GPT Store Leaks, Realtime AI Phonecalls and More
# 704         Major AI News #23 - Google Gemini -2 , Major ChatGPT Breaches, Google Text To Image And More
# 714    Googles GEMINI Just SHOCKED The ENTIRE INDUSTRY! (GPT-4 Beaten) Full Breakdown + Technical Report
# 716                                   How to Use NEW Google Gemini Bard (Full Google Gemini AI Tutorial)
# 742                        Google Gemini LEAKED + Rumours and Predictions - It's about to get real silly
# 762                                    Google Deepmind CEO Shocks Everyone With NEW Statements On GEMINI
# 813                                   Google's  NEW GEMINI Takes the Industry By STORM! (NOW ANNOUNCED!)
#
#       published  view_count hms_format
# 3    2026-02-20       28324    0:12:43
# 7    2026-02-16        9084    0:10:32
# 8    2026-02-14       57799    0:22:33
# 22   2026-02-04        3937    0:05:19
# 37   2026-01-20       13781    0:09:31
# 78   2025-11-19       71630    0:23:40
# 94   2025-11-01       22441    0:36:05
# 102  2025-10-20       38024    0:14:28
# 124  2025-08-29        4706    0:14:34
# 166  2025-05-09       41715    0:17:08
# 214  2025-03-26       29893    0:12:45
# 226  2025-03-13      100672    0:11:58
# 242  2025-02-16       72943    0:30:45
# 301  2024-12-13       76905    0:08:50
# 304  2024-12-11      650177    0:31:01
# 326  2024-11-24       37712    0:31:55
# 330  2024-11-22       20552    0:22:36
# 345  2024-11-10       22364    0:24:20
# 381  2024-10-26       18154    0:11:49
# 397  2024-10-20      137766    0:11:10
# 407  2024-10-15       49001    0:26:45
# 411  2024-10-12       47007    0:13:51
# 433  2024-09-19       59214    0:27:29
# 443  2024-09-04       30485    0:21:30
# 448  2024-08-30       39383    0:24:45
# 464  2024-08-13       15306    0:20:00
# 486  2024-07-21       45897    0:20:01
# 542  2024-05-22       21227    0:20:28
# 547  2024-05-18       62967    0:21:30
# 549  2024-05-17       39871    0:23:57
# 567  2024-05-03       44288    0:25:41
# 591  2024-04-11       53650    0:50:28
# 623  2024-03-16       40331    0:14:57
# 634  2024-03-04      123230    0:23:45
# 650  2024-02-15      145189    0:18:00
# 657  2024-02-08       27827    0:37:47
# 662  2024-02-03       39214    0:23:35
# 665  2024-01-30       42512    0:26:33
# 685  2024-01-10       25585    0:33:50
# 704  2023-12-18       47714    0:29:35
# 714  2023-12-06     3939934    0:30:43
# 716  2023-12-04      166410    0:14:45
# 742  2023-11-03       12203    0:14:14
# 762  2023-08-09       18771    0:09:57
# 813  2023-05-14       99263    0:10:49

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Excel path (xsl_path): {xsl_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\YouTube
# Base path: C:\Users\PC1\OneDrive\A4
# Excel path (xsl_path): C:\Users\PC1\OneDrive\A4\Excel

# %%
xsl_file = channel_name + '.xlsx'
xsl_file = os.path.join(xsl_path, xsl_file)
xsl_file
# Out:
# 'C:\\Users\\PC1\\OneDrive\\A4\\Excel\\TheAiGrid.xlsx'

# %%
colt = 'video_id title published view_count hms_format read'.split()
df_highest_views['read'] = 'N'
df_highest_views[colt].to_excel(xsl_file, index=False)
