# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build

YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

# def parse_publish_date(video):
#     return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
from dateutil import parser

def parse_publish_date(video):
    return (
        video['snippet']['resourceId']['videoId'],
        parser.parse(video['snippet']['publishedAt']),
        video['snippet']['title']
    )

# %%
res = youtube.search().list(part='snippet', 
                            q='UCkbl59_mrmuCL6aJgrlHnEQ',
                            type='channel').execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'YWyT7Bm3Bec2SC8DbIzJtwA0Cqg',
#  'regionCode': 'TH',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'Se-JePoOx6fE-9OazXZWo22VbTw',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ'},
#    'snippet': {'publishedAt': '2018-07-30T15:55:45Z',
#     'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#     'title': 'Crayons and Carry-Ons',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kBhEpkp0lQDV2GMKLJiZSR1Q3YX547Bc1TK9JlQ5YXmV0=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kBhEpkp0lQDV2GMKLJiZSR1Q3YX547Bc1TK9JlQ5YXmV0=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kBhEpkp0lQDV2GMKLJiZSR1Q3YX547Bc1TK9JlQ5YXmV0=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'Crayons and Carry-Ons',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-07-30T15:55:45Z'}}]}

# %%
channel_name = 'ฟังเพลงสบายๆสไตล์ฮารุ'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCtiwG9AQO_mXolmTi-N-0rQ'

# %%
videos = get_videos(channel_id, limit=7500)
videos[:5]
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'CYfWinzghDooQ3dQf62fzX3ciVc',
#   'id': 'VVV0aXdHOUFRT19tWG9sbVRpLU4tMHJRLkVFOEhoa2Y0N09n',
#   'snippet': {'publishedAt': '2025-12-13T05:58:12Z',
#    'channelId': 'UCtiwG9AQO_mXolmTi-N-0rQ',
#    'title': '💽เบียร์ วราวุธ #เพลงเพราะ …ในใจเรา #เธอคือชีวิต #บุพเพสันนิวาส คำดีๆที่อยากบอก',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EE8Hhkf47Og/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EE8Hhkf47Og/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EE8Hhkf47Og/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/EE8Hhkf47Og/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/EE8Hhkf47Og/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'playlistId': 'UUtiwG9AQO_mXolmTi-N-0rQ',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'EE8Hhkf47Og'},
#    'videoOwnerChannelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'videoOwnerChannelId': 'UCtiwG9AQO_mXolmTi-N-0rQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'j8K_X2lv2g171CKIHry9rSG6zuo',
#   'id': 'VVV0aXdHOUFRT19tWG9sbVRpLU4tMHJRLllfbWU0UzNqWjBV',
#   'snippet': {'publishedAt': '2025-12-08T08:14:04Z',
#    'channelId': 'UCtiwG9AQO_mXolmTi-N-0rQ',
#    'title': '🕊#เพลงดัง…เจ็บแบบเบาๆ#สายลมเจ็บปวด #สุดมือปล่อยวางสุดทางปล่อยมือ #โลกทั้งใบ #วันที่อ่อนแอ #เพลงเพราะ',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y_me4S3jZ0U/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Y_me4S3jZ0U/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Y_me4S3jZ0U/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Y_me4S3jZ0U/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Y_me4S3jZ0U/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'playlistId': 'UUtiwG9AQO_mXolmTi-N-0rQ',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Y_me4S3jZ0U'},
#    'videoOwnerChannelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'videoOwnerChannelId': 'UCtiwG9AQO_mXolmTi-N-0rQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '81nw3C9-cEg_dfwIJCiYJK9kTgs',
#   'id': 'VVV0aXdHOUFRT19tWG9sbVRpLU4tMHJRLjNPUGJKZHFaV3BZ',
#   'snippet': {'publishedAt': '2025-10-05T15:10:33Z',
#    'channelId': 'UCtiwG9AQO_mXolmTi-N-0rQ',
#    'title': '🎧บทเพลงเก่าๆที่เราคิดถึง 🎧#โกหกหน้าตาย #เธอจะเลือกใคร  #ต่างคนต่างไป #เพลงฮิต #เพลงเก่า #เพลงดัง',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3OPbJdqZWpY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3OPbJdqZWpY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3OPbJdqZWpY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/3OPbJdqZWpY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/3OPbJdqZWpY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'playlistId': 'UUtiwG9AQO_mXolmTi-N-0rQ',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '3OPbJdqZWpY'},
#    'videoOwnerChannelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'videoOwnerChannelId': 'UCtiwG9AQO_mXolmTi-N-0rQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'jc-hRQR6WzkvO2_yVlzZgSuZbzE',
#   'id': 'VVV0aXdHOUFRT19tWG9sbVRpLU4tMHJRLnljZEFzeU1QY3Rz',
#   'snippet': {'publishedAt': '2025-06-30T10:17:06Z',
#    'channelId': 'UCtiwG9AQO_mXolmTi-N-0rQ',
#    'title': 'คิดถึงเสียงร้องเพราะๆเศร้าๆ 🎧โจ้ วงPause #รักเธอทั้งหมดของหัวใจ #วันใหม่ #ดาว#เพลงเก่า #เพลงเศร้า🕊🕊',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ycdAsyMPcts/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ycdAsyMPcts/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ycdAsyMPcts/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ycdAsyMPcts/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/ycdAsyMPcts/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'playlistId': 'UUtiwG9AQO_mXolmTi-N-0rQ',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ycdAsyMPcts'},
#    'videoOwnerChannelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'videoOwnerChannelId': 'UCtiwG9AQO_mXolmTi-N-0rQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'rUFnYJN9FS3yc4eoR7VwRumRmqQ',
#   'id': 'VVV0aXdHOUFRT19tWG9sbVRpLU4tMHJRLkpBTG85cU9qV1RZ',
#   'snippet': {'publishedAt': '2025-06-29T11:22:32Z',
#    'channelId': 'UCtiwG9AQO_mXolmTi-N-0rQ',
#    'title': '🎸รวมเพลง…นูโว 🎸#ไม่เป็นไรเลย #ลึกสุดใจ #กวีบทเก่า #นิยามรัก #โง่งมงาย #หมดคำถาม #เพลงดัง #เพลงเพราะ',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JALo9qOjWTY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/JALo9qOjWTY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/JALo9qOjWTY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/JALo9qOjWTY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/JALo9qOjWTY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'playlistId': 'UUtiwG9AQO_mXolmTi-N-0rQ',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'JALo9qOjWTY'},
#    'videoOwnerChannelTitle': 'ฟังเพลงสบายๆ สไตล์ฮารุ🎶🎶',
#    'videoOwnerChannelId': 'UCtiwG9AQO_mXolmTi-N-0rQ'}}]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 202

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 202

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)[:15]

# %%
for video in most_viewed:
    print(video['id'], video['statistics']['viewCount'])
# Out:
# NF--CEQ1sL8 1925301
# HamBxK2Y8k0 1559054
# Y4c5F_-f9Bk 1125990
# w2RkqiWE2Is 1118260
# l5_pz4WBVAM 1094154
# wwCLaZtP_3E 838269
# RNALBlGgzAI 773978
# buMBVcPerLM 769870
# 4tOsYLICbLQ 763533
# 2szVSUOqyas 727170
# fP3-n_zmJZY 713259
# pa1pLnaDrMA 696046
# cqYuBx0ome4 676948
# QFyYK6Xb55M 610408
# c2-U3ViD3mM 602340

# %%
def parse_count(video):
    return video['id'],video['statistics']['viewCount']

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 15

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count
# Out:
#         videoId  viewCount
# 0   u7yCirQaWTs  145082340
# 1   2kh-re0Wass   29482433
# 2   ZhCPD2ujT88   16411644
# 3   3HrkQPGm8Cc    7919589
# 4   WIXZGOnmZMA    7105654
# 5   FdiU-C7Sfk0    6160189
# 6   45GYOIY2Qz4    5188982
# 7   2HvWl3ovDrk    4951602
# 8   MzQv9Q7B9cs    4501389
# 9   4DhYA5ZyhM4    4457076
# 10  dDqrnmCclBQ    3980589
# 11  AvimffNkQ-0    3834609
# 12  42xfS4HGZvY    3708252
# 13  g7XuCfT08yU    3611271
# 14  Xx8xRGLN628    3563468

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False])
# Out:
#         videoId    viewCount
# 0   u7yCirQaWTs  145082340.0
# 1   2kh-re0Wass   29482433.0
# 2   ZhCPD2ujT88   16411644.0
# 3   3HrkQPGm8Cc    7919589.0
# 4   WIXZGOnmZMA    7105654.0
# 5   FdiU-C7Sfk0    6160189.0
# 6   45GYOIY2Qz4    5188982.0
# 7   2HvWl3ovDrk    4951602.0
# 8   MzQv9Q7B9cs    4501389.0
# 9   4DhYA5ZyhM4    4457076.0
# 10  dDqrnmCclBQ    3980589.0
# 11  AvimffNkQ-0    3834609.0
# 12  42xfS4HGZvY    3708252.0
# 13  g7XuCfT08yU    3611271.0
# 14  Xx8xRGLN628    3563468.0

# %%
def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# 7500

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date
# Out:
#           videoId               publishedAt  \
# 0     rqGitI2Lb-A 2025-12-30 08:01:13+00:00
# 1     nQI3kSJf044 2025-12-30 08:00:59+00:00
# 2     Z-6NzhBAXBQ 2025-12-29 08:00:44+00:00
# 3     yZNzSW1NGms 2025-12-28 08:01:16+00:00
# 4     aKHefUKOhO8 2025-12-28 08:00:01+00:00
# ...           ...                       ...
# 7495  vWFAVyXSVjc 2021-10-11 15:00:26+00:00
# 7496  JWpoMQSNVN8 2021-10-11 11:10:02+00:00
# 7497  jbAGuc2FMj0 2021-10-11 09:00:30+00:00
# 7498  TlTNWLXT4os 2021-10-11 09:00:13+00:00
# 7499  clkhYTJB43s 2021-10-11 02:00:05+00:00
#
#                                                   title
# 0     สิ่งที่ได้ไปต่อในปีหน้าและปีต่อ ๆ ไป ❤️ #เรา #...
# 1     รวมเพลงฮิต GMM GRAMMY Best of The Year 2025 l ...
# 2     รวมเพลงฮิต ฟีล ๆ ฟังแบบปล่อยจอย ไม่หลับไม่นอน ...
# 3     ได้โปรดเถอะสวรรค์ เป็นฉันบ้างได้มั้ยที่ถูกเลือ...
# 4     รวมเพลงฮิต ฟีล ๆ ฟังแบบปล่อยจอย ไม่หลับไม่นอน ...
# ...                                                 ...
# 7495  เพลงร็อกปาดน้ำตาหยดที่ 1 | เธอทำให้ฉันเสียใจ C...
# 7496  “เราแค่หมดรักกัน อย่าฝืนมันอีกเลย”Official MV ...
# 7497  ตรวจที่หัวไม่มีไข้ ตรวจที่หัวใจไม่มีแฟน โสด1 |...
# 7498  Rewind เพลงฮิต ที่คิดถึง | ไม่ได้หมดรักแต่หัวใ...
# 7499  รวมเพลงฮิต เกิดทัน X-change 3 2542 | เธอบอกให้...
#
# [7500 rows x 3 columns]

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   videoId      15 non-null     object
#  1   publishedAt  15 non-null     datetime64[ns, tzutc()]
#  2   title        15 non-null     object
#  3   viewCount    15 non-null     float64
# dtypes: datetime64[ns, tzutc()](1), float64(1), object(2)
# memory usage: 612.0+ bytes

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False])
# Out:
#         videoId               publishedAt  \
# 0   FdiU-C7Sfk0 2025-10-10 03:00:16+00:00
# 1   ZhCPD2ujT88 2025-08-22 05:00:27+00:00
# 2   u7yCirQaWTs 2023-08-21 06:00:31+00:00
# 3   WIXZGOnmZMA 2023-07-07 13:00:23+00:00
# 4   45GYOIY2Qz4 2023-03-01 08:00:01+00:00
# 5   4DhYA5ZyhM4 2022-12-14 13:00:04+00:00
# 6   3HrkQPGm8Cc 2022-10-27 13:28:01+00:00
# 7   2HvWl3ovDrk 2022-09-16 09:00:02+00:00
# 8   dDqrnmCclBQ 2022-08-29 01:00:10+00:00
# 9   Xx8xRGLN628 2022-08-24 12:00:16+00:00
# 10  g7XuCfT08yU 2022-05-02 16:00:21+00:00
# 11  AvimffNkQ-0 2022-04-22 05:00:06+00:00
# 12  42xfS4HGZvY 2022-03-09 09:22:00+00:00
# 13  MzQv9Q7B9cs 2022-02-07 16:00:14+00:00
# 14  2kh-re0Wass 2021-11-08 06:00:00+00:00
#
#                                                 title    viewCount
# 0   ไม่ต้องคิดเผื่อใจ (You In Mind) - Tilly Birds ...    6160189.0
# 1   ใจเกินร้อย - TaitosmitH เพลงชูกำลัง  [Official...   16411644.0
# 2   รักเอ๋ย - ธงไชย แมคอินไตย์ (เพลงจากละครพนมนาคา...  145082340.0
# 3   เธอคือพลังของฉัน (My Energy) - BIRD THONGCHAI ...    7105654.0
# 4        ฟ้อนทั้งน้ำตา - เบิร์ด ธงไชย [ Official MV ]    5188982.0
# 5               ปีของเรา – เบิร์ด ธงไชย [OFFICIAL MV]    4457076.0
# 6               ทดลองใช้ - เบิร์ด ธงไชย [OFFICIAL MV]    7919589.0
# 7   รวมเพลงยอดวิวเยอะ ใคร ๆ ก็ฟัง 4 | สลักจิต POP ...    4951602.0
# 8                หวังดีเสมอ - POTATO [เกิดทันตัวท็อป]    3980589.0
# 9   ฉันอยู่ตรงนี้ OST.เข็มซ่อนปลาย - เก้า จิรายุ [...    3563468.0
# 10                     อรวรรณ - TAXI [เกิดทันตัวท็อป]    3611271.0
# 11  เพลงที่ไม่มีใครฟัง - เบิร์ด ธงไชย [OFFICIAL LY...    3834609.0
# 12              มื้อนี้.. กินลาบกันบ่สู 😐  ต่าย อรทัย    3708252.0
# 13                 ไออุ่นรัก - CLASH [เกิดทันตัวท็อป]    4501389.0
# 14  ใครคิดถึง - เบิร์ด ธงไชย (เพลงประกอบละคร วิมาน...   29482433.0

# %%
df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
df_count_date.head(100)
# Out:
#         videoId    viewCount               publishedAt  \
# 0   u7yCirQaWTs  145082340.0 2023-08-21 06:00:31+00:00
# 1   2kh-re0Wass   29482433.0 2021-11-08 06:00:00+00:00
# 2   ZhCPD2ujT88   16411644.0 2025-08-22 05:00:27+00:00
# 3   3HrkQPGm8Cc    7919589.0 2022-10-27 13:28:01+00:00
# 4   WIXZGOnmZMA    7105654.0 2023-07-07 13:00:23+00:00
# 5   FdiU-C7Sfk0    6160189.0 2025-10-10 03:00:16+00:00
# 6   45GYOIY2Qz4    5188982.0 2023-03-01 08:00:01+00:00
# 7   2HvWl3ovDrk    4951602.0 2022-09-16 09:00:02+00:00
# 8   MzQv9Q7B9cs    4501389.0 2022-02-07 16:00:14+00:00
# 9   4DhYA5ZyhM4    4457076.0 2022-12-14 13:00:04+00:00
# 10  dDqrnmCclBQ    3980589.0 2022-08-29 01:00:10+00:00
# 11  AvimffNkQ-0    3834609.0 2022-04-22 05:00:06+00:00
# 12  42xfS4HGZvY    3708252.0 2022-03-09 09:22:00+00:00
# 13  g7XuCfT08yU    3611271.0 2022-05-02 16:00:21+00:00
# 14  Xx8xRGLN628    3563468.0 2022-08-24 12:00:16+00:00
#
#                                                 title
# 0   รักเอ๋ย - ธงไชย แมคอินไตย์ (เพลงจากละครพนมนาคา...
# 1   ใครคิดถึง - เบิร์ด ธงไชย (เพลงประกอบละคร วิมาน...
# 2   ใจเกินร้อย - TaitosmitH เพลงชูกำลัง  [Official...
# 3               ทดลองใช้ - เบิร์ด ธงไชย [OFFICIAL MV]
# 4   เธอคือพลังของฉัน (My Energy) - BIRD THONGCHAI ...
# 5   ไม่ต้องคิดเผื่อใจ (You In Mind) - Tilly Birds ...
# 6        ฟ้อนทั้งน้ำตา - เบิร์ด ธงไชย [ Official MV ]
# 7   รวมเพลงยอดวิวเยอะ ใคร ๆ ก็ฟัง 4 | สลักจิต POP ...
# 8                  ไออุ่นรัก - CLASH [เกิดทันตัวท็อป]
# 9               ปีของเรา – เบิร์ด ธงไชย [OFFICIAL MV]
# 10               หวังดีเสมอ - POTATO [เกิดทันตัวท็อป]
# 11  เพลงที่ไม่มีใครฟัง - เบิร์ด ธงไชย [OFFICIAL LY...
# 12              มื้อนี้.. กินลาบกันบ่สู 😐  ต่าย อรทัย
# 13                     อรวรรณ - TAXI [เกิดทันตัวท็อป]
# 14  ฉันอยู่ตรงนี้ OST.เข็มซ่อนปลาย - เก้า จิรายุ [...

# %%
print(df_count_date.info())
print("\nColumn dtypes:")
print(df_count_date.dtypes)

# Check if any datetime columns have timezone
for col in df_count_date.columns:
    if pd.api.types.is_datetime64_any_dtype(df_count_date[col]):
        print(f"\n{col}: {df_count_date[col].dtype}")
        if df_count_date[col].dt.tz is not None:
            print(f"  Has timezone: {df_count_date[col].dt.tz}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   videoId      15 non-null     object
#  1   viewCount    15 non-null     float64
#  2   publishedAt  15 non-null     datetime64[ns, tzutc()]
#  3   title        15 non-null     object
# dtypes: datetime64[ns, tzutc()](1), float64(1), object(2)
# memory usage: 612.0+ bytes
# None
#
# Column dtypes:
# videoId                         object
# viewCount                      float64
# publishedAt    datetime64[ns, tzutc()]
# title                           object
# dtype: object
#
# publishedAt: datetime64[ns, tzutc()]
#   Has timezone: tzutc()

# %%
# If you know the datetime column name (e.g., 'publish_date')
# df_count_date['publish_date'] = df_count_date['publish_date'].dt.tz_localize(None)
df_count_date['publishedAt'] = df_count_date['publishedAt'].dt.tz_localize(None)
df_count_date.to_excel('C:\\Users\\PC1\\OneDrive\\A5\\Data\\videos\\grammy.xlsx', index=False)

# %%
req = youtube.search().list(q='TMr6subvuQI',part='snippet',type='video',maxResults=1)

# %%
res = req.execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'OPcaiv_eMridy6IuJlQuwOqE_Cw',
#  'nextPageToken': 'CAEQAA',
#  'regionCode': 'TH',
#  'pageInfo': {'totalResults': 183, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'iHyWOjrsVTcL66CKK2riJBfm1X0',
#    'id': {'kind': 'youtube#video', 'videoId': 'TMr6subvuQI'},
#    'snippet': {'publishedAt': '2018-07-31T13:00:06Z',
#     'channelId': 'UCNdqGgAK2u-EucN4IAIqP7Q',
#     'title': 'ความเงียบดังที่สุด - Getsunova [Official MV]',
#     'description': 'เพลง ความเงียบดังที่สุด ศิลปิน GETSUNOVA ซิงเกิลล่าสุด ที่พวกเขาเลือกมาให้ฟังกันก่อนเข้าสู่คอนเสิร์ตใหญ่เต็มรูปแบบครั้งแรก ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OfficialWhiteMusic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-07-31T13:00:06Z'}}]}

# %%
req = youtube.search().list(q='TMr6subvuQI', part='snippet', type='video', maxResults=1)
res = req.execute()

if res['items']:
    item = res['items'][0]
    video_id = item['id']['videoId']
    title = item['snippet']['title']
    published_at = item['snippet']['publishedAt']
    channel_title = item['snippet']['channelTitle']
    description = item['snippet']['description']
    
    print(f"Video ID: {video_id}")
    print(f"Title: {title}")
    print(f"Published: {published_at}")
    print(f"Channel: {channel_title}")
    print(f"Description: {description[:100]}...")  # First 100 chars
# Out:
# Video ID: TMr6subvuQI
# Title: ความเงียบดังที่สุด - Getsunova [Official MV]
# Published: 2018-07-31T13:00:06Z
# Channel: OfficialWhiteMusic
# Description: เพลง ความเงียบดังที่สุด ศิลปิน GETSUNOVA ซิงเกิลล่าสุด ที่พวกเขาเลือกมาให้ฟังกันก่อนเข้าสู่คอนเสิร์ต...

# %%
def get_videos_dates(video_ids):
    dates = []
    for video in video_ids:
        #res = youtube.videos().list(id=','.join(video_ids[i]),
                                   #part='statistics').execute()
        res = youtube.search().list(q=video,part='snippet',type='video',maxResults=1).execute()
        temp = item['id']['videoId'],item['snippet']['title'],item['snippet']['publishedAt']
        dates += temp
        
    return dates
