# %%
channel_name = 'per_simmons'

# %%
import pandas as pd
from datetime import datetime, timedelta
from googleapiclient.discovery import build
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

# Retrieve API key from environment variables
YOUTUBE_DEVELOPER_KEY = os.getenv('YOUTUBE_DEVELOPER_KEY')

# Verify API key is loaded
if not YOUTUBE_DEVELOPER_KEY:
    raise ValueError("YouTube API key not found. Please create a .env file with YOUTUBE_API_KEY=")
    
youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_quota_reset_info():
    """Get information about when quota resets and suggest action"""
    from datetime import datetime, timezone, timedelta
    import pytz
    
    pacific = pytz.timezone('America/Los_Angeles')
    now_pt = datetime.now(pacific)
    
    # Calculate next reset time (midnight PT)
    reset_time = now_pt.replace(hour=0, minute=0, second=0, microsecond=0)
    if now_pt >= reset_time:
        reset_time += timedelta(days=1)
    
    time_until_reset = reset_time - now_pt
    hours_until_reset = time_until_reset.total_seconds() / 3600
    
    print(f"Current PT time: {now_pt.strftime('%H:%M')}")
    print(f"Quota resets in: {hours_until_reset:.1f} hours")
    
    if hours_until_reset < 4:
        print("⚠️  Caution: Limited time until quota reset")
        if hours_until_reset < 1:
            print("✅ Consider waiting for fresh quota")
    
    return hours_until_reset

# Use it like this:
if get_quota_reset_info() < 2:
    # Very little time until reset
    print("You might want to wait for quota reset")
# Out:
# Current PT time: 02:32
# Quota resets in: 21.5 hours

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]

channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCTt7rUhU483njba45wq7MOg'

# %%
# Search for channels matching your channel name
search_response = youtube.search().list(
    q=channel_name,
    type='channel',
    part='id,snippet',
    maxResults=10  # Get more results
).execute()

print(f"Found {len(search_response['items'])} channels matching '{channel_name}':\n")

for i, item in enumerate(search_response['items']):
    channel_id = item['id']['channelId']
    channel_title = item['snippet']['title']
    description = item['snippet']['description'][:100] if item['snippet']['description'] else 'No description'
    
    # Get subscriber count for each channel
    stats_request = youtube.channels().list(
        part="statistics",
        id=channel_id
    ).execute()
    
    if stats_request['items']:
        subs = stats_request['items'][0]['statistics'].get('subscriberCount', 'Hidden')
        videos = stats_request['items'][0]['statistics'].get('videoCount', 'Unknown')
    else:
        subs = 'Unknown'
        videos = 'Unknown'
    
    print(f"{i+1}. Channel: {channel_title}")
    print(f"   ID: {channel_id}")
    print(f"   Subscribers: {subs}")
    print(f"   Videos: {videos}")
    print(f"   Description: {description[:100]}")
    print()
# Out:
# Found 10 channels matching 'per_simmons':
#
# 1. Channel: persimmon asmr
#    ID: UCTt7rUhU483njba45wq7MOg
#    Subscribers: 6570
#    Videos: 99
#    Description: hello there :) I hope you can find comfort, sleep, and relaxing times by watching my asmr videos I t
#
# 2. Channel: per_simmon
#    ID: UCxyuemZEhtl8Czsf9rpOzWQ
#    Subscribers: 6
#    Videos: 2
#    Description: No description
#
# 3. Channel: Pat Simmons
#    ID: UCY8ZKVxXj0FgIvSfeiSDclg
#    Subscribers: 19900
#    Videos: 69
#    Description: On this channel you'll find non-technical AI tools and workflows that will help you save hours, do b
#
# 4. Channel: Persimmon Homes UK
#    ID: UCPvk-_AE6YeKRTpRel7xpcQ
#    Subscribers: 3980
#    Videos: 645
#    Description: See what's possible in a new Persimmon home. We're a 5-star homebuilder committed to making these dr
#
# 5. Channel: パーシモンズ Persimmons
#    ID: UCqRDbgGLatOf27jaeuIOYNg
#    Subscribers: 27
#    Videos: 7
#    Description: No description
#
# 6. Channel: Persimmons Australia
#    ID: UCAZCj4d9eIC7eRTAXMDBv3A
#    Subscribers: 406
#    Videos: 3
#    Description: Welcome to the Persimmons Australia YouTube channel! We're passionate about our delicious autumnal p
#
# 7. Channel: Fuyu Persimmons
#    ID: UCE2ADw8HM_Qibkfnyp5BLyQ
#    Subscribers: 10
#    Videos: 15
#    Description: No description
#
# 8. Channel: Persimmons Studio
#    ID: UCrghykEIo0iGBwVjgF4brWA
#    Subscribers: 57
#    Videos: 175
#    Description: Why do children love to color fairytale heroes so much? Because they want to know as much about this
#
# 9. Channel: PERSIMMONS - Topic
#    ID: UC9_cHTBhQyZ4gelBJq-klCg
#    Subscribers: 2
#    Videos: 2
#    Description: No description
#
# 10. Channel: I PERSIMMONS
#    ID: UCbtFVePUKTKdXbshmIa8-BQ
#    Subscribers: 4
#    Videos: 1
#    Description: No description

# %%
# Search for the exact video you want
video_query = "Claude Design Is ABSURD"

video_search = youtube.search().list(
    q=video_query,
    type='video',
    part='id,snippet',
    maxResults=10
).execute()

print(f"Found {len(video_search['items'])} videos:\n")

for i, item in enumerate(video_search['items']):
    video_title = item['snippet']['title']
    channel_title = item['snippet']['channelTitle']
    channel_id = item['snippet']['channelId']
    video_id = item['id']['videoId']
    description = item['snippet']['description'][:150] if item['snippet']['description'] else 'No description'
    
    print(f"{i+1}. Video: {video_title}")
    print(f"   Channel: {channel_title}")
    print(f"   Channel ID: {channel_id}")
    print(f"   Video ID: {video_id}")
    print(f"   Description: {description}")
    print()
    
    # Check if this is the right channel by looking at its description
    if "Want to learn the latest and best ways to use AI" in description:
        print("   ✅ THIS IS THE RIGHT CHANNEL!")
        correct_channel_id = channel_id
        print(f"   Use this Channel ID: {correct_channel_id}")
# Out:
# Found 10 videos:
#
# 1. Video: How to Actually Use Claude Design Like a Pro | Claude Design Tutorial
#    Channel: Ferdy․com | Ferdy Korpershoek
#    Channel ID: UCZpkfpfGe2ZC3AIQ69ERCJw
#    Video ID: 3ZBY7oVZpuM
#    Description: Want to create a beautiful, professional website without hiring a designer or writing code? In this step-by-step tutorial, I'll show you ...
#
# 2. Video: How to Use Claude Design To Make Sites 10X More Beautiful
#    Channel: Mikey Website
#    Channel ID: UCSSB338C8A9ZOXtsbfM7phg
#    Video ID: y2n1NMrMNBo
#    Description: Claim your FREE $499 Masterclass: Build & Sell Apps, AI Agents & Websites with AI https://mikeyno-code.com/Skool-base44 In ...
#
# 3. Video: Claude Design 2.0 Just Changed Everything...
#    Channel: Jack Roberts
#    Channel ID: UCxVxcTULO9cFU6SB9qVaisQ
#    Video ID: 58CQM6I6DZg
#    Description: Firecrawl: https://bit.ly/4aHCD8A ALL Systems: https://bit.ly/4kol0y5 🎙️ Glaido: https://bit.ly/4eGoI3R Claude Design 2.0 just ...
#
# 4. Video: Claude Design: Everything You Can Build in 16 Minutes (5 Real Use Cases)
#    Channel: Peter Yang
#    Channel ID: UCnpBg7yqNauHtlNSpOl5-cg
#    Video ID: WMnk1LFBMqA
#    Description: Today, I want to share a hands-on review of Claude Design, Anthropic's brand new AI design tool. I'll run through 5 real use cases ...
#
# 5. Video: Why Claude Design Is Already My Favorite
#    Channel: Matt Maher
#    Channel ID: UC6-EGajbNF0DPD9AJ8oQC1A
#    Video ID: PQTpkQIwBDE
#    Description: I sat down with Claude Design today expecting the usual — a few flashy demos, a polite review, move on. Three builds and one ...
#
# 6. Video: How to Actually Use Claude Design Like a Pro (Real Use Cases)
#    Channel: Ben AI
#    Channel ID: UC3KK7ENB_ierAXvrxVNnbZQ
#    Video ID: cl5Oudk3Hjo
#    Description: Get the FREE Design skills and resources mentioned in this video ⤵️ https://c.benai.co/htucd-free Join my AI Accelerator to get ...
#
# 7. Video: Master 95% of Claude Design in 17 Minutes
#    Channel: Brock Mesarich | AI for Non Techies
#    Channel ID: UCjc1vfduI7BhVMXBLJLDjmA
#    Video ID: e7ngdzwzRZ0
#    Description: Join My Skool Community: https://bit.ly/4errGKX ✓ Build Custom Claude Systems with My Team: https://bit.ly/4bRondh Claude ...
#
# 8. Video: Claude Design is NOT what you think
#    Channel: Malewicz
#    Channel ID: UC_Dq0oUEi7uXhdUX8prunbw
#    Video ID: IkspcJdeP3U
#    Description: Anthropic has just announced Claude Design. Pushed to production on a Friday. This is their own, Claude powered design tool.
#
# 9. Video: Claude Design + Claude Code = No Designer Needed
#    Channel: Leon van Zyl
#    Channel ID: UCtevzRsHEKhs-RK8pAqwSyQ
#    Video ID: -W8uYEX4gLQ
#    Description: Ready to level up? Get full access to my Agentic Coding Masterclass, weekly lab challenges, live Q&As, and a community of ...
#
# 10. Video: The ONLY Claude Design Guide You Should Watch
#    Channel: Chase AI
#    Channel ID: UCoy6cTJ7Tg0dqS-DI-_REsA
#    Video ID: iJRq1kLLRmY
#    Description: Master Claude Code, Build Your Agency, Land Your First Client⚡ https://www.skool.com/chase-ai FREE community with tons of ...

# %%
channel_id = 'UCY8ZKVxXj0FgIvSfeiSDclg'
#UCtZWlHoNRuo1PNk2ElAMPHg

# %% [markdown]
# # Diving into YouTube Analytics
# Deepnote presented a live stream featuring a showcase of how to use Google's YouTube API. We had a few Deepnote coders and a Deepnote user Allan who helped crack the API and start getting data. Below is a project inspired from that stream!
#
# In this notebook we are going to dive in and check out the popular YouTube channel Good Mythical Morning.

# %% [markdown]
# ## API Functions
# In this section we setup some API functions to help us gather data. We create a function to gather channel stats and video stats. To do this in a effecient way and save API calls we do not use the search function. We pull in GMM's upload playlist ( containing all of their videos ) and use that to build a video list. Then grab the data from each video.

# %%
# Function to get the channels stats
# It will also contain the upload playlist ID we can use to grab videos.
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    
    return response['items']

# %%
# This will get us a list of videos from a playlist.
# Note a page of results has a max value of 50 so we will
# need to loop over our results with a pageToken

def get_video_list(youtube, upload_id):
    video_list = []
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=upload_id,
        maxResults=50
    )
    next_page = True
    while next_page:
        response = request.execute()
        data = response['items']

        for video in data:
            video_id = video['contentDetails']['videoId']
            if video_id not in video_list:
                video_list.append(video_id)

        # Do we have more pages?
        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=upload_id,
                pageToken=response['nextPageToken'],
                maxResults=50
            )
        else:
            next_page = False

    return video_list

# %%
# new function
def get_video_details(youtube, video_list):
    stats_list = []

    # Can only get 50 videos at a time.
    for i in range(0, len(video_list), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_list[i:i+50]
        )

        data = request.execute()
        for video in data['items']:
            video_id = video['id']  # Extract video_id 
            title = video['snippet']['title']
            published = video['snippet']['publishedAt']
            description = video['snippet']['description']
            view_count = video['statistics'].get('viewCount', 0)
            like_count = video['statistics'].get('likeCount', 0)
            dislike_count = video['statistics'].get('dislikeCount', 0)
            comment_count = video['statistics'].get('commentCount', 0)
            duration = video['contentDetails'].get('duration', 'Unknown')  # Use .get() with a default value

            # Include video_id in the dictionary
            stats_dict = dict(
                video_id=video_id,
                title=title,
                description=description,
                published=published,
                view_count=view_count,
                like_count=like_count,
                dislike_count=dislike_count,
                comment_count=comment_count,
                duration=duration             
            )
            stats_list.append(stats_dict)

    return stats_list

# %%
def convert_iso_duration_to_hms(duration):
    """
    Converts an ISO 8601 duration string (e.g., 'PT3M54S') to 'H:M:S' format.
    
    Args:
        duration (str): The ISO 8601 duration string (e.g., 'PT3M54S').
    
    Returns:
        str: The duration in 'H:M:S' format.
    """
    # Regex to extract hours, minutes, and seconds from the ISO 8601 duration
    pattern = re.compile(r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?')
    match = pattern.match(duration)
    
    if not match:
        return "0:00:00"  # Default if the format is invalid
    
    # Extract hours, minutes, and seconds
    hours = int(match.group(1)) if match.group(1) else 0
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    
    # Create a timedelta object
    delta = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    
    # Convert to total seconds
    total_seconds = int(delta.total_seconds())
    
    # Convert total seconds to H:M:S format
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    
    return f"{hours}:{minutes:02d}:{seconds:02d}"

# %% [markdown]
# ## Create our Channel Stats

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %% [markdown]
# ## Find our Upload Playlist ( will contain all video uploads )

# %%
upload_id = channel_stats[0]['contentDetails']['relatedPlaylists']['uploads']
upload_id
# Out:
# 'UUY8ZKVxXj0FgIvSfeiSDclg'

# %% [markdown]
# ## Get our Video List

# %%
def get_all_channel_videos_direct(youtube, channel_id, max_results=100):
    """
    Get videos directly using search API instead of uploads playlist
    """
    video_list = []
    next_page_token = None
    
    while len(video_list) < max_results:
        search_request = youtube.search().list(
            channelId=channel_id,
            type='video',
            part='id,snippet',
            maxResults=50,
            pageToken=next_page_token,
            order='date'  # Get most recent videos first
        )
        search_response = search_request.execute()
        
        for item in search_response['items']:
            video_id = item['id']['videoId']
            if video_id not in video_list:
                video_list.append(video_id)
        
        next_page_token = search_response.get('nextPageToken')
        if not next_page_token or len(video_list) >= max_results:
            break
    
    return video_list

# Test with your channel ID
YOUR_CHANNEL_ID = 'UCsv6YMh5kLhixuepSEzHKzg'  # Replace with the correct ID

# Get videos directly
video_list = get_all_channel_videos_direct(youtube, YOUR_CHANNEL_ID)
print(f"Found {len(video_list)} videos")

# Get video details
video_data = get_video_details(youtube, video_list)
df = pd.DataFrame(video_data)
print(f"Fetched details for {len(df)} videos")
# Out:
# Found 51 videos
# Fetched details for 51 videos

# %%
video_list = get_video_list(youtube, upload_id)

# %% [markdown]
# ## Get our Video Details
# Finally we will get all of our videos details returned in a dictionary.

# %%
video_data = get_video_details(youtube, video_list)
'Number 0f Videos: ' + str(len(video_data))
# Out:
# 'Number 0f Videos: 70'

# %% [markdown]
# ## Pause and think what to do next

# %%
df=pd.DataFrame(video_data)
df.shape
# Out:
# (70, 9)

# %%
df['title_length'] = df['title'].str.len()
df["view_count"] = pd.to_numeric(df["view_count"])
df["like_count"] = pd.to_numeric(df["like_count"])
df["dislike_count"] = pd.to_numeric(df["dislike_count"])
df["comment_count"] = pd.to_numeric(df["comment_count"])
df["published"] = pd.to_datetime(df["published"])
# Format the 'published' column to "%Y-%m-%d"
df["published"] = df["published"].dt.strftime("%Y-%m-%d")
# reaction used later add up likes + dislikes + comments
df["reactions"] = df["like_count"] + df["dislike_count"] + df["comment_count"] + df["comment_count"]
df['hms_format'] = df['duration'].apply(convert_iso_duration_to_hms)

# %%
# Select rows where the title contains "Animation Maker"
result = df
#result = df.query('title.str.lower().str.contains("opencode")', engine='python')
result.shape
# Out:
# (70, 12)

# %%
# Filter your existing dataframe for the specific video
specific_video = df[df['title'].str.contains("Claude Design Is ABSURD", case=False, na=False)]

if not specific_video.empty:
    print(f"Found {len(specific_video)} matching videos:")
    display(specific_video[cols])
else:
    print("Video not found in current dataset. Try refreshing your video list.")
# Out:
# Found 1 matching videos:
#        video_id                    title   published  view_count  \
# 32  SzUi_PJwnKY  Claude Design Is ABSURD  2026-04-18        8164
#
#     title_length hms_format
# 32            23    0:10:30

# %%
cols = 'video_id title published view_count title_length hms_format'.split()

# %%
# Retrieve the maximum value from the title_length column
max_title_length = result['title_length'].max()
print("Maximum title length:", max_title_length)
# Set pandas column display width to the maximum title_length value
pd.set_option('display.max_colwidth', max_title_length)
result[cols].sort_values(by='published', ascending=False).head(30)
# Out:
# Maximum title length: 100
#        video_id  \
# 0   5QQXbeYwIwU
# 1   lPP6iBRuzgA
# 2   1njjOIiA8Kc
# 3   rdqgMNjvhMY
# 4   ke3LJ6lpluI
# 5   HhWwllcbc2g
# 6   2PH9f6yM8KI
# 7   q4dqFC7hf1c
# 8   MosF8v77YTw
# 9   JbW6a71DsDw
# 10  YD_XyZcXO6w
# 11  uPmy2ERmkVU
# 12  0Pf5GSCjfj4
# 13  TzJCly4YgDQ
# 14  B9fFEucPNnA
# 15  xmNulT55Bak
# 16  9EiG26FMcZk
# 17  mjfQQYVUv8k
# 18  f6C5wvXjn5k
# 19  M8JyCenl2-w
# 20  C7nSfD8DHAI
# 21  a8xPIfJpEOI
# 22  zwSZenzc6nc
# 23  J8HplfBVpHk
# 24  WF-hfYJhUWQ
# 25  XL9aYGUuEb4
# 26  1ZHxkiSZneA
# 27  vNOLPwiQ-uY
# 28  YyTkPNxevAo
# 29  RyqP972maEw
#
#                                                                          title  \
# 0                            GLM 5.2 vs Kimi K3: Which Open Source Model Wins?
# 1                                     Kimi K3 Is Here! (Better Than Opus 4.8?)
# 2                  I Made GPT 5.6 and Fable 5 Build the Same App (RAW RESULTS)
# 3                                   GPT 5.6 Sol: No-Hype Full Review & Testing
# 4                         Practicing Spanish with the new GPT-Live (it’s good)
# 5                         Claude Fable 5 Just Built the Ultimate Agent Harness
# 6                           Fable 5 Is BACK. And It Just Built This Mobile App
# 7                                 Fable 5 Is BACK And It Just One Shotted THIS
# 8                            Claude Sonnet 5: No Hype Full Breakdown & Testing
# 9                   Is GLM 5.2 ACTUALLY Better Than Opus 4.8? (Full Breakdown)
# 10                                   They're Banning The Best AI. Do This Now.
# 11                            Claude Just Became A CRACKED Video Game Designer
# 12           GPT Realtime 2 Can Now Run Your Entire Computer (Just Your Voice)
# 13                I Made Opus 4.8 and Fable 5 Build the Same App (RAW RESULTS)
# 14                            Claude Fable 5: No Hype Full Breakdown & Testing
# 15                              Watch Opus 4.8 Clone a $1.2B App in 19 Minutes
# 16  Codex Just Quietly Changed How People Work FOREVER (Role Specific Plugins)
# 17                   Did OpenAI Just Kill Every Website Builder? (Codex Sites)
# 18                     I Tried Claude's New Dynamic Workflows (Honest Results)
# 19                 Zero To Your First AI Agent In 10 Minutes (no code, no n8n)
# 20                                        Claude Opus-4.8 Just Dropped, And...
# 21                                          Codex + Paper = INCREDIBLE Designs
# 22                            Codex + Hyperframes = INCREDIBLE Motion Graphics
# 23                   How to Build AI Agents in 2026: Ultimate Beginner’s Guide
# 24                         The 7 Codex Plugins I Use Everyday (Just Copy Them)
# 25                           Master 95% of Codex for Office Work (FULL COURSE)
# 26               I Tested GPT-5.5 vs Opus 4.7 on 8 Real Tasks. Here's Who Won.
# 27                              GPT 5.5 Full Review & 5 Mind-Blowing Use Cases
# 28                               Mini Max 2.7 + Nvidia Nims = FREE Claude Code
# 29                                  ChatGPT Images 2.0 is WILD - 50+ Use Cases
#
#      published  view_count  title_length hms_format
# 0   2026-07-21        5749            49    0:42:06
# 1   2026-07-17       21883            40    0:36:06
# 2   2026-07-11      106710            59    0:26:26
# 3   2026-07-10       51290            42    0:40:04
# 4   2026-07-09        3040            52    0:02:52
# 5   2026-07-07       43670            52    0:19:21
# 6   2026-07-03       41458            50    0:15:06
# 7   2026-07-02       22465            44    0:07:07
# 8   2026-07-01       24683            49    0:22:53
# 9   2026-06-30        2846            58    0:37:14
# 10  2026-06-27       10603            41    0:16:52
# 11  2026-06-24       20429            48    0:20:26
# 12  2026-06-17       17548            65    0:19:17
# 13  2026-06-11      920133            60    0:21:12
# 14  2026-06-10       75625            48    0:10:14
# 15  2026-06-08        8761            46    0:19:11
# 16  2026-06-05       20836            74    0:11:20
# 17  2026-06-03        7478            57    0:12:12
# 18  2026-05-30       41433            55    0:12:49
# 19  2026-05-29        1504            59    0:10:18
# 20  2026-05-28         836            36    0:11:51
# 21  2026-05-27        3902            34    0:22:33
# 22  2026-05-21        3687            48    0:14:31
# 23  2026-05-19        2505            57    0:49:27
# 24  2026-05-08        3471            51    0:27:11
# 25  2026-05-01        1178            49    0:46:16
# 26  2026-04-28         854            61    0:26:59
# 27  2026-04-24        2037            46    0:13:22
# 28  2026-04-23       16465            45    0:11:29
# 29  2026-04-22        1063            42    0:21:12

# %% [markdown]
# ## Most Viewed Videos

# %%
df_highest_views = result.nlargest(10, 'view_count')
df_highest_views['title'] = df_highest_views['title'].str[:94]
df_highest_views['view_count_millions'] = df_highest_views['view_count'] / 5000
df_highest_views[cols]
# Out:
#        video_id                                                         title  \
# 13  TzJCly4YgDQ  I Made Opus 4.8 and Fable 5 Build the Same App (RAW RESULTS)
# 2   1njjOIiA8Kc   I Made GPT 5.6 and Fable 5 Build the Same App (RAW RESULTS)
# 14  B9fFEucPNnA              Claude Fable 5: No Hype Full Breakdown & Testing
# 3   rdqgMNjvhMY                    GPT 5.6 Sol: No-Hype Full Review & Testing
# 5   HhWwllcbc2g          Claude Fable 5 Just Built the Ultimate Agent Harness
# 6   2PH9f6yM8KI            Fable 5 Is BACK. And It Just Built This Mobile App
# 18  f6C5wvXjn5k       I Tried Claude's New Dynamic Workflows (Honest Results)
# 8   MosF8v77YTw             Claude Sonnet 5: No Hype Full Breakdown & Testing
# 7   q4dqFC7hf1c                  Fable 5 Is BACK And It Just One Shotted THIS
# 1   lPP6iBRuzgA                      Kimi K3 Is Here! (Better Than Opus 4.8?)
#
#      published  view_count  title_length hms_format
# 13  2026-06-11      920133            60    0:21:12
# 2   2026-07-11      106710            59    0:26:26
# 14  2026-06-10       75625            48    0:10:14
# 3   2026-07-10       51290            42    0:40:04
# 5   2026-07-07       43670            52    0:19:21
# 6   2026-07-03       41458            50    0:15:06
# 18  2026-05-30       41433            55    0:12:49
# 8   2026-07-01       24683            49    0:22:53
# 7   2026-07-02       22465            44    0:07:07
# 1   2026-07-17       21883            40    0:36:06

# %%
df_highest_views[cols].sort_values(by="published",ascending=False)
# Out:
#        video_id                                                         title  \
# 1   lPP6iBRuzgA                      Kimi K3 Is Here! (Better Than Opus 4.8?)
# 2   1njjOIiA8Kc   I Made GPT 5.6 and Fable 5 Build the Same App (RAW RESULTS)
# 3   rdqgMNjvhMY                    GPT 5.6 Sol: No-Hype Full Review & Testing
# 5   HhWwllcbc2g          Claude Fable 5 Just Built the Ultimate Agent Harness
# 6   2PH9f6yM8KI            Fable 5 Is BACK. And It Just Built This Mobile App
# 7   q4dqFC7hf1c                  Fable 5 Is BACK And It Just One Shotted THIS
# 8   MosF8v77YTw             Claude Sonnet 5: No Hype Full Breakdown & Testing
# 13  TzJCly4YgDQ  I Made Opus 4.8 and Fable 5 Build the Same App (RAW RESULTS)
# 14  B9fFEucPNnA              Claude Fable 5: No Hype Full Breakdown & Testing
# 18  f6C5wvXjn5k       I Tried Claude's New Dynamic Workflows (Honest Results)
#
#      published  view_count  title_length hms_format
# 1   2026-07-17       21883            40    0:36:06
# 2   2026-07-11      106710            59    0:26:26
# 3   2026-07-10       51290            42    0:40:04
# 5   2026-07-07       43670            52    0:19:21
# 6   2026-07-03       41458            50    0:15:06
# 7   2026-07-02       22465            44    0:07:07
# 8   2026-07-01       24683            49    0:22:53
# 13  2026-06-11      920133            60    0:21:12
# 14  2026-06-10       75625            48    0:10:14
# 18  2026-05-30       41433            55    0:12:49

# %%
# Set the figure size
sns.set(rc={'figure.figsize': (20, 10)})

# Create the barplot
plot = sns.barplot(
    x="view_count_millions", 
    y="title", 
    hue="title",  # Assign y variable to hue
    data=df_highest_views, 
    palette="bright", 
    legend=False  # Disable the legend
)

# Set labels and title
plot.set(xlabel='Millions of Views', ylabel='')
plot.set_title('Most Viewed Videos')

# Set x-axis limits
plt.xlim(20, 32)

# Show the plot
plt.show()

# %%
colt = 'video_id title published view_count hms_format'.split()
output_file = channel_name + '.csv'
result[colt].to_csv(output_file, index=None)
result[colt].sort_values(by="published",ascending=False)
# Out:
#        video_id                                                        title  \
# 0   5QQXbeYwIwU            GLM 5.2 vs Kimi K3: Which Open Source Model Wins?
# 1   lPP6iBRuzgA                     Kimi K3 Is Here! (Better Than Opus 4.8?)
# 2   1njjOIiA8Kc  I Made GPT 5.6 and Fable 5 Build the Same App (RAW RESULTS)
# 3   rdqgMNjvhMY                   GPT 5.6 Sol: No-Hype Full Review & Testing
# 4   ke3LJ6lpluI         Practicing Spanish with the new GPT-Live (it’s good)
# ..          ...                                                          ...
# 65  cvdL2oOVR1Q              35mm Street Photography | Composition Breakdown
# 66  gf9i6mK5OLg              Photographing Madrid’s Pride Parade | Fuji X-T5
# 67  1SSRamlANyI    7 Minutes of Photography in Buenos Aires’s Busiest Market
# 68  d82rrl493bY      Film Photography in Buenos Aires’s Busiest Neighborhood
# 69  sH2ayxcQxXc     POV Photography in Buenos Aires’s trendiest neighborhood
#
#      published  view_count hms_format
# 0   2026-07-21        5749    0:42:06
# 1   2026-07-17       21883    0:36:06
# 2   2026-07-11      106710    0:26:26
# 3   2026-07-10       51290    0:40:04
# 4   2026-07-09        3040    0:02:52
# ..         ...         ...        ...
# 65  2024-10-11         355    0:00:59
# 66  2024-10-10         139    0:00:40
# 67  2024-10-09         622    0:00:30
# 68  2024-10-03          62    0:00:24
# 69  2024-10-03         631    0:00:19
#
# [70 rows x 5 columns]

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Excel
xsl_path = os.path.join(base_path, "Excel")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Excel path (xsl_path): {xsl_path}")
# Out:
# User path: C:\Users\User
# Current path: C:\Users\User\OneDrive\A4\YouTube
# Base path: C:\Users\User\OneDrive\A4
# Excel path (xsl_path): C:\Users\User\OneDrive\A4\Excel

# %%
xsl_file = channel_name + '.xlsx'
xsl_file = os.path.join(xsl_path, xsl_file)
xsl_file
# Out:
# 'C:\\Users\\User\\OneDrive\\A4\\Excel\\per_simmons.xlsx'

# %%
colt = 'video_id title published view_count hms_format read'.split()
df_highest_views['read'] = 'N'
df_highest_views[colt].to_excel(xsl_file, index=False)
