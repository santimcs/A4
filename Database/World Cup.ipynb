# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/wc22_development"
)
wc22 = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/wc26_development"
)
wc26 = engine.connect()

output_path = "../data/"

# %%
sql = """
SELECT *
FROM teams LIMIT 1
"""
wc22_teams = pd.read_sql(sql, wc22)
wc22_teams.dtypes
# Out:
# id          int64
# name       object
# group      object
# ranking     int64
# flag       object
# year        int64
# dtype: object

# %%
sql = """
SELECT *
FROM teams LIMIT 1
"""
wc26_teams = pd.read_sql(sql, wc26)
wc26_teams.dtypes
# Out:
# id                        int64
# name                     object
# group                    object
# ranking                   int64
# flag                     object
# confederation            object
# created_at       datetime64[ns]
# updated_at       datetime64[ns]
# dtype: object

# %%
sql = """
SELECT *
FROM fixtures LIMIT 1
"""
wc22_fixtures = pd.read_sql(sql, wc22)
wc22_fixtures.dtypes
# Out:
# id                       int64
# round_id                 int64
# date                    object
# session_id               int64
# home_id                  int64
# away_id                  int64
# channel_id               int64
# criterium_id             int64
# created_at      datetime64[ns]
# updated_at      datetime64[ns]
# year                     int64
# dtype: object

# %%
sql = """
SELECT *
FROM fixtures LIMIT 1
"""
wc26_fixtures = pd.read_sql(sql, wc26)
wc26_fixtures.dtypes
# Out:
# id                       int64
# round_id                 int64
# date                    object
# session_id               int64
# home_team_id             int64
# away_team_id             int64
# channel_id               int64
# created_at      datetime64[ns]
# updated_at      datetime64[ns]
# criterium_id            object
# dtype: object

# %%
sql = """
SELECT *
FROM criteria LIMIT 1
"""
wc22_criteria = pd.read_sql(sql, wc22)
wc22_criteria.dtypes
# Out:
# id                     int64
# show_date             object
# created_at    datetime64[ns]
# updated_at    datetime64[ns]
# dtype: object

# %%
sql = """
SELECT *
FROM criteria LIMIT 1
"""
wc26_criteria = pd.read_sql(sql, wc26)
wc26_criteria.dtypes
# Out:
# id                     int64
# show_date             object
# created_at    datetime64[ns]
# updated_at    datetime64[ns]
# dtype: object

# %%
sql = """
SELECT *
FROM sessions LIMIT 1
"""
wc22_sessions = pd.read_sql(sql, wc22)
wc22_sessions.dtypes
# Out:
# id           int64
# sequence     int64
# time        object
# dtype: object

# %%
sql = """
SELECT *
FROM sessions LIMIT 1
"""
wc26_sessions = pd.read_sql(sql, wc26)
wc26_sessions.dtypes
# Out:
# id                     int64
# sequence               int64
# time                  object
# created_at    datetime64[ns]
# updated_at    datetime64[ns]
# dtype: object

# %%
sql = """
SELECT *
FROM sessions ORDER BY sequence
"""
wc26_sessions = pd.read_sql(sql, wc26)
wc26_sessions
# Out:
#     id  sequence      time                 created_at  \
# 0   31         1  00:00:00 2026-06-19 08:46:26.772329
# 1   32         2  00:30:00 2026-06-19 08:46:26.773309
# 2   33         3  01:00:00 2026-06-19 08:46:26.774298
# 3   34         4  01:30:00 2026-06-19 08:46:26.775277
# 4   35         5  02:00:00 2026-06-19 08:46:26.776257
# 5   36         6  02:30:00 2026-06-19 08:46:26.777242
# 6   37         7  03:00:00 2026-06-19 08:46:26.778222
# 7   38         8  03:30:00 2026-06-19 08:46:26.779211
# 8   39         9  04:00:00 2026-06-19 08:46:26.780194
# 9   40        10  04:30:00 2026-06-19 08:46:26.781174
# 10  41        11  05:00:00 2026-06-19 08:46:26.782209
# 11  42        12  05:30:00 2026-06-19 08:46:26.783202
# 12  43        13  06:00:00 2026-06-19 08:46:26.784287
# 13  44        14  06:30:00 2026-06-19 08:46:26.785269
# 14  45        15  07:00:00 2026-06-19 08:46:26.786251
# 15  46        16  07:30:00 2026-06-19 08:46:26.787334
# ...

# %%
sql = """
SELECT F.date, S.id, S.sequence
FROM fixtures F
JOIN sessions S ON F.session_id = S.id
ORDER BY date asc, S.sequence asc
"""
wc26_fixtures = pd.read_sql(sql, wc26)
wc26_fixtures
# Out:
#           date  id  sequence
# 0   2026-06-12  35         5
# 1   2026-06-12  49        19
# 2   2026-06-13  35         5
# 3   2026-06-13  47        17
# 4   2026-06-14  35         5
# ..         ...  ..       ...
# 67  2026-06-28  37         7
# 68  2026-06-28  43        13
# 69  2026-06-28  43        13
# 70  2026-06-28  49        19
# 71  2026-06-28  49        19
#
# [72 rows x 3 columns]
