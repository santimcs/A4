# %% [markdown]
# ### Modify last statement then Run all - statement: 24

# %% [markdown]
# ### Output files: buy-input
# ### Input files: prices-change

# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import * 
import calendar

pd.options.display.max_rows = 31
float_formatter = "฿{:,.2f}"

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

today = date.today()
print(today)
# Out:
# 2026-07-20

# %%
# If run after actual work day
#today = date(2026,6,18)
print(today)
# Out:
# 2026-07-20

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Daily
# Base path: C:\Users\PC1\OneDrive\A4
# Data path (dat_path): C:\Users\PC1\OneDrive\A4\Data
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}','price':'{:.2f}','price1':'{:.2f}','price2':'{:.2f}',
    'beta':'{:,.2f}','change':'{:.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%','%change':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}','volume':'{:,.0f}','shares':'{:,.0f}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}','amount':'{:,.2f}'
}

# %%
sql = '''
SELECT period, name, volbuy AS shares
FROM buy
WHERE active = 1
ORDER BY period, name'''
buy = pd.read_sql(sql, const)
buy['shares'] = buy['shares'].astype('int64')
buy.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa54b">
#   <thead>
#     <tr>
#       <th id="T_fa54b_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_fa54b_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_fa54b_level0_col2" class="col_heading level0 col2" >shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fa54b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_fa54b_row0_col1" class="data row0 col1" >PTTGC</td>
#       <td id="T_fa54b_row0_col2" class="data row0 col2" >6,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_fa54b_row1_col1" class="data row1 col1" >SINGER</td>
#       <td id="T_fa54b_row1_col2" class="data row1 col2" >6,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_fa54b_row2_col1" class="data row2 col1" >STA</td>
#       <td id="T_fa54b_row2_col2" class="data row2 col2" >10,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_fa54b_row3_col1" class="data row3 col1" >3BBIF</td>
#       <td id="T_fa54b_row3_col2" class="data row3 col2" >120,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_fa54b_row4_col1" class="data row4 col1" >AIMIRT</td>
#       <td id="T_fa54b_row4_col2" class="data row4 col2" >10,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_fa54b_row5_col1" class="data row5 col1" >CPNREIT</td>
#       <td id="T_fa54b_row5_col2" class="data row5 col2" >55,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_fa54b_row6_col1" class="data row6 col1" >DIF</td>
#       <td id="T_fa54b_row6_col2" class="data row6 col2" >45,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_fa54b_row7_col1" class="data row7 col1" >GVREIT</td>
#       <td id="T_fa54b_row7_col2" class="data row7 col2" >69,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_fa54b_row8_col1" class="data row8 col1" >MCS</td>
#       <td id="T_fa54b_row8_col2" class="data row8 col2" >75,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_fa54b_row9_col1" class="data row9 col1" >NER</td>
#       <td id="T_fa54b_row9_col2" class="data row9 col2" >27,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_fa54b_row10_col1" class="data row10 col1" >PROSPECT</td>
#       <td id="T_fa54b_row10_col2" class="data row10 col2" >20,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_fa54b_row11_col1" class="data row11 col1" >PTT</td>
#       <td id="T_fa54b_row11_col2" class="data row11 col2" >7,500</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_fa54b_row12_col1" class="data row12 col1" >SENA</td>
#       <td id="T_fa54b_row12_col2" class="data row12 col2" >105,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_fa54b_row13_col1" class="data row13 col1" >TFFIF</td>
#       <td id="T_fa54b_row13_col2" class="data row13 col2" >25,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_fa54b_row14_col1" class="data row14 col1" >WHAIR</td>
#       <td id="T_fa54b_row14_col2" class="data row14 col2" >50,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_fa54b_row15_col1" class="data row15 col1" >WHART</td>
#       <td id="T_fa54b_row15_col2" class="data row15 col2" >20,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_fa54b_row16_col1" class="data row16 col1" >ADVANC</td>
#       <td id="T_fa54b_row16_col2" class="data row16 col2" >400</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row17_col0" class="data row17 col0" >3</td>
#       <td id="T_fa54b_row17_col1" class="data row17 col1" >AH</td>
#       <td id="T_fa54b_row17_col2" class="data row17 col2" >1,200</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row18_col0" class="data row18 col0" >3</td>
#       <td id="T_fa54b_row18_col1" class="data row18 col1" >AWC</td>
#       <td id="T_fa54b_row18_col2" class="data row18 col2" >9,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row19_col0" class="data row19 col0" >3</td>
#       <td id="T_fa54b_row19_col1" class="data row19 col1" >BCH</td>
#       <td id="T_fa54b_row19_col2" class="data row19 col2" >4,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row20_col0" class="data row20 col0" >3</td>
#       <td id="T_fa54b_row20_col1" class="data row20 col1" >CPF</td>
#       <td id="T_fa54b_row20_col2" class="data row20 col2" >10,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row21_col0" class="data row21 col0" >3</td>
#       <td id="T_fa54b_row21_col1" class="data row21 col1" >PTG</td>
#       <td id="T_fa54b_row21_col2" class="data row21 col2" >3,600</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row22_col0" class="data row22 col0" >3</td>
#       <td id="T_fa54b_row22_col1" class="data row22 col1" >RCL</td>
#       <td id="T_fa54b_row22_col2" class="data row22 col2" >27,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row23_col0" class="data row23 col0" >3</td>
#       <td id="T_fa54b_row23_col1" class="data row23 col1" >SYNEX</td>
#       <td id="T_fa54b_row23_col2" class="data row23 col2" >17,500</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row24_col0" class="data row24 col0" >3</td>
#       <td id="T_fa54b_row24_col1" class="data row24 col1" >TOA</td>
#       <td id="T_fa54b_row24_col2" class="data row24 col2" >1,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row25_col0" class="data row25 col0" >3</td>
#       <td id="T_fa54b_row25_col1" class="data row25 col1" >TVO</td>
#       <td id="T_fa54b_row25_col2" class="data row25 col2" >4,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row26_col0" class="data row26 col0" >4</td>
#       <td id="T_fa54b_row26_col1" class="data row26 col1" >IVL</td>
#       <td id="T_fa54b_row26_col2" class="data row26 col2" >7,200</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row27_col0" class="data row27 col0" >4</td>
#       <td id="T_fa54b_row27_col1" class="data row27 col1" >JMT</td>
#       <td id="T_fa54b_row27_col2" class="data row27 col2" >7,000</td>
#     </tr>
#     <tr>
#       <td id="T_fa54b_row28_col0" class="data row28 col0" >4</td>
#       <td id="T_fa54b_row28_col1" class="data row28 col1" >ORI</td>
#       <td id="T_fa54b_row28_col2" class="data row28 col2" >50,000</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = "buy-input.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file: {output_file}") 
print(f"icd_file (icd_file): {icd_file}") 
print(f"god_file (god_file): {god_file}") 
print(f"osd_file (osd_file): {osd_file}")
# Out:
# Output file: C:\Users\PC1\OneDrive\A4\Data\buy-input.csv
# icd_file (icd_file): C:\Users\PC1\iCloudDrive\Data\buy-input.csv
# god_file (god_file): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\buy-input.csv
# osd_file (osd_file): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\buy-input.csv

# %%
buy.to_csv(output_file, index=False)
buy.to_csv(god_file, index=False)
buy.to_csv(icd_file, index=False)
buy.to_csv(osd_file, index=False)

# %% [markdown]
# ### Call ruby ruby\find-change-fm-2-dates.rb

# %%
# Extract the last folder from the base directory
last_folder = os.path.basename(base_path)
print(f"Last Folder: {last_folder}")
# Out:
# Last Folder: A4

# %%
# Change to the derived directory (optional)
os.chdir(base_path)
# %pwd
# Out:
# 'C:\\Users\\PC1\\OneDrive\\A4'

# %%
# !ruby ruby\\find-change-fm-2-dates.rb '2025-12-30' '{today}' '{last_folder}'
# Out:
#     period       name     shares      date1      date2     price1     price2     change    %change     amount        spd
#          1      PTTGC       6000   25-12-30   26-07-20      21.00      37.00      16.00      76.19  96,000.00         88
#          1     SINGER       6000   25-12-30   26-07-20       4.88      12.60       7.72     158.20  46,320.00        132
#          1        STA      10000   25-12-30   26-07-20      12.20      18.70       6.50      53.28  65,000.00         65
#          2      3BBIF     120000   25-12-30   26-07-20       6.30       6.60       0.30       4.76  36,000.00          6
#          2     AIMIRT      10000   25-12-30   26-07-20      10.90      12.20       1.30      11.93  13,000.00         13
#          2    CPNREIT      55000   25-12-30   26-07-20      11.30      13.50       2.20      19.47 121,000.00         22
#          2        DIF      45000   25-12-30   26-07-20       9.45      10.30       0.85       8.99  38,250.00         14
#          2     GVREIT      69000   25-12-30   26-07-20       6.75       8.50       1.75      25.93 120,750.00         35
#          2        MCS      75000   25-12-30   26-07-20       8.35       8.00      -0.35      -4.19 -26,250.00         -7
#          2        NER      27000   25-12-30   26-07-20       4.48       4.54       0.06       1.34   1,620.00          3
#          2   PROSPECT      20000   25-12-30   26-07-20       9.30      10.50       1.20      12.90  24,000.00         18
#          2        PTT       7500   25-12-30   26-07-20      32.00      39.25       7.25      22.66  54,375.00         29
#          2       SENA     105000   25-12-30   26-07-20       1.69       1.81       0.12       7.10  12,600.00         12
#          2      TFFIF      25000   25-12-30   26-07-20       6.25       6.85       0.60       9.60  15,000.00         12
#          2      WHAIR      50000   25-12-30   26-07-20       6.15       8.10       1.95      31.71  97,500.00         39
#          2      WHART      20000   25-12-30   26-07-20      10.70      11.10       0.40       3.74   8,000.00          4
#          3     ADVANC        400   25-12-30   26-07-20     313.00     383.00      70.00      22.36  28,000.00         70
#          3         AH       1200   25-12-30   26-07-20      12.60      15.20       2.60      20.63   3,120.00         26
#          3        AWC       9000   25-12-30   26-07-20       2.12       2.82       0.70      33.02   6,300.00         35
#          3        BCH       4000   25-12-30   26-07-20      10.40      10.80       0.40       3.85   1,600.00          4
#          3        CPF      10000   25-12-30   26-07-20      21.80      22.40       0.60       2.75   6,000.00          6
#          3        PTG       3600   25-12-30   26-07-20       7.10       7.85       0.75      10.56   2,700.00         15
#          3        RCL      27000   25-12-30   26-07-20      27.25      33.25       6.00      22.02 162,000.00         24
#          3      SYNEX      17500   25-12-30   26-07-20       9.95       9.75      -0.20      -2.01  -3,500.00         -4
#          3        TOA       1000   25-12-30   26-07-20      13.60      15.60       2.00      14.71   2,000.00         20
#          3        TVO       4000   25-12-30   26-07-20      22.40      27.00       4.60      20.54  18,400.00         34
#          4        IVL       7200   25-12-30   26-07-20      16.10      24.60       8.50      52.80  61,200.00         85
#          4        JMT       7000   25-12-30   26-07-20       8.75      12.10       3.35      38.29  23,450.00         46
#          4        ORI      50000   25-12-30   26-07-20       1.79       2.02       0.23      12.85  11,500.00         21

# %%
os.chdir(current_path)
# %pwd
# Out:
# 'C:\\Users\\PC1\\OneDrive\\A4\\Daily'

# %%
file_name   = 'prices-change.csv'
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A4\Data\prices-change.csv

# %%
df = pd.read_csv(input_file, sep=',', index_col=None)
df.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8150f">
#   <thead>
#     <tr>
#       <th id="T_8150f_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_8150f_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_8150f_level0_col2" class="col_heading level0 col2" >shares</th>
#       <th id="T_8150f_level0_col3" class="col_heading level0 col3" >date1</th>
#       <th id="T_8150f_level0_col4" class="col_heading level0 col4" >date2</th>
#       <th id="T_8150f_level0_col5" class="col_heading level0 col5" >price1</th>
#       <th id="T_8150f_level0_col6" class="col_heading level0 col6" >price2</th>
#       <th id="T_8150f_level0_col7" class="col_heading level0 col7" >change</th>
#       <th id="T_8150f_level0_col8" class="col_heading level0 col8" >%change</th>
#       <th id="T_8150f_level0_col9" class="col_heading level0 col9" >amount</th>
#       <th id="T_8150f_level0_col10" class="col_heading level0 col10" >spd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8150f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8150f_row0_col1" class="data row0 col1" >PTTGC</td>
#       <td id="T_8150f_row0_col2" class="data row0 col2" >6,000</td>
#       <td id="T_8150f_row0_col3" class="data row0 col3" >2025-12-30</td>
#       <td id="T_8150f_row0_col4" class="data row0 col4" >2026-07-20</td>
#       <td id="T_8150f_row0_col5" class="data row0 col5" >21.00</td>
#       <td id="T_8150f_row0_col6" class="data row0 col6" >37.00</td>
#       <td id="T_8150f_row0_col7" class="data row0 col7" >16.00</td>
#       <td id="T_8150f_row0_col8" class="data row0 col8" >76.19%</td>
#       <td id="T_8150f_row0_col9" class="data row0 col9" >96,000.00</td>
#       <td id="T_8150f_row0_col10" class="data row0 col10" >88</td>
#     </tr>
#     <tr>
#       <td id="T_8150f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8150f_row1_col1" class="data row1 col1" >SINGER</td>
#       <td id="T_8150f_row1_col2" class="data row1 col2" >6,000</td>
#       <td id="T_8150f_row1_col3" class="data row1 col3" >2025-12-30</td>
#       <td id="T_8150f_row1_col4" class="data row1 col4" >2026-07-20</td>
#       <td id="T_8150f_row1_col5" class="data row1 col5" >4.88</td>
#       <td id="T_8150f_row1_col6" class="data row1 col6" >12.60</td>
#       <td id="T_8150f_row1_col7" class="data row1 col7" >7.72</td>
#       <td id="T_8150f_row1_col8" class="data row1 col8" >158.20%</td>
#       <td id="T_8150f_row1_col9" class="data row1 col9" >46,320.00</td>
#       <td id="T_8150f_row1_col10" class="data row1 col10" >132</td>
#     </tr>
#     <tr>
#       <td id="T_8150f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_8150f_row2_col1" class="data row2 col1" >STA</td>
#       <td id="T_8150f_row2_col2" class="data row2 col2" >10,000</td>
#       <td id="T_8150f_row2_col3" class="data row2 col3" >2025-12-30</td>
#       <td id="T_8150f_row2_col4" class="data row2 col4" >2026-07-20</td>
#       <td id="T_8150f_row2_col5" class="data row2 col5" >12.20</td>
#       <td id="T_8150f_row2_col6" class="data row2 col6" >18.70</td>
#       <td id="T_8150f_row2_col7" class="data row2 col7" >6.50</td>
#       <td id="T_8150f_row2_col8" class="data row2 col8" >53.28%</td>
#       <td id="T_8150f_row2_col9" class="data row2 col9" >65,000.00</td>
#       <td id="T_8150f_row2_col10" class="data row2 col10" >65</td>
#     </tr>
#     <tr>
#       <td id="T_8150f_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_8150f_row3_col1" class="data row3 col1" >3BBIF</td>
#       <td id="T_8150f_row3_col2" class="data row3 col2" >120,000</td>
#       <td id="T_8150f_row3_col3" class="data row3 col3" >2025-12-30</td>
#       <td id="T_8150f_row3_col4" class="data row3 col4" >2026-07-20</td>
#       <td id="T_8150f_row3_col5" class="data row3 col5" >6.30</td>
#       <td id="T_8150f_row3_col6" class="data row3 col6" >6.60</td>
#       <td id="T_8150f_row3_col7" class="data row3 col7" >0.30</td>
#       <td id="T_8150f_row3_col8" class="data row3 col8" >4.76%</td>
#       <td id="T_8150f_row3_col9" class="data row3 col9" >36,000.00</td>
#       <td id="T_8150f_row3_col10" class="data row3 col10" >6</td>
#     </tr>
#     <tr>
#       <td id="T_8150f_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_8150f_row4_col1" class="data row4 col1" >AIMIRT</td>
#       <td id="T_8150f_row4_col2" class="data row4 col2" >10,000</td>
#       <td id="T_8150f_row4_col3" class="data row4 col3" >2025-12-30</td>
#       <td id="T_8150f_row4_col4" class="data row4 col4" >2026-07-20</td>
#       <td id="T_8150f_row4_col5" class="data row4 col5" >10.90</td>
#       <td id="T_8150f_row4_col6" class="data row4 col6" >12.20</td>
#       <td id="T_8150f_row4_col7" class="data row4 col7" >1.30</td>
#       <td id="T_8150f_row4_col8" class="data row4 col8" >11.93%</td>
#       <td id="T_8150f_row4_col9" class="data row4 col9" >13,000.00</td>
#       <td id="T_8150f_row4_col10" class="data row4 col10" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (29, 11)

# %%
df.sort_values(['spd'],ascending=True).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_632e0">
#   <thead>
#     <tr>
#       <th id="T_632e0_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_632e0_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_632e0_level0_col2" class="col_heading level0 col2" >shares</th>
#       <th id="T_632e0_level0_col3" class="col_heading level0 col3" >date1</th>
#       <th id="T_632e0_level0_col4" class="col_heading level0 col4" >date2</th>
#       <th id="T_632e0_level0_col5" class="col_heading level0 col5" >price1</th>
#       <th id="T_632e0_level0_col6" class="col_heading level0 col6" >price2</th>
#       <th id="T_632e0_level0_col7" class="col_heading level0 col7" >change</th>
#       <th id="T_632e0_level0_col8" class="col_heading level0 col8" >%change</th>
#       <th id="T_632e0_level0_col9" class="col_heading level0 col9" >amount</th>
#       <th id="T_632e0_level0_col10" class="col_heading level0 col10" >spd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_632e0_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_632e0_row0_col1" class="data row0 col1" >MCS</td>
#       <td id="T_632e0_row0_col2" class="data row0 col2" >75,000</td>
#       <td id="T_632e0_row0_col3" class="data row0 col3" >2025-12-30</td>
#       <td id="T_632e0_row0_col4" class="data row0 col4" >2026-07-20</td>
#       <td id="T_632e0_row0_col5" class="data row0 col5" >8.35</td>
#       <td id="T_632e0_row0_col6" class="data row0 col6" >8.00</td>
#       <td id="T_632e0_row0_col7" class="data row0 col7" >-0.35</td>
#       <td id="T_632e0_row0_col8" class="data row0 col8" >-4.19%</td>
#       <td id="T_632e0_row0_col9" class="data row0 col9" >-26,250.00</td>
#       <td id="T_632e0_row0_col10" class="data row0 col10" >-7</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_632e0_row1_col1" class="data row1 col1" >SYNEX</td>
#       <td id="T_632e0_row1_col2" class="data row1 col2" >17,500</td>
#       <td id="T_632e0_row1_col3" class="data row1 col3" >2025-12-30</td>
#       <td id="T_632e0_row1_col4" class="data row1 col4" >2026-07-20</td>
#       <td id="T_632e0_row1_col5" class="data row1 col5" >9.95</td>
#       <td id="T_632e0_row1_col6" class="data row1 col6" >9.75</td>
#       <td id="T_632e0_row1_col7" class="data row1 col7" >-0.20</td>
#       <td id="T_632e0_row1_col8" class="data row1 col8" >-2.01%</td>
#       <td id="T_632e0_row1_col9" class="data row1 col9" >-3,500.00</td>
#       <td id="T_632e0_row1_col10" class="data row1 col10" >-4</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_632e0_row2_col1" class="data row2 col1" >NER</td>
#       <td id="T_632e0_row2_col2" class="data row2 col2" >27,000</td>
#       <td id="T_632e0_row2_col3" class="data row2 col3" >2025-12-30</td>
#       <td id="T_632e0_row2_col4" class="data row2 col4" >2026-07-20</td>
#       <td id="T_632e0_row2_col5" class="data row2 col5" >4.48</td>
#       <td id="T_632e0_row2_col6" class="data row2 col6" >4.54</td>
#       <td id="T_632e0_row2_col7" class="data row2 col7" >0.06</td>
#       <td id="T_632e0_row2_col8" class="data row2 col8" >1.34%</td>
#       <td id="T_632e0_row2_col9" class="data row2 col9" >1,620.00</td>
#       <td id="T_632e0_row2_col10" class="data row2 col10" >3</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_632e0_row3_col1" class="data row3 col1" >BCH</td>
#       <td id="T_632e0_row3_col2" class="data row3 col2" >4,000</td>
#       <td id="T_632e0_row3_col3" class="data row3 col3" >2025-12-30</td>
#       <td id="T_632e0_row3_col4" class="data row3 col4" >2026-07-20</td>
#       <td id="T_632e0_row3_col5" class="data row3 col5" >10.40</td>
#       <td id="T_632e0_row3_col6" class="data row3 col6" >10.80</td>
#       <td id="T_632e0_row3_col7" class="data row3 col7" >0.40</td>
#       <td id="T_632e0_row3_col8" class="data row3 col8" >3.85%</td>
#       <td id="T_632e0_row3_col9" class="data row3 col9" >1,600.00</td>
#       <td id="T_632e0_row3_col10" class="data row3 col10" >4</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_632e0_row4_col1" class="data row4 col1" >WHART</td>
#       <td id="T_632e0_row4_col2" class="data row4 col2" >20,000</td>
#       <td id="T_632e0_row4_col3" class="data row4 col3" >2025-12-30</td>
#       <td id="T_632e0_row4_col4" class="data row4 col4" >2026-07-20</td>
#       <td id="T_632e0_row4_col5" class="data row4 col5" >10.70</td>
#       <td id="T_632e0_row4_col6" class="data row4 col6" >11.10</td>
#       <td id="T_632e0_row4_col7" class="data row4 col7" >0.40</td>
#       <td id="T_632e0_row4_col8" class="data row4 col8" >3.74%</td>
#       <td id="T_632e0_row4_col9" class="data row4 col9" >8,000.00</td>
#       <td id="T_632e0_row4_col10" class="data row4 col10" >4</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_632e0_row5_col1" class="data row5 col1" >3BBIF</td>
#       <td id="T_632e0_row5_col2" class="data row5 col2" >120,000</td>
#       <td id="T_632e0_row5_col3" class="data row5 col3" >2025-12-30</td>
#       <td id="T_632e0_row5_col4" class="data row5 col4" >2026-07-20</td>
#       <td id="T_632e0_row5_col5" class="data row5 col5" >6.30</td>
#       <td id="T_632e0_row5_col6" class="data row5 col6" >6.60</td>
#       <td id="T_632e0_row5_col7" class="data row5 col7" >0.30</td>
#       <td id="T_632e0_row5_col8" class="data row5 col8" >4.76%</td>
#       <td id="T_632e0_row5_col9" class="data row5 col9" >36,000.00</td>
#       <td id="T_632e0_row5_col10" class="data row5 col10" >6</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_632e0_row6_col1" class="data row6 col1" >CPF</td>
#       <td id="T_632e0_row6_col2" class="data row6 col2" >10,000</td>
#       <td id="T_632e0_row6_col3" class="data row6 col3" >2025-12-30</td>
#       <td id="T_632e0_row6_col4" class="data row6 col4" >2026-07-20</td>
#       <td id="T_632e0_row6_col5" class="data row6 col5" >21.80</td>
#       <td id="T_632e0_row6_col6" class="data row6 col6" >22.40</td>
#       <td id="T_632e0_row6_col7" class="data row6 col7" >0.60</td>
#       <td id="T_632e0_row6_col8" class="data row6 col8" >2.75%</td>
#       <td id="T_632e0_row6_col9" class="data row6 col9" >6,000.00</td>
#       <td id="T_632e0_row6_col10" class="data row6 col10" >6</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_632e0_row7_col1" class="data row7 col1" >TFFIF</td>
#       <td id="T_632e0_row7_col2" class="data row7 col2" >25,000</td>
#       <td id="T_632e0_row7_col3" class="data row7 col3" >2025-12-30</td>
#       <td id="T_632e0_row7_col4" class="data row7 col4" >2026-07-20</td>
#       <td id="T_632e0_row7_col5" class="data row7 col5" >6.25</td>
#       <td id="T_632e0_row7_col6" class="data row7 col6" >6.85</td>
#       <td id="T_632e0_row7_col7" class="data row7 col7" >0.60</td>
#       <td id="T_632e0_row7_col8" class="data row7 col8" >9.60%</td>
#       <td id="T_632e0_row7_col9" class="data row7 col9" >15,000.00</td>
#       <td id="T_632e0_row7_col10" class="data row7 col10" >12</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_632e0_row8_col1" class="data row8 col1" >SENA</td>
#       <td id="T_632e0_row8_col2" class="data row8 col2" >105,000</td>
#       <td id="T_632e0_row8_col3" class="data row8 col3" >2025-12-30</td>
#       <td id="T_632e0_row8_col4" class="data row8 col4" >2026-07-20</td>
#       <td id="T_632e0_row8_col5" class="data row8 col5" >1.69</td>
#       <td id="T_632e0_row8_col6" class="data row8 col6" >1.81</td>
#       <td id="T_632e0_row8_col7" class="data row8 col7" >0.12</td>
#       <td id="T_632e0_row8_col8" class="data row8 col8" >7.10%</td>
#       <td id="T_632e0_row8_col9" class="data row8 col9" >12,600.00</td>
#       <td id="T_632e0_row8_col10" class="data row8 col10" >12</td>
#     </tr>
#     <tr>
#       <td id="T_632e0_row9_col0" class="data row9 c

# %%
# Group by 'period' and sum only specific columns
result = df.groupby('period')[['shares', 'amount', 'spd']].sum()
print(result)
# Out:
#         shares    amount  spd
# period
# 1        22000  207320.0  285
# 2       628500  515845.0  200
# 3        77700  226620.0  230
# 4        64200   96150.0  152

# %%
df.groupby('period').agg(
      ttl_shr = pd.NamedAgg('shares', 'sum'),
      avr_p1  = pd.NamedAgg('price1','mean'),
      avr_p2  = pd.NamedAgg('price2','mean'),  
      avr_chg = pd.NamedAgg('change','mean'),
      avr_spd = pd.NamedAgg('spd','mean'),
      ttl_amt = pd.NamedAgg('amount', 'sum')
   )
# Out:
#         ttl_shr     avr_p1     avr_p2    avr_chg    avr_spd   ttl_amt
# period
# 1         22000  12.693333  22.766667  10.073333  95.000000  207320.0
# 2        628500   9.509231  10.865385   1.356154  15.384615  515845.0
# 3         77700  44.022000  52.767000   8.745000  23.000000  226620.0
# 4         64200   8.880000  12.906667   4.026667  50.666667   96150.0

# %%
pl = df.amount.sum()
float_formatter.format(pl)
# Out:
# '฿1,045,935.00'

# %%
prev_pl = 1_045_935
diff = pl - prev_pl
float_formatter.format(diff)
# Out:
# '฿64,290.00'

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-07-20 21:17:40
