# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
print(today)
# Out:
# 2026-07-20

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(today, yesterday)
# Out:
# 2026-07-20 2026-07-17

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-07-20 21:15:42

# %% [markdown]
# ### Restart and run all cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Daily
# Base path: C:\Users\PC1\OneDrive\A4
# Data path : C:\Users\PC1\OneDrive\A4\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}', 'volbuy':'{:,}',   
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}',
    'opnp':'{:.2f}','price_x':'{:.2f}','price_y':'{:.2f}',
    'price_today':'{:.2f}','price_yesterday':'{:.2f}',   
    'date':'{:%Y-%m-%d}',
    
    'price_mean':'{:.2f}','price_today':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}','dividend':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_mean':'{:,}','qty_today':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}','daily_volume':'{:,.2f}',   
    'value(m)':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2026, 7, 20)

# %%
sql = f"""
SELECT * 
FROM price 
WHERE date = '{today}'
ORDER BY name
"""
print(sql)

prices = pd.read_sql(sql, const)
#prices.sample(5).style.format(format_dict)
prices.shape
# Out:
# SELECT *
# FROM price
# WHERE date = '2026-07-20'
# ORDER BY name
# (160, 7)

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a3cf">
#   <thead>
#     <tr>
#       <th id="T_1a3cf_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_1a3cf_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1a3cf_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_1a3cf_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_1a3cf_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_1a3cf_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_1a3cf_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_1a3cf_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_1a3cf_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_1a3cf_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_1a3cf_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_1a3cf_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_1a3cf_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_1a3cf_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_1a3cf_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1a3cf_row0_col0" class="data row0 col0" >790</td>
#       <td id="T_1a3cf_row0_col1" class="data row0 col1" >GC</td>
#       <td id="T_1a3cf_row0_col2" class="data row0 col2" >SET    </td>
#       <td id="T_1a3cf_row0_col3" class="data row0 col3" >4.98</td>
#       <td id="T_1a3cf_row0_col4" class="data row0 col4" >5.10</td>
#       <td id="T_1a3cf_row0_col5" class="data row0 col5" >3.50</td>
#       <td id="T_1a3cf_row0_col6" class="data row0 col6" >14.57</td>
#       <td id="T_1a3cf_row0_col7" class="data row0 col7" >4.64</td>
#       <td id="T_1a3cf_row0_col8" class="data row0 col8" >220.00</td>
#       <td id="T_1a3cf_row0_col9" class="data row0 col9" >2,530.00</td>
#       <td id="T_1a3cf_row0_col10" class="data row0 col10" >0.35</td>
#       <td id="T_1a3cf_row0_col11" class="data row0 col11" >1.08</td>
#       <td id="T_1a3cf_row0_col12" class="data row0 col12" >188</td>
#       <td id="T_1a3cf_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_1a3cf_row0_col14" class="data row0 col14" >2026-07-17</td>
#     </tr>
#     <tr>
#       <td id="T_1a3cf_row1_col0" class="data row1 col0" >923</td>
#       <td id="T_1a3cf_row1_col1" class="data row1 col1" >TOA</td>
#       <td id="T_1a3cf_row1_col2" class="data row1 col2" >SETTHSI    </td>
#       <td id="T_1a3cf_row1_col3" class="data row1 col3" >15.70</td>
#       <td id="T_1a3cf_row1_col4" class="data row1 col4" >16.40</td>
#       <td id="T_1a3cf_row1_col5" class="data row1 col5" >11.50</td>
#       <td id="T_1a3cf_row1_col6" class="data row1 col6" >42.37</td>
#       <td id="T_1a3cf_row1_col7" class="data row1 col7" >5.38</td>
#       <td id="T_1a3cf_row1_col8" class="data row1 col8" >2,029.00</td>
#       <td id="T_1a3cf_row1_col9" class="data row1 col9" >67,971.50</td>
#       <td id="T_1a3cf_row1_col10" class="data row1 col10" >117.78</td>
#       <td id="T_1a3cf_row1_col11" class="data row1 col11" >0.81</td>
#       <td id="T_1a3cf_row1_col12" class="data row1 col12" >562</td>
#       <td id="T_1a3cf_row1_col13" class="data row1 col13" >2022-05-17</td>
#       <td id="T_1a3cf_row1_col14" class="data row1 col14" >2026-07-17</td>
#     </tr>
#     <tr>
#       <td id="T_1a3cf_row2_col0" class="data row2 col0" >898</td>
#       <td id="T_1a3cf_row2_col1" class="data row2 col1" >STA</td>
#       <td id="T_1a3cf_row2_col2" class="data row2 col2" >SET100 / SETTHSI / SETWB    </td>
#       <td id="T_1a3cf_row2_col3" class="data row2 col3" >18.70</td>
#       <td id="T_1a3cf_row2_col4" class="data row2 col4" >20.50</td>
#       <td id="T_1a3cf_row2_col5" class="data row2 col5" >11.20</td>
#       <td id="T_1a3cf_row2_col6" class="data row2 col6" >6.29</td>
#       <td id="T_1a3cf_row2_col7" class="data row2 col7" >0.67</td>
#       <td id="T_1a3cf_row2_col8" class="data row2 col8" >1,536.00</td>
#       <td id="T_1a3cf_row2_col9" class="data row2 col9" >34,099.20</td>
#       <td id="T_1a3cf_row2_col10" class="data row2 col10" >121.31</td>
#       <td id="T_1a3cf_row2_col11" class="data row2 col11" >1.25</td>
#       <td id="T_1a3cf_row2_col12" class="data row2 col12" >489</td>
#       <td id="T_1a3cf_row2_col13" class="data row2 col13" >2022-05-17</td>
#       <td id="T_1a3cf_row2_col14" class="data row2 col14" >2026-07-17</td>
#     </tr>
#     <tr>
#       <td id="T_1a3cf_row3_col0" class="data row3 col0" >918</td>
#       <td id="T_1a3cf_row3_col1" class="data row3 col1" >TK</td>
#       <td id="T_1a3cf_row3_col2" class="data row3 col2" >sSET    </td>
#       <td id="T_1a3cf_row3_col3" class="data row3 col3" >4.10</td>
#       <td id="T_1a3cf_row3_col4" class="data row3 col4" >4.90</td>
#       <td id="T_1a3cf_row3_col5" class="data row3 col5" >3.28</td>
#       <td id="T_1a3cf_row3_col6" class="data row3 col6" >9.80</td>
#       <td id="T_1a3cf_row3_col7" class="data row3 col7" >0.75</td>
#       <td id="T_1a3cf_row3_col8" class="data row3 col8" >500.00</td>
#       <td id="T_1a3cf_row3_col9" class="data row3 col9" >4,300.00</td>
#       <td id="T_1a3cf_row3_col10" class="data row3 col10" >2.49</td>
#       <td id="T_1a3cf_row3_col11" class="data row3 col11" >1.01</td>
#       <td id="T_1a3cf_row3_col12" class="data row3 col12" >541</td>
#       <td id="T_1a3cf_row3_col13" class="data row3 col13" >2022-05-17</td>
#       <td id="T_1a3cf_row3_col14" class="data row3 col14" >2026-03-16</td>
#     </tr>
#     <tr>
#       <td id="T_1a3cf_row4_col0" class="data row4 col0" >827</td>
#       <td id="T_1a3cf_row4_col1" class="data row4 col1" >LALIN</td>
#       <td id="T_1a3cf_row4_col2" class="data row4 col2" >sSET    </td>
#       <td id="T_1a3cf_row4_col3" class="data row4 col3" >4.42</td>
#       <td id="T_1a3cf_row4_col4" class="data row4 col4" >5.15</td>
#       <td id="T_1a3cf_row4_col5" class="data row4 col5" >4.26</td>
#       <td id="T_1a3cf_row4_col6" class="data row4 col6" >6.45</td>
#       <td id="T_1a3cf_row4_col7" class="data row4 col7" >1.00</td>
#       <td id="T_1a3cf_row4_col8" class="data row4 col8" >925.00</td>
#       <td id="T_1a3cf_row4_col9" class="data row4 col9" >8,648.74</td>
#       <td id="T_1a3cf_row4_col10" class="data row4 col10" >2.46</td>
#       <td id="T_1a3cf_row4_col11" class="data row4 col11" >0.84</td>
#       <td id="T_1a3cf_row4_col12" class="data row4 col12" >271</td>
#       <td id="T_1a3cf_row4_col13" class="data row4 col13" >2022-05-17</td>
#       <td id="T_1a3cf_row4_col14" class="data row4 col14" >2026-07-17</td>
#     </tr>
#   </tbody>
# </table>

# %%
stocks.query('name == "PTTGC"').style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_77467">
#   <thead>
#     <tr>
#       <th id="T_77467_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_77467_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_77467_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_77467_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_77467_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_77467_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_77467_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_77467_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_77467_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_77467_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_77467_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_77467_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_77467_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_77467_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_77467_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_77467_row0_col0" class="data row0 col0" >866</td>
#       <td id="T_77467_row0_col1" class="data row0 col1" >PTTGC</td>
#       <td id="T_77467_row0_col2" class="data row0 col2" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_77467_row0_col3" class="data row0 col3" >37.00</td>
#       <td id="T_77467_row0_col4" class="data row0 col4" >41.25</td>
#       <td id="T_77467_row0_col5" class="data row0 col5" >19.00</td>
#       <td id="T_77467_row0_col6" class="data row0 col6" >999.99</td>
#       <td id="T_77467_row0_col7" class="data row0 col7" >0.77</td>
#       <td id="T_77467_row0_col8" class="data row0 col8" >45,088.49</td>
#       <td id="T_77467_row0_col9" class="data row0 col9" >225,442.46</td>
#       <td id="T_77467_row0_col10" class="data row0 col10" >961.87</td>
#       <td id="T_77467_row0_col11" class="data row0 col11" >1.13</td>
#       <td id="T_77467_row0_col12" class="data row0 col12" >391</td>
#       <td id="T_77467_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_77467_row0_col14" class="data row0 col14" >2026-07-17</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.drop(columns=['id','ticker_id','created_at','updated_at','paid_up','market_cap'],inplace=True)
#df_merge.sample(5).style.format(format_dict)
df_merge.head(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_730b5">
#   <thead>
#     <tr>
#       <th id="T_730b5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_730b5_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_730b5_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_730b5_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_730b5_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_730b5_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_730b5_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_730b5_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_730b5_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_730b5_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_730b5_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_730b5_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_730b5_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_730b5_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_730b5_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_730b5_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_730b5_row0_col1" class="data row0 col1" >2026-07-20</td>
#       <td id="T_730b5_row0_col2" class="data row0 col2" >6.60</td>
#       <td id="T_730b5_row0_col3" class="data row0 col3" >6.60</td>
#       <td id="T_730b5_row0_col4" class="data row0 col4" >6.55</td>
#       <td id="T_730b5_row0_col5" class="data row0 col5" >2,325,557</td>
#       <td id="T_730b5_row0_col6" class="data row0 col6" >6.55</td>
#       <td id="T_730b5_row0_col7" class="data row0 col7" >SET    </td>
#       <td id="T_730b5_row0_col8" class="data row0 col8" >6.55</td>
#       <td id="T_730b5_row0_col9" class="data row0 col9" >6.95</td>
#       <td id="T_730b5_row0_col10" class="data row0 col10" >6.00</td>
#       <td id="T_730b5_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_730b5_row0_col12" class="data row0 col12" >0.74</td>
#       <td id="T_730b5_row0_col13" class="data row0 col13" >40.31</td>
#       <td id="T_730b5_row0_col14" class="data row0 col14" >0.59</td>
#     </tr>
#     <tr>
#       <td id="T_730b5_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T
row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_730b5_row4_col1" class="data row4 col1" >2026-07-20</td>
#       <td id="T_730b5_row4_col2" class="data row4 col2" >15.20</td>
#       <td id="T_730b5_row4_col3" class="data row4 col3" >15.50</td>
#       <td id="T_730b5_row4_col4" class="data row4 col4" >15.10</td>
#       <td id="T_730b5_row4_col5" class="data row4 col5" >435,881</td>
#       <td id="T_730b5_row4_col6" class="data row4 col6" >15.50</td>
#       <td id="T_730b5_row4_col7" class="data row4 col7" >sSET / SETTHSI    </td>
#       <td id="T_730b5_row4_col8" class="data row4 col8" >15.40</td>
#       <td id="T_730b5_row4_col9" class="data row4 col9" >15.80</td>
#       <td id="T_730b5_row4_col10" class="data row4 col10" >11.70</td>
#       <td id="T_730b5_row4_col11" class="data row4 col11" >7.48</td>
#       <td id="T_730b5_row4_col12" class="data row4 col12" >1.21</td>
#       <td id="T_730b5_row4_col13" class="data row4 col13" >70.31</td>
#       <td id="T_730b5_row4_col14" class="data row4 col14" >1.51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 1000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_12bda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12bda_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_12bda_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_12bda_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_12bda_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_12bda_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_12bda_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12bda_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_12bda_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_12bda_row0_col1" class="data row0 col1" >SET100 / SETTHSI    </td>
#       <td id="T_12bda_row0_col2" class="data row0 col2" >1.44</td>
#       <td id="T_12bda_row0_col3" class="data row0 col3" >1.52</td>
#       <td id="T_12bda_row0_col4" class="data row0 col4" >1.36</td>
#       <td id="T_12bda_row0_col5" class="data row0 col5" >24,042,033</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_12bda_row1_col0" class="data row1 col0" >BCP</td>
#       <td id="T_12bda_row1_col1" class="data row1 col1" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_12bda_row1_col2" class="data row1 col2" >43.50</td>
#       <td id="T_12bda_row1_col3" class="data row1 col3" >44.00</td>
#       <td id="T_12bda_row1_col4" class="data row1 col4" >42.75</td>
#       <td id="T_12bda_row1_col5" class="data row1 col5" >14,498,877</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_12bda_row2_col0" class="data row2 col0" >BEM</td>
#       <td id="T_12bda_row2_col1" class="data row2 col1" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_12bda_row2_col2" class="data row2 col2" >6.80</td>
#       <td id="T_12bda_row2_col3" class="data row2 col3" >6.95</td>
#       <td id="T_12bda_row2_col4" class="data row2 col4" >6.65</td>
#       <td id="T_12bda_row2_col5" class="data row2 col5" >79,449,086</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row3" class="row_heading level0 row3" >30</th>
#       <td id="T_12bda_row3_col0" class="data row3 col0" >BLAND</td>
#       <td id="T_12bda_row3_col1" class="data row3 col1" >SET    </td>
#       <td id="T_12bda_row3_col2" class="data row3 col2" >0.70</td>
#       <td id="T_12bda_row3_col3" class="data row3 col3" >0.78</td>
#       <td id="T_12bda_row3_col4" class="data row3 col4" >0.76</td>
#       <td id="T_12bda_row3_col5" class="data row3 col5" >160,756,978</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_12bda_row4_col0" class="data row4 col0" >COM7</td>
#       <td id="T_12bda_row4_col1" class="data row4 col1" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_12bda_row4_col2" class="data row4 col2" >30.25</td>
#       <td id="T_12bda_row4_col3" class="data row4 col3" >30.50</td>
#       <td id="T_12bda_row4_col4" class="data row4 col4" >30.25</td>
#       <td id="T_12bda_row4_col5" class="data row4 col5" >14,511,222</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row5" class="row_heading level0 row5" >55</th>
#       <td id="T_12bda_row5_col0" class="data row5 col0" >GPSC</td>
#       <td id="T_12bda_row5_col1" class="data row5 col1" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_12bda_row5_col2" class="data row5 col2" >54.50</td>
#       <td id="T_12bda_row5_col3" class="data row5 col3" >55.75</td>
#       <td id="T_12bda_row5_col4" class="data row5 col4" >55.00</td>
#       <td id="T_12bda_row5_col5" class="data row5 col5" >11,513,468</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row6" class="row_heading level0 row6" >57</th>
#       <td id="T_12bda_row6_col0" class="data row6 col0" >GUNKUL</td>
#       <td id="T_12bda_row6_col1" class="data row6 col1" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_12bda_row6_col2" class="data row6 col2" >5.30</td>
#       <td id="T_12bda_row6_col3" class="data row6 col3" >5.45</td>
#       <td id="T_12bda_row6_col4" class="data row6 col4" >5.35</td>
#       <td id="T_12bda_row6_col5" class="data row6 col5" >131,466,631</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row7" class="row_heading level0 row7" >58</th>
#       <td id="T_12bda_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_12bda_row7_col1" class="data row7 col1" >SET    </td>
#       <td id="T_12bda_row7_col2" class="data row7 col2" >8.50</td>
#       <td id="T_12bda_row7_col3" class="data row7 col3" >8.50</td>
#       <td id="T_12bda_row7_col4" class="data row7 col4" >8.40</td>
#       <td id="T_12bda_row7_col5" class="data row7 col5" >271,936</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row8" class="row_heading level0 row8" >66</th>
#       <td id="T_12bda_row8_col0" class="data row8 col0" >IMPACT</td>
#       <td id="T_12bda_row8_col1" class="data row8 col1" >SET    </td>
#       <td id="T_12bda_row8_col2" class="data row8 col2" >12.50</td>
#       <td id="T_12bda_row8_col3" class="data row8 col3" >12.60</td>
#       <td id="T_12bda_row8_col4" class="data row8 col4" >12.50</td>
#       <td id="T_12bda_row8_col5" class="data row8 col5" >875,178</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row9" class="row_heading level0 row9" >71</th>
#       <td id="T_12bda_row9_col0" class="data row9 col0" >KBANK</td>
#       <td id="T_12bda_row9_col1" class="data row9 col1" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_12bda_row9_col2" class="data row9 col2" >238.00</td>
#       <td id="T_12bda_row9_col3" class="data row9 col3" >238.00</td>
#       <td id="T_12bda_row9_col4" class="data row9 col4" >237.00</td>
#       <td id="T_12bda_row9_col5" class="data row9 col5" >16,237,504</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row10" class="row_heading level0 row10" >74</th>
#       <td id="T_12bda_row10_col0" class="data row10 col0" >KKP</td>
#       <td id="T_12bda_row10_col1" class="data row10 col1" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_12bda_row10_col2" class="data row10 col2" >109.50</td>
#       <td id="T_12bda_row10_col3" class="data row10 col3" >109.50</td>
#       <td id="T_12bda_row10_col4" class="data row10 col4" >107.50</td>
#       <td id="T_12bda_row10_col5" class="data row10 col5" >14,375,421</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row11" class="row_heading level0 row11" >75</th>
#       <td id="T_12bda_row11_col0" class="data row11 col0" >KTB</td>
#       <td id="T_12bda_row11_col1" class="data row11 col1" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_12bda_row11_col2" class="data row11 col2" >42.25</td>
#       <td id="T_12bda_row11_col3" class="data row11 col3" >42.25</td>
#       <td id="T_12bda_row11_col4" class="data row11 col4" >42.00</td>
#       <td id="T_12bda_row11_col5" class="data row11 col5" >114,834,633</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row12" class="row_heading level0 row12" >76</th>
#       <td id="T_12bda_row12_col0" class="data row12 col0" >KTC</td>
#       <td id="T_12bda_row12_col1" class="data row12 col1" >SET50 / SETTHSI    </td>
#       <td id="T_12bda_row12_col2" class="data row12 col2" >40.50</td>
#       <td id="T_12bda_row12_col3" class="data row12 col3" >41.25</td>
#       <td id="T_12bda_row12_col4" class="data row12 col4" >39.25</td>
#       <td id="T_12bda_row12_col5" class="data row12 col5" >48,776,054</td>
#     </tr>
#     <tr>
#       <th id="T_12bda_level0_row13" class="row_heading level0 row13" >99</th>
#       <td id="T_12bda_row13_col0" class="data row13 col0" >PTT</td>
#       <td id="T_12bda_row13_col1" class="data row13 col1" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_12bda_row13_col2" class="data row13 col2" >39.25</td>
#       <td id="T_12bda_row13_col3" class="data row13 col3" >39.25</td>
#       <td id="T_12bda_row13_col4" class="data row13 col4" >39.00</td>
#       <td id="T_12bda_row13_col5" class="data

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 26 stocks'

# %% [markdown]
# ### New High by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_46d10">
#   <thead>
#     <tr>
#       <th id="T_46d10_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_46d10_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_46d10_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_46d10_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_46d10_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_46d10_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_46d10_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_46d10_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_46d10_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_46d10_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_46d10_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_46d10_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_46d10_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_46d10_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_46d10_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46d10_row0_col0" class="data row0 col0" >BEM</td>
#       <td id="T_46d10_row0_col1" class="data row0 col1" >2026-07-20</td>
#       <td id="T_46d10_row0_col2" class="data row0 col2" >6.80</td>
#       <td id="T_46d10_row0_col3" class="data row0 col3" >6.95</td>
#       <td id="T_46d10_row0_col4" class="data row0 col4" >6.55</td>
#       <td id="T_46d10_row0_col5" class="data row0 col5" >79,449,086</td>
#       <td id="T_46d10_row0_col6" class="data row0 col6" >6.65</td>
#       <td id="T_46d10_row0_col7" class="data row0 col7" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_46d10_row0_col8" class="data row0 col8" >6.65</td>
#       <td id="T_46d10_row0_col9" class="data row0 col9" >6.65</td>
#       <td id="T_46d10_row0_col10" class="data row0 col10" >4.84</td>
#       <td id="T_46d10_row0_col11" class="data row0 col11" >67.20</td>
#       <td id="T_46d10_row0_col12" class="data row0 col12" >3.97</td>
#       <td id="T_46d10_row0_col13" class="data row0 col13" >720.96</td>
#       <td id="T_46d10_row0_col14" class="data row0 col14" >0.69</td>
#     </tr>
#     <tr>
#       <td id="T_46d10_row1_col0" class="data row1 col0" >COM7</td>
#       <td id="T_46d10_row1_col1" class="data row1 col1" >2026-07-20</td>
#       <td id="T_46d10_row1_col2" class="data row1 col2" >30.25</td>
#       <td id="T_46d10_row1_col3" class="data row1 col3" >30.50</td>
#       <td id="T_46d10_row1_col4" class="data row1 col4" >29.50</td>
#       <td id="T_46d10_row1_col5" class="data row1 col5" >14,511,222</td>
#       <td id="T_46d10_row1_col6" class="data row1 col6" >29.75</td>
#       <td id="T_46d10_row1_col7" class="data row1 col7" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T
>SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_78d84_row3_col8" class="data row3 col8" >106.00</td>
#       <td id="T_78d84_row3_col9" class="data row3 col9" >107.50</td>
#       <td id="T_78d84_row3_col10" class="data row3 col10" >48.00</td>
#       <td id="T_78d84_row3_col11" class="data row3 col11" >7.21</td>
#       <td id="T_78d84_row3_col12" class="data row3 col12" >1.10</td>
#       <td id="T_78d84_row3_col13" class="data row3 col13" >513.30</td>
#       <td id="T_78d84_row3_col14" class="data row3 col14" >0.84</td>
#     </tr>
#     <tr>
#       <td id="T_78d84_row4_col0" class="data row4 col0" >SPRC</td>
#       <td id="T_78d84_row4_col1" class="data row4 col1" >2026-07-20</td>
#       <td id="T_78d84_row4_col2" class="data row4 col2" >9.25</td>
#       <td id="T_78d84_row4_col3" class="data row4 col3" >9.40</td>
#       <td id="T_78d84_row4_col4" class="data row4 col4" >9.20</td>
#       <td id="T_78d84_row4_col5" class="data row4 col5" >29,423,616</td>
#       <td id="T_78d84_row4_col6" class="data row4 col6" >9.20</td>
#       <td id="T_78d84_row4_col7" class="data row4 col7" >SET100 / SETCLMV    </td>
#       <td id="T_78d84_row4_col8" class="data row4 col8" >9.10</td>
#       <td id="T_78d84_row4_col9" class="data row4 col9" >9.25</td>
#       <td id="T_78d84_row4_col10" class="data row4 col10" >4.28</td>
#       <td id="T_78d84_row4_col11" class="data row4 col11" >5.43</td>
#       <td id="T_78d84_row4_col12" class="data row4 col12" >1.18</td>
#       <td id="T_78d84_row4_col13" class="data row4 col13" >295.42</td>
#       <td id="T_78d84_row4_col14" class="data row4 col14" >0.98</td>
#     </tr>
#     <tr>
#       <td id="T_78d84_row5_col0" class="data row5 col0" >TCAP</td>
#       <td id="T_78d84_row5_col1" class="data row5 col1" >2026-07-20</td>
#       <td id="T_78d84_row5_col2" class="data row5 col2" >74.50</td>
#       <td id="T_78d84_row5_col3" class="data row5 col3" >74.50</td>
#       <td id="T_78d84_row5_col4" class="data row5 col4" >71.25</td>
#       <td id="T_78d84_row5_col5" class="data row5 col5" >6,139,449</td>
#       <td id="T_78d84_row5_col6" class="data row5 col6" >72.00</td>
#       <td id="T_78d84_row5_col7" class="data row5 col7" >SET100 / SETHD    </td>
#       <td id="T_78d84_row5_col8" class="data row5 col8" >71.50</td>
#       <td id="T_78d84_row5_col9" class="data row5 col9" >73.00</td>
#       <td id="T_78d84_row5_col10" class="data row5 col10" >47.00</td>
#       <td id="T_78d84_row5_col11" class="data row5 col11" >7.64</td>
#       <td id="T_78d84_row5_col12" class="data row5 col12" >0.67</td>
#       <td id="T_78d84_row5_col13" class="data row5 col13" >129.87</td>
#       <td id="T_78d84_row5_col14" class="data row5 col14" >0.86</td>
#     </tr>
#     <tr>
#       <td id="T_78d84_row6_col0" class="data row6 col0" >THANI</td>
#       <td id="T_78d84_row6_col1" class="data row6 col1" >2026-07-20</td>
#       <td id="T_78d84_row6_col2" class="data row6 col2" >2.22</td>
#       <td id="T_78d84_

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_69a50">
#   <thead>
#     <tr>
#       <th id="T_69a50_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_69a50_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_69a50_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_69a50_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_69a50_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_69a50_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_69a50_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_69a50_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_69a50_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_69a50_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_69a50_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_69a50_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_69a50_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_69a50_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_69a50_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69a50_row0_col0" class="data row0 col0" >ROJNA</td>
#       <td id="T_69a50_row0_col1" class="data row0 col1" >2026-07-20</td>
#       <td id="T_69a50_row0_col2" class="data row0 col2" >6.25</td>
#       <td id="T_69a50_row0_col3" class="data row0 col3" >6.30</td>
#       <td id="T_69a50_row0_col4" class="data row0 col4" >6.15</td>
#       <td id="T_69a50_row0_col5" class="data row0 col5" >5,744,589</td>
#       <td id="T_69a50_row0_col6" class="data row0 col6" >6.20</td>
#       <td id="T_69a50_row0_col7" class="data row0 col7" >sSET    </td>
#       <td id="T_69a50_row0_col8" class="data row0 col8" >6.15</td>
#       <td id="T_69a50_row0_col9" class="data row0 col9" >6.20</td>
#       <td id="T_69a50_row0_col10" class="data row0 col10" >4.26</td>
#       <td id="T_69a50_row0_col11" class="data row0 col11" >16.46</td>
#       <td id="T_69a50_row0_col12" class="data row0 col12" >0.78</td>
#       <td id="T_69a50_row0_col13" class="data row0 col13" >4.95</td>
#       <td id="T_69a50_row0_col14" class="data row0 col14" >1.18</td>
#     </tr>
#     <tr>
#       <td id="T_69a50_row1_col0" class="data row1 col0" >SSP</td>
#       <td id="T_69a50_row1_col1" class="data row1 col1" >2026-07-20</td>
#       <td id="T_69a50_row1_col2" class="data row1 col2" >4.36</td>
#       <td id="T_69a50_row1_col3" class="data row1 col3" >4.38</td>
#       <td id="T_69a50_row1_col4" class="data row1 col4" >4.12</td>
#       <td id="T_69a50_row1_col5" class="data row1 col5" >8,356,362</td>
#       <td id="T_69a50_row1_col6" class="data row1 col6" >4.12</td>
#       <td id="T_69a50_row1_col7" class="data row1 col7" >sSET / SETCLMV    </td>
#       <td id="T_69a50_row1_col8" class="data row1 col8" >4.06</td>
#       <td id="T_69a50_row1_col9" class="data row1 col9" >4.34</td>
#       <td id="T_69a50_row1_col10" class="data row1 col10" >3.00</td>
#       <td id="T_69a50_row1_col11" class="data row1 col11" >9.46</td>
#       <td id="T_69a50_row1_col12" class="data row1 col12" >1.59</td>
#       <td id="T_69a50_row1_col13" class="data row1 col13" >19.83</td>
#       <td id="T_69a50_row1_col14" class="data row1 col14" >1.27</td>
#     </tr>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e27f4">
#   <thead>
#     <tr>
#       <th id="T_e27f4_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e27f4_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_e27f4_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_e27f4_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_e27f4_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_e27f4_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_e27f4_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_e27f4_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_e27f4_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_e27f4_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_e27f4_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_e27f4_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_e27f4_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_e27f4_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_e27f4_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c1e6">
#   <thead>
#     <tr>
#       <th id="T_0c1e6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_0c1e6_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_0c1e6_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_0c1e6_level0_col3" class="col_heading level0 col3" >minp</th>
#       <th id="T_0c1e6_level0_col4" class="col_heading level0 col4" >min_price</th>
#       <th id="T_0c1e6_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 0 stocks'

# %% [markdown]
# ### New Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ce465">
#   <thead>
#     <tr>
#       <th id="T_ce465_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ce465_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_ce465_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_ce465_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_ce465_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_ce465_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_ce465_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_ce465_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_ce465_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_ce465_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_ce465_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_ce465_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_ce465_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_ce465_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_ce465_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7821d">
#   <thead>
#     <tr>
#       <th id="T_7821d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7821d_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_7821d_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_7821d_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_7821d_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_7821d_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_7821d_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_7821d_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_7821d_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_7821d_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_7821d_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_7821d_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_7821d_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_7821d_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_7821d_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_98321">
#   <thead>
#     <tr>
#       <th id="T_98321_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_98321_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_98321_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_98321_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_98321_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_98321_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_98321_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_98321_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_98321_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_98321_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_98321_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_98321_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_98321_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_98321_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_98321_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = f"""
SELECT name, qty, price, date As today
FROM price 
WHERE date = {today}
ORDER BY name
"""
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = 2026-07-20
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_8c3e8">
#   <thead>
#     <tr>
#       <th id="T_8c3e8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8c3e8_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_8c3e8_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_8c3e8_level0_col3" class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2026, 7, 17)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b5ce">
#   <thead>
#     <tr>
#       <th id="T_6b5ce_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_6b5ce_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_6b5ce_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_6b5ce_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_6b5ce_level0_col4" class="col_heading level0 col4" >end_date</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2026, 7, 16)

# %%
# You already have start_date calculated earlier
# Just assign it to all rows in today_vol
today_vol['start_date'] = start_date
today_vol.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4e7c">
#   <thead>
#     <tr>
#       <th id="T_d4e7c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d4e7c_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_d4e7c_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_d4e7c_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_d4e7c_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_d4e7c_level0_col5" class="col_heading level0 col5" >start_date</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sql = f"""
SELECT * 
FROM price 
WHERE date BETWEEN {start_date} AND {end_date}
"""
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name','date'],ascending=[True,True]).head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN 2026-07-16 AND 2026-07-17
# <style type="text/css">
# </style>
# <table id="T_43b85">
#   <thead>
#     <tr>
#       <th id="T_43b85_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_43b85_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_43b85_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_43b85_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_43b85_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_43b85_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_43b85_level0_col6" class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner", 
                     suffixes=( "_today","_mean"))
df_merge2.columns
# Out:
# Index(['name', 'qty_today', 'price_today', 'today', 'end_date', 'start_date',
#        'qty_mean', 'price_mean'],
#       dtype='object')

# %%
df_merge2["qty_mean"] = df_merge2.qty_mean.astype("int64")
df_merge2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c65d9">
#   <thead>
#     <tr>
#       <th id="T_c65d9_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c65d9_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_c65d9_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_c65d9_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_c65d9_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_c65d9_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_c65d9_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_c65d9_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_today > df_merge2.qty_mean)]
break_five_day_mean.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2096">
#   <thead>
#     <tr>
#       <th id="T_d2096_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d2096_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_d2096_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_d2096_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_d2096_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_d2096_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_d2096_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_d2096_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sql = """
SELECT name, date, volbuy, price, dividend 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.volbuy = buys.volbuy.astype("int64")
buys.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3285e">
#   <thead>
#     <tr>
#       <th id="T_3285e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3285e_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_3285e_level0_col2" class="col_heading level0 col2" >volbuy</th>
#       <th id="T_3285e_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_3285e_level0_col4" class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3285e_row0_col0" class="data row0 col0" >TOA</td>
#       <td id="T_3285e_row0_col1" class="data row0 col1" >2023-09-06</td>
#       <td id="T_3285e_row0_col2" class="data row0 col2" >1,000</td>
#       <td id="T_3285e_row0_col3" class="data row0 col3" >26.00</td>
#       <td id="T_3285e_row0_col4" class="data row0 col4" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_3285e_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_3285e_row1_col1" class="data row1 col1" >2023-01-19</td>
#       <td id="T_3285e_row1_col2" class="data row1 col2" >6,000</td>
#       <td id="T_3285e_row1_col3" class="data row1 col3" >24.80</td>
#       <td id="T_3285e_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_3285e_row2_col0" class="data row2 col0" >SYNEX</td>
#       <td id="T_3285e_row2_col1" class="data row2 col1" >2022-01-07</td>
#       <td id="T_3285e_row2_col2" class="data row2 col2" >17,500</td>
#       <td id="T_3285e_row2_col3" class="data row2 col3" >26.40</td>
#       <td id="T_3285e_row2_col4" class="data row2 col4" >0.48</td>
#     </tr>
#     <tr>
#       <td id="T_3285e_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_3285e_row3_col1" class="data row3 col1" >2020-08-01</td>
#       <td id="T_3285e_row3_col2" class="data row3 col2" >45,000</td>
#       <td id="T_3285e_row3_col3" class="data row3 col3" >12.70</td>
#       <td id="T_3285e_row3_col4" class="data row3 col4" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_3285e_row4_col0" class="data row4 col0" >AWC</td>
#       <td id="T_3285e_row4_col1" class="data row4 col1" >2023-06-15</td>
#       <td id="T_3285e_row4_col2" class="data row4 col2" >9,000</td>
#       <td id="T_3285e_row4_col3" class="data row4 col3" >4.96</td>
#       <td id="T_3285e_row4_col4" class="data row4 col4" >0.08</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner", suffixes=("_mean","_today"))
df_merge3["qty_pct"] = round((df_merge3.qty_today - df_merge3.qty_mean) / abs(df_merge3.qty_mean) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_today - df_merge3.price_mean) / abs(df_merge3.price_mean) * 100,2)
df_merge3.rename(columns={'price_mean':'avg_price','price_today':'tdy_price',
                          'qty_mean':'avg_qty','qty_today':'tdy_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9fbf1">
#   <thead>
#     <tr>
#       <th id="T_9fbf1_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9fbf1_level0_col1" class="col_heading level0 col1" >prc_pct</th>
#       <th id="T_9fbf1_level0_col2" class="col_heading level0 col2" >tdy_price</th>
#       <th id="T_9fbf1_level0_col3" class="col_heading level0 col3" >avg_price</th>
#       <th id="T_9fbf1_level0_col4" class="col_heading level0 col4" >qty_pct</th>
#       <th id="T_9fbf1_level0_col5" class="col_heading level0 col5" >tdy_qty</th>
#       <th id="T_9fbf1_level0_col6" class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\5-day-average.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\5-day-average.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\5-day-average.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\5-day-average.csv

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(god_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(icd_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f99c">
#   <thead>
#     <tr>
#       <th id="T_7f99c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7f99c_level0_col1" class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f99c_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_7f99c_row0_col1" class="data row0 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_7f99c_row1_col0" class="data row1 col0" >MCS</td>
#       <td id="T_7f99c_row1_col1" class="data row1 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_7f99c_row2_col0" class="data row2 col0" >ORI</td>
#       <td id="T_7f99c_row2_col1" class="data row2 col1" >B</td>
#     </tr>
#     <tr>
#       <td id="T_7f99c_row3_col0" class="data row3 col0" >CPNREIT</td>
#       <td id="T_7f99c_row3_col1" class="data row3 col1" >X</td>
#     </tr>
#     <tr>
#       <td id="T_7f99c_row4_col0" class="data row4 col0" >RCL</td>
#       <td id="T_7f99c_row4_col1" class="data row4 col1" >B</td>
#     </tr>
#   </tbody>
# </table>

# %%
stock_list = stocks["name"].unique().tolist()
stock_list_str = "','".join(stock_list)
print(stock_list_str)
# Out:
# AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC','AIMIRT','PROSPECT

# %%
sql = f"""
SELECT name, price 
FROM price 
WHERE date = {today} AND name IN ('{stock_list_str}') 
ORDER BY name"""
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = 2026-07-20 AND name IN ('AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC','AIMIRT','PROSPECT')
# ORDER BY name

# %%
tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# '0 stocks'

# %%
sql = f"""
SELECT name, price 
FROM price 
WHERE date = {yesterday} AND name IN ('{stock_list_str}') 
ORDER BY name"""
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = 2026-07-17 AND name IN ('AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC','AIMIRT','PROSPECT')
# ORDER BY name

# %%
ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# '0 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner',suffixes=("_today","_yesterday"))
compare1.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c459">
#   <thead>
#     <tr>
#       <th id="T_3c459_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3c459_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_3c459_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3e9e">
#   <thead>
#     <tr>
#       <th id="T_e3e9e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e3e9e_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_e3e9e_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#       <th id="T_e3e9e_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
compare2.columns
# Out:
# Index(['name', 'price_today', 'price_yesterday', 'status'], dtype='object')

# %%
colx = ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']
colx
# Out:
# ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']

# %%
compare2['diff'] = round((compare2.price_today - compare2.price_yesterday),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_yesterday'] * 100,2)
compare2[colx].sort_values(['pct'],ascending=[False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd14e">
#   <thead>
#     <tr>
#       <th id="T_bd14e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bd14e_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_bd14e_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_bd14e_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_bd14e_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_bd14e_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9cdb5">
#   <thead>
#     <tr>
#       <th id="T_9cdb5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9cdb5_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_9cdb5_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_9cdb5_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_9cdb5_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_9cdb5_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\extremes.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\extremes.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\extremes.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\extremes.csv

# %%
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(god_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(icd_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(osd_file, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-07-20 21:15:43
