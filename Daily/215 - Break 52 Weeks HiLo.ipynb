# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
print(today)
# Out:
# 2026-03-19

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(today, yesterday)
# Out:
# 2026-03-19 2026-03-18

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-03-19 20:38:56

# %% [markdown]
# ### Restart and run all cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Daily
# Base path: C:\Users\PC1\OneDrive\A4
# Data path : C:\Users\PC1\OneDrive\A4\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}', 'volbuy':'{:,}',   
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}',
    'opnp':'{:.2f}','price_x':'{:.2f}','price_y':'{:.2f}',
    'price_today':'{:.2f}','price_yesterday':'{:.2f}',   
    'date':'{:%Y-%m-%d}',
    
    'price_mean':'{:.2f}','price_today':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}','dividend':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_mean':'{:,}','qty_today':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}','daily_volume':'{:,.2f}',   
    'value(m)':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2026, 3, 19)

# %%
sql = f"""
SELECT * 
FROM price 
WHERE date = {today}
ORDER BY name
"""
print(sql)

prices = pd.read_sql(sql, const)
#prices.sample(5).style.format(format_dict)
prices.shape
# Out:
# SELECT *
# FROM price
# WHERE date = 2026-03-19
# ORDER BY name
# (0, 7)

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3bdc9">
#   <thead>
#     <tr>
#       <th id="T_3bdc9_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_3bdc9_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_3bdc9_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_3bdc9_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_3bdc9_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_3bdc9_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_3bdc9_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_3bdc9_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_3bdc9_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_3bdc9_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_3bdc9_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_3bdc9_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_3bdc9_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_3bdc9_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_3bdc9_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3bdc9_row0_col0" class="data row0 col0" >851</td>
#       <td id="T_3bdc9_row0_col1" class="data row0 col1" >ORI</td>
#       <td id="T_3bdc9_row0_col2" class="data row0 col2" >SET100 / SETHD / SETTHSI    </td>
#       <td id="T_3bdc9_row0_col3" class="data row0 col3" >1.83</td>
#       <td id="T_3bdc9_row0_col4" class="data row0 col4" >3.12</td>
#       <td id="T_3bdc9_row0_col5" class="data row0 col5" >1.50</td>
#       <td id="T_3bdc9_row0_col6" class="data row0 col6" >8.30</td>
#       <td id="T_3bdc9_row0_col7" class="data row0 col7" >1.81</td>
#       <td id="T_3bdc9_row0_col8" class="data row0 col8" >1,227.06</td>
#       <td id="T_3bdc9_row0_col9" class="data row0 col9" >29,449.47</td>
#       <td id="T_3bdc9_row0_col10" class="data row0 col10" >109.84</td>
#       <td id="T_3bdc9_row0_col11" class="data row0 col11" >1.64</td>
#       <td id="T_3bdc9_row0_col12" class="data row0 col12" >347</td>
#       <td id="T_3bdc9_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_3bdc9_row0_col14" class="data row0 col14" >2026-03-18</td>
#     </tr>
#     <tr>
#       <td id="T_3bdc9_row1_col0" class="data row1 col0" >759</td>
#       <td id="T_3bdc9_row1_col1" class="data row1 col1" >BTSGIF</td>
#       <td id="T_3bdc9_row1_col2" class="data row1 col2" >SET    </td>
#       <td id="T_3bdc9_row1_col3" class="data row1 col3" >2.56</td>
#       <td id="T_3bdc9_row1_col4" class="data row1 col4" >2.86</td>
#       <td id="T_3bdc9_row1_col5" class="data row1 col5" >2.46</td>
#       <td id="T_3bdc9_row1_col6" class="data row1 col6" >999.99</td>
#       <td id="T_3bdc9_row1_col7" class="data row1 col7" >0.58</td>
#       <td id="T_3bdc9_row1_col8" class="data row1 col8" >53,533.21</td>
#       <td id="T_3bdc9_row1_col9" class="data row1 col9" >22,457.44</td>
#       <td id="T_3bdc9_row1_col10" class="data row1 col10" >25.78</td>
#       <td id="T_3bdc9_row1_col11" class="data row1 col11" >0.43</td>
#       <td id="T_3bdc9_row1_col12" class="data row1 col12" >87</td>
#       <td id="T_3bdc9_row1_col13" class="data row1 col13" >2022-05-17</td>
#       <td id="T_3bdc9_row1_col14" class="data row1 col14" >2026-03-18</td>
#     </tr>
#     <tr>
#       <td id="T_3bdc9_row2_col0" class="data row2 col0" >758</td>
#       <td id="T_3bdc9_row2_col1" class="data row2 col1" >BTS</td>
#       <td id="T_3bdc9_row2_col2" class="data row2 col2" >SET50 / SETHD / SETTHSI / SETWB    </td>
#       <td id="T_3bdc9_row2_col3" class="data row2 col3" >2.06</td>
#       <td id="T_3bdc9_row2_col4" class="data row2 col4" >5.90</td>
#       <td id="T_3bdc9_row2_col5" class="data row2 col5" >1.98</td>
#       <td id="T_3bdc9_row2_col6" class="data row2 col6" >39.14</td>
#       <td id="T_3bdc9_row2_col7" class="data row2 col7" >1.84</td>
#       <td id="T_3bdc9_row2_col8" class="data row2 col8" >52,670.55</td>
#       <td id="T_3bdc9_row2_col9" class="data row2 col9" >112,583.31</td>
#       <td id="T_3bdc9_row2_col10" class="data row2 col10" >196.53</td>
#       <td id="T_3bdc9_row2_col11" class="data row2 col11" >0.85</td>
#       <td id="T_3bdc9_row2_col12" class="data row2 col12" >86</td>
#       <td id="T_3bdc9_row2_col13" class="data row2 col13" >2022-05-17</td>
#       <td id="T_3bdc9_row2_col14" class="data row2 col14" >2026-03-18</td>
#     </tr>
#     <tr>
#       <td id="T_3bdc9_row3_col0" class="data row3 col0" >894</td>
#       <td id="T_3bdc9_row3_col1" class="data row3 col1" >SPCG</td>
#       <td id="T_3bdc9_row3_col2" class="data row3 col2" >sSET    </td>
#       <td id="T_3bdc9_row3_col3" class="data row3 col3" >9.05</td>
#       <td id="T_3bdc9_row3_col4" class="data row3 col4" >10.30</td>
#       <td id="T_3bdc9_row3_col5" class="data row3 col5" >6.60</td>
#       <td id="T_3bdc9_row3_col6" class="data row3 col6" >6.85</td>
#       <td id="T_3bdc9_row3_col7" class="data row3 col7" >0.88</td>
#       <td id="T_3bdc9_row3_col8" class="data row3 col8" >1,055.79</td>
#       <td id="T_3bdc9_row3_col9" class="data row3 col9" >15,414.53</td>
#       <td id="T_3bdc9_row3_col10" class="data row3 col10" >6.45</td>
#       <td id="T_3bdc9_row3_col11" class="data row3 col11" >0.58</td>
#       <td id="T_3bdc9_row3_col12" class="data row3 col12" >472</td>
#       <td id="T_3bdc9_row3_col13" class="data row3 col13" >2022-05-17</td>
#       <td id="T_3bdc9_row3_col14" class="data row3 col14" >2026-03-18</td>
#     </tr>
#     <tr>
#       <td id="T_3bdc9_row4_col0" class="data row4 col0" >876</td>
#       <td id="T_3bdc9_row4_col1" class="data row4 col1" >SAT</td>
#       <td id="T_3bdc9_row4_col2" class="data row4 col2" >sSET / SETTHSI    </td>
#       <td id="T_3bdc9_row4_col3" class="data row4 col3" >14.40</td>
#       <td id="T_3bdc9_row4_col4" class="data row4 col4" >16.70</td>
#       <td id="T_3bdc9_row4_col5" class="data row4 col5" >9.95</td>
#       <td id="T_3bdc9_row4_col6" class="data row4 col6" >9.93</td>
#       <td id="T_3bdc9_row4_col7" class="data row4 col7" >1.16</td>
#       <td id="T_3bdc9_row4_col8" class="data row4 col8" >425.19</td>
#       <td id="T_3bdc9_row4_col9" class="data row4 col9" >9,014.11</td>
#       <td id="T_3bdc9_row4_col10" class="data row4 col10" >36.56</td>
#       <td id="T_3bdc9_row4_col11" class="data row4 col11" >0.99</td>
#       <td id="T_3bdc9_row4_col12" class="data row4 col12" >427</td>
#       <td id="T_3bdc9_row4_col13" class="data row4 col13" >2022-05-17</td>
#       <td id="T_3bdc9_row4_col14" class="data row4 col14" >2026-03-18</td>
#     </tr>
#   </tbody>
# </table>

# %%
stocks.query('name == "PTTGC"').style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5d7e">
#   <thead>
#     <tr>
#       <th id="T_f5d7e_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_f5d7e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_f5d7e_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_f5d7e_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_f5d7e_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_f5d7e_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_f5d7e_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_f5d7e_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_f5d7e_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_f5d7e_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_f5d7e_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_f5d7e_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_f5d7e_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_f5d7e_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_f5d7e_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5d7e_row0_col0" class="data row0 col0" >866</td>
#       <td id="T_f5d7e_row0_col1" class="data row0 col1" >PTTGC</td>
#       <td id="T_f5d7e_row0_col2" class="data row0 col2" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_f5d7e_row0_col3" class="data row0 col3" >30.75</td>
#       <td id="T_f5d7e_row0_col4" class="data row0 col4" >32.00</td>
#       <td id="T_f5d7e_row0_col5" class="data row0 col5" >14.20</td>
#       <td id="T_f5d7e_row0_col6" class="data row0 col6" >999.99</td>
#       <td id="T_f5d7e_row0_col7" class="data row0 col7" >0.77</td>
#       <td id="T_f5d7e_row0_col8" class="data row0 col8" >45,088.49</td>
#       <td id="T_f5d7e_row0_col9" class="data row0 col9" >225,442.46</td>
#       <td id="T_f5d7e_row0_col10" class="data row0 col10" >961.87</td>
#       <td id="T_f5d7e_row0_col11" class="data row0 col11" >1.13</td>
#       <td id="T_f5d7e_row0_col12" class="data row0 col12" >391</td>
#       <td id="T_f5d7e_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_f5d7e_row0_col14" class="data row0 col14" >2026-03-18</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.drop(columns=['id','ticker_id','created_at','updated_at','paid_up','market_cap'],inplace=True)
#df_merge.sample(5).style.format(format_dict)
df_merge.head(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f81d2">
#   <thead>
#     <tr>
#       <th id="T_f81d2_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_f81d2_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_f81d2_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_f81d2_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_f81d2_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_f81d2_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_f81d2_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_f81d2_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_f81d2_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_f81d2_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_f81d2_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_f81d2_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_f81d2_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_f81d2_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_f81d2_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 1000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89eaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89eaa_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_89eaa_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_89eaa_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_89eaa_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_89eaa_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_89eaa_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 0 stocks'

# %% [markdown]
# ### New High by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8e533">
#   <thead>
#     <tr>
#       <th id="T_8e533_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8e533_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_8e533_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_8e533_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_8e533_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_8e533_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_8e533_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_8e533_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_8e533_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_8e533_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_8e533_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_8e533_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_8e533_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_8e533_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_8e533_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set100H = Final_High["market"].str.contains("SET100")
Final_High[set100H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_98c77">
#   <thead>
#     <tr>
#       <th id="T_98c77_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_98c77_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_98c77_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_98c77_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_98c77_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_98c77_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_98c77_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_98c77_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_98c77_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_98c77_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_98c77_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_98c77_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_98c77_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_98c77_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_98c77_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7dd56">
#   <thead>
#     <tr>
#       <th id="T_7dd56_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7dd56_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_7dd56_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_7dd56_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_7dd56_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_7dd56_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_7dd56_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_7dd56_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_7dd56_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_7dd56_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_7dd56_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_7dd56_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_7dd56_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_7dd56_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_7dd56_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6598">
#   <thead>
#     <tr>
#       <th id="T_e6598_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e6598_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_e6598_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_e6598_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_e6598_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_e6598_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_e6598_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_e6598_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_e6598_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_e6598_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_e6598_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_e6598_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_e6598_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_e6598_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_e6598_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_562fa">
#   <thead>
#     <tr>
#       <th id="T_562fa_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_562fa_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_562fa_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_562fa_level0_col3" class="col_heading level0 col3" >minp</th>
#       <th id="T_562fa_level0_col4" class="col_heading level0 col4" >min_price</th>
#       <th id="T_562fa_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 0 stocks'

# %% [markdown]
# ### New Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_09b56">
#   <thead>
#     <tr>
#       <th id="T_09b56_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_09b56_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_09b56_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_09b56_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_09b56_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_09b56_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_09b56_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_09b56_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_09b56_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_09b56_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_09b56_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_09b56_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_09b56_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_09b56_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_09b56_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb232">
#   <thead>
#     <tr>
#       <th id="T_bb232_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bb232_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_bb232_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_bb232_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_bb232_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_bb232_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_bb232_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_bb232_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_bb232_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_bb232_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_bb232_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_bb232_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_bb232_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_bb232_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_bb232_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3361c">
#   <thead>
#     <tr>
#       <th id="T_3361c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3361c_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_3361c_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_3361c_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_3361c_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_3361c_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_3361c_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_3361c_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_3361c_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_3361c_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_3361c_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_3361c_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_3361c_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_3361c_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_3361c_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = f"""
SELECT name, qty, price, date As today
FROM price 
WHERE date = {today}
ORDER BY name
"""
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = 2026-03-19
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_c07e6">
#   <thead>
#     <tr>
#       <th id="T_c07e6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c07e6_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_c07e6_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_c07e6_level0_col3" class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2026, 3, 18)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_37c2f">
#   <thead>
#     <tr>
#       <th id="T_37c2f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_37c2f_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_37c2f_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_37c2f_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_37c2f_level0_col4" class="col_heading level0 col4" >end_date</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2026, 3, 17)

# %%
# You already have start_date calculated earlier
# Just assign it to all rows in today_vol
today_vol['start_date'] = start_date
today_vol.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_340aa">
#   <thead>
#     <tr>
#       <th id="T_340aa_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_340aa_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_340aa_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_340aa_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_340aa_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_340aa_level0_col5" class="col_heading level0 col5" >start_date</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sql = f"""
SELECT * 
FROM price 
WHERE date BETWEEN {start_date} AND {end_date}
"""
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name','date'],ascending=[True,True]).head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN 2026-03-17 AND 2026-03-18
# <style type="text/css">
# </style>
# <table id="T_dda72">
#   <thead>
#     <tr>
#       <th id="T_dda72_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_dda72_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_dda72_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_dda72_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_dda72_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_dda72_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_dda72_level0_col6" class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner", 
                     suffixes=( "_today","_mean"))
df_merge2.columns
# Out:
# Index(['name', 'qty_today', 'price_today', 'today', 'end_date', 'start_date',
#        'qty_mean', 'price_mean'],
#       dtype='object')

# %%
df_merge2["qty_mean"] = df_merge2.qty_mean.astype("int64")
df_merge2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bd9d">
#   <thead>
#     <tr>
#       <th id="T_8bd9d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8bd9d_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_8bd9d_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_8bd9d_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_8bd9d_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_8bd9d_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_8bd9d_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_8bd9d_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_today > df_merge2.qty_mean)]
break_five_day_mean.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_dcb02">
#   <thead>
#     <tr>
#       <th id="T_dcb02_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_dcb02_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_dcb02_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_dcb02_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_dcb02_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_dcb02_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_dcb02_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_dcb02_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sql = """
SELECT name, date, volbuy, price, dividend 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.volbuy = buys.volbuy.astype("int64")
buys.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b689">
#   <thead>
#     <tr>
#       <th id="T_8b689_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8b689_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_8b689_level0_col2" class="col_heading level0 col2" >volbuy</th>
#       <th id="T_8b689_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_8b689_level0_col4" class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8b689_row0_col0" class="data row0 col0" >WHAIR</td>
#       <td id="T_8b689_row0_col1" class="data row0 col1" >2021-10-11</td>
#       <td id="T_8b689_row0_col2" class="data row0 col2" >50,000</td>
#       <td id="T_8b689_row0_col3" class="data row0 col3" >8.70</td>
#       <td id="T_8b689_row0_col4" class="data row0 col4" >0.57</td>
#     </tr>
#     <tr>
#       <td id="T_8b689_row1_col0" class="data row1 col0" >RCL</td>
#       <td id="T_8b689_row1_col1" class="data row1 col1" >2021-11-08</td>
#       <td id="T_8b689_row1_col2" class="data row1 col2" >27,000</td>
#       <td id="T_8b689_row1_col3" class="data row1 col3" >38.78</td>
#       <td id="T_8b689_row1_col4" class="data row1 col4" >2.50</td>
#     </tr>
#     <tr>
#       <td id="T_8b689_row2_col0" class="data row2 col0" >ORI</td>
#       <td id="T_8b689_row2_col1" class="data row2 col1" >2022-04-07</td>
#       <td id="T_8b689_row2_col2" class="data row2 col2" >50,000</td>
#       <td id="T_8b689_row2_col3" class="data row2 col3" >9.00</td>
#       <td id="T_8b689_row2_col4" class="data row2 col4" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_8b689_row3_col0" class="data row3 col0" >ADVANC</td>
#       <td id="T_8b689_row3_col1" class="data row3 col1" >2026-02-27</td>
#       <td id="T_8b689_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_8b689_row3_col3" class="data row3 col3" >380.00</td>
#       <td id="T_8b689_row3_col4" class="data row3 col4" >10.00</td>
#     </tr>
#     <tr>
#       <td id="T_8b689_row4_col0" class="data row4 col0" >CPNREIT</td>
#       <td id="T_8b689_row4_col1" class="data row4 col1" >2022-08-16</td>
#       <td id="T_8b689_row4_col2" class="data row4 col2" >55,000</td>
#       <td id="T_8b689_row4_col3" class="data row4 col3" >18.00</td>
#       <td id="T_8b689_row4_col4" class="data row4 col4" >0.83</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner", suffixes=("_mean","_today"))
df_merge3["qty_pct"] = round((df_merge3.qty_today - df_merge3.qty_mean) / abs(df_merge3.qty_mean) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_today - df_merge3.price_mean) / abs(df_merge3.price_mean) * 100,2)
df_merge3.rename(columns={'price_mean':'avg_price','price_today':'tdy_price',
                          'qty_mean':'avg_qty','qty_today':'tdy_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_06e2b">
#   <thead>
#     <tr>
#       <th id="T_06e2b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_06e2b_level0_col1" class="col_heading level0 col1" >prc_pct</th>
#       <th id="T_06e2b_level0_col2" class="col_heading level0 col2" >tdy_price</th>
#       <th id="T_06e2b_level0_col3" class="col_heading level0 col3" >avg_price</th>
#       <th id="T_06e2b_level0_col4" class="col_heading level0 col4" >qty_pct</th>
#       <th id="T_06e2b_level0_col5" class="col_heading level0 col5" >tdy_qty</th>
#       <th id="T_06e2b_level0_col6" class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\5-day-average.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\5-day-average.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\5-day-average.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\5-day-average.csv

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(god_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(icd_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad3a0">
#   <thead>
#     <tr>
#       <th id="T_ad3a0_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ad3a0_level0_col1" class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ad3a0_row0_col0" class="data row0 col0" >JMT</td>
#       <td id="T_ad3a0_row0_col1" class="data row0 col1" >B</td>
#     </tr>
#     <tr>
#       <td id="T_ad3a0_row1_col0" class="data row1 col0" >SYNEX</td>
#       <td id="T_ad3a0_row1_col1" class="data row1 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_ad3a0_row2_col0" class="data row2 col0" >MCS</td>
#       <td id="T_ad3a0_row2_col1" class="data row2 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_ad3a0_row3_col0" class="data row3 col0" >SENA</td>
#       <td id="T_ad3a0_row3_col1" class="data row3 col1" >X</td>
#     </tr>
#     <tr>
#       <td id="T_ad3a0_row4_col0" class="data row4 col0" >NER</td>
#       <td id="T_ad3a0_row4_col1" class="data row4 col1" >B</td>
#     </tr>
#   </tbody>
# </table>

# %%
stock_list = stocks["name"].unique().tolist()
stock_list_str = "','".join(stock_list)
print(stock_list_str)
# Out:
# AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC

# %%
sql = f"""
SELECT name, price 
FROM price 
WHERE date = {today} AND name IN ('{stock_list_str}') 
ORDER BY name"""
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = 2026-03-19 AND name IN ('AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC')
# ORDER BY name

# %%
tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# '0 stocks'

# %%
sql = f"""
SELECT name, price 
FROM price 
WHERE date = {yesterday} AND name IN ('{stock_list_str}') 
ORDER BY name"""
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = 2026-03-18 AND name IN ('AH','AWC','BCH','CPNREIT','DIF','GVREIT','IVL','3BBIF','JMT','MCS','NER','ORI','PTG','PTTGC','RCL','SENA','SINGER','STA','SYNEX','TFFIF','WHAIR','TOA','WHART','TVO','PTT','CPF','ADVANC')
# ORDER BY name

# %%
ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# '0 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner',suffixes=("_today","_yesterday"))
compare1.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_934c3">
#   <thead>
#     <tr>
#       <th id="T_934c3_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_934c3_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_934c3_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_61649">
#   <thead>
#     <tr>
#       <th id="T_61649_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_61649_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_61649_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#       <th id="T_61649_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
compare2.columns
# Out:
# Index(['name', 'price_today', 'price_yesterday', 'status'], dtype='object')

# %%
colx = ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']
colx
# Out:
# ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']

# %%
compare2['diff'] = round((compare2.price_today - compare2.price_yesterday),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_yesterday'] * 100,2)
compare2[colx].sort_values(['pct'],ascending=[False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8350">
#   <thead>
#     <tr>
#       <th id="T_f8350_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_f8350_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_f8350_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_f8350_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_f8350_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_f8350_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7fec">
#   <thead>
#     <tr>
#       <th id="T_b7fec_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b7fec_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_b7fec_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_b7fec_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_b7fec_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_b7fec_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\extremes.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\extremes.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\extremes.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\extremes.csv

# %%
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(god_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(icd_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(osd_file, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-03-19 20:38:57
