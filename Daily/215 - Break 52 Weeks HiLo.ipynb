# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
print(today)
# Out:
# 2026-02-06

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(today, yesterday)
# Out:
# 2026-02-06 2026-02-05

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-02-06 20:40:40

# %% [markdown]
# ### Restart and run all cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Daily
# Base path: C:\Users\PC1\OneDrive\A4
# Data path : C:\Users\PC1\OneDrive\A4\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}', 'volbuy':'{:,}',   
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}',
    'opnp':'{:.2f}','price_x':'{:.2f}','price_y':'{:.2f}',
    'price_today':'{:.2f}','price_yesterday':'{:.2f}',   
    'date':'{:%Y-%m-%d}',
    
    'price_mean':'{:.2f}','price_today':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}','dividend':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_mean':'{:,}','qty_today':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}','daily_volume':'{:,.2f}',   
    'value(m)':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2026, 2, 6)

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
#sql = sql % yesterday
print(sql)

prices = pd.read_sql(sql, const)
#prices.sample(5).style.format(format_dict)
prices.shape
# Out:
# SELECT *
# FROM price
# WHERE date = '2026-02-06'
# ORDER BY name
# (165, 7)

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b083">
#   <thead>
#     <tr>
#       <th id="T_7b083_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_7b083_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7b083_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_7b083_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_7b083_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_7b083_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_7b083_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_7b083_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_7b083_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_7b083_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_7b083_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_7b083_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_7b083_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_7b083_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_7b083_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7b083_row0_col0" class="data row0 col0" >915</td>
#       <td id="T_7b083_row0_col1" class="data row0 col1" >TIPCO</td>
#       <td id="T_7b083_row0_col2" class="data row0 col2" >sSET    </td>
#       <td id="T_7b083_row0_col3" class="data row0 col3" >7.60</td>
#       <td id="T_7b083_row0_col4" class="data row0 col4" >10.30</td>
#       <td id="T_7b083_row0_col5" class="data row0 col5" >7.50</td>
#       <td id="T_7b083_row0_col6" class="data row0 col6" >16.64</td>
#       <td id="T_7b083_row0_col7" class="data row0 col7" >0.97</td>
#       <td id="T_7b083_row0_col8" class="data row0 col8" >482.58</td>
#       <td id="T_7b083_row0_col9" class="data row0 col9" >4,367.35</td>
#       <td id="T_7b083_row0_col10" class="data row0 col10" >1.73</td>
#       <td id="T_7b083_row0_col11" class="data row0 col11" >0.45</td>
#       <td id="T_7b083_row0_col12" class="data row0 col12" >538</td>
#       <td id="T_7b083_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_7b083_row0_col14" class="data row0 col14" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_7b083_row1_col0" class="data row1 col0" >899</td>
#       <td id="T_7b083_row1_col1" class="data row1 col1" >STANLY</td>
#       <td id="T_7b083_row1_col2" class="data row1 col2" >sSET    </td>
#       <td id="T_7b083_row1_col3" class="data row1 col3" >192.50</td>
#       <td id="T_7b083_row1_col4" class="data row1 col4" >225.00</td>
#       <td id="T_7b083_row1_col5" class="data row1 col5" >176.00</td>
#       <td id="T_7b083_row1_col6" class="data row1 col6" >8.71</td>
#       <td id="T_7b083_row1_col7" class="data row1 col7" >0.71</td>
#       <td id="T_7b083_row1_col8" class="data row1 col8" >383.12</td>
#       <td id="T_7b083_row1_col9" class="data row1 col9" >14,405.50</td>
#       <td id="T_7b083_row1_col10" class="data row1 col10" >4.91</td>
#       <td id="T_7b083_row1_col11" class="data row1 col11" >0.56</td>
#       <td id="T_7b083_row1_col12" class="data row1 col12" >490</td>
#       <td id="T_7b083_row1_col13" class="data row1 col13" >2022-05-17</td>
#       <td id="T_7b083_row1_col14" class="data row1 col14" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_7b083_row2_col0" class="data row2 col0" >908</td>
#       <td id="T_7b083_row2_col1" class="data row2 col1" >TCAP</td>
#       <td id="T_7b083_row2_col2" class="data row2 col2" >SET100 / SETHD    </td>
#       <td id="T_7b083_row2_col3" class="data row2 col3" >56.75</td>
#       <td id="T_7b083_row2_col4" class="data row2 col4" >60.00</td>
#       <td id="T_7b083_row2_col5" class="data row2 col5" >44.25</td>
#       <td id="T_7b083_row2_col6" class="data row2 col6" >7.64</td>
#       <td id="T_7b083_row2_col7" class="data row2 col7" >0.67</td>
#       <td id="T_7b083_row2_col8" class="data row2 col8" >11,456.50</td>
#       <td id="T_7b083_row2_col9" class="data row2 col9" >49,262.94</td>
#       <td id="T_7b083_row2_col10" class="data row2 col10" >129.87</td>
#       <td id="T_7b083_row2_col11" class="data row2 col11" >0.86</td>
#       <td id="T_7b083_row2_col12" class="data row2 col12" >512</td>
#       <td id="T_7b083_row2_col13" class="data row2 col13" >2022-05-17</td>
#       <td id="T_7b083_row2_col14" class="data row2 col14" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_7b083_row3_col0" class="data row3 col0" >844</td>
#       <td id="T_7b083_row3_col1" class="data row3 col1" >MINT</td>
#       <td id="T_7b083_row3_col2" class="data row3 col2" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_7b083_row3_col3" class="data row3 col3" >25.25</td>
#       <td id="T_7b083_row3_col4" class="data row3 col4" >29.50</td>
#       <td id="T_7b083_row3_col5" class="data row3 col5" >19.60</td>
#       <td id="T_7b083_row3_col6" class="data row3 col6" >217.54</td>
#       <td id="T_7b083_row3_col7" class="data row3 col7" >2.46</td>
#       <td id="T_7b083_row3_col8" class="data row3 col8" >5,275.01</td>
#       <td id="T_7b083_row3_col9" class="data row3 col9" >178,031.75</td>
#       <td id="T_7b083_row3_col10" class="data row3 col10" >979.32</td>
#       <td id="T_7b083_row3_col11" class="data row3 col11" >1.35</td>
#       <td id="T_7b083_row3_col12" class="data row3 col12" >309</td>
#       <td id="T_7b083_row3_col13" class="data row3 col13" >2022-05-17</td>
#       <td id="T_7b083_row3_col14" class="data row3 col14" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_7b083_row4_col0" class="data row4 col0" >928</td>
#       <td id="T_7b083_row4_col1" class="data row4 col1" >TR</td>
#       <td id="T_7b083_row4_col2" class="data row4 col2" >SET    </td>
#       <td id="T_7b083_row4_col3" class="data row4 col3" >41.00</td>
#       <td id="T_7b083_row4_col4" class="data row4 col4" >44.00</td>
#       <td id="T_7b083_row4_col5" class="data row4 col5" >37.75</td>
#       <td id="T_7b083_row4_col6" class="data row4 col6" >2.96</td>
#       <td id="T_7b083_row4_col7" class="data row4 col7" >0.30</td>
#       <td id="T_7b083_row4_col8" class="data row4 col8" >201.60</td>
#       <td id="T_7b083_row4_col9" class="data row4 col9" >9,626.40</td>
#       <td id="T_7b083_row4_col10" class="data row4 col10" >0.24</td>
#       <td id="T_7b083_row4_col11" class="data row4 col11" >0.30</td>
#       <td id="T_7b083_row4_col12" class="data row4 col12" >573</td>
#       <td id="T_7b083_row4_col13" class="data row4 col13" >2022-05-17</td>
#       <td id="T_7b083_row4_col14" class="data row4 col14" >2024-09-20</td>
#     </tr>
#   </tbody>
# </table>

# %%
stocks.query('name == "JMT"').style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cac62">
#   <thead>
#     <tr>
#       <th id="T_cac62_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_cac62_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_cac62_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_cac62_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_cac62_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_cac62_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_cac62_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_cac62_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_cac62_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_cac62_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_cac62_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_cac62_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_cac62_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_cac62_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_cac62_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cac62_row0_col0" class="data row0 col0" >816</td>
#       <td id="T_cac62_row0_col1" class="data row0 col1" >JMT</td>
#       <td id="T_cac62_row0_col2" class="data row0 col2" >SET50    </td>
#       <td id="T_cac62_row0_col3" class="data row0 col3" >8.45</td>
#       <td id="T_cac62_row0_col4" class="data row0 col4" >14.90</td>
#       <td id="T_cac62_row0_col5" class="data row0 col5" >7.35</td>
#       <td id="T_cac62_row0_col6" class="data row0 col6" >45.05</td>
#       <td id="T_cac62_row0_col7" class="data row0 col7" >3.47</td>
#       <td id="T_cac62_row0_col8" class="data row0 col8" >729.58</td>
#       <td id="T_cac62_row0_col9" class="data row0 col9" >78,064.96</td>
#       <td id="T_cac62_row0_col10" class="data row0 col10" >675.65</td>
#       <td id="T_cac62_row0_col11" class="data row0 col11" >1.69</td>
#       <td id="T_cac62_row0_col12" class="data row0 col12" >245</td>
#       <td id="T_cac62_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_cac62_row0_col14" class="data row0 col14" >2026-02-05</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.drop(columns=['id','ticker_id','created_at','updated_at','paid_up','market_cap'],inplace=True)
#df_merge.sample(5).style.format(format_dict)
df_merge.head(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa462">
#   <thead>
#     <tr>
#       <th id="T_aa462_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_aa462_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_aa462_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_aa462_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_aa462_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_aa462_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_aa462_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_aa462_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_aa462_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_aa462_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_aa462_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_aa462_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_aa462_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_aa462_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_aa462_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa462_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_aa462_row0_col1" class="data row0 col1" >2026-02-06</td>
#       <td id="T_aa462_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_aa462_row0_col3" class="data row0 col3" >6.70</td>
#       <td id="T_aa462_row0_col4" class="data row0 col4" >6.65</td>
#       <td id="T_aa462_row0_col5" class="data row0 col5" >15,795,914</td>
#       <td id="T_aa462_row0_col6" class="data row0 col6" >6.65</td>
#       <td id="T_aa462_row0_col7" class="data row0 col7" >SET    </td>
#       <td id="T_aa462_row0_col8" class="data row0 col8" >6.65</td>
#       <td id="T_aa462_row0_col9" class="data row0 col9" >6.85</td>
#       <td id="T_aa462_row0_col10" class="data row0 col10" >5.15</td>
#       <td id="T_aa462_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_aa462_row0_col12" class="data row0 col12" >0.74</td>
#       <td id="T_aa462_row0_col13" class="data row0 col13" >40.31</td>
#       <td id="T_aa462_row0_col14" class="data row0 col14" >0.59</td>
#     </tr>
#     <tr>
#       <td id="T_aa462_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_aa462_row1_col1" class="data row1 col1" >2026-02-06</td>
#       <td id="T_aa462_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_aa462_row1_col3" class="data row1 col3" >1.30</td>
#       <td id="T_aa462_row1_col4" class="data row1 col4" >1.29</td>
#       <td id="T_aa462_row1_col5" class="data row1 col5" >524,901</td>
#       <td id="T_aa462_row1_col6" class="data row1 col6" >1.29</td>
#       <td id="T_aa462_row1_col7" class="data row1 col7" >SET100 / SETTHSI    </td>
#       <td id="T_aa462_row1_col8" class="data row1 col8" >1.29</td>
#       <td id="T_aa462_row1_col9" class="data row1 col9" >1.38</td>
#       <td id="T_aa462_row1_col10" class="data row1 col10" >1.23</td>
#       <td id="T_aa462_row1_col11" class="data row1 col11" >17.72</td>
#       <td id="T_aa462_row1_col12" class="data row1 col12" >1.82</td>
#       <td id="T_aa462_row1_col13" class="data row1 col13" >54.63</td>
#       <td id="T_aa462_row1_col14" class="data row1 col14" >0.92</td>
#     </tr>
#     <tr>
#       <td id="T_aa462_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_aa462_row2_col1" class="data row2 col1" >2026-02-06</td>
#       <td id="T_aa462_row2_col2" class="data row2 col2" >365.00</td>
#       <td id="T_aa462_row2_col3" class="data row2 col3" >373.00</td>
#       <td id="T_aa462_row2_col4" class="data row2 col4" >363.00</td>
#       <td id="T_aa462_row2_col5" class="data row2 col5" >10,824,649</td>
#       <td id="T_aa462_row2_col6" class="data row2 col6" >365.00</td>
#       <td id="T_aa462_row2_col7" class="data row2 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_aa462_row2_col8" class="data row2 col8" >367.00</td>
#       <td id="T_aa462_row2_col9" class="data row2 col9" >383.00</td>
#       <td id="T_aa462_row2_col10" class="data row2 col10" >259.00</td>
#       <td id="T_aa462_row2_col11" class="data row2 col11" >23.03</td>
#       <td id="T_aa462_row2_col12" class="data row2 col12" >7.52</td>
#       <td id="T_aa462_row2_col13" class="data row2 col13" >954.23</td>
#       <td id="T_aa462_row2_col14" class="data row2 col14" >0.79</td>
#     </tr>
#     <tr>
#       <td id="T_aa462_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_aa462_row3_col1" class="data row3 col1" >2026-02-06</td>
#       <td id="T_aa462_row3_col2" class="data row3 col2" >95.50</td>
#       <td id="T_aa462_row3_col3" class="data row3 col3" >97.00</td>
#       <td id="T_aa462_row3_col4" class="data row3 col4" >95.25</td>
#       <td id="T_aa462_row3_col5" class="data row3 col5" >910,697</td>
#       <td id="T_aa462_row3_col6" class="data row3 col6" >97.00</td>
#       <td id="T_aa462_row3_col7" class="data row3 col7" >SET    </td>
#       <td id="T_aa462_row3_col8" class="data row3 col8" >96.75</td>
#       <td id="T_aa462_row3_col9" class="data row3 col9" >122.50</td>
#       <td id="T_aa462_row3_col10" class="data row3 col10" >90.50</td>
#       <td id="T_aa462_row3_col11" class="data row3 col11" >12.18</td>
#       <td id="T_aa462_row3_col12" class="data row3 col12" >2.26</td>
#       <td id="T_aa462_row3_col13" class="data row3 col13" >100.95</td>
#       <td id="T_aa462_row3_col14" class="data row3 col14" >1.15</td>
#     </tr>
#     <tr>
#       <td id="T_aa462_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_aa462_row4_col1" class="data row4 col1" >2026-02-06</td>
#       <td id="T_aa462_row4_col2" class="data row4 col2" >13.20</td>
#       <td id="T_aa462_row4_col3" class="data row4 col3" >13.30</td>
#       <td id="T_aa462_row4_col4" class="data row4 col4" >13.00</td>
#       <td id="T_aa462_row4_col5" class="data row4 col5" >180,574</td>
#       <td id="T_aa462_row4_col6" class="data row4 col6" >13.00</td>
#       <td id="T_aa462_row4_col7" class="data row4 col7" >sSET / SETTHSI    </td>
#       <td id="T_aa462_row4_col8" class="data row4 col8" >13.10</td>
#       <td id="T_aa462_row4_col9" class="data row4 col9" >15.80</td>
#       <td id="T_aa462_row4_col10" class="data row4 col10" >10.00</td>
#       <td id="T_aa462_row4_col11" class="data row4 col11" >7.48</td>
#       <td id="T_aa462_row4_col12" class="data row4 col12" >1.21</td>
#       <td id="T_aa462_row4_col13" class="data row4 col13" >70.31</td>
#       <td id="T_aa462_row4_col14" class="data row4 col14" >1.51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d731">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d731_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_5d731_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_5d731_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_5d731_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_5d731_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_5d731_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d731_level0_row0" class="row_heading level0 row0" >76</th>
#       <td id="T_5d731_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_5d731_row0_col1" class="data row0 col1" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_5d731_row0_col2" class="data row0 col2" >72.50</td>
#       <td id="T_5d731_row0_col3" class="data row0 col3" >73.50</td>
#       <td id="T_5d731_row0_col4" class="data row0 col4" >73.00</td>
#       <td id="T_5d731_row0_col5" class="data row0 col5" >4,471,209</td>
#     </tr>
#     <tr>
#       <th id="T_5d731_level0_row1" class="row_heading level0 row1" >103</th>
#       <td id="T_5d731_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_5d731_row1_col1" class="data row1 col1" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_5d731_row1_col2" class="data row1 col2" >35.25</td>
#       <td id="T_5d731_row1_col3" class="data row1 col3" >35.50</td>
#       <td id="T_5d731_row1_col4" class="data row1 col4" >35.25</td>
#       <td id="T_5d731_row1_col5" class="data row1 col5" >58,620,929</td>
#     </tr>
#     <tr>
#       <th id="T_5d731_level0_row2" class="row_heading level0 row2" >127</th>
#       <td id="T_5d731_row2_col0" class="data row2 col0" >SPRC</td>
#       <td id="T_5d731_row2_col1" class="data row2 col1" >SET100 / SETCLMV    </td>
#       <td id="T_5d731_row2_col2" class="data row2 col2" >7.15</td>
#       <td id="T_5d731_row2_col3" class="data row2 col3" >7.15</td>
#       <td id="T_5d731_row2_col4" class="data row2 col4" >6.95</td>
#       <td id="T_5d731_row2_col5" class="data row2 col5" >36,396,256</td>
#     </tr>
#     <tr>
#       <th id="T_5d731_level0_row3" class="row_heading level0 row3" >147</th>
#       <td id="T_5d731_row3_col0" class="data row3 col0" >TOP</td>
#       <td id="T_5d731_row3_col1" class="data row3 col1" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_5d731_row3_col2" class="data row3 col2" >47.75</td>
#       <td id="T_5d731_row3_col3" class="data row3 col3" >48.00</td>
#       <td id="T_5d731_row3_col4" class="data row3 col4" >45.75</td>
#       <td id="T_5d731_row3_col5" class="data row3 col5" >20,854,958</td>
#     </tr>
#   </tbody>
# </table>

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 4 stocks'

# %% [markdown]
# ### New High by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ebd8">
#   <thead>
#     <tr>
#       <th id="T_4ebd8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_4ebd8_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_4ebd8_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_4ebd8_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_4ebd8_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_4ebd8_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_4ebd8_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_4ebd8_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_4ebd8_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_4ebd8_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_4ebd8_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_4ebd8_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_4ebd8_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_4ebd8_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_4ebd8_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ebd8_row0_col0" class="data row0 col0" >PTT</td>
#       <td id="T_4ebd8_row0_col1" class="data row0 col1" >2026-02-06</td>
#       <td id="T_4ebd8_row0_col2" class="data row0 col2" >35.25</td>
#       <td id="T_4ebd8_row0_col3" class="data row0 col3" >35.50</td>
#       <td id="T_4ebd8_row0_col4" class="data row0 col4" >35.00</td>
#       <td id="T_4ebd8_row0_col5" class="data row0 col5" >58,620,929</td>
#       <td id="T_4ebd8_row0_col6" class="data row0 col6" >35.25</td>
#       <td id="T_4ebd8_row0_col7" class="data row0 col7" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_4ebd8_row0_col8" class="data row0 col8" >35.25</td>
#       <td id="T_4ebd8_row0_col9" class="data row0 col9" >35.25</td>
#       <td id="T_4ebd8_row0_col10" class="data row0 col10" >27.00</td>
#       <td id="T_4ebd8_row0_col11" class="data row0 col11" >9.42</td>
#       <td id="T_4ebd8_row0_col12" class="data row0 col12" >0.88</td>
#       <td id="T_4ebd8_row0_col13" class="data row0 col13" >1,410.13</td>
#       <td id="T_4ebd8_row0_col14" class="data row0 col14" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_4ebd8_row1_col0" class="data row1 col0" >TOP</td>
#       <td id="T_4ebd8_row1_col1" class="data row1 col1" >2026-02-06</td>
#       <td id="T_4ebd8_row1_col2" class="data row1 col2" >47.75</td>
#       <td id="T_4ebd8_row1_col3" class="data row1 col3" >48.00</td>
#       <td id="T_4ebd8_row1_col4" class="data row1 col4" >45.25</td>
#       <td id="T_4ebd8_row1_col5" class="data row1 col5" >20,854,958</td>
#       <td id="T_4ebd8_row1_col6" class="data row1 col6" >45.25</td>
#       <td id="T_4ebd8_row1_col7" class="data row1 col7" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_4ebd8_row1_col8" class="data row1 col8" >45.50</td>
#       <td id="T_4ebd8_row1_col9" class="data row1 col9" >45.75</td>
#       <td id="T_4ebd8_row1_col10" class="data row1 col10" >21.00</td>
#       <td id="T_4ebd8_row1_col11" class="data row1 col11" >3.55</td>
#       <td id="T_4ebd8_row1_col12" class="data row1 col12" >0.86</td>
#       <td id="T_4ebd8_row1_col13" class="data row1 col13" >606.83</td>
#       <td id="T_4ebd8_row1_col14" class="data row1 col14" >1.07</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100H = Final_High["market"].str.contains("SET100")
Final_High[set100H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8025e">
#   <thead>
#     <tr>
#       <th id="T_8025e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8025e_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_8025e_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_8025e_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_8025e_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_8025e_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_8025e_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_8025e_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_8025e_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_8025e_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_8025e_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_8025e_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_8025e_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_8025e_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_8025e_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8025e_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_8025e_row0_col1" class="data row0 col1" >2026-02-06</td>
#       <td id="T_8025e_row0_col2" class="data row0 col2" >72.50</td>
#       <td id="T_8025e_row0_col3" class="data row0 col3" >73.50</td>
#       <td id="T_8025e_row0_col4" class="data row0 col4" >72.25</td>
#       <td id="T_8025e_row0_col5" class="data row0 col5" >4,471,209</td>
#       <td id="T_8025e_row0_col6" class="data row0 col6" >73.00</td>
#       <td id="T_8025e_row0_col7" class="data row0 col7" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_8025e_row0_col8" class="data row0 col8" >73.00</td>
#       <td id="T_8025e_row0_col9" class="data row0 col9" >73.00</td>
#       <td id="T_8025e_row0_col10" class="data row0 col10" >43.50</td>
#       <td id="T_8025e_row0_col11" class="data row0 col11" >7.21</td>
#       <td id="T_8025e_row0_col12" class="data row0 col12" >1.10</td>
#       <td id="T_8025e_row0_col13" class="data row0 col13" >513.30</td>
#       <td id="T_8025e_row0_col14" class="data row0 col14" >0.84</td>
#     </tr>
#     <tr>
#       <td id="T_8025e_row1_col0" class="data row1 col0" >SPRC</td>
#       <td id="T_8025e_row1_col1" class="data row1 col1" >2026-02-06</td>
#       <td id="T_8025e_row1_col2" class="data row1 col2" >7.15</td>
#       <td id="T_8025e_row1_col3" class="data row1 col3" >7.15</td>
#       <td id="T_8025e_row1_col4" class="data row1 col4" >6.70</td>
#       <td id="T_8025e_row1_col5" class="data row1 col5" >36,396,256</td>
#       <td id="T_8025e_row1_col6" class="data row1 col6" >6.75</td>
#       <td id="T_8025e_row1_col7" class="data row1 col7" >SET100 / SETCLMV    </td>
#       <td id="T_8025e_row1_col8" class="data row1 col8" >6.70</td>
#       <td id="T_8025e_row1_col9" class="data row1 col9" >6.95</td>
#       <td id="T_8025e_row1_col10" class="data row1 col10" >4.26</td>
#       <td id="T_8025e_row1_col11" class="data row1 col11" >5.43</td>
#       <td id="T_8025e_row1_col12" class="data row1 col12" >1.18</td>
#       <td id="T_8025e_row1_col13" class="data row1 col13" >295.42</td>
#       <td id="T_8025e_row1_col14" class="data row1 col14" >0.98</td>
#     </tr>
#   </tbody>
# </table>

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a04c4">
#   <thead>
#     <tr>
#       <th id="T_a04c4_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a04c4_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_a04c4_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_a04c4_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_a04c4_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_a04c4_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_a04c4_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_a04c4_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_a04c4_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_a04c4_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_a04c4_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_a04c4_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_a04c4_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_a04c4_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_a04c4_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1c392">
#   <thead>
#     <tr>
#       <th id="T_1c392_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1c392_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_1c392_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_1c392_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_1c392_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_1c392_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_1c392_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_1c392_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_1c392_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_1c392_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_1c392_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_1c392_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_1c392_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_1c392_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_1c392_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9234d">
#   <thead>
#     <tr>
#       <th id="T_9234d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9234d_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_9234d_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_9234d_level0_col3" class="col_heading level0 col3" >minp</th>
#       <th id="T_9234d_level0_col4" class="col_heading level0 col4" >min_price</th>
#       <th id="T_9234d_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 0 stocks'

# %% [markdown]
# ### New Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_56076">
#   <thead>
#     <tr>
#       <th id="T_56076_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_56076_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_56076_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_56076_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_56076_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_56076_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_56076_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_56076_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_56076_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_56076_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_56076_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_56076_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_56076_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_56076_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_56076_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3198d">
#   <thead>
#     <tr>
#       <th id="T_3198d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3198d_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_3198d_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_3198d_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_3198d_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_3198d_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_3198d_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_3198d_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_3198d_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_3198d_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_3198d_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_3198d_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_3198d_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_3198d_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_3198d_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ee84">
#   <thead>
#     <tr>
#       <th id="T_7ee84_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7ee84_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_7ee84_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_7ee84_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_7ee84_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_7ee84_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_7ee84_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_7ee84_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_7ee84_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_7ee84_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_7ee84_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_7ee84_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_7ee84_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_7ee84_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_7ee84_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT name, qty, price, date As today
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = '2026-02-06'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_db424">
#   <thead>
#     <tr>
#       <th id="T_db424_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_db424_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_db424_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_db424_level0_col3" class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db424_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_db424_row0_col1" class="data row0 col1" >15,795,914</td>
#       <td id="T_db424_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_db424_row0_col3" class="data row0 col3" >2026-02-06</td>
#     </tr>
#     <tr>
#       <td id="T_db424_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_db424_row1_col1" class="data row1 col1" >524,901</td>
#       <td id="T_db424_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_db424_row1_col3" class="data row1 col3" >2026-02-06</td>
#     </tr>
#     <tr>
#       <td id="T_db424_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_db424_row2_col1" class="data row2 col1" >10,824,649</td>
#       <td id="T_db424_row2_col2" class="data row2 col2" >365.00</td>
#       <td id="T_db424_row2_col3" class="data row2 col3" >2026-02-06</td>
#     </tr>
#     <tr>
#       <td id="T_db424_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_db424_row3_col1" class="data row3 col1" >910,697</td>
#       <td id="T_db424_row3_col2" class="data row3 col2" >95.50</td>
#       <td id="T_db424_row3_col3" class="data row3 col3" >2026-02-06</td>
#     </tr>
#     <tr>
#       <td id="T_db424_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_db424_row4_col1" class="data row4 col1" >180,574</td>
#       <td id="T_db424_row4_col2" class="data row4 col2" >13.20</td>
#       <td id="T_db424_row4_col3" class="data row4 col3" >2026-02-06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2026, 2, 5)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa071">
#   <thead>
#     <tr>
#       <th id="T_fa071_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_fa071_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_fa071_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_fa071_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_fa071_level0_col4" class="col_heading level0 col4" >end_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fa071_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_fa071_row0_col1" class="data row0 col1" >15,795,914</td>
#       <td id="T_fa071_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_fa071_row0_col3" class="data row0 col3" >2026-02-06</td>
#       <td id="T_fa071_row0_col4" class="data row0 col4" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_fa071_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_fa071_row1_col1" class="data row1 col1" >524,901</td>
#       <td id="T_fa071_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_fa071_row1_col3" class="data row1 col3" >2026-02-06</td>
#       <td id="T_fa071_row1_col4" class="data row1 col4" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_fa071_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_fa071_row2_col1" class="data row2 col1" >10,824,649</td>
#       <td id="T_fa071_row2_col2" class="data row2 col2" >365.00</td>
#       <td id="T_fa071_row2_col3" class="data row2 col3" >2026-02-06</td>
#       <td id="T_fa071_row2_col4" class="data row2 col4" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_fa071_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_fa071_row3_col1" class="data row3 col1" >910,697</td>
#       <td id="T_fa071_row3_col2" class="data row3 col2" >95.50</td>
#       <td id="T_fa071_row3_col3" class="data row3 col3" >2026-02-06</td>
#       <td id="T_fa071_row3_col4" class="data row3 col4" >2026-02-05</td>
#     </tr>
#     <tr>
#       <td id="T_fa071_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_fa071_row4_col1" class="data row4 col1" >180,574</td>
#       <td id="T_fa071_row4_col2" class="data row4 col2" >13.20</td>
#       <td id="T_fa071_row4_col3" class="data row4 col3" >2026-02-06</td>
#       <td id="T_fa071_row4_col4" class="data row4 col4" >2026-02-05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2026, 2, 4)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['start_date'] = today_vol['end_date'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ab4a">
#   <thead>
#     <tr>
#       <th id="T_5ab4a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_5ab4a_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_5ab4a_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_5ab4a_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_5ab4a_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_5ab4a_level0_col5" class="col_heading level0 col5" >start_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5ab4a_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_5ab4a_row0_col1" class="data row0 col1" >15,795,914</td>
#       <td id="T_5ab4a_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_5ab4a_row0_col3" class="data row0 col3" >2026-02-06</td>
#       <td id="T_5ab4a_row0_col4" class="data row0 col4" >2026-02-05</td>
#       <td id="T_5ab4a_row0_col5" class="data row0 col5" >2026-02-04</td>
#     </tr>
#     <tr>
#       <td id="T_5ab4a_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_5ab4a_row1_col1" class="data row1 col1" >524,901</td>
#       <td id="T_5ab4a_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_5ab4a_row1_col3" class="data row1 col3" >2026-02-06</td>
#       <td id="T_5ab4a_row1_col4" class="data row1 col4" >2026-02-05</td>
#       <td id="T_5ab4a_row1_col5" class="data row1 col5" >2026-02-04</td>
#     </tr>
#     <tr>
#       <td id="T_5ab4a_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_5ab4a_row2_col1" class="data row2 col1" >10,824,649</td>
#       <td id="T_5ab4a_row2_col2" class="data row2 col2" >365.00</td>
#       <td id="T_5ab4a_row2_col3" class="data row2 col3" >2026-02-06</td>
#       <td id="T_5ab4a_row2_col4" class="data row2 col4" >2026-02-05</td>
#       <td id="T_5ab4a_row2_col5" class="data row2 col5" >2026-02-04</td>
#     </tr>
#     <tr>
#       <td id="T_5ab4a_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_5ab4a_row3_col1" class="data row3 col1" >910,697</td>
#       <td id="T_5ab4a_row3_col2" class="data row3 col2" >95.50</td>
#       <td id="T_5ab4a_row3_col3" class="data row3 col3" >2026-02-06</td>
#       <td id="T_5ab4a_row3_col4" class="data row3 col4" >2026-02-05</td>
#       <td id="T_5ab4a_row3_col5" class="data row3 col5" >2026-02-04</td>
#     </tr>
#     <tr>
#       <td id="T_5ab4a_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_5ab4a_row4_col1" class="data row4 col1" >180,574</td>
#       <td id="T_5ab4a_row4_col2" class="data row4 col2" >13.20</td>
#       <td id="T_5ab4a_row4_col3" class="data row4 col3" >2026-02-06</td>
#       <td id="T_5ab4a_row4_col4" class="data row4 col4" >2026-02-05</td>
#       <td id="T_5ab4a_row4_col5" class="data row4 col5" >2026-02-04</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (start_date, end_date)
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name','date'],ascending=[True,True]).head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN '2026-02-04' AND '2026-02-05'
# <style type="text/css">
# </style>
# <table id="T_faac4">
#   <thead>
#     <tr>
#       <th id="T_faac4_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_faac4_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_faac4_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_faac4_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_faac4_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_faac4_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_faac4_level0_col6" class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_faac4_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_faac4_row0_col1" class="data row0 col1" >2026-02-04</td>
#       <td id="T_faac4_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_faac4_row0_col3" class="data row0 col3" >6.70</td>
#       <td id="T_faac4_row0_col4" class="data row0 col4" >6.60</td>
#       <td id="T_faac4_row0_col5" class="data row0 col5" >26,627,816</td>
#       <td id="T_faac4_row0_col6" class="data row0 col6" >6.60</td>
#     </tr>
#     <tr>
#       <td id="T_faac4_row1_col0" class="data row1 col0" >3BBIF</td>
#       <td id="T_faac4_row1_col1" class="data row1 col1" >2026-02-05</td>
#       <td id="T_faac4_row1_col2" class="data row1 col2" >6.65</td>
#       <td id="T_faac4_row1_col3" class="data row1 col3" >6.70</td>
#       <td id="T_faac4_row1_col4" class="data row1 col4" >6.65</td>
#       <td id="T_faac4_row1_col5" class="data row1 col5" >17,683,558</td>
#       <td id="T_faac4_row1_col6" class="data row1 col6" >6.70</td>
#     </tr>
#     <tr>
#       <td id="T_faac4_row2_col0" class="data row2 col0" >ACE</td>
#       <td id="T_faac4_row2_col1" class="data row2 col1" >2026-02-04</td>
#       <td id="T_faac4_row2_col2" class="data row2 col2" >1.30</td>
#       <td id="T_faac4_row2_col3" class="data row2 col3" >1.30</td>
#       <td id="T_faac4_row2_col4" class="data row2 col4" >1.29</td>
#       <td id="T_faac4_row2_col5" class="data row2 col5" >983,938</td>
#       <td id="T_faac4_row2_col6" class="data row2 col6" >1.30</td>
#     </tr>
#     <tr>
#       <td id="T_faac4_row3_col0" class="data row3 col0" >ACE</td>
#       <td id="T_faac4_row3_col1" class="data row3 col1" >2026-02-05</td>
#       <td id="T_faac4_row3_col2" class="data row3 col2" >1.29</td>
#       <td id="T_faac4_row3_col3" class="data row3 col3" >1.30</td>
#       <td id="T_faac4_row3_col4" class="data row3 col4" >1.29</td>
#       <td id="T_faac4_row3_col5" class="data row3 col5" >517,052</td>
#       <td id="T_faac4_row3_col6" class="data row3 col6" >1.30</td>
#     </tr>
#     <tr>
#       <td id="T_faac4_row4_col0" class="data row4 col0" >ADVANC</td>
#       <td id="T_faac4_row4_col1" class="data row4 col1" >2026-02-04</td>
#       <td id="T_faac4_row4_col2" class="data row4 col2" >374.00</td>
#       <td id="T_faac4_row4_col3" class="data row4 col3" >381.00</td>
#       <td id="T_faac4_row4_col4" class="data row4 col4" >370.00</td>
#       <td id="T_faac4_row4_col5" class="data row4 col5" >13,641,121</td>
#       <td id="T_faac4_row4_col6" class="data row4 col6" >376.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner", 
                     suffixes=( "_today","_mean"))
df_merge2.columns
# Out:
# Index(['name', 'qty_today', 'price_today', 'today', 'end_date', 'start_date',
#        'qty_mean', 'price_mean'],
#       dtype='object')

# %%
df_merge2["qty_mean"] = df_merge2.qty_mean.astype("int64")
df_merge2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_93264">
#   <thead>
#     <tr>
#       <th id="T_93264_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_93264_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_93264_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_93264_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_93264_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_93264_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_93264_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_93264_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93264_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_93264_row0_col1" class="data row0 col1" >15,795,914</td>
#       <td id="T_93264_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_93264_row0_col3" class="data row0 col3" >2026-02-06</td>
#       <td id="T_93264_row0_col4" class="data row0 col4" >2026-02-05</td>
#       <td id="T_93264_row0_col5" class="data row0 col5" >2026-02-04</td>
#       <td id="T_93264_row0_col6" class="data row0 col6" >22,155,687</td>
#       <td id="T_93264_row0_col7" class="data row0 col7" >6.65</td>
#     </tr>
#     <tr>
#       <td id="T_93264_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_93264_row1_col1" class="data row1 col1" >524,901</td>
#       <td id="T_93264_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_93264_row1_col3" class="data row1 col3" >2026-02-06</td>
#       <td id="T_93264_row1_col4" class="data row1 col4" >2026-02-05</td>
#       <td id="T_93264_row1_col5" class="data row1 col5" >2026-02-04</td>
#       <td id="T_93264_row1_col6" class="data row1 col6" >750,495</td>
#       <td id="T_93264_row1_col7" class="data row1 col7" >1.29</td>
#     </tr>
#     <tr>
#       <td id="T_93264_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_93264_row2_col1" class="data row2 col1" >10,824,649</td>
#       <td id="T_93264_row2_col2" class="data row2 col2" >365.00</td>
#       <td id="T_93264_row2_col3" class="data row2 col3" >2026-02-06</td>
#       <td id="T_93264_row2_col4" class="data row2 col4" >2026-02-05</td>
#       <td id="T_93264_row2_col5" class="data row2 col5" >2026-02-04</td>
#       <td id="T_93264_row2_col6" class="data row2 col6" >16,138,618</td>
#       <td id="T_93264_row2_col7" class="data row2 col7" >370.50</td>
#     </tr>
#     <tr>
#       <td id="T_93264_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_93264_row3_col1" class="data row3 col1" >910,697</td>
#       <td id="T_93264_row3_col2" class="data row3 col2" >95.50</td>
#       <td id="T_93264_row3_col3" class="data row3 col3" >2026-02-06</td>
#       <td id="T_93264_row3_col4" class="data row3 col4" >2026-02-05</td>
#       <td id="T_93264_row3_col5" class="data row3 col5" >2026-02-04</td>
#       <td id="T_93264_row3_col6" class="data row3 col6" >812,522</td>
#       <td id="T_93264_row3_col7" class="data row3 col7" >96.12</td>
#     </tr>
#     <tr>
#       <td id="T_93264_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_93264_row4_col1" class="data row4 col1" >180,574</td>
#       <td id="T_93264_row4_col2" class="data row4 col2" >13.20</td>
#       <td id="T_93264_row4_col3" class="data row4 col3" >2026-02-06</td>
#       <td id="T_93264_row4_col4" class="data row4 col4" >2026-02-05</td>
#       <td id="T_93264_row4_col5" class="data row4 col5" >2026-02-04</td>
#       <td id="T_93264_row4_col6" class="data row4 col6" >186,886</td>
#       <td id="T_93264_row4_col7" class="data row4 col7" >13.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_today > df_merge2.qty_mean)]
break_five_day_mean.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_57f4d">
#   <thead>
#     <tr>
#       <th id="T_57f4d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_57f4d_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_57f4d_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_57f4d_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_57f4d_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_57f4d_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_57f4d_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_57f4d_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_57f4d_row0_col0" class="data row0 col0" >AEONTS</td>
#       <td id="T_57f4d_row0_col1" class="data row0 col1" >910,697</td>
#       <td id="T_57f4d_row0_col2" class="data row0 col2" >95.50</td>
#       <td id="T_57f4d_row0_col3" class="data row0 col3" >2026-02-06</td>
#       <td id="T_57f4d_row0_col4" class="data row0 col4" >2026-02-05</td>
#       <td id="T_57f4d_row0_col5" class="data row0 col5" >2026-02-04</td>
#       <td id="T_57f4d_row0_col6" class="data row0 col6" >812,522</td>
#       <td id="T_57f4d_row0_col7" class="data row0 col7" >96.12</td>
#     </tr>
#     <tr>
#       <td id="T_57f4d_row1_col0" class="data row1 col0" >AIE</td>
#       <td id="T_57f4d_row1_col1" class="data row1 col1" >1,078,953</td>
#       <td id="T_57f4d_row1_col2" class="data row1 col2" >1.04</td>
#       <td id="T_57f4d_row1_col3" class="data row1 col3" >2026-02-06</td>
#       <td id="T_57f4d_row1_col4" class="data row1 col4" >2026-02-05</td>
#       <td id="T_57f4d_row1_col5" class="data row1 col5" >2026-02-04</td>
#       <td id="T_57f4d_row1_col6" class="data row1 col6" >293,900</td>
#       <td id="T_57f4d_row1_col7" class="data row1 col7" >1.01</td>
#     </tr>
#     <tr>
#       <td id="T_57f4d_row2_col0" class="data row2 col0" >AIT</td>
#       <td id="T_57f4d_row2_col1" class="data row2 col1" >554,772</td>
#       <td id="T_57f4d_row2_col2" class="data row2 col2" >4.98</td>
#       <td id="T_57f4d_row2_col3" class="data row2 col3" >2026-02-06</td>
#       <td id="T_57f4d_row2_col4" class="data row2 col4" >2026-02-05</td>
#       <td id="T_57f4d_row2_col5" class="data row2 col5" >2026-02-04</td>
#       <td id="T_57f4d_row2_col6" class="data row2 col6" >365,353</td>
#       <td id="T_57f4d_row2_col7" class="data row2 col7" >4.97</td>
#     </tr>
#     <tr>
#       <td id="T_57f4d_row3_col0" class="data row3 col0" >AOT</td>
#       <td id="T_57f4d_row3_col1" class="data row3 col1" >33,164,263</td>
#       <td id="T_57f4d_row3_col2" class="data row3 col2" >53.00</td>
#       <td id="T_57f4d_row3_col3" class="data row3 col3" >2026-02-06</td>
#       <td id="T_57f4d_row3_col4" class="data row3 col4" >2026-02-05</td>
#       <td id="T_57f4d_row3_col5" class="data row3 col5" >2026-02-04</td>
#       <td id="T_57f4d_row3_col6" class="data row3 col6" >17,502,318</td>
#       <td id="T_57f4d_row3_col7" class="data row3 col7" >52.00</td>
#     </tr>
#     <tr>
#       <td id="T_57f4d_row4_col0" class="data row4 col0" >ASIAN</td>
#       <td id="T_57f4d_row4_col1" class="data row4 col1" >671,875</td>
#       <td id="T_57f4d_row4_col2" class="data row4 col2" >7.50</td>
#       <td id="T_57f4d_row4_col3" class="data row4 col3" >2026-02-06</td>
#       <td id="T_57f4d_row4_col4" class="data row4 col4" >2026-02-05</td>
#       <td id="T_57f4d_row4_col5" class="data row4 col5" >2026-02-04</td>
#       <td id="T_57f4d_row4_col6" class="data row4 col6" >479,066</td>
#       <td id="T_57f4d_row4_col7" class="data row4 col7" >7.47</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT name, date, volbuy, price, dividend 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.volbuy = buys.volbuy.astype("int64")
buys.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5c25">
#   <thead>
#     <tr>
#       <th id="T_a5c25_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a5c25_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_a5c25_level0_col2" class="col_heading level0 col2" >volbuy</th>
#       <th id="T_a5c25_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_a5c25_level0_col4" class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a5c25_row0_col0" class="data row0 col0" >PTTGC</td>
#       <td id="T_a5c25_row0_col1" class="data row0 col1" >2021-03-17</td>
#       <td id="T_a5c25_row0_col2" class="data row0 col2" >6,000</td>
#       <td id="T_a5c25_row0_col3" class="data row0 col3" >64.75</td>
#       <td id="T_a5c25_row0_col4" class="data row0 col4" >0.50</td>
#     </tr>
#     <tr>
#       <td id="T_a5c25_row1_col0" class="data row1 col0" >WHAIR</td>
#       <td id="T_a5c25_row1_col1" class="data row1 col1" >2021-10-11</td>
#       <td id="T_a5c25_row1_col2" class="data row1 col2" >50,000</td>
#       <td id="T_a5c25_row1_col3" class="data row1 col3" >8.70</td>
#       <td id="T_a5c25_row1_col4" class="data row1 col4" >0.46</td>
#     </tr>
#     <tr>
#       <td id="T_a5c25_row2_col0" class="data row2 col0" >WHART</td>
#       <td id="T_a5c25_row2_col1" class="data row2 col1" >2022-01-05</td>
#       <td id="T_a5c25_row2_col2" class="data row2 col2" >20,000</td>
#       <td id="T_a5c25_row2_col3" class="data row2 col3" >12.30</td>
#       <td id="T_a5c25_row2_col4" class="data row2 col4" >0.69</td>
#     </tr>
#     <tr>
#       <td id="T_a5c25_row3_col0" class="data row3 col0" >SCC</td>
#       <td id="T_a5c25_row3_col1" class="data row3 col1" >2021-09-20</td>
#       <td id="T_a5c25_row3_col2" class="data row3 col2" >600</td>
#       <td id="T_a5c25_row3_col3" class="data row3 col3" >405.00</td>
#       <td id="T_a5c25_row3_col4" class="data row3 col4" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_a5c25_row4_col0" class="data row4 col0" >3BBIF</td>
#       <td id="T_a5c25_row4_col1" class="data row4 col1" >2018-05-17</td>
#       <td id="T_a5c25_row4_col2" class="data row4 col2" >120,000</td>
#       <td id="T_a5c25_row4_col3" class="data row4 col3" >10.10</td>
#       <td id="T_a5c25_row4_col4" class="data row4 col4" >0.52</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner", suffixes=("_mean","_today"))
df_merge3["qty_pct"] = round((df_merge3.qty_today - df_merge3.qty_mean) / abs(df_merge3.qty_mean) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_today - df_merge3.price_mean) / abs(df_merge3.price_mean) * 100,2)
df_merge3.rename(columns={'price_mean':'avg_price','price_today':'tdy_price',
                          'qty_mean':'avg_qty','qty_today':'tdy_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_824cd">
#   <thead>
#     <tr>
#       <th id="T_824cd_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_824cd_level0_col1" class="col_heading level0 col1" >prc_pct</th>
#       <th id="T_824cd_level0_col2" class="col_heading level0 col2" >tdy_price</th>
#       <th id="T_824cd_level0_col3" class="col_heading level0 col3" >avg_price</th>
#       <th id="T_824cd_level0_col4" class="col_heading level0 col4" >qty_pct</th>
#       <th id="T_824cd_level0_col5" class="col_heading level0 col5" >tdy_qty</th>
#       <th id="T_824cd_level0_col6" class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_824cd_row0_col0" class="data row0 col0" >SCC</td>
#       <td id="T_824cd_row0_col1" class="data row0 col1" >2.59%</td>
#       <td id="T_824cd_row0_col2" class="data row0 col2" >218.00</td>
#       <td id="T_824cd_row0_col3" class="data row0 col3" >212.50</td>
#       <td id="T_824cd_row0_col4" class="data row0 col4" >112.92%</td>
#       <td id="T_824cd_row0_col5" class="data row0 col5" >6,614,213</td>
#       <td id="T_824cd_row0_col6" class="data row0 col6" >3,106,405</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row1_col0" class="data row1 col0" >CPF</td>
#       <td id="T_824cd_row1_col1" class="data row1 col1" >1.69%</td>
#       <td id="T_824cd_row1_col2" class="data row1 col2" >21.00</td>
#       <td id="T_824cd_row1_col3" class="data row1 col3" >20.65</td>
#       <td id="T_824cd_row1_col4" class="data row1 col4" >33.87%</td>
#       <td id="T_824cd_row1_col5" class="data row1 col5" >21,513,744</td>
#       <td id="T_824cd_row1_col6" class="data row1 col6" >16,070,448</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row2_col0" class="data row2 col0" >BCH</td>
#       <td id="T_824cd_row2_col1" class="data row2 col1" >0.75%</td>
#       <td id="T_824cd_row2_col2" class="data row2 col2" >10.10</td>
#       <td id="T_824cd_row2_col3" class="data row2 col3" >10.02</td>
#       <td id="T_824cd_row2_col4" class="data row2 col4" >27.87%</td>
#       <td id="T_824cd_row2_col5" class="data row2 col5" >18,367,895</td>
#       <td id="T_824cd_row2_col6" class="data row2 col6" >14,364,716</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row3_col0" class="data row3 col0" >TFFIF</td>
#       <td id="T_824cd_row3_col1" class="data row3 col1" >0.38%</td>
#       <td id="T_824cd_row3_col2" class="data row3 col2" >6.65</td>
#       <td id="T_824cd_row3_col3" class="data row3 col3" >6.62</td>
#       <td id="T_824cd_row3_col4" class="data row3 col4" >68.22%</td>
#       <td id="T_824cd_row3_col5" class="data row3 col5" >5,598,529</td>
#       <td id="T_824cd_row3_col6" class="data row3 col6" >3,328,196</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row4_col0" class="data row4 col0" >MCS</td>
#       <td id="T_824cd_row4_col1" class="data row4 col1" >0.29%</td>
#       <td id="T_824cd_row4_col2" class="data row4 col2" >8.55</td>
#       <td id="T_824cd_row4_col3" class="data row4 col3" >8.53</td>
#       <td id="T_824cd_row4_col4" class="data row4 col4" >62.31%</td>
#       <td id="T_824cd_row4_col5" class="data row4 col5" >295,914</td>
#       <td id="T_824cd_row4_col6" class="data row4 col6" >182,315</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row5_col0" class="data row5 col0" >SYNEX</td>
#       <td id="T_824cd_row5_col1" class="data row5 col1" >0.00%</td>
#       <td id="T_824cd_row5_col2" class="data row5 col2" >10.10</td>
#       <td id="T_824cd_row5_col3" class="data row5 col3" >10.10</td>
#       <td id="T_824cd_row5_col4" class="data row5 col4" >105.45%</td>
#       <td id="T_824cd_row5_col5" class="data row5 col5" >1,934,409</td>
#       <td id="T_824cd_row5_col6" class="data row5 col6" >941,537</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row6_col0" class="data row6 col0" >GVREIT</td>
#       <td id="T_824cd_row6_col1" class="data row6 col1" >-0.37%</td>
#       <td id="T_824cd_row6_col2" class="data row6 col2" >6.65</td>
#       <td id="T_824cd_row6_col3" class="data row6 col3" >6.68</td>
#       <td id="T_824cd_row6_col4" class="data row6 col4" >132.44%</td>
#       <td id="T_824cd_row6_col5" class="data row6 col5" >438,414</td>
#       <td id="T_824cd_row6_col6" class="data row6 col6" >188,615</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row7_col0" class="data row7 col0" >NER</td>
#       <td id="T_824cd_row7_col1" class="data row7 col1" >-1.05%</td>
#       <td id="T_824cd_row7_col2" class="data row7 col2" >4.72</td>
#       <td id="T_824cd_row7_col3" class="data row7 col3" >4.77</td>
#       <td id="T_824cd_row7_col4" class="data row7 col4" >19.53%</td>
#       <td id="T_824cd_row7_col5" class="data row7 col5" >6,839,815</td>
#       <td id="T_824cd_row7_col6" class="data row7 col6" >5,722,041</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row8_col0" class="data row8 col0" >CPNREIT</td>
#       <td id="T_824cd_row8_col1" class="data row8 col1" >-1.31%</td>
#       <td id="T_824cd_row8_col2" class="data row8 col2" >11.30</td>
#       <td id="T_824cd_row8_col3" class="data row8 col3" >11.45</td>
#       <td id="T_824cd_row8_col4" class="data row8 col4" >2.30%</td>
#       <td id="T_824cd_row8_col5" class="data row8 col5" >2,973,212</td>
#       <td id="T_824cd_row8_col6" class="data row8 col6" >2,906,429</td>
#     </tr>
#     <tr>
#       <td id="T_824cd_row9_col0" class="data row9 col0" >SINGER</td>
#       <td id="T_824cd_row9_col1" class="data row9 col1" >-2.92%</td>
#       <td id="T_824cd_row9_col2" class="data row9 col2" >4.66</td>
#       <td id="T_824cd_row9_col3" class="data row9 col3" >4.80</td>
#       <td id="T_824cd_row9_col4" class="data row9 col4" >193.34%</td>
#       <td id="T_824cd_row9_col5" class="data row9 col5" >3,672,125</td>
#       <td id="T_824cd_row9_col6" class="data row9 col6" >1,251,827</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\5-day-average.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\5-day-average.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\5-day-average.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\5-day-average.csv

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(god_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(icd_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c6d2">
#   <thead>
#     <tr>
#       <th id="T_5c6d2_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_5c6d2_level0_col1" class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5c6d2_row0_col0" class="data row0 col0" >AWC</td>
#       <td id="T_5c6d2_row0_col1" class="data row0 col1" >X</td>
#     </tr>
#     <tr>
#       <td id="T_5c6d2_row1_col0" class="data row1 col0" >RCL</td>
#       <td id="T_5c6d2_row1_col1" class="data row1 col1" >B</td>
#     </tr>
#     <tr>
#       <td id="T_5c6d2_row2_col0" class="data row2 col0" >AH</td>
#       <td id="T_5c6d2_row2_col1" class="data row2 col1" >X</td>
#     </tr>
#     <tr>
#       <td id="T_5c6d2_row3_col0" class="data row3 col0" >SYNEX</td>
#       <td id="T_5c6d2_row3_col1" class="data row3 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_5c6d2_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_5c6d2_row4_col1" class="data row4 col1" >X</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = stocks["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'AIMIRT', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF'"

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
print(sql)

tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2026-02-06' AND name IN ('AH', 'AIMIRT', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF')
# ORDER BY name
# '29 stocks'

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)

ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2026-02-05' AND name IN ('AH', 'AIMIRT', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF')
# ORDER BY name
# '29 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner',suffixes=("_today","_yesterday"))
compare1.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_530b6">
#   <thead>
#     <tr>
#       <th id="T_530b6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_530b6_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_530b6_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_530b6_row0_col0" class="data row0 col0" >CPNREIT</td>
#       <td id="T_530b6_row0_col1" class="data row0 col1" >11.30</td>
#       <td id="T_530b6_row0_col2" class="data row0 col2" >11.40</td>
#     </tr>
#     <tr>
#       <td id="T_530b6_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_530b6_row1_col1" class="data row1 col1" >4.66</td>
#       <td id="T_530b6_row1_col2" class="data row1 col2" >4.80</td>
#     </tr>
#     <tr>
#       <td id="T_530b6_row2_col0" class="data row2 col0" >AIMIRT</td>
#       <td id="T_530b6_row2_col1" class="data row2 col1" >10.80</td>
#       <td id="T_530b6_row2_col2" class="data row2 col2" >10.80</td>
#     </tr>
#     <tr>
#       <td id="T_530b6_row3_col0" class="data row3 col0" >NER</td>
#       <td id="T_530b6_row3_col1" class="data row3 col1" >4.72</td>
#       <td id="T_530b6_row3_col2" class="data row3 col2" >4.78</td>
#     </tr>
#     <tr>
#       <td id="T_530b6_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_530b6_row4_col1" class="data row4 col1" >6.65</td>
#       <td id="T_530b6_row4_col2" class="data row4 col2" >6.65</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_86eb5">
#   <thead>
#     <tr>
#       <th id="T_86eb5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_86eb5_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_86eb5_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#       <th id="T_86eb5_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_86eb5_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_86eb5_row0_col1" class="data row0 col1" >6.65</td>
#       <td id="T_86eb5_row0_col2" class="data row0 col2" >6.65</td>
#       <td id="T_86eb5_row0_col3" class="data row0 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_86eb5_row1_col0" class="data row1 col0" >AH</td>
#       <td id="T_86eb5_row1_col1" class="data row1 col1" >13.20</td>
#       <td id="T_86eb5_row1_col2" class="data row1 col2" >13.10</td>
#       <td id="T_86eb5_row1_col3" class="data row1 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_86eb5_row2_col0" class="data row2 col0" >AIMIRT</td>
#       <td id="T_86eb5_row2_col1" class="data row2 col1" >10.80</td>
#       <td id="T_86eb5_row2_col2" class="data row2 col2" >10.80</td>
#       <td id="T_86eb5_row2_col3" class="data row2 col3" >B</td>
#     </tr>
#     <tr>
#       <td id="T_86eb5_row3_col0" class="data row3 col0" >AWC</td>
#       <td id="T_86eb5_row3_col1" class="data row3 col1" >2.32</td>
#       <td id="T_86eb5_row3_col2" class="data row3 col2" >2.34</td>
#       <td id="T_86eb5_row3_col3" class="data row3 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_86eb5_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_86eb5_row4_col1" class="data row4 col1" >10.10</td>
#       <td id="T_86eb5_row4_col2" class="data row4 col2" >10.10</td>
#       <td id="T_86eb5_row4_col3" class="data row4 col3" >X</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2.columns
# Out:
# Index(['name', 'price_today', 'price_yesterday', 'status'], dtype='object')

# %%
colx = ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']
colx
# Out:
# ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']

# %%
compare2['diff'] = round((compare2.price_today - compare2.price_yesterday),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_yesterday'] * 100,2)
compare2[colx].sort_values(['pct'],ascending=[False]).sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_891c5">
#   <thead>
#     <tr>
#       <th id="T_891c5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_891c5_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_891c5_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_891c5_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_891c5_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_891c5_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_891c5_row0_col0" class="data row0 col0" >TVO</td>
#       <td id="T_891c5_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_891c5_row0_col2" class="data row0 col2" >23.70</td>
#       <td id="T_891c5_row0_col3" class="data row0 col3" >23.70</td>
#       <td id="T_891c5_row0_col4" class="data row0 col4" >S</td>
#       <td id="T_891c5_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_891c5_row1_col0" class="data row1 col0" >CPF</td>
#       <td id="T_891c5_row1_col1" class="data row1 col1" >1.45%</td>
#       <td id="T_891c5_row1_col2" class="data row1 col2" >21.00</td>
#       <td id="T_891c5_row1_col3" class="data row1 col3" >20.70</td>
#       <td id="T_891c5_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_891c5_row1_col5" class="data row1 col5" >0.30</td>
#     </tr>
#     <tr>
#       <td id="T_891c5_row2_col0" class="data row2 col0" >PTTGC</td>
#       <td id="T_891c5_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_891c5_row2_col2" class="data row2 col2" >25.25</td>
#       <td id="T_891c5_row2_col3" class="data row2 col3" >25.25</td>
#       <td id="T_891c5_row2_col4" class="data row2 col4" >X</td>
#       <td id="T_891c5_row2_col5" class="data row2 col5" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_891c5_row3_col0" class="data row3 col0" >SYNEX</td>
#       <td id="T_891c5_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_891c5_row3_col2" class="data row3 col2" >10.10</td>
#       <td id="T_891c5_row3_col3" class="data row3 col3" >10.10</td>
#       <td id="T_891c5_row3_col4" class="data row3 col4" >S</td>
#       <td id="T_891c5_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_891c5_row4_col0" class="data row4 col0" >WHAIR</td>
#       <td id="T_891c5_row4_col1" class="data row4 col1" >0.00%</td>
#       <td id="T_891c5_row4_col2" class="data row4 col2" >6.40</td>
#       <td id="T_891c5_row4_col3" class="data row4 col3" >6.40</td>
#       <td id="T_891c5_row4_col4" class="data row4 col4" >B</td>
#       <td id="T_891c5_row4_col5" class="data row4 col5" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1c266">
#   <thead>
#     <tr>
#       <th id="T_1c266_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1c266_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_1c266_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_1c266_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_1c266_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_1c266_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1c266_row0_col0" class="data row0 col0" >ORI</td>
#       <td id="T_1c266_row0_col1" class="data row0 col1" >-3.30%</td>
#       <td id="T_1c266_row0_col2" class="data row0 col2" >1.76</td>
#       <td id="T_1c266_row0_col3" class="data row0 col3" >1.82</td>
#       <td id="T_1c266_row0_col4" class="data row0 col4" >B</td>
#       <td id="T_1c266_row0_col5" class="data row0 col5" >-0.06</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\extremes.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\extremes.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\extremes.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\extremes.csv

# %%
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(god_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(icd_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(osd_file, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-02-06 20:40:41
