# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
print(today)
# Out:
# 2026-03-05

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(today, yesterday)
# Out:
# 2026-03-05 2026-03-04

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-03-05 21:00:11

# %% [markdown]
# ### Restart and run all cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A4\Daily
# Base path: C:\Users\PC1\OneDrive\A4
# Data path : C:\Users\PC1\OneDrive\A4\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}', 'volbuy':'{:,}',   
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}',
    'opnp':'{:.2f}','price_x':'{:.2f}','price_y':'{:.2f}',
    'price_today':'{:.2f}','price_yesterday':'{:.2f}',   
    'date':'{:%Y-%m-%d}',
    
    'price_mean':'{:.2f}','price_today':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}','dividend':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_mean':'{:,}','qty_today':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}','daily_volume':'{:,.2f}',   
    'value(m)':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2026, 3, 5)

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
#sql = sql % yesterday
print(sql)

prices = pd.read_sql(sql, const)
#prices.sample(5).style.format(format_dict)
prices.shape
# Out:
# SELECT *
# FROM price
# WHERE date = '2026-03-05'
# ORDER BY name
# (165, 7)

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f7df">
#   <thead>
#     <tr>
#       <th id="T_7f7df_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_7f7df_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7f7df_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_7f7df_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_7f7df_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_7f7df_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_7f7df_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_7f7df_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_7f7df_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_7f7df_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_7f7df_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_7f7df_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_7f7df_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_7f7df_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_7f7df_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f7df_row0_col0" class="data row0 col0" >830</td>
#       <td id="T_7f7df_row0_col1" class="data row0 col1" >LHFG</td>
#       <td id="T_7f7df_row0_col2" class="data row0 col2" >SET    </td>
#       <td id="T_7f7df_row0_col3" class="data row0 col3" >0.96</td>
#       <td id="T_7f7df_row0_col4" class="data row0 col4" >1.04</td>
#       <td id="T_7f7df_row0_col5" class="data row0 col5" >0.72</td>
#       <td id="T_7f7df_row0_col6" class="data row0 col6" >30.02</td>
#       <td id="T_7f7df_row0_col7" class="data row0 col7" >0.72</td>
#       <td id="T_7f7df_row0_col8" class="data row0 col8" >21,183.66</td>
#       <td id="T_7f7df_row0_col9" class="data row0 col9" >25,844.07</td>
#       <td id="T_7f7df_row0_col10" class="data row0 col10" >14.86</td>
#       <td id="T_7f7df_row0_col11" class="data row0 col11" >1.10</td>
#       <td id="T_7f7df_row0_col12" class="data row0 col12" >276</td>
#       <td id="T_7f7df_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_7f7df_row0_col14" class="data row0 col14" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_7f7df_row1_col0" class="data row1 col0" >796</td>
#       <td id="T_7f7df_row1_col1" class="data row1 col1" >GULF</td>
#       <td id="T_7f7df_row1_col2" class="data row1 col2" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_7f7df_row1_col3" class="data row1 col3" >49.75</td>
#       <td id="T_7f7df_row1_col4" class="data row1 col4" >70.75</td>
#       <td id="T_7f7df_row1_col5" class="data row1 col5" >37.00</td>
#       <td id="T_7f7df_row1_col6" class="data row1 col6" >69.97</td>
#       <td id="T_7f7df_row1_col7" class="data row1 col7" >5.93</td>
#       <td id="T_7f7df_row1_col8" class="data row1 col8" >11,733.15</td>
#       <td id="T_7f7df_row1_col9" class="data row1 col9" >633,590.10</td>
#       <td id="T_7f7df_row1_col10" class="data row1 col10" >820.10</td>
#       <td id="T_7f7df_row1_col11" class="data row1 col11" >1.32</td>
#       <td id="T_7f7df_row1_col12" class="data row1 col12" >207</td>
#       <td id="T_7f7df_row1_col13" class="data row1 col13" >2022-05-17</td>
#       <td id="T_7f7df_row1_col14" class="data row1 col14" >2025-03-20</td>
#     </tr>
#     <tr>
#       <td id="T_7f7df_row2_col0" class="data row2 col0" >755</td>
#       <td id="T_7f7df_row2_col1" class="data row2 col1" >BLA</td>
#       <td id="T_7f7df_row2_col2" class="data row2 col2" >SET100 / SETTHSI    </td>
#       <td id="T_7f7df_row2_col3" class="data row2 col3" >19.70</td>
#       <td id="T_7f7df_row2_col4" class="data row2 col4" >24.00</td>
#       <td id="T_7f7df_row2_col5" class="data row2 col5" >14.00</td>
#       <td id="T_7f7df_row2_col6" class="data row2 col6" >15.71</td>
#       <td id="T_7f7df_row2_col7" class="data row2 col7" >1.21</td>
#       <td id="T_7f7df_row2_col8" class="data row2 col8" >1,707.57</td>
#       <td id="T_7f7df_row2_col9" class="data row2 col9" >50,373.20</td>
#       <td id="T_7f7df_row2_col10" class="data row2 col10" >123.99</td>
#       <td id="T_7f7df_row2_col11" class="data row2 col11" >0.71</td>
#       <td id="T_7f7df_row2_col12" class="data row2 col12" >73</td>
#       <td id="T_7f7df_row2_col13" class="data row2 col13" >2022-05-17</td>
#       <td id="T_7f7df_row2_col14" class="data row2 col14" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_7f7df_row3_col0" class="data row3 col0" >891</td>
#       <td id="T_7f7df_row3_col1" class="data row3 col1" >SNC</td>
#       <td id="T_7f7df_row3_col2" class="data row3 col2" >sSET / SETTHSI    </td>
#       <td id="T_7f7df_row3_col3" class="data row3 col3" >5.50</td>
#       <td id="T_7f7df_row3_col4" class="data row3 col4" >7.35</td>
#       <td id="T_7f7df_row3_col5" class="data row3 col5" >5.10</td>
#       <td id="T_7f7df_row3_col6" class="data row3 col6" >7.28</td>
#       <td id="T_7f7df_row3_col7" class="data row3 col7" >1.07</td>
#       <td id="T_7f7df_row3_col8" class="data row3 col8" >362.22</td>
#       <td id="T_7f7df_row3_col9" class="data row3 col9" >5,288.42</td>
#       <td id="T_7f7df_row3_col10" class="data row3 col10" >9.67</td>
#       <td id="T_7f7df_row3_col11" class="data row3 col11" >0.69</td>
#       <td id="T_7f7df_row3_col12" class="data row3 col12" >465</td>
#       <td id="T_7f7df_row3_col13" class="data row3 col13" >2022-05-17</td>
#       <td id="T_7f7df_row3_col14" class="data row3 col14" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_7f7df_row4_col0" class="data row4 col0" >720</td>
#       <td id="T_7f7df_row4_col1" class="data row4 col1" >AEONTS</td>
#       <td id="T_7f7df_row4_col2" class="data row4 col2" >SET    </td>
#       <td id="T_7f7df_row4_col3" class="data row4 col3" >89.75</td>
#       <td id="T_7f7df_row4_col4" class="data row4 col4" >122.50</td>
#       <td id="T_7f7df_row4_col5" class="data row4 col5" >87.00</td>
#       <td id="T_7f7df_row4_col6" class="data row4 col6" >12.18</td>
#       <td id="T_7f7df_row4_col7" class="data row4 col7" >2.26</td>
#       <td id="T_7f7df_row4_col8" class="data row4 col8" >250.00</td>
#       <td id="T_7f7df_row4_col9" class="data row4 col9" >49,125.00</td>
#       <td id="T_7f7df_row4_col10" class="data row4 col10" >100.95</td>
#       <td id="T_7f7df_row4_col11" class="data row4 col11" >1.15</td>
#       <td id="T_7f7df_row4_col12" class="data row4 col12" >9</td>
#       <td id="T_7f7df_row4_col13" class="data row4 col13" >2022-05-17</td>
#       <td id="T_7f7df_row4_col14" class="data row4 col14" >2026-03-04</td>
#     </tr>
#   </tbody>
# </table>

# %%
stocks.query('name == "JMT"').style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c6c6">
#   <thead>
#     <tr>
#       <th id="T_0c6c6_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_0c6c6_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_0c6c6_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_0c6c6_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_0c6c6_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_0c6c6_level0_col5" class="col_heading level0 col5" >min_price</th>
#       <th id="T_0c6c6_level0_col6" class="col_heading level0 col6" >pe</th>
#       <th id="T_0c6c6_level0_col7" class="col_heading level0 col7" >pbv</th>
#       <th id="T_0c6c6_level0_col8" class="col_heading level0 col8" >paid_up</th>
#       <th id="T_0c6c6_level0_col9" class="col_heading level0 col9" >market_cap</th>
#       <th id="T_0c6c6_level0_col10" class="col_heading level0 col10" >daily_volume</th>
#       <th id="T_0c6c6_level0_col11" class="col_heading level0 col11" >beta</th>
#       <th id="T_0c6c6_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_0c6c6_level0_col13" class="col_heading level0 col13" >created_at</th>
#       <th id="T_0c6c6_level0_col14" class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c6c6_row0_col0" class="data row0 col0" >816</td>
#       <td id="T_0c6c6_row0_col1" class="data row0 col1" >JMT</td>
#       <td id="T_0c6c6_row0_col2" class="data row0 col2" >SET50    </td>
#       <td id="T_0c6c6_row0_col3" class="data row0 col3" >8.90</td>
#       <td id="T_0c6c6_row0_col4" class="data row0 col4" >14.90</td>
#       <td id="T_0c6c6_row0_col5" class="data row0 col5" >7.35</td>
#       <td id="T_0c6c6_row0_col6" class="data row0 col6" >45.05</td>
#       <td id="T_0c6c6_row0_col7" class="data row0 col7" >3.47</td>
#       <td id="T_0c6c6_row0_col8" class="data row0 col8" >729.58</td>
#       <td id="T_0c6c6_row0_col9" class="data row0 col9" >78,064.96</td>
#       <td id="T_0c6c6_row0_col10" class="data row0 col10" >675.65</td>
#       <td id="T_0c6c6_row0_col11" class="data row0 col11" >1.69</td>
#       <td id="T_0c6c6_row0_col12" class="data row0 col12" >245</td>
#       <td id="T_0c6c6_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_0c6c6_row0_col14" class="data row0 col14" >2026-03-04</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.drop(columns=['id','ticker_id','created_at','updated_at','paid_up','market_cap'],inplace=True)
#df_merge.sample(5).style.format(format_dict)
df_merge.head(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c88c9">
#   <thead>
#     <tr>
#       <th id="T_c88c9_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c88c9_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_c88c9_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_c88c9_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_c88c9_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_c88c9_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_c88c9_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_c88c9_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_c88c9_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_c88c9_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_c88c9_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_c88c9_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_c88c9_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_c88c9_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_c88c9_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c88c9_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_c88c9_row0_col1" class="data row0 col1" >2026-03-05</td>
#       <td id="T_c88c9_row0_col2" class="data row0 col2" >6.50</td>
#       <td id="T_c88c9_row0_col3" class="data row0 col3" >6.55</td>
#       <td id="T_c88c9_row0_col4" class="data row0 col4" >6.45</td>
#       <td id="T_c88c9_row0_col5" class="data row0 col5" >6,381,490</td>
#       <td id="T_c88c9_row0_col6" class="data row0 col6" >6.45</td>
#       <td id="T_c88c9_row0_col7" class="data row0 col7" >SET    </td>
#       <td id="T_c88c9_row0_col8" class="data row0 col8" >6.40</td>
#       <td id="T_c88c9_row0_col9" class="data row0 col9" >6.85</td>
#       <td id="T_c88c9_row0_col10" class="data row0 col10" >5.25</td>
#       <td id="T_c88c9_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_c88c9_row0_col12" class="data row0 col12" >0.74</td>
#       <td id="T_c88c9_row0_col13" class="data row0 col13" >40.31</td>
#       <td id="T_c88c9_row0_col14" class="data row0 col14" >0.59</td>
#     </tr>
#     <tr>
#       <td id="T_c88c9_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_c88c9_row1_col1" class="data row1 col1" >2026-03-05</td>
#       <td id="T_c88c9_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_c88c9_row1_col3" class="data row1 col3" >1.29</td>
#       <td id="T_c88c9_row1_col4" class="data row1 col4" >1.27</td>
#       <td id="T_c88c9_row1_col5" class="data row1 col5" >1,165,117</td>
#       <td id="T_c88c9_row1_col6" class="data row1 col6" >1.28</td>
#       <td id="T_c88c9_row1_col7" class="data row1 col7" >SET100 / SETTHSI    </td>
#       <td id="T_c88c9_row1_col8" class="data row1 col8" >1.27</td>
#       <td id="T_c88c9_row1_col9" class="data row1 col9" >1.38</td>
#       <td id="T_c88c9_row1_col10" class="data row1 col10" >1.24</td>
#       <td id="T_c88c9_row1_col11" class="data row1 col11" >17.72</td>
#       <td id="T_c88c9_row1_col12" class="data row1 col12" >1.82</td>
#       <td id="T_c88c9_row1_col13" class="data row1 col13" >54.63</td>
#       <td id="T_c88c9_row1_col14" class="data row1 col14" >0.92</td>
#     </tr>
#     <tr>
#       <td id="T_c88c9_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_c88c9_row2_col1" class="data row2 col1" >2026-03-05</td>
#       <td id="T_c88c9_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_c88c9_row2_col3" class="data row2 col3" >367.00</td>
#       <td id="T_c88c9_row2_col4" class="data row2 col4" >352.00</td>
#       <td id="T_c88c9_row2_col5" class="data row2 col5" >9,831,591</td>
#       <td id="T_c88c9_row2_col6" class="data row2 col6" >365.00</td>
#       <td id="T_c88c9_row2_col7" class="data row2 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_c88c9_row2_col8" class="data row2 col8" >360.00</td>
#       <td id="T_c88c9_row2_col9" class="data row2 col9" >410.00</td>
#       <td id="T_c88c9_row2_col10" class="data row2 col10" >259.00</td>
#       <td id="T_c88c9_row2_col11" class="data row2 col11" >23.03</td>
#       <td id="T_c88c9_row2_col12" class="data row2 col12" >7.52</td>
#       <td id="T_c88c9_row2_col13" class="data row2 col13" >954.23</td>
#       <td id="T_c88c9_row2_col14" class="data row2 col14" >0.79</td>
#     </tr>
#     <tr>
#       <td id="T_c88c9_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_c88c9_row3_col1" class="data row3 col1" >2026-03-05</td>
#       <td id="T_c88c9_row3_col2" class="data row3 col2" >90.00</td>
#       <td id="T_c88c9_row3_col3" class="data row3 col3" >92.00</td>
#       <td id="T_c88c9_row3_col4" class="data row3 col4" >88.75</td>
#       <td id="T_c88c9_row3_col5" class="data row3 col5" >1,003,644</td>
#       <td id="T_c88c9_row3_col6" class="data row3 col6" >92.00</td>
#       <td id="T_c88c9_row3_col7" class="data row3 col7" >SET    </td>
#       <td id="T_c88c9_row3_col8" class="data row3 col8" >89.75</td>
#       <td id="T_c88c9_row3_col9" class="data row3 col9" >122.50</td>
#       <td id="T_c88c9_row3_col10" class="data row3 col10" >87.00</td>
#       <td id="T_c88c9_row3_col11" class="data row3 col11" >12.18</td>
#       <td id="T_c88c9_row3_col12" class="data row3 col12" >2.26</td>
#       <td id="T_c88c9_row3_col13" class="data row3 col13" >100.95</td>
#       <td id="T_c88c9_row3_col14" class="data row3 col14" >1.15</td>
#     </tr>
#     <tr>
#       <td id="T_c88c9_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_c88c9_row4_col1" class="data row4 col1" >2026-03-05</td>
#       <td id="T_c88c9_row4_col2" class="data row4 col2" >14.30</td>
#       <td id="T_c88c9_row4_col3" class="data row4 col3" >14.80</td>
#       <td id="T_c88c9_row4_col4" class="data row4 col4" >14.00</td>
#       <td id="T_c88c9_row4_col5" class="data row4 col5" >179,432</td>
#       <td id="T_c88c9_row4_col6" class="data row4 col6" >14.00</td>
#       <td id="T_c88c9_row4_col7" class="data row4 col7" >sSET / SETTHSI    </td>
#       <td id="T_c88c9_row4_col8" class="data row4 col8" >14.20</td>
#       <td id="T_c88c9_row4_col9" class="data row4 col9" >15.80</td>
#       <td id="T_c88c9_row4_col10" class="data row4 col10" >10.00</td>
#       <td id="T_c88c9_row4_col11" class="data row4 col11" >7.48</td>
#       <td id="T_c88c9_row4_col12" class="data row4 col12" >1.21</td>
#       <td id="T_c88c9_row4_col13" class="data row4 col13" >70.31</td>
#       <td id="T_c88c9_row4_col14" class="data row4 col14" >1.51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_84ae6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84ae6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_84ae6_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_84ae6_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_84ae6_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_84ae6_level0_col4" class="col_heading level0 col4" >max_price</th>
#       <th id="T_84ae6_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84ae6_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_84ae6_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_84ae6_row0_col1" class="data row0 col1" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_84ae6_row0_col2" class="data row0 col2" >6.20</td>
#       <td id="T_84ae6_row0_col3" class="data row0 col3" >6.35</td>
#       <td id="T_84ae6_row0_col4" class="data row0 col4" >6.20</td>
#       <td id="T_84ae6_row0_col5" class="data row0 col5" >425,073,560</td>
#     </tr>
#   </tbody>
# </table>

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 1 stocks'

# %% [markdown]
# ### New High by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_efa27">
#   <thead>
#     <tr>
#       <th id="T_efa27_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_efa27_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_efa27_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_efa27_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_efa27_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_efa27_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_efa27_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_efa27_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_efa27_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_efa27_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_efa27_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_efa27_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_efa27_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_efa27_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_efa27_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_efa27_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_efa27_row0_col1" class="data row0 col1" >2026-03-05</td>
#       <td id="T_efa27_row0_col2" class="data row0 col2" >6.20</td>
#       <td id="T_efa27_row0_col3" class="data row0 col3" >6.35</td>
#       <td id="T_efa27_row0_col4" class="data row0 col4" >5.85</td>
#       <td id="T_efa27_row0_col5" class="data row0 col5" >425,073,560</td>
#       <td id="T_efa27_row0_col6" class="data row0 col6" >5.95</td>
#       <td id="T_efa27_row0_col7" class="data row0 col7" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_efa27_row0_col8" class="data row0 col8" >5.70</td>
#       <td id="T_efa27_row0_col9" class="data row0 col9" >6.20</td>
#       <td id="T_efa27_row0_col10" class="data row0 col10" >4.00</td>
#       <td id="T_efa27_row0_col11" class="data row0 col11" >2.29</td>
#       <td id="T_efa27_row0_col12" class="data row0 col12" >0.91</td>
#       <td id="T_efa27_row0_col13" class="data row0 col13" >1,482.62</td>
#       <td id="T_efa27_row0_col14" class="data row0 col14" >0.72</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100H = Final_High["market"].str.contains("SET100")
Final_High[set100H].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2eb8c">
#   <thead>
#     <tr>
#       <th id="T_2eb8c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2eb8c_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_2eb8c_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_2eb8c_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_2eb8c_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_2eb8c_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_2eb8c_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_2eb8c_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_2eb8c_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_2eb8c_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_2eb8c_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_2eb8c_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_2eb8c_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_2eb8c_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_2eb8c_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_37a15">
#   <thead>
#     <tr>
#       <th id="T_37a15_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_37a15_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_37a15_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_37a15_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_37a15_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_37a15_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_37a15_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_37a15_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_37a15_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_37a15_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_37a15_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_37a15_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_37a15_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_37a15_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_37a15_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d92ca">
#   <thead>
#     <tr>
#       <th id="T_d92ca_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d92ca_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_d92ca_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_d92ca_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_d92ca_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_d92ca_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_d92ca_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_d92ca_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_d92ca_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_d92ca_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_d92ca_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_d92ca_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_d92ca_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_d92ca_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_d92ca_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_18188">
#   <thead>
#     <tr>
#       <th id="T_18188_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_18188_level0_col1" class="col_heading level0 col1" >market</th>
#       <th id="T_18188_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_18188_level0_col3" class="col_heading level0 col3" >minp</th>
#       <th id="T_18188_level0_col4" class="col_heading level0 col4" >min_price</th>
#       <th id="T_18188_level0_col5" class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18188_row0_col0" class="data row0 col0" >CBG</td>
#       <td id="T_18188_row0_col1" class="data row0 col1" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_18188_row0_col2" class="data row0 col2" >37.00</td>
#       <td id="T_18188_row0_col3" class="data row0 col3" >36.25</td>
#       <td id="T_18188_row0_col4" class="data row0 col4" >36.75</td>
#       <td id="T_18188_row0_col5" class="data row0 col5" >8,765,633</td>
#     </tr>
#     <tr>
#       <td id="T_18188_row1_col0" class="data row1 col0" >SPRIME</td>
#       <td id="T_18188_row1_col1" class="data row1 col1" >SET    </td>
#       <td id="T_18188_row1_col2" class="data row1 col2" >3.44</td>
#       <td id="T_18188_row1_col3" class="data row1 col3" >3.40</td>
#       <td id="T_18188_row1_col4" class="data row1 col4" >3.66</td>
#       <td id="T_18188_row1_col5" class="data row1 col5" >495,200</td>
#     </tr>
#     <tr>
#       <td id="T_18188_row2_col0" class="data row2 col0" >SYNEX</td>
#       <td id="T_18188_row2_col1" class="data row2 col1" >sSET / SETTHSI    </td>
#       <td id="T_18188_row2_col2" class="data row2 col2" >9.10</td>
#       <td id="T_18188_row2_col3" class="data row2 col3" >8.90</td>
#       <td id="T_18188_row2_col4" class="data row2 col4" >9.15</td>
#       <td id="T_18188_row2_col5" class="data row2 col5" >4,523,644</td>
#     </tr>
#   </tbody>
# </table>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 3 stocks'

# %% [markdown]
# ### New Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab120">
#   <thead>
#     <tr>
#       <th id="T_ab120_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ab120_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_ab120_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_ab120_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_ab120_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_ab120_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_ab120_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_ab120_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_ab120_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_ab120_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_ab120_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_ab120_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_ab120_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_ab120_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_ab120_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab120_row0_col0" class="data row0 col0" >CBG</td>
#       <td id="T_ab120_row0_col1" class="data row0 col1" >2026-03-05</td>
#       <td id="T_ab120_row0_col2" class="data row0 col2" >37.00</td>
#       <td id="T_ab120_row0_col3" class="data row0 col3" >39.75</td>
#       <td id="T_ab120_row0_col4" class="data row0 col4" >36.25</td>
#       <td id="T_ab120_row0_col5" class="data row0 col5" >8,765,633</td>
#       <td id="T_ab120_row0_col6" class="data row0 col6" >39.50</td>
#       <td id="T_ab120_row0_col7" class="data row0 col7" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_ab120_row0_col8" class="data row0 col8" >38.50</td>
#       <td id="T_ab120_row0_col9" class="data row0 col9" >69.00</td>
#       <td id="T_ab120_row0_col10" class="data row0 col10" >36.75</td>
#       <td id="T_ab120_row0_col11" class="data row0 col11" >41.35</td>
#       <td id="T_ab120_row0_col12" class="data row0 col12" >10.02</td>
#       <td id="T_ab120_row0_col13" class="data row0 col13" >396.56</td>
#       <td id="T_ab120_row0_col14" class="data row0 col14" >1.21</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b377c">
#   <thead>
#     <tr>
#       <th id="T_b377c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b377c_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_b377c_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_b377c_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_b377c_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_b377c_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_b377c_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_b377c_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_b377c_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_b377c_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_b377c_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_b377c_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_b377c_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_b377c_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_b377c_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=[True]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_97631">
#   <thead>
#     <tr>
#       <th id="T_97631_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_97631_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_97631_level0_col2" class="col_heading level0 col2" >price_x</th>
#       <th id="T_97631_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_97631_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_97631_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_97631_level0_col6" class="col_heading level0 col6" >opnp</th>
#       <th id="T_97631_level0_col7" class="col_heading level0 col7" >market</th>
#       <th id="T_97631_level0_col8" class="col_heading level0 col8" >price_y</th>
#       <th id="T_97631_level0_col9" class="col_heading level0 col9" >max_price</th>
#       <th id="T_97631_level0_col10" class="col_heading level0 col10" >min_price</th>
#       <th id="T_97631_level0_col11" class="col_heading level0 col11" >pe</th>
#       <th id="T_97631_level0_col12" class="col_heading level0 col12" >pbv</th>
#       <th id="T_97631_level0_col13" class="col_heading level0 col13" >daily_volume</th>
#       <th id="T_97631_level0_col14" class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97631_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_97631_row0_col1" class="data row0 col1" >2026-03-05</td>
#       <td id="T_97631_row0_col2" class="data row0 col2" >9.10</td>
#       <td id="T_97631_row0_col3" class="data row0 col3" >9.45</td>
#       <td id="T_97631_row0_col4" class="data row0 col4" >8.90</td>
#       <td id="T_97631_row0_col5" class="data row0 col5" >4,523,644</td>
#       <td id="T_97631_row0_col6" class="data row0 col6" >9.35</td>
#       <td id="T_97631_row0_col7" class="data row0 col7" >sSET / SETTHSI    </td>
#       <td id="T_97631_row0_col8" class="data row0 col8" >9.15</td>
#       <td id="T_97631_row0_col9" class="data row0 col9" >12.80</td>
#       <td id="T_97631_row0_col10" class="data row0 col10" >9.15</td>
#       <td id="T_97631_row0_col11" class="data row0 col11" >15.26</td>
#       <td id="T_97631_row0_col12" class="data row0 col12" >3.52</td>
#       <td id="T_97631_row0_col13" class="data row0 col13" >35.16</td>
#       <td id="T_97631_row0_col14" class="data row0 col14" >2.04</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT name, qty, price, date As today
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = '2026-03-05'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_c4576">
#   <thead>
#     <tr>
#       <th id="T_c4576_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c4576_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_c4576_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_c4576_level0_col3" class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c4576_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_c4576_row0_col1" class="data row0 col1" >6,381,490</td>
#       <td id="T_c4576_row0_col2" class="data row0 col2" >6.50</td>
#       <td id="T_c4576_row0_col3" class="data row0 col3" >2026-03-05</td>
#     </tr>
#     <tr>
#       <td id="T_c4576_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_c4576_row1_col1" class="data row1 col1" >1,165,117</td>
#       <td id="T_c4576_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_c4576_row1_col3" class="data row1 col3" >2026-03-05</td>
#     </tr>
#     <tr>
#       <td id="T_c4576_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_c4576_row2_col1" class="data row2 col1" >9,831,591</td>
#       <td id="T_c4576_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_c4576_row2_col3" class="data row2 col3" >2026-03-05</td>
#     </tr>
#     <tr>
#       <td id="T_c4576_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_c4576_row3_col1" class="data row3 col1" >1,003,644</td>
#       <td id="T_c4576_row3_col2" class="data row3 col2" >90.00</td>
#       <td id="T_c4576_row3_col3" class="data row3 col3" >2026-03-05</td>
#     </tr>
#     <tr>
#       <td id="T_c4576_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_c4576_row4_col1" class="data row4 col1" >179,432</td>
#       <td id="T_c4576_row4_col2" class="data row4 col2" >14.30</td>
#       <td id="T_c4576_row4_col3" class="data row4 col3" >2026-03-05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2026, 3, 4)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2432">
#   <thead>
#     <tr>
#       <th id="T_e2432_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e2432_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_e2432_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_e2432_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_e2432_level0_col4" class="col_heading level0 col4" >end_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2432_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_e2432_row0_col1" class="data row0 col1" >6,381,490</td>
#       <td id="T_e2432_row0_col2" class="data row0 col2" >6.50</td>
#       <td id="T_e2432_row0_col3" class="data row0 col3" >2026-03-05</td>
#       <td id="T_e2432_row0_col4" class="data row0 col4" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_e2432_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_e2432_row1_col1" class="data row1 col1" >1,165,117</td>
#       <td id="T_e2432_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_e2432_row1_col3" class="data row1 col3" >2026-03-05</td>
#       <td id="T_e2432_row1_col4" class="data row1 col4" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_e2432_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_e2432_row2_col1" class="data row2 col1" >9,831,591</td>
#       <td id="T_e2432_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_e2432_row2_col3" class="data row2 col3" >2026-03-05</td>
#       <td id="T_e2432_row2_col4" class="data row2 col4" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_e2432_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_e2432_row3_col1" class="data row3 col1" >1,003,644</td>
#       <td id="T_e2432_row3_col2" class="data row3 col2" >90.00</td>
#       <td id="T_e2432_row3_col3" class="data row3 col3" >2026-03-05</td>
#       <td id="T_e2432_row3_col4" class="data row3 col4" >2026-03-04</td>
#     </tr>
#     <tr>
#       <td id="T_e2432_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_e2432_row4_col1" class="data row4 col1" >179,432</td>
#       <td id="T_e2432_row4_col2" class="data row4 col2" >14.30</td>
#       <td id="T_e2432_row4_col3" class="data row4 col3" >2026-03-05</td>
#       <td id="T_e2432_row4_col4" class="data row4 col4" >2026-03-04</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2026, 3, 3)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['start_date'] = today_vol['end_date'] - num_business_days
today_vol.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_875e8">
#   <thead>
#     <tr>
#       <th id="T_875e8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_875e8_level0_col1" class="col_heading level0 col1" >qty</th>
#       <th id="T_875e8_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_875e8_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_875e8_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_875e8_level0_col5" class="col_heading level0 col5" >start_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_875e8_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_875e8_row0_col1" class="data row0 col1" >6,381,490</td>
#       <td id="T_875e8_row0_col2" class="data row0 col2" >6.50</td>
#       <td id="T_875e8_row0_col3" class="data row0 col3" >2026-03-05</td>
#       <td id="T_875e8_row0_col4" class="data row0 col4" >2026-03-04</td>
#       <td id="T_875e8_row0_col5" class="data row0 col5" >2026-03-03</td>
#     </tr>
#     <tr>
#       <td id="T_875e8_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_875e8_row1_col1" class="data row1 col1" >1,165,117</td>
#       <td id="T_875e8_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_875e8_row1_col3" class="data row1 col3" >2026-03-05</td>
#       <td id="T_875e8_row1_col4" class="data row1 col4" >2026-03-04</td>
#       <td id="T_875e8_row1_col5" class="data row1 col5" >2026-03-03</td>
#     </tr>
#     <tr>
#       <td id="T_875e8_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_875e8_row2_col1" class="data row2 col1" >9,831,591</td>
#       <td id="T_875e8_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_875e8_row2_col3" class="data row2 col3" >2026-03-05</td>
#       <td id="T_875e8_row2_col4" class="data row2 col4" >2026-03-04</td>
#       <td id="T_875e8_row2_col5" class="data row2 col5" >2026-03-03</td>
#     </tr>
#     <tr>
#       <td id="T_875e8_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_875e8_row3_col1" class="data row3 col1" >1,003,644</td>
#       <td id="T_875e8_row3_col2" class="data row3 col2" >90.00</td>
#       <td id="T_875e8_row3_col3" class="data row3 col3" >2026-03-05</td>
#       <td id="T_875e8_row3_col4" class="data row3 col4" >2026-03-04</td>
#       <td id="T_875e8_row3_col5" class="data row3 col5" >2026-03-03</td>
#     </tr>
#     <tr>
#       <td id="T_875e8_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_875e8_row4_col1" class="data row4 col1" >179,432</td>
#       <td id="T_875e8_row4_col2" class="data row4 col2" >14.30</td>
#       <td id="T_875e8_row4_col3" class="data row4 col3" >2026-03-05</td>
#       <td id="T_875e8_row4_col4" class="data row4 col4" >2026-03-04</td>
#       <td id="T_875e8_row4_col5" class="data row4 col5" >2026-03-03</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (start_date, end_date)
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name','date'],ascending=[True,True]).head().style.format(format_dict).hide(axis="index")
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN '2026-03-03' AND '2026-03-04'
# <style type="text/css">
# </style>
# <table id="T_9e456">
#   <thead>
#     <tr>
#       <th id="T_9e456_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9e456_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_9e456_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_9e456_level0_col3" class="col_heading level0 col3" >maxp</th>
#       <th id="T_9e456_level0_col4" class="col_heading level0 col4" >minp</th>
#       <th id="T_9e456_level0_col5" class="col_heading level0 col5" >qty</th>
#       <th id="T_9e456_level0_col6" class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e456_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_9e456_row0_col1" class="data row0 col1" >2026-03-04</td>
#       <td id="T_9e456_row0_col2" class="data row0 col2" >6.40</td>
#       <td id="T_9e456_row0_col3" class="data row0 col3" >6.50</td>
#       <td id="T_9e456_row0_col4" class="data row0 col4" >6.35</td>
#       <td id="T_9e456_row0_col5" class="data row0 col5" >39,655,482</td>
#       <td id="T_9e456_row0_col6" class="data row0 col6" >6.50</td>
#     </tr>
#     <tr>
#       <td id="T_9e456_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_9e456_row1_col1" class="data row1 col1" >2026-03-04</td>
#       <td id="T_9e456_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_9e456_row1_col3" class="data row1 col3" >1.29</td>
#       <td id="T_9e456_row1_col4" class="data row1 col4" >1.27</td>
#       <td id="T_9e456_row1_col5" class="data row1 col5" >5,459,738</td>
#       <td id="T_9e456_row1_col6" class="data row1 col6" >1.29</td>
#     </tr>
#     <tr>
#       <td id="T_9e456_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_9e456_row2_col1" class="data row2 col1" >2026-03-04</td>
#       <td id="T_9e456_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_9e456_row2_col3" class="data row2 col3" >362.00</td>
#       <td id="T_9e456_row2_col4" class="data row2 col4" >344.00</td>
#       <td id="T_9e456_row2_col5" class="data row2 col5" >17,803,917</td>
#       <td id="T_9e456_row2_col6" class="data row2 col6" >344.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e456_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_9e456_row3_col1" class="data row3 col1" >2026-03-04</td>
#       <td id="T_9e456_row3_col2" class="data row3 col2" >89.75</td>
#       <td id="T_9e456_row3_col3" class="data row3 col3" >92.00</td>
#       <td id="T_9e456_row3_col4" class="data row3 col4" >87.00</td>
#       <td id="T_9e456_row3_col5" class="data row3 col5" >2,501,890</td>
#       <td id="T_9e456_row3_col6" class="data row3 col6" >91.75</td>
#     </tr>
#     <tr>
#       <td id="T_9e456_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_9e456_row4_col1" class="data row4 col1" >2026-03-04</td>
#       <td id="T_9e456_row4_col2" class="data row4 col2" >14.20</td>
#       <td id="T_9e456_row4_col3" class="data row4 col3" >14.20</td>
#       <td id="T_9e456_row4_col4" class="data row4 col4" >13.10</td>
#       <td id="T_9e456_row4_col5" class="data row4 col5" >270,600</td>
#       <td id="T_9e456_row4_col6" class="data row4 col6" >14.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner", 
                     suffixes=( "_today","_mean"))
df_merge2.columns
# Out:
# Index(['name', 'qty_today', 'price_today', 'today', 'end_date', 'start_date',
#        'qty_mean', 'price_mean'],
#       dtype='object')

# %%
df_merge2["qty_mean"] = df_merge2.qty_mean.astype("int64")
df_merge2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b4ca">
#   <thead>
#     <tr>
#       <th id="T_7b4ca_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7b4ca_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_7b4ca_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_7b4ca_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_7b4ca_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_7b4ca_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_7b4ca_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_7b4ca_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7b4ca_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_7b4ca_row0_col1" class="data row0 col1" >6,381,490</td>
#       <td id="T_7b4ca_row0_col2" class="data row0 col2" >6.50</td>
#       <td id="T_7b4ca_row0_col3" class="data row0 col3" >2026-03-05</td>
#       <td id="T_7b4ca_row0_col4" class="data row0 col4" >2026-03-04</td>
#       <td id="T_7b4ca_row0_col5" class="data row0 col5" >2026-03-03</td>
#       <td id="T_7b4ca_row0_col6" class="data row0 col6" >39,655,482</td>
#       <td id="T_7b4ca_row0_col7" class="data row0 col7" >6.40</td>
#     </tr>
#     <tr>
#       <td id="T_7b4ca_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_7b4ca_row1_col1" class="data row1 col1" >1,165,117</td>
#       <td id="T_7b4ca_row1_col2" class="data row1 col2" >1.27</td>
#       <td id="T_7b4ca_row1_col3" class="data row1 col3" >2026-03-05</td>
#       <td id="T_7b4ca_row1_col4" class="data row1 col4" >2026-03-04</td>
#       <td id="T_7b4ca_row1_col5" class="data row1 col5" >2026-03-03</td>
#       <td id="T_7b4ca_row1_col6" class="data row1 col6" >5,459,738</td>
#       <td id="T_7b4ca_row1_col7" class="data row1 col7" >1.27</td>
#     </tr>
#     <tr>
#       <td id="T_7b4ca_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_7b4ca_row2_col1" class="data row2 col1" >9,831,591</td>
#       <td id="T_7b4ca_row2_col2" class="data row2 col2" >360.00</td>
#       <td id="T_7b4ca_row2_col3" class="data row2 col3" >2026-03-05</td>
#       <td id="T_7b4ca_row2_col4" class="data row2 col4" >2026-03-04</td>
#       <td id="T_7b4ca_row2_col5" class="data row2 col5" >2026-03-03</td>
#       <td id="T_7b4ca_row2_col6" class="data row2 col6" >17,803,917</td>
#       <td id="T_7b4ca_row2_col7" class="data row2 col7" >360.00</td>
#     </tr>
#     <tr>
#       <td id="T_7b4ca_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_7b4ca_row3_col1" class="data row3 col1" >1,003,644</td>
#       <td id="T_7b4ca_row3_col2" class="data row3 col2" >90.00</td>
#       <td id="T_7b4ca_row3_col3" class="data row3 col3" >2026-03-05</td>
#       <td id="T_7b4ca_row3_col4" class="data row3 col4" >2026-03-04</td>
#       <td id="T_7b4ca_row3_col5" class="data row3 col5" >2026-03-03</td>
#       <td id="T_7b4ca_row3_col6" class="data row3 col6" >2,501,890</td>
#       <td id="T_7b4ca_row3_col7" class="data row3 col7" >89.75</td>
#     </tr>
#     <tr>
#       <td id="T_7b4ca_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_7b4ca_row4_col1" class="data row4 col1" >179,432</td>
#       <td id="T_7b4ca_row4_col2" class="data row4 col2" >14.30</td>
#       <td id="T_7b4ca_row4_col3" class="data row4 col3" >2026-03-05</td>
#       <td id="T_7b4ca_row4_col4" class="data row4 col4" >2026-03-04</td>
#       <td id="T_7b4ca_row4_col5" class="data row4 col5" >2026-03-03</td>
#       <td id="T_7b4ca_row4_col6" class="data row4 col6" >270,600</td>
#       <td id="T_7b4ca_row4_col7" class="data row4 col7" >14.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_today > df_merge2.qty_mean)]
break_five_day_mean.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_33775">
#   <thead>
#     <tr>
#       <th id="T_33775_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_33775_level0_col1" class="col_heading level0 col1" >qty_today</th>
#       <th id="T_33775_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_33775_level0_col3" class="col_heading level0 col3" >today</th>
#       <th id="T_33775_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_33775_level0_col5" class="col_heading level0 col5" >start_date</th>
#       <th id="T_33775_level0_col6" class="col_heading level0 col6" >qty_mean</th>
#       <th id="T_33775_level0_col7" class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33775_row0_col0" class="data row0 col0" >ASW</td>
#       <td id="T_33775_row0_col1" class="data row0 col1" >842,381</td>
#       <td id="T_33775_row0_col2" class="data row0 col2" >7.75</td>
#       <td id="T_33775_row0_col3" class="data row0 col3" >2026-03-05</td>
#       <td id="T_33775_row0_col4" class="data row0 col4" >2026-03-04</td>
#       <td id="T_33775_row0_col5" class="data row0 col5" >2026-03-03</td>
#       <td id="T_33775_row0_col6" class="data row0 col6" >440,667</td>
#       <td id="T_33775_row0_col7" class="data row0 col7" >7.75</td>
#     </tr>
#     <tr>
#       <td id="T_33775_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_33775_row1_col1" class="data row1 col1" >425,073,560</td>
#       <td id="T_33775_row1_col2" class="data row1 col2" >6.20</td>
#       <td id="T_33775_row1_col3" class="data row1 col3" >2026-03-05</td>
#       <td id="T_33775_row1_col4" class="data row1 col4" >2026-03-04</td>
#       <td id="T_33775_row1_col5" class="data row1 col5" >2026-03-03</td>
#       <td id="T_33775_row1_col6" class="data row1 col6" >180,632,483</td>
#       <td id="T_33775_row1_col7" class="data row1 col7" >5.70</td>
#     </tr>
#     <tr>
#       <td id="T_33775_row2_col0" class="data row2 col0" >BPP</td>
#       <td id="T_33775_row2_col1" class="data row2 col1" >782,357</td>
#       <td id="T_33775_row2_col2" class="data row2 col2" >12.50</td>
#       <td id="T_33775_row2_col3" class="data row2 col3" >2026-03-05</td>
#       <td id="T_33775_row2_col4" class="data row2 col4" >2026-03-04</td>
#       <td id="T_33775_row2_col5" class="data row2 col5" >2026-03-03</td>
#       <td id="T_33775_row2_col6" class="data row2 col6" >354,748</td>
#       <td id="T_33775_row2_col7" class="data row2 col7" >11.70</td>
#     </tr>
#     <tr>
#       <td id="T_33775_row3_col0" class="data row3 col0" >HANA</td>
#       <td id="T_33775_row3_col1" class="data row3 col1" >67,169,667</td>
#       <td id="T_33775_row3_col2" class="data row3 col2" >19.10</td>
#       <td id="T_33775_row3_col3" class="data row3 col3" >2026-03-05</td>
#       <td id="T_33775_row3_col4" class="data row3 col4" >2026-03-04</td>
#       <td id="T_33775_row3_col5" class="data row3 col5" >2026-03-03</td>
#       <td id="T_33775_row3_col6" class="data row3 col6" >56,660,064</td>
#       <td id="T_33775_row3_col7" class="data row3 col7" >17.30</td>
#     </tr>
#     <tr>
#       <td id="T_33775_row4_col0" class="data row4 col0" >HFT</td>
#       <td id="T_33775_row4_col1" class="data row4 col1" >2,894,100</td>
#       <td id="T_33775_row4_col2" class="data row4 col2" >4.14</td>
#       <td id="T_33775_row4_col3" class="data row4 col3" >2026-03-05</td>
#       <td id="T_33775_row4_col4" class="data row4 col4" >2026-03-04</td>
#       <td id="T_33775_row4_col5" class="data row4 col5" >2026-03-03</td>
#       <td id="T_33775_row4_col6" class="data row4 col6" >557,000</td>
#       <td id="T_33775_row4_col7" class="data row4 col7" >4.16</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT name, date, volbuy, price, dividend 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.volbuy = buys.volbuy.astype("int64")
buys.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_88415">
#   <thead>
#     <tr>
#       <th id="T_88415_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_88415_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_88415_level0_col2" class="col_heading level0 col2" >volbuy</th>
#       <th id="T_88415_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_88415_level0_col4" class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88415_row0_col0" class="data row0 col0" >NER</td>
#       <td id="T_88415_row0_col1" class="data row0 col1" >2021-09-01</td>
#       <td id="T_88415_row0_col2" class="data row0 col2" >27,000</td>
#       <td id="T_88415_row0_col3" class="data row0 col3" >7.45</td>
#       <td id="T_88415_row0_col4" class="data row0 col4" >0.31</td>
#     </tr>
#     <tr>
#       <td id="T_88415_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_88415_row1_col1" class="data row1 col1" >2025-08-08</td>
#       <td id="T_88415_row1_col2" class="data row1 col2" >7,500</td>
#       <td id="T_88415_row1_col3" class="data row1 col3" >32.00</td>
#       <td id="T_88415_row1_col4" class="data row1 col4" >2.30</td>
#     </tr>
#     <tr>
#       <td id="T_88415_row2_col0" class="data row2 col0" >ORI</td>
#       <td id="T_88415_row2_col1" class="data row2 col1" >2022-04-07</td>
#       <td id="T_88415_row2_col2" class="data row2 col2" >50,000</td>
#       <td id="T_88415_row2_col3" class="data row2 col3" >9.00</td>
#       <td id="T_88415_row2_col4" class="data row2 col4" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_88415_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_88415_row3_col1" class="data row3 col1" >2020-08-01</td>
#       <td id="T_88415_row3_col2" class="data row3 col2" >45,000</td>
#       <td id="T_88415_row3_col3" class="data row3 col3" >12.70</td>
#       <td id="T_88415_row3_col4" class="data row3 col4" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_88415_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_88415_row4_col1" class="data row4 col1" >2021-09-20</td>
#       <td id="T_88415_row4_col2" class="data row4 col2" >600</td>
#       <td id="T_88415_row4_col3" class="data row4 col3" >405.00</td>
#       <td id="T_88415_row4_col4" class="data row4 col4" >5.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner", suffixes=("_mean","_today"))
df_merge3["qty_pct"] = round((df_merge3.qty_today - df_merge3.qty_mean) / abs(df_merge3.qty_mean) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_today - df_merge3.price_mean) / abs(df_merge3.price_mean) * 100,2)
df_merge3.rename(columns={'price_mean':'avg_price','price_today':'tdy_price',
                          'qty_mean':'avg_qty','qty_today':'tdy_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_133ef">
#   <thead>
#     <tr>
#       <th id="T_133ef_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_133ef_level0_col1" class="col_heading level0 col1" >prc_pct</th>
#       <th id="T_133ef_level0_col2" class="col_heading level0 col2" >tdy_price</th>
#       <th id="T_133ef_level0_col3" class="col_heading level0 col3" >avg_price</th>
#       <th id="T_133ef_level0_col4" class="col_heading level0 col4" >qty_pct</th>
#       <th id="T_133ef_level0_col5" class="col_heading level0 col5" >tdy_qty</th>
#       <th id="T_133ef_level0_col6" class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_133ef_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_133ef_row0_col1" class="data row0 col1" >-0.55%</td>
#       <td id="T_133ef_row0_col2" class="data row0 col2" >9.10</td>
#       <td id="T_133ef_row0_col3" class="data row0 col3" >9.15</td>
#       <td id="T_133ef_row0_col4" class="data row0 col4" >112.43%</td>
#       <td id="T_133ef_row0_col5" class="data row0 col5" >4,523,644</td>
#       <td id="T_133ef_row0_col6" class="data row0 col6" >2,129,485</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\5-day-average.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\5-day-average.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\5-day-average.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\5-day-average.csv

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(god_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(icd_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8788">
#   <thead>
#     <tr>
#       <th id="T_b8788_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b8788_level0_col1" class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b8788_row0_col0" class="data row0 col0" >MCS</td>
#       <td id="T_b8788_row0_col1" class="data row0 col1" >S</td>
#     </tr>
#     <tr>
#       <td id="T_b8788_row1_col0" class="data row1 col0" >CPNREIT</td>
#       <td id="T_b8788_row1_col1" class="data row1 col1" >X</td>
#     </tr>
#     <tr>
#       <td id="T_b8788_row2_col0" class="data row2 col0" >ORI</td>
#       <td id="T_b8788_row2_col1" class="data row2 col1" >B</td>
#     </tr>
#     <tr>
#       <td id="T_b8788_row3_col0" class="data row3 col0" >TFFIF</td>
#       <td id="T_b8788_row3_col1" class="data row3 col1" >B</td>
#     </tr>
#     <tr>
#       <td id="T_b8788_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_b8788_row4_col1" class="data row4 col1" >X</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = stocks["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF', 'ADVANC'"

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
print(sql)

tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2026-03-05' AND name IN ('AH', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF', 'ADVANC')
# ORDER BY name
# '29 stocks'

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)

ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2026-03-04' AND name IN ('AH', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', '3BBIF', 'JMART', 'JMT', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'WHAIR', 'TOA', 'WHART', 'TVO', 'PTT', 'CPF', 'ADVANC')
# ORDER BY name
# '29 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner',suffixes=("_today","_yesterday"))
compare1.sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1424f">
#   <thead>
#     <tr>
#       <th id="T_1424f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1424f_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_1424f_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1424f_row0_col0" class="data row0 col0" >NER</td>
#       <td id="T_1424f_row0_col1" class="data row0 col1" >4.66</td>
#       <td id="T_1424f_row0_col2" class="data row0 col2" >4.58</td>
#     </tr>
#     <tr>
#       <td id="T_1424f_row1_col0" class="data row1 col0" >JMART</td>
#       <td id="T_1424f_row1_col1" class="data row1 col1" >6.55</td>
#       <td id="T_1424f_row1_col2" class="data row1 col2" >6.30</td>
#     </tr>
#     <tr>
#       <td id="T_1424f_row2_col0" class="data row2 col0" >BCH</td>
#       <td id="T_1424f_row2_col1" class="data row2 col1" >9.75</td>
#       <td id="T_1424f_row2_col2" class="data row2 col2" >9.80</td>
#     </tr>
#     <tr>
#       <td id="T_1424f_row3_col0" class="data row3 col0" >TFFIF</td>
#       <td id="T_1424f_row3_col1" class="data row3 col1" >6.50</td>
#       <td id="T_1424f_row3_col2" class="data row3 col2" >6.45</td>
#     </tr>
#     <tr>
#       <td id="T_1424f_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_1424f_row4_col1" class="data row4 col1" >14.30</td>
#       <td id="T_1424f_row4_col2" class="data row4 col2" >14.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cd33c">
#   <thead>
#     <tr>
#       <th id="T_cd33c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_cd33c_level0_col1" class="col_heading level0 col1" >price_today</th>
#       <th id="T_cd33c_level0_col2" class="col_heading level0 col2" >price_yesterday</th>
#       <th id="T_cd33c_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd33c_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_cd33c_row0_col1" class="data row0 col1" >6.50</td>
#       <td id="T_cd33c_row0_col2" class="data row0 col2" >6.40</td>
#       <td id="T_cd33c_row0_col3" class="data row0 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_cd33c_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_cd33c_row1_col1" class="data row1 col1" >360.00</td>
#       <td id="T_cd33c_row1_col2" class="data row1 col2" >360.00</td>
#       <td id="T_cd33c_row1_col3" class="data row1 col3" >I</td>
#     </tr>
#     <tr>
#       <td id="T_cd33c_row2_col0" class="data row2 col0" >AH</td>
#       <td id="T_cd33c_row2_col1" class="data row2 col1" >14.30</td>
#       <td id="T_cd33c_row2_col2" class="data row2 col2" >14.20</td>
#       <td id="T_cd33c_row2_col3" class="data row2 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_cd33c_row3_col0" class="data row3 col0" >AWC</td>
#       <td id="T_cd33c_row3_col1" class="data row3 col1" >2.08</td>
#       <td id="T_cd33c_row3_col2" class="data row3 col2" >2.08</td>
#       <td id="T_cd33c_row3_col3" class="data row3 col3" >X</td>
#     </tr>
#     <tr>
#       <td id="T_cd33c_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_cd33c_row4_col1" class="data row4 col1" >9.75</td>
#       <td id="T_cd33c_row4_col2" class="data row4 col2" >9.80</td>
#       <td id="T_cd33c_row4_col3" class="data row4 col3" >X</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2.columns
# Out:
# Index(['name', 'price_today', 'price_yesterday', 'status'], dtype='object')

# %%
colx = ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']
colx
# Out:
# ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']

# %%
compare2['diff'] = round((compare2.price_today - compare2.price_yesterday),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_yesterday'] * 100,2)
compare2[colx].sort_values(['pct'],ascending=[False]).sample(5).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b178a">
#   <thead>
#     <tr>
#       <th id="T_b178a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b178a_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_b178a_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_b178a_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_b178a_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_b178a_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b178a_row0_col0" class="data row0 col0" >AWC</td>
#       <td id="T_b178a_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_b178a_row0_col2" class="data row0 col2" >2.08</td>
#       <td id="T_b178a_row0_col3" class="data row0 col3" >2.08</td>
#       <td id="T_b178a_row0_col4" class="data row0 col4" >X</td>
#       <td id="T_b178a_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_b178a_row1_col0" class="data row1 col0" >IVL</td>
#       <td id="T_b178a_row1_col1" class="data row1 col1" >2.13%</td>
#       <td id="T_b178a_row1_col2" class="data row1 col2" >19.20</td>
#       <td id="T_b178a_row1_col3" class="data row1 col3" >18.80</td>
#       <td id="T_b178a_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_b178a_row1_col5" class="data row1 col5" >0.40</td>
#     </tr>
#     <tr>
#       <td id="T_b178a_row2_col0" class="data row2 col0" >STA</td>
#       <td id="T_b178a_row2_col1" class="data row2 col1" >5.65%</td>
#       <td id="T_b178a_row2_col2" class="data row2 col2" >13.10</td>
#       <td id="T_b178a_row2_col3" class="data row2 col3" >12.40</td>
#       <td id="T_b178a_row2_col4" class="data row2 col4" >X</td>
#       <td id="T_b178a_row2_col5" class="data row2 col5" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_b178a_row3_col0" class="data row3 col0" >CPNREIT</td>
#       <td id="T_b178a_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_b178a_row3_col2" class="data row3 col2" >11.50</td>
#       <td id="T_b178a_row3_col3" class="data row3 col3" >11.50</td>
#       <td id="T_b178a_row3_col4" class="data row3 col4" >X</td>
#       <td id="T_b178a_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_b178a_row4_col0" class="data row4 col0" >ORI</td>
#       <td id="T_b178a_row4_col1" class="data row4 col1" >3.98%</td>
#       <td id="T_b178a_row4_col2" class="data row4 col2" >1.83</td>
#       <td id="T_b178a_row4_col3" class="data row4 col3" >1.76</td>
#       <td id="T_b178a_row4_col4" class="data row4 col4" >B</td>
#       <td id="T_b178a_row4_col5" class="data row4 col5" >0.07</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a446d">
#   <thead>
#     <tr>
#       <th id="T_a446d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a446d_level0_col1" class="col_heading level0 col1" >pct</th>
#       <th id="T_a446d_level0_col2" class="col_heading level0 col2" >price_today</th>
#       <th id="T_a446d_level0_col3" class="col_heading level0 col3" >price_yesterday</th>
#       <th id="T_a446d_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_a446d_level0_col5" class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a446d_row0_col0" class="data row0 col0" >ORI</td>
#       <td id="T_a446d_row0_col1" class="data row0 col1" >3.98%</td>
#       <td id="T_a446d_row0_col2" class="data row0 col2" >1.83</td>
#       <td id="T_a446d_row0_col3" class="data row0 col3" >1.76</td>
#       <td id="T_a446d_row0_col4" class="data row0 col4" >B</td>
#       <td id="T_a446d_row0_col5" class="data row0 col5" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_a446d_row1_col0" class="data row1 col0" >JMART</td>
#       <td id="T_a446d_row1_col1" class="data row1 col1" >3.97%</td>
#       <td id="T_a446d_row1_col2" class="data row1 col2" >6.55</td>
#       <td id="T_a446d_row1_col3" class="data row1 col3" >6.30</td>
#       <td id="T_a446d_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_a446d_row1_col5" class="data row1 col5" >0.25</td>
#     </tr>
#     <tr>
#       <td id="T_a446d_row2_col0" class="data row2 col0" >PTT</td>
#       <td id="T_a446d_row2_col1" class="data row2 col1" >-3.55%</td>
#       <td id="T_a446d_row2_col2" class="data row2 col2" >34.00</td>
#       <td id="T_a446d_row2_col3" class="data row2 col3" >35.25</td>
#       <td id="T_a446d_row2_col4" class="data row2 col4" >S</td>
#       <td id="T_a446d_row2_col5" class="data row2 col5" >-1.25</td>
#     </tr>
#     <tr>
#       <td id="T_a446d_row3_col0" class="data row3 col0" >STA</td>
#       <td id="T_a446d_row3_col1" class="data row3 col1" >5.65%</td>
#       <td id="T_a446d_row3_col2" class="data row3 col2" >13.10</td>
#       <td id="T_a446d_row3_col3" class="data row3 col3" >12.40</td>
#       <td id="T_a446d_row3_col4" class="data row3 col4" >X</td>
#       <td id="T_a446d_row3_col5" class="data row3 col5" >0.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# Output file : C:\Users\PC1\OneDrive\A4\Data\extremes.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\extremes.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\extremes.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\extremes.csv

# %%
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(god_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(icd_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(osd_file, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2026-03-05 21:00:12
