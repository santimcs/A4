# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine, text
from pandas.tseries.offsets import BDay

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
print(today)
# Out:
# 2026-03-20

# %%
# If run after actual work day
#today = today - timedelta(days=1)
#print(today)

# %%
value = 1432.99

# %%
# Method 1: Using named parameters
sql_statement = text("INSERT INTO setindex VALUES(:date, :value)")
rp = const.execute(sql_statement, {"date": today, "value": value})

# %%
sql = """SELECT * FROM setindex ORDER BY date DESC LIMIT 2"""
df_tmp = pd.read_sql(sql, const)
df_tmp
# Out:
#          date  setindex
# 0  2026-03-20   1432.99
# 1  2026-03-19   1417.45

# %%
print(df_tmp.iloc[0] - df_tmp.iloc[1])
# Out:
# date        1 day, 0:00:00
# setindex             15.54
# dtype: object

# %%
const.commit()
const.close()

# %%
sqlUpd = text("""UPDATE setindex SET setindex = 1528.26 WHERE date = '2026-02-27'""")
print(sqlUpd)
# Out:
# UPDATE setindex SET setindex = 1528.26 WHERE date = '2026-02-27'

# %%
rp = const.execute(sqlUpd)
rp.rowcount
# Out:
# 1

# %%
sqlDel = text("""DELETE FROM setindex WHERE date='2026-01-09' AND setindex = 1253.6""")
print(sqlDel)
# Out:
# DELETE FROM setindex WHERE date='2026-01-09' AND setindex = 1253.6

# %%
rp = const.execute(sqlDel)
rp.rowcount
# Out:
# 1
