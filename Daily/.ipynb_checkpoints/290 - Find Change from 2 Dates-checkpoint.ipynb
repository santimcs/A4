# %% [markdown]
# ### Modify last statement then Run all - statement: 24

# %% [markdown]
# ### Output files: buy-input
# ### Input files: prices-change

# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import * 
import calendar

pd.options.display.max_rows = 31
float_formatter = "฿{:,.2f}"

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-12-30 2025-12-29

# %%
#today = date(2025, 3, 6)
#yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-12-30 2025-12-29

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(2)
yesterday = today - num_business_days
print(f'today: {today}')
to_mmdd = today.strftime('%m-%d')
print(f'Today in mm-dd format: {to_mmdd}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-12-30
# Today in mm-dd format: 12-30
# yesterday: 2025-12-26 00:00:00

# %%
# If run after actual work day
#today = date(2025,2,25)
print(today)
# Out:
# 2025-12-30

# %%
#yesterday = yesterday.date()
#yesterday = date(2025,2,24)
print(yesterday)
# Out:
# 2025-12-26 00:00:00

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Data path (dat_path): {dat_path}") 
print(f"Google Drive path (god_path): {god_path}")
print(f"iCloudDrive path (icd_path): {icd_path}") 
print(f"Obsidian path (osd_path): {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Data path (dat_path): C:\Users\PC1\OneDrive\A5\Data
# Google Drive path (god_path): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path (icd_path): C:\Users\PC1\iCloudDrive\Data
# Obsidian path (osd_path): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}','price':'{:.2f}','price1':'{:.2f}','price2':'{:.2f}',
    'beta':'{:,.2f}','change':'{:.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%','%change':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}','volume':'{:,.0f}','shares':'{:,.0f}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}','amount':'{:,.2f}'
}

# %%
sql = '''
SELECT period, name, volbuy AS shares
FROM buy
ORDER BY period, name'''
buy = pd.read_sql(sql, const)
buy['shares'] = buy['shares'].astype('int64')
buy.style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_98d35">
#   <thead>
#     <tr>
#       <th id="T_98d35_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_98d35_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_98d35_level0_col2" class="col_heading level0 col2" >shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_98d35_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_98d35_row0_col1" class="data row0 col1" >AH</td>
#       <td id="T_98d35_row0_col2" class="data row0 col2" >1,200</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_98d35_row1_col1" class="data row1 col1" >AWC</td>
#       <td id="T_98d35_row1_col2" class="data row1 col2" >9,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_98d35_row2_col1" class="data row2 col1" >JMART</td>
#       <td id="T_98d35_row2_col2" class="data row2 col2" >6,800</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_98d35_row3_col1" class="data row3 col1" >JMT</td>
#       <td id="T_98d35_row3_col2" class="data row3 col2" >7,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_98d35_row4_col1" class="data row4 col1" >TOA</td>
#       <td id="T_98d35_row4_col2" class="data row4 col2" >1,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_98d35_row5_col1" class="data row5 col1" >AIMIRT</td>
#       <td id="T_98d35_row5_col2" class="data row5 col2" >17,500</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_98d35_row6_col1" class="data row6 col1" >CPNREIT</td>
#       <td id="T_98d35_row6_col2" class="data row6 col2" >55,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_98d35_row7_col1" class="data row7 col1" >DIF</td>
#       <td id="T_98d35_row7_col2" class="data row7 col2" >45,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_98d35_row8_col1" class="data row8 col1" >GVREIT</td>
#       <td id="T_98d35_row8_col2" class="data row8 col2" >69,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_98d35_row9_col1" class="data row9 col1" >MCS</td>
#       <td id="T_98d35_row9_col2" class="data row9 col2" >75,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_98d35_row10_col1" class="data row10 col1" >NER</td>
#       <td id="T_98d35_row10_col2" class="data row10 col2" >27,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_98d35_row11_col1" class="data row11 col1" >PTT</td>
#       <td id="T_98d35_row11_col2" class="data row11 col2" >7,500</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_98d35_row12_col1" class="data row12 col1" >SENA</td>
#       <td id="T_98d35_row12_col2" class="data row12 col2" >105,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_98d35_row13_col1" class="data row13 col1" >TFFIF</td>
#       <td id="T_98d35_row13_col2" class="data row13 col2" >20,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_98d35_row14_col1" class="data row14 col1" >WHAIR</td>
#       <td id="T_98d35_row14_col2" class="data row14 col2" >50,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_98d35_row15_col1" class="data row15 col1" >WHART</td>
#       <td id="T_98d35_row15_col2" class="data row15 col2" >20,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_98d35_row16_col1" class="data row16 col1" >3BBIF</td>
#       <td id="T_98d35_row16_col2" class="data row16 col2" >120,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row17_col0" class="data row17 col0" >3</td>
#       <td id="T_98d35_row17_col1" class="data row17 col1" >BCH</td>
#       <td id="T_98d35_row17_col2" class="data row17 col2" >4,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row18_col0" class="data row18 col0" >3</td>
#       <td id="T_98d35_row18_col1" class="data row18 col1" >PTG</td>
#       <td id="T_98d35_row18_col2" class="data row18 col2" >3,600</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row19_col0" class="data row19 col0" >3</td>
#       <td id="T_98d35_row19_col1" class="data row19 col1" >RCL</td>
#       <td id="T_98d35_row19_col2" class="data row19 col2" >27,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row20_col0" class="data row20 col0" >3</td>
#       <td id="T_98d35_row20_col1" class="data row20 col1" >STA</td>
#       <td id="T_98d35_row20_col2" class="data row20 col2" >10,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row21_col0" class="data row21 col0" >3</td>
#       <td id="T_98d35_row21_col1" class="data row21 col1" >SYNEX</td>
#       <td id="T_98d35_row21_col2" class="data row21 col2" >17,500</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row22_col0" class="data row22 col0" >3</td>
#       <td id="T_98d35_row22_col1" class="data row22 col1" >TVO</td>
#       <td id="T_98d35_row22_col2" class="data row22 col2" >4,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row23_col0" class="data row23 col0" >4</td>
#       <td id="T_98d35_row23_col1" class="data row23 col1" >CPF</td>
#       <td id="T_98d35_row23_col2" class="data row23 col2" >10,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row24_col0" class="data row24 col0" >4</td>
#       <td id="T_98d35_row24_col1" class="data row24 col1" >IVL</td>
#       <td id="T_98d35_row24_col2" class="data row24 col2" >7,200</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row25_col0" class="data row25 col0" >4</td>
#       <td id="T_98d35_row25_col1" class="data row25 col1" >ORI</td>
#       <td id="T_98d35_row25_col2" class="data row25 col2" >50,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row26_col0" class="data row26 col0" >4</td>
#       <td id="T_98d35_row26_col1" class="data row26 col1" >PTTGC</td>
#       <td id="T_98d35_row26_col2" class="data row26 col2" >6,000</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row27_col0" class="data row27 col0" >4</td>
#       <td id="T_98d35_row27_col1" class="data row27 col1" >SCC</td>
#       <td id="T_98d35_row27_col2" class="data row27 col2" >600</td>
#     </tr>
#     <tr>
#       <td id="T_98d35_row28_col0" class="data row28 col0" >4</td>
#       <td id="T_98d35_row28_col1" class="data row28 col1" >SINGER</td>
#       <td id="T_98d35_row28_col2" class="data row28 col2" >6,000</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = "buy-input.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"Output file: {output_file}") 
print(f"icd_file (icd_file): {icd_file}") 
print(f"god_file (god_file): {god_file}") 
print(f"osd_file (osd_file): {osd_file}")
# Out:
# Output file: C:\Users\PC1\OneDrive\A5\Data\buy-input.csv
# icd_file (icd_file): C:\Users\PC1\iCloudDrive\Data\buy-input.csv
# god_file (god_file): C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\buy-input.csv
# osd_file (osd_file): C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\buy-input.csv

# %%
buy.to_csv(output_file, index=False)
buy.to_csv(god_file, index=False)
buy.to_csv(icd_file, index=False)
buy.to_csv(osd_file, index=False)

# %% [markdown]
# ### Call ruby ruby\find-change-fm-2-dates.rb

# %%
# Extract the last folder from the base directory
last_folder = os.path.basename(base_path)
print(f"Last Folder: {last_folder}")
# Out:
# Last Folder: A5

# %%
# Change to the derived directory (optional)
os.chdir(base_path)
# %pwd
# Out:
# 'C:\\Users\\PC1\\OneDrive\\A5'

# %%
# !ruby ruby\\find-change-fm-2-dates.rb '2024-12-30' '{today}' '{last_folder}'
# Out:
#     period       name     shares      date1      date2     price1     price2     change    %change     amount        spd
#          1         AH       1200   24-12-30   25-12-30      16.30      12.60      -3.70     -22.70  -4,440.00        -37
#          1        AWC       9000   24-12-30   25-12-30       3.52       2.12      -1.40     -39.77 -12,600.00        -70
#          1      JMART       6800   24-12-30   25-12-30      13.20       6.90      -6.30     -47.73 -42,840.00        -93
#          1        JMT       7000   24-12-30   25-12-30      18.20       8.75      -9.45     -51.92 -66,150.00       -107
#          1        TOA       1000   24-12-30   25-12-30      15.00      13.60      -1.40      -9.33  -1,400.00        -14
#          2     AIMIRT      17500   24-12-30   25-12-30      10.60      10.90       0.30       2.83   5,250.00          3
#          2    CPNREIT      55000   24-12-30   25-12-30      12.30      11.30      -1.00      -8.13 -55,000.00        -10
#          2        DIF      45000   24-12-30   25-12-30       8.60       9.45       0.85       9.88  38,250.00         17
#          2     GVREIT      69000   24-12-30   25-12-30       6.50       6.75       0.25       3.85  17,250.00          5
#          2        MCS      75000   24-12-30   25-12-30       6.70       8.35       1.65      24.63 123,750.00         33
#          2        NER      27000   24-12-30   25-12-30       4.62       4.48      -0.14      -3.03  -3,780.00         -7
#          2        PTT       7500   24-12-30   25-12-30      31.75      32.00       0.25       0.79   1,875.00          1
#          2       SENA     105000   24-12-30   25-12-30       2.22       1.69      -0.53     -23.87 -55,650.00        -42
#          2      TFFIF      20000   24-12-30   25-12-30       6.35       6.25      -0.10      -1.57  -2,000.00         -2
#          2      WHAIR      50000   24-12-30   25-12-30       6.50       6.15      -0.35      -5.38 -17,500.00         -7
#          2      WHART      20000   24-12-30   25-12-30      10.20      10.70       0.50       4.90  10,000.00          5
#          3      3BBIF     120000   24-12-30   25-12-30       5.20       6.30       1.10      21.15 132,000.00         22
#          3        BCH       4000   24-12-30   25-12-30      15.30      10.40      -4.90     -32.03 -19,600.00        -49
#          3        PTG       3600   24-12-30   25-12-30       8.20       7.10      -1.10     -13.41  -3,960.00        -22
#          3        RCL      27000   24-12-30   25-12-30      28.25      27.25      -1.00      -3.54 -27,000.00         -4
#          3        STA      10000   24-12-30   25-12-30      18.10      12.20      -5.90     -32.60 -59,000.00        -59
#          3      SYNEX      17500   24-12-30   25-12-30      15.40       9.95      -5.45     -35.39 -95,375.00        -55
#          3        TVO       4000   24-12-30   25-12-30      23.00      22.40      -0.60      -2.61  -2,400.00         -6
#          4        CPF      10000   24-12-30   25-12-30      22.80      21.80      -1.00      -4.39 -10,000.00        -10
#          4        IVL       7200   24-12-30   25-12-30      24.90      16.10      -8.80     -35.34 -63,360.00        -88
#          4        ORI      50000   24-12-30   25-12-30       3.62       1.79      -1.83     -50.55 -91,500.00       -101
#          4      PTTGC       6000   24-12-30   25-12-30      24.40      21.00      -3.40     -13.93 -20,400.00        -34
#          4        SCC        600   24-12-30   25-12-30     168.00     183.50      15.50       9.23   9,300.00         31
#          4     SINGER       6000   24-12-30   25-12-30       7.90       4.88      -3.02     -38.23 -18,120.00        -64

# %%
os.chdir(current_path)
# %pwd
# Out:
# 'C:\\Users\\PC1\\OneDrive\\A5\\Daily'

# %%
file_name   = 'prices-change.csv'
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\prices-change.csv

# %%
df = pd.read_csv(input_file, sep=',', index_col=None)
df.head().style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4fb1f">
#   <thead>
#     <tr>
#       <th id="T_4fb1f_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_4fb1f_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_4fb1f_level0_col2" class="col_heading level0 col2" >shares</th>
#       <th id="T_4fb1f_level0_col3" class="col_heading level0 col3" >date1</th>
#       <th id="T_4fb1f_level0_col4" class="col_heading level0 col4" >date2</th>
#       <th id="T_4fb1f_level0_col5" class="col_heading level0 col5" >price1</th>
#       <th id="T_4fb1f_level0_col6" class="col_heading level0 col6" >price2</th>
#       <th id="T_4fb1f_level0_col7" class="col_heading level0 col7" >change</th>
#       <th id="T_4fb1f_level0_col8" class="col_heading level0 col8" >%change</th>
#       <th id="T_4fb1f_level0_col9" class="col_heading level0 col9" >amount</th>
#       <th id="T_4fb1f_level0_col10" class="col_heading level0 col10" >spd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4fb1f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4fb1f_row0_col1" class="data row0 col1" >AH</td>
#       <td id="T_4fb1f_row0_col2" class="data row0 col2" >1,200</td>
#       <td id="T_4fb1f_row0_col3" class="data row0 col3" >2024-12-30</td>
#       <td id="T_4fb1f_row0_col4" class="data row0 col4" >2025-12-30</td>
#       <td id="T_4fb1f_row0_col5" class="data row0 col5" >16.30</td>
#       <td id="T_4fb1f_row0_col6" class="data row0 col6" >12.60</td>
#       <td id="T_4fb1f_row0_col7" class="data row0 col7" >-3.70</td>
#       <td id="T_4fb1f_row0_col8" class="data row0 col8" >-22.70%</td>
#       <td id="T_4fb1f_row0_col9" class="data row0 col9" >-4,440.00</td>
#       <td id="T_4fb1f_row0_col10" class="data row0 col10" >-37</td>
#     </tr>
#     <tr>
#       <td id="T_4fb1f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T
row4_col0" class="data row4 col0" >1</td>
#       <td id="T_4fb1f_row4_col1" class="data row4 col1" >TOA</td>
#       <td id="T_4fb1f_row4_col2" class="data row4 col2" >1,000</td>
#       <td id="T_4fb1f_row4_col3" class="data row4 col3" >2024-12-30</td>
#       <td id="T_4fb1f_row4_col4" class="data row4 col4" >2025-12-30</td>
#       <td id="T_4fb1f_row4_col5" class="data row4 col5" >15.00</td>
#       <td id="T_4fb1f_row4_col6" class="data row4 col6" >13.60</td>
#       <td id="T_4fb1f_row4_col7" class="data row4 col7" >-1.40</td>
#       <td id="T_4fb1f_row4_col8" class="data row4 col8" >-9.33%</td>
#       <td id="T_4fb1f_row4_col9" class="data row4 col9" >-1,400.00</td>
#       <td id="T_4fb1f_row4_col10" class="data row4 col10" >-14</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sort_values(['spd'],ascending=True).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4210c">
#   <thead>
#     <tr>
#       <th id="T_4210c_level0_col0" class="col_heading level0 col0" >period</th>
#       <th id="T_4210c_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_4210c_level0_col2" class="col_heading level0 col2" >shares</th>
#       <th id="T_4210c_level0_col3" class="col_heading level0 col3" >date1</th>
#       <th id="T_4210c_level0_col4" class="col_heading level0 col4" >date2</th>
#       <th id="T_4210c_level0_col5" class="col_heading level0 col5" >price1</th>
#       <th id="T_4210c_level0_col6" class="col_heading level0 col6" >price2</th>
#       <th id="T_4210c_level0_col7" class="col_heading level0 col7" >change</th>
#       <th id="T_4210c_level0_col8" class="col_heading level0 col8" >%change</th>
#       <th id="T_4210c_level0_col9" class="col_heading level0 col9" >amount</th>
#       <th id="T_4210c_level0_col10" class="col_heading level0 col10" >spd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4210c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4210c_row0_col1" class="data row0 col1" >JMT</td>
#       <td id="T_4210c_row0_col2" class="data row0 col2" >7,000</td>
#       <td id="T_4210c_row0_col3" class="data row0 col3" >2024-12-30</td>
#       <td id="T_4210c_row0_col4" class="data row0 col4" >2025-12-30</td>
#       <td id="T_4210c_row0_col5" class="data row0 col5" >18.20</td>
#       <td id="T_4210c_row0_col6" class="data row0 col6" >8.75</td>
#       <td id="T_4210c_row0_col7" class="data row0 col7" >-9.45</td>
#       <td id="T_4210c_row0_col8" class="data row0 col8" >-51.92%</td>
#       <td id="T_4210c_row0_col9" class="data row0 col9" >-66,150.00</td>
#       <td id="T_4210c_row0_col10" class="data row0 col10" >-107</td>
#     </tr>
#     <tr>
#       <td id="T_4210c_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_4210c_row1_col1" class="data row1 col1" >ORI</td>
#       <td id="T_4210c_row1_col2" class="data row1 col2" >50,000</td>
#       <td id="T_4210c_row1_col3" class="data row1 col3" >2024-12-30</td>
#       <td id="T_4210c_row1_col4" class="data row1 col4" >2025-12-30</td>
#       <td id="T_4210c_row1_col5" class="data row1 col5" >3.62</td>
#       <td id="T_4210c_row1_col6" class="data row1 col6" >1.79</td>
#       <td id="T_4210c_row1_col7" class="data row1 col7" >-1.83</td>
#       <td id="T_4210c_row1_col8" class="data row1 col8" >-50.55%</td>
#       <td id="T_4210c_row1_col9" class="data row1 col9" >-91,500.00</td>
#       <td id="T_4210c_row1_col10" class="data row1 col10" >-101</td>
#     </tr>
#     <tr>
#       <td id="T_4210c_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_4210c_row2_col1" class="data row2 col1" >JMART</td>
#       <td id="T_4210c_row2_col2" class="data row2 col2" >6,800</td>
#       <td id="T_4210c_row2_col3" class="data row2 col3" >2024-12-30</td>
#       <td id="T_4210c_row2_col4" class="data row2 col4" >2025-12-30</td>
#       <td id="T_4210c_row2_col5" class="data row2 col5" >13.20</td>
#       <td id="T_4210c_row2_col6" class="data row2 col6" >6.90</td>
#       <td id="T_4210c_row2_col7" class="data row2 col7" >-6.30</td>
#       <td id="T_4210c_row2_col8" class="data row2 col8" >-47.73%</td>
#       <td id="T_4210c_row2_col9" class="data row2 col9" >-42,840.00</td>
#       <td id="T_4210c_row2_col10" class="data row2 col10" >-93</td>
#     </tr>
#     <tr>
#       <td id="T_4210c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T
row7_col0" class="data row7 col0" >3</td>
#       <td id="T_4210c_row7_col1" class="data row7 col1" >SYNEX</td>
#       <td id="T_4210c_row7_col2" class="data row7 col2" >17,500</td>
#       <td id="T_4210c_row7_col3" class="data row7 col3" >2024-12-30</td>
#       <td id="T_4210c_row7_col4" class="data row7 col4" >2025-12-30</td>
#       <td id="T_4210c_row7_col5" class="data row7 col5" >15.40</td>
#       <td id="T_4210c_row7_col6" class="data row7 col6" >9.95</td>
#       <td id="T_4210c_row7_col7" class="data row7 col7" >-5.45</td>
#       <td id="T_4210c_row7_col8" class="data row7 col8" >-35.39%</td>
#       <td id="T_4210c_row7_col9" class="data row7 col9" >-95,375.00</td>
#       <td id="T_4210c_row7_col10" class="data row7 col10" >-55</td>
#     </tr>
#     <tr>
#       <td id="T_4210c_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_4210c_row8_col1" class="data row8 col1" >BCH</td>
#       <td id="T_4210c_row8_col2" class="data row8 col2" >4,000</td>
#       <td id="T_4210c_row8_col3" class="data row8 col3" >2024-12-30</td>
#       <td id="T_4210c_row8_col4" class="data row8 col4" >2025-12-30</td>
#       <td id="T_4210c_row8_col5" class="data row8 col5" >15.30</td>
#       <td id="T_4210c_row8_col6" class="data row8 col6" >10.40</td>
#       <td id="T_4210c_row8_col7" class="data row8 col7" >-4.90</td>
#       <td id="T_4210c_row8_col8" class="data row8 col8" >-32.03%</td>
#       <td id="T_4210c_row8_col9" class="data row8 col9" >-19,600.00</td>
#       <td id="T_4210c_row8_col10" class="data row8 col10" >-49</td>
#     </tr>
#     <tr>

# %%
# Group by 'period' and sum only specific columns
result = df.groupby('period')[['shares', 'amount', 'spd']].sum()
print(result)
# Out:
#         shares    amount  spd
# period
# 1        25000 -127430.0 -321
# 2       491000   62445.0   -4
# 3       186100  -75335.0 -173
# 4        79800 -194080.0 -266

# %%
df.groupby('period').agg(
      ttl_shr = pd.NamedAgg('shares', 'sum'),
      avr_p1  = pd.NamedAgg('price1','mean'),
      avr_p2  = pd.NamedAgg('price2','mean'),  
      avr_chg = pd.NamedAgg('change','mean'),
      avr_spd = pd.NamedAgg('spd','mean'),
      ttl_amt = pd.NamedAgg('amount', 'sum')
   )
# Out:
#         ttl_shr     avr_p1     avr_p2   avr_chg    avr_spd   ttl_amt
# period
# 1         25000  13.244000   8.794000 -4.450000 -64.200000 -127430.0
# 2        491000   9.667273   9.820000  0.152727  -0.363636   62445.0
# 3        186100  16.207143  13.657143 -2.550000 -24.714286  -75335.0
# 4         79800  41.936667  41.511667 -0.425000 -44.333333 -194080.0

# %%
pl = df.amount.sum()
float_formatter.format(pl)
# Out:
# '฿-334,400.00'

# %%
prev_pl = -334_400
diff = pl - prev_pl
float_formatter.format(diff)
# Out:
# '฿14,835.00'

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-12-30 20:45:34
